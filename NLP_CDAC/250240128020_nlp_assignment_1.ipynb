# %% [markdown]
# # Question 1
#
# Extract the contents of C-DAC wikipedia page.
#
# Tokenize using NLTK and SpaCy (both word and sentences)
#
# Display word and sentences counts in both cases.

# %%
import urllib3
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/Centre_for_Development_of_Advanced_Computing"

http = urllib3.PoolManager()

response = http.request('GET', url)

soup = BeautifulSoup(response.data, 'html.parser')

text = soup.get_text()

with open('cdac_article.txt', 'w', encoding='utf-8') as f:
    f.write(text)

print("Article saved to cdac_article.txt")
# Out:
# Article saved to cdac_article.txt

# %%
# Tokenize using NLTK
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
with open('cdac_article.txt', encoding='utf-8') as f:
    text = f.read()


tokens_nltk = nltk.word_tokenize(text)

sentences_nltk = nltk.sent_tokenize(text)

print("Number of tokens: ", len(tokens_nltk))
print("Number of sentences: ", len(sentences_nltk))
# Out:
# Number of tokens:  3555
# Number of sentences:  248

# %%
# Tokenize using spaCy

import spacy

nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

nlp.add_pipe('sentencizer')

with open('cdac_article.txt', encoding='utf-8') as f:
    text = f.read()

doc = nlp(text)

tokens_spacy = [token.text for token in doc]

sentences_spacy = [sent.text for sent in doc.sents]

print("Number of tokens: ", len(tokens_spacy))
print("Number of sentences: ", len(sentences_spacy))
# Out:
# Number of tokens:  3840
# Number of sentences:  222

# %% [markdown]
# # Question 2
#
# Use text from https://en.wikipedia.org/wiki/Geoffrey_Hinton
#
# Perform text cleaning. All five steps.
#
# Display final text.
#
# Use both NLTK and spaCy.

# %%
import urllib3
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/Geoffrey_Hinton"

http = urllib3.PoolManager()

response = http.request('GET', url)

soup = BeautifulSoup(response.data, 'html.parser')

text = soup.get_text()

with open('Geoffrey_Hinton_article.txt', 'w', encoding='utf-8') as f:
    f.write(text)

print("Article saved to Geoffrey_Hinton_article.txt")
# Out:
# Article saved to Geoffrey_Hinton_article.txt

# %%
# Cleaning using NLTK

import string
import nltk
nltk.download('punkt')


with open('cdac_article.txt', encoding='utf-8') as f:
    text = f.read()

text= text.replace("\n", " ")

for punct in string.punctuation:

    text = text.replace(punct, " ")

print("Text without Punctuation  : \n")
print(text)
# Out:
# Text without Punctuation  :
#
#     Centre for Development of Advanced Computing   Wikipedia                                    Jump to content        Main menu      Main menu move to sidebar hide    		Navigation 	   Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us      		Contribute 	   HelpLearn to editCommunity portalRecent changesUpload fileSpecial pages                    Search            Search                       Appearance                 Donate  Create account  Log in         Personal tools      Donate Create account Log in      		Pages for logged out editors learn more    ContributionsTalk                             Contents move to sidebar hide      Top       1 History         2 Research activities         3 Centres         4 Education and training         5 Commercialization         6 Products and developments         7 Notable researchers and alumnus         8 Notable awards and accolades         9 Other projects         10 See also         11 References                   Toggle the table of contents        Centre for Development of Advanced Computing    6 languages     हिन्दीമലയാളംमराठीРусскийதமிழ்Українська  Edit links            ArticleTalk      English                  ReadEditView history        Tools      Tools move to sidebar hide    		Actions 	   ReadEditView history      		General 	   What links hereRelated changesUpload filePermanent linkPage informationCite this pageGet shortened URLDownload QR code      		Print export 	   Download as PDFPrintable version      		In other projects 	   Wikidata item                      Appearance move to sidebar hide          Coordinates  18°33′06″N 73°49′26″E﻿   ﻿18 551747°N 73 823750°E﻿   18 551747  73 823750  From Wikipedia  the free encyclopedia   Autonomous scientific society  18°33′06″N 73°49′26″E﻿   ﻿18 551747°N 73 823750°E﻿   18 551747  73 823750  Centre for Development of Advanced ComputingMottoज्ञानादेव तु कैवल्यम्  Sanskrit Only through knowledge one attains liberation  English translated Established1988  37 years ago  1988 Field of researchHigh Performance Computing  Multi lingual Computing and Heritage Computing  Professional Electronics  Software Technologies  Cyber Security  Blockchain  Data Science  Health InformaticsDirectorMagesh Ethirajan 1   Director General AddressC DAC Innovation Park  Panchavati  Pashan Pune   411 008  Maharashtra  IndiaLocationPune  India  headquarters NicknameC DACOperating agencyMinistry of Electronics and Information Technology  Government of IndiaWebsitewww cdac in The Centre for Development of Advanced Computing  C DAC  is an Indian autonomous scientific society  operating under the Ministry of Electronics and Information Technology  2    History edit  Further information  Supercomputing in India and PARAM C DAC was created in November 1987  3  initially as the Centre for Development of Advanced Computing Technology  C DACT   4  3  In 1988  the US Government refused to sell India a Cray supercomputer due to concerns about India using it to develop nuclear weapons  5  In response India started development of its own supercomputer  and C DACT was created as part of this programme  6  7  Dr Vijay Bhatkar was hired as the director of C DACT  7  The project was given an initial run of three years and an initial funding of ₹30 00 00 000  the cost of a Cray supercomputer  7  A prototype computer was benchmarked at the 1990 Zurich Super computing Show  It demonstrated that India had the second most powerful  publicly demonstrated  supercomputer in the world after the United States  7  8  The final result of the effort was the PARAM 8000  released in 1991  9  The National Centre for Software Technology  NCST   Electronic Research and Development Centre  ER DC  and CEDTI were merged into C DAC in 2003  10  11   Research activities edit  Originally established to research and assemble High Performance Computers  the research of C DAC now includes    High Performance Computing Grid Computing Cloud Computing Multilingual and Heritage Computing V ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
text = text.lower()

print("Text in Lower Case : \n")
print(text)
# Out:
# Text in Lower Case :
#
#     centre for development of advanced computing   wikipedia                                    jump to content        main menu      main menu move to sidebar hide    		navigation 	   main pagecontentscurrent eventsrandom articleabout wikipediacontact us      		contribute 	   helplearn to editcommunity portalrecent changesupload filespecial pages                    search            search                       appearance                 donate  create account  log in         personal tools      donate create account log in      		pages for logged out editors learn more    contributionstalk                             contents move to sidebar hide      top       1 history         2 research activities         3 centres         4 education and training         5 commercialization         6 products and developments         7 notable researchers and alumnus         8 notable awards and accolades         9 other projects         10 see also         11 references                   toggle the table of contents        centre for development of advanced computing    6 languages     हिन्दीമലയാളംमराठीрусскийதமிழ்українська  edit links            articletalk      english                  readeditview history        tools      tools move to sidebar hide    		actions 	   readeditview history      		general 	   what links hererelated changesupload filepermanent linkpage informationcite this pageget shortened urldownload qr code      		print export 	   download as pdfprintable version      		in other projects 	   wikidata item                      appearance move to sidebar hide          coordinates  18°33′06″n 73°49′26″e﻿   ﻿18 551747°n 73 823750°e﻿   18 551747  73 823750  from wikipedia  the free encyclopedia   autonomous scientific society  18°33′06″n 73°49′26″e﻿   ﻿18 551747°n 73 823750°e﻿   18 551747  73 823750  centre for development of advanced computingmottoज्ञानादेव तु कैवल्यम्  sanskrit only through knowledge one attains liberation  english translated established1988  37 years ago  1988 field of researchhigh performance computing  multi lingual computing and heritage computing  professional electronics  software technologies  cyber security  blockchain  data science  health informaticsdirectormagesh ethirajan 1   director general addressc dac innovation park  panchavati  pashan pune   411 008  maharashtra  indialocationpune  india  headquarters nicknamec dacoperating agencyministry of electronics and information technology  government of indiawebsitewww cdac in the centre for development of advanced computing  c dac  is an indian autonomous scientific society  operating under the ministry of electronics and information technology  2    history edit  further information  supercomputing in india and param c dac was created in november 1987  3  initially as the centre for development of advanced computing technology  c dact   4  3  in 1988  the us government refused to sell india a cray supercomputer due to concerns about india using it to develop nuclear weapons  5  in response india started development of its own supercomputer  and c dact was created as part of this programme  6  7  dr vijay bhatkar was hired as the director of c dact  7  the project was given an initial run of three years and an initial funding of ₹30 00 00 000  the cost of a cray supercomputer  7  a prototype computer was benchmarked at the 1990 zurich super computing show  it demonstrated that india had the second most powerful  publicly demonstrated  supercomputer in the world after the united states  7  8  the final result of the effort was the param 8000  released in 1991  9  the national centre for software technology  ncst   electronic research and development centre  er dc  and cedti were merged into c dac in 2003  10  11   research activities edit  originally established to research and assemble high performance computers  the research of c dac now includes    high performance computing grid computing cloud computing multilingual and heritage computing v ...

# %%
tokenized_text = word_tokenize(text)

print("Tokenized Text : \n")
print(tokenized_text)
# Out:
# Tokenized Text :
#
# ['centre', 'for', 'development', 'of', 'advanced', 'computing', 'wikipedia', 'jump', 'to', 'content', 'main', 'menu', 'main', 'menu', 'move', 'to', 'sidebar', 'hide', 'navigation', 'main', 'pagecontentscurrent', 'eventsrandom', 'articleabout', 'wikipediacontact', 'us', 'contribute', 'helplearn', 'to', 'editcommunity', 'portalrecent', 'changesupload', 'filespecial', 'pages', 'search', 'search', 'appearance', 'donate', 'create', 'account', 'log', 'in', 'personal', 'tools', 'donate', 'create', 'account', 'log', 'in', 'pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'contributionstalk', 'contents', 'move', 'to', 'sidebar', 'hide', 'top', '1', 'history', '2', 'research', 'activities', '3', 'centres', '4', 'education', 'and', 'training', '5', 'commercialization', '6', 'products', 'and', 'developments', '7', 'notable', 'researchers', 'and', 'alumnus', '8', 'notable', 'awards', 'and', 'accolades', '9', 'other', 'projects', '10', 'see', 'also', '11', 'references', 'toggle', 'the', 'table', 'of', 'contents', 'centre', 'for', 'development', 'of', 'advanced', 'computing', '6', 'languages', 'हिन्दीമലയാളംमराठीрусскийதமிழ்українська', 'edit', 'links', 'articletalk', 'english', 'readeditview', 'history', 'tools', 'tools', 'move', 'to', 'sidebar', 'hide', 'actions', 'readeditview', 'history', 'general', 'what', 'links', 'hererelated', 'changesupload', 'filepermanent', 'linkpage', 'informationcite', 'this', 'pageget', 'shortened', 'urldownload', 'qr', 'code', 'print', 'export', 'download', 'as', 'pdfprintable', 'version', 'in', 'other', 'projects', 'wikidata', 'item', 'appearance', 'move', 'to', 'sidebar', 'hide', 'coordinates', '18°33′06″n', '73°49′26″e\ufeff', '\ufeff18', '551747°n', '73', '823750°e\ufeff', '18', '551747', '73', '823750', 'from', 'wikipedia', 'the', 'free', 'encyclopedia', 'autonomous', 'scientific', 'society', '18°33′06″n', '73°49′26″e\ufeff', '\ufeff18', '551747°n', '73', '823750°e\ufeff', '18', '551747', '73', '823750', 'centre', 'for', 'development', 'of', 'advanced', 'computingmottoज्ञानादेव', 'तु', 'कैवल्यम्', 'sanskrit', 'only', 'through', 'knowledge', 'one', 'attains', 'liberation', 'english', 'translated', 'established1988', '37', 'years', 'ago', '1988', 'field', 'of', 'researchhigh', 'performance', 'computing', 'multi', 'lingual', 'computing', 'and', 'heritage', 'computing', 'professional', 'electronics', 'software', 'technologies', 'cyber', 'security', 'blockchain', 'data', 'science', 'health', 'informaticsdirectormagesh', 'ethirajan', '1', 'director', 'general', 'addressc', 'dac', 'innovation', 'park', 'panchavati', 'pashan', 'pune', '411', '008', 'maharashtra', 'indialocationpune', 'india', 'headquarters', 'nicknamec', 'dacoperating', 'agencyministry', 'of', 'electronics', 'and', 'information', 'technology', 'government', 'of', 'indiawebsitewww', 'cdac', 'in', 'the', 'centre', 'for', 'development', 'of', 'advanced', 'computing', 'c', 'dac', 'is', 'an', 'indian', 'autonomous', 'scientific', 'society', 'operating', 'under', 'the', 'ministry', 'of', 'electronics', 'and', 'information', 'technology', '2', 'history', 'edit', 'further', 'information', 'supercomputing', 'in', 'india', 'and', 'param', 'c', 'dac', 'was', 'created', 'in', 'november', '1987', '3', 'initially', 'as', 'the', 'centre', 'for', 'development', 'of', 'advanced', 'computing', 'technology', 'c', 'dact', '4', '3', 'in', '1988', 'the', 'us', 'government', 'refused', 'to', 'sell', 'india', 'a', 'cray', 'supercomputer', 'due', 'to', 'concerns', 'about', 'india', 'using', 'it', 'to', 'develop', 'nuclear', 'weapons', '5', 'in', 'response', 'india', 'started', 'development', 'of', 'its', 'own', 'supercomputer', 'and', 'c', 'dact', 'was', 'created', 'as', 'part', 'of', 'this', 'programme', '6', '7', 'dr', 'vijay', 'bhatkar', 'was', 'hired', 'as', 'the', 'director', 'of', 'c', 'dact', '7', 'the', 'project', 'was', 'given', 'an', 'initial', 'run', 'of', 'three', 'years', 'and', 'an', 'initial', 'funding', 'of', '₹30', '00', '00', '000', 'the', 'co ...

# %%
print("\nFirst 10 tokens : \n")

print(tokenized_text[:10])
# Out:
# First 10 tokens :
#
# ['centre', 'for', 'development', 'of', 'advanced', 'computing', 'wikipedia', 'jump', 'to', 'content']

# %%
from pprint import pprint

from nltk.probability import FreqDist

fdist = FreqDist(tokenized_text)

top_20_tokens = fdist.most_common(20)

pprint(top_20_tokens)
# Out:
# [('the', 92),
#  ('of', 85),
#  ('and', 57),
#  ('c', 52),
#  ('in', 49),
#  ('dac', 47),
#  ('india', 44),
#  ('for', 36),
#  ('a', 30),
#  ('retrieved', 28),
#  ('computing', 27),
#  ('to', 26),
#  ('on', 22),
#  ('centre', 20),
#  ('from', 20),
#  ('september', 18),
#  ('s', 17),
#  ('development', 16),
#  ('technology', 14),
#  ('e', 14)]

# %%
# Cleaning using spaCy

import spacy
import re

nlp = spacy.load("en_core_web_sm")

with open('Geoffrey_Hinton_article.txt', encoding='utf-8') as f:
    text = f.read()

text = text.replace("\n", " ")

text = re.sub(r'[!"#$%&\'()*+,-./:;<=>?@[\]^_`{|}~]', ' ', text)

text = text.lower()

doc = nlp(text)

tokenized_text = [token.text for token in doc if not token.is_stop and token.text.strip()]

print("Processed Tokens:", tokenized_text)
# Out:
# Processed Tokens: ['geoffrey', 'hinton', 'wikipedia', 'jump', 'content', 'main', 'menu', 'main', 'menu', 'sidebar', 'hide', 'navigation', 'main', 'pagecontentscurrent', 'eventsrandom', 'articleabout', 'wikipediacontact', 'contribute', 'helplearn', 'editcommunity', 'portalrecent', 'changesupload', 'filespecial', 'pages', 'search', 'search', 'appearance', 'donate', 'create', 'account', 'log', 'personal', 'tools', 'donate', 'create', 'account', 'log', 'pages', 'logged', 'editors', 'learn', 'contributionstalk', 'contents', 'sidebar', 'hide', '1', 'education', '2', 'career', 'research', 'toggle', 'career', 'research', 'subsection', '2', '1', 'honours', 'awards', '3', 'views', 'toggle', 'views', 'subsection', '3', '1', 'risks', 'artificial', 'intelligence', '3', '1', '1', 'existential', 'risk', 'agi', '3', '1', '2', 'catastrophic', 'misuse', '3', '1', '3', 'economic', 'impacts', '3', '2', 'politics', '4', 'personal', 'life', '5', 'references', '6', 'reading', 'toggle', 'table', 'contents', 'geoffrey', 'hinton', '54', 'languages', 'afrikaansالعربيةঅসমীয়াazərbaycancaتۆرکجهবাংলাбеларускаяcatalàčeštinadanskdeutschespañolesperantoeuskaraفارسیfrançaisgaeilgegalego한국어հայերենbahasa', 'indonesiaitalianoעבריתಕನ್ನಡქართულიकॉशुर', 'کٲشُرlatinalietuviųمصرىnederlands日本語norsk', 'bokmåloccitanplattdüütschpolskiportuguêsromânăрусскийसंस्कृतम्سرائیکیshqipsimple', 'englishslovenčinaکوردیсрпски', 'srpskisuomisvenskaதமிழ்ไทยtürkçeукраїнськаاردوئۇيغۇرچە', 'uyghurche中文', 'edit', 'links', 'articletalk', 'english', 'readeditview', 'history', 'tools', 'tools', 'sidebar', 'hide', 'actions', 'readeditview', 'history', 'general', 'links', 'hererelated', 'changesupload', 'filepermanent', 'linkpage', 'informationcite', 'pageget', 'shortened', 'urldownload', 'qr', 'code', 'print', 'export', 'download', 'pdfprintable', 'version', 'projects', 'wikimedia', 'commonswikiquotewikidata', 'item', 'appearance', 'sidebar', 'hide', 'wikipedia', 'free', 'encyclopedia', 'british', 'canadian', 'computer', 'scientist', 'born', '1947', 'geoffrey', 'hintoncc', 'frs', 'frschinton', 'speaking', 'nobel', 'prize', 'lectures', 'stockholm', '2024borngeoffrey', 'everest', 'hinton', '1947', '12', '06', '6', 'december', '1947', 'age', '77', 'wimbledon', 'englandalma', 'mater', 'king', 's', 'college', 'cambridge', 'university', 'edinburgh', 'known', 'applications', 'backpropagation', 'boltzmann', 'machine', 'deep', 'learning', 'capsule', 'neural', 'networks', 'spousesjoanne', 'citation', 'needed', 'rosalind', 'zalin', '\u200b', 'died', '1994', '\u200b', 'jacqueline', 'ford', '\u200b', '\u200b', 'm', '1997', 'died', '2018', '\u200bfatherh', 'e', 'hintonrelativescolin', 'clark', 'uncle', 'george', 'boole', 'great', 'great', 'grandfather', 'awards', 'rumelhart', 'prize', '2001', 'turing', 'award', '2018', 'dickson', 'prize', '2021', 'princess', 'asturias', 'award', '2022', 'nobel', 'prize', 'physics', '2024', 'vinfuture', 'prize', '2024', 'queen', 'elizabeth', 'prize', 'engineering', '2025', 'scientific', 'careerfields', 'machine', 'learning', 'psychology', 'artificial', 'intelligence', 'cognitive', 'science', 'computer', 'science', '1', 'institutions', 'university', 'toronto', 'google', 'carnegie', 'mellon', 'university', 'university', 'college', 'london', 'university', 'california', 'san', 'diego', 'thesisrelaxation', 'role', 'vision', '1977', 'doctoral', 'advisorchristopher', 'longuet', 'higginsdoctoral', 'students', 'richard', 'zemel', '2', 'brendan', 'frey', '3', 'radford', 'm', 'neal', '4', 'yee', 'whye', 'teh', '5', 'ruslan', 'salakhutdinov', '6', 'ilya', 'sutskever', '7', 'alex', 'krizhevsky', '8', 'notable', 'students', 'yann', 'lecun', 'peter', 'dayan', 'max', 'welling', 'zoubin', 'ghahramani', 'alex', 'graves', 'websitewww', 'cs', 'toronto', 'edu', 'hinton', 'geoffrey', 'everest', 'hinton', 'born', '1947', 'british', 'canadian', 'computer', 'scientist', 'cognitive', 'scientist', 'cognitive', 'psychologist', 'known', 'work', 'artificial', 'neural', 'networks', 'earned', 'title', 'god ...

# %%
word_freq = {}
for token in tokenized_text:
    word_freq[token] = word_freq.get(token, 0) + 1


print("\nWord Frequencies:", word_freq)
# Out:
# Word Frequencies: {'geoffrey': 70, 'hinton': 130, 'wikipedia': 6, 'jump': 1, 'content': 1, 'main': 3, 'menu': 2, 'sidebar': 4, 'hide': 4, 'navigation': 1, 'pagecontentscurrent': 1, 'eventsrandom': 1, 'articleabout': 1, 'wikipediacontact': 1, 'contribute': 1, 'helplearn': 1, 'editcommunity': 1, 'portalrecent': 1, 'changesupload': 2, 'filespecial': 1, 'pages': 4, 'search': 4, 'appearance': 2, 'donate': 2, 'create': 3, 'account': 2, 'log': 2, 'personal': 3, 'tools': 3, 'logged': 1, 'editors': 1, 'learn': 7, 'contributionstalk': 1, 'contents': 3, '1': 26, 'education': 3, '2': 20, 'career': 3, 'research': 27, 'toggle': 4, 'subsection': 2, 'honours': 3, 'awards': 7, '3': 19, 'views': 3, 'risks': 6, 'artificial': 30, 'intelligence': 28, 'existential': 3, 'risk': 4, 'agi': 5, 'catastrophic': 2, 'misuse': 4, 'economic': 5, 'impacts': 4, 'politics': 3, '4': 7, 'life': 7, '5': 9, 'references': 2, '6': 10, 'reading': 2, 'table': 2, '54': 3, 'languages': 2, 'afrikaansالعربيةঅসমীয়াazərbaycancaتۆرکجهবাংলাбеларускаяcatalàčeštinadanskdeutschespañolesperantoeuskaraفارسیfrançaisgaeilgegalego한국어հայերենbahasa': 1, 'indonesiaitalianoעבריתಕನ್ನಡქართულიकॉशुर': 1, 'کٲشُرlatinalietuviųمصرىnederlands日本語norsk': 1, 'bokmåloccitanplattdüütschpolskiportuguêsromânăрусскийसंस्कृतम्سرائیکیshqipsimple': 1, 'englishslovenčinaکوردیсрпски': 1, 'srpskisuomisvenskaதமிழ்ไทยtürkçeукраїнськаاردوئۇيغۇرچە': 1, 'uyghurche中文': 1, 'edit': 13, 'links': 3, 'articletalk': 1, 'english': 2, 'readeditview': 2, 'history': 3, 'actions': 1, 'general': 8, 'hererelated': 1, 'filepermanent': 1, 'linkpage': 1, 'informationcite': 1, 'pageget': 1, 'shortened': 1, 'urldownload': 1, 'qr': 1, 'code': 2, 'print': 1, 'export': 1, 'download': 1, 'pdfprintable': 1, 'version': 1, 'projects': 1, 'wikimedia': 2, 'commonswikiquotewikidata': 1, 'item': 1, 'free': 3, 'encyclopedia': 1, 'british': 6, 'canadian': 5, 'computer': 12, 'scientist': 4, 'born': 4, '1947': 6, 'hintoncc': 1, 'frs': 3, 'frschinton': 1, 'speaking': 1, 'nobel': 21, 'prize': 35, 'lectures': 1, 'stockholm': 1, '2024borngeoffrey': 1, 'everest': 8, '12': 8, '06': 1, 'december': 21, 'age': 2, '77': 2, 'wimbledon': 3, 'englandalma': 1, 'mater': 1, 'king': 3, 's': 46, 'college': 6, 'cambridge': 3, 'university': 46, 'edinburgh': 7, 'known': 3, 'applications': 1, 'backpropagation': 8, 'boltzmann': 5, 'machine': 10, 'deep': 16, 'learning': 34, 'capsule': 2, 'neural': 29, 'networks': 25, 'spousesjoanne': 1, 'citation': 2, 'needed': 4, 'rosalind': 2, 'zalin': 2, '\u200b': 4, 'died': 4, '1994': 6, 'jacqueline': 2, 'ford': 3, 'm': 20, '1997': 4, '2018': 32, '\u200bfatherh': 1, 'e': 34, 'hintonrelativescolin': 1, 'clark': 2, 'uncle': 1, 'george': 6, 'boole': 4, 'great': 7, 'grandfather': 2, 'rumelhart': 7, '2001': 7, 'turing': 14, 'award': 28, 'dickson': 3, '2021': 15, 'princess': 6, 'asturias': 7, '2022': 15, 'physics': 9, '2024': 56, 'vinfuture': 3, 'queen': 3, 'elizabeth': 3, 'engineering': 11, '2025': 12, 'scientific': 11, 'careerfields': 1, 'psychology': 3, 'cognitive': 7, 'science': 15, 'institutions': 1, 'toronto': 27, 'google': 25, 'carnegie': 6, 'mellon': 7, 'london': 5, 'california': 4, 'san': 3, 'diego': 3, 'thesisrelaxation': 1, 'role': 2, 'vision': 4, '1977': 5, 'doctoral': 1, 'advisorchristopher': 1, 'longuet': 2, 'higginsdoctoral': 1, 'students': 5, 'richard': 13, 'zemel': 3, 'brendan': 3, 'frey': 3, 'radford': 3, 'neal': 3, 'yee': 3, 'whye': 3, 'teh': 3, 'ruslan': 3, 'salakhutdinov': 4, 'ilya': 8, 'sutskever': 8, '7': 9, 'alex': 8, 'krizhevsky': 4, '8': 16, 'notable': 2, 'yann': 15, 'lecun': 17, 'peter': 9, 'dayan': 2, 'max': 2, 'welling': 2, 'zoubin': 2, 'ghahramani': 2, 'graves': 2, 'websitewww': 1, 'cs': 3, 'edu': 2, 'psychologist': 1, 'work': 12, 'earned': 1, 'title': 2, 'godfather': 22, 'ai': 65, '9': 14, 'professor': 5, 'emeritus': 2, '2013': 12, '2023': 59, 'divided': 1, 'time': 5, 'working': 1, 'brain': 4, 'publicly': 2, 'announcing': 1, 'departure': 1, 'citing': 1, 'concerns': 6, 'technology': 6, '10': 12, '11': 8, '2017 ...

# %% [markdown]
# # Question 3
#
# For the same url, perform:
#
# Stemming using Porter stemmer, Snowball stemmer.
#
# Lemmatization using both NLTK and spaCy.
#
# Display the results.

# %%
import nltk
from nltk.stem import PorterStemmer
nltk.download('punkt')

porter_stemmer = PorterStemmer()

with open('cdac_article.txt', encoding='utf-8') as f:
    text = f.read()

text = word_tokenize(text)

for word in text:

    print(f"Original : {word} --------> Stemmed : {porter_stemmer.stem(word)}")
# Out:
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : - --------> Stemmed : -
# Original : Wikipedia --------> Stemmed : wikipedia
# Original : Jump --------> Stemmed : jump
# Original : to --------> Stemmed : to
# Original : content --------> Stemmed : content
# Original : Main --------> Stemmed : main
# Original : menu --------> Stemmed : menu
# Original : Main --------> Stemmed : main
# Original : menu --------> Stemmed : menu
# Original : move --------> Stemmed : move
# Original : to --------> Stemmed : to
# Original : sidebar --------> Stemmed : sidebar
# Original : hide --------> Stemmed : hide
# Original : Navigation --------> Stemmed : navig
# Original : Main --------> Stemmed : main
# Original : pageContentsCurrent --------> Stemmed : pagecontentscurr
# Original : eventsRandom --------> Stemmed : eventsrandom
# Original : articleAbout --------> Stemmed : articleabout
# Original : WikipediaContact --------> Stemmed : wikipediacontact
# Original : us --------> Stemmed : us
# Original : Contribute --------> Stemmed : contribut
# Original : HelpLearn --------> Stemmed : helplearn
# Original : to --------> Stemmed : to
# Original : editCommunity --------> Stemmed : editcommun
# Original : portalRecent --------> Stemmed : portalrec
# Original : changesUpload --------> Stemmed : changesupload
# Original : fileSpecial --------> Stemmed : filespeci
# Original : pages --------> Stemmed : page
# Original : Search --------> Stemmed : search
# Original : Search --------> Stemmed : search
# Original : Appearance --------> Stemmed : appear
# Original : Donate --------> Stemmed : donat
# Original : Create --------> Stemmed : creat
# Original : account --------> Stemmed : account
# Original : Log --------> Stemmed : log
# Original : in --------> Stemmed : in
# Original : Personal --------> Stemmed : person
# Original : tools --------> Stemmed : tool
# Original : Donate --------> Stemmed : donat
# Original : Create --------> Stemmed : creat
# Original : account --------> Stemmed : account
# Original : Log --------> Stemmed : log
# Original : in --------> Stemmed : in
# Original : Pages --------> Stemmed : page
# Original : for --------> Stemmed : for
# Original : logged --------> Stemmed : log
# Original : out --------> Stemmed : out
# Original : editors --------> Stemmed : editor
# Original : learn --------> Stemmed : learn
# Original : more --------> Stemmed : more
# Original : ContributionsTalk --------> Stemmed : contributionstalk
# Original : Contents --------> Stemmed : content
# Original : move --------> Stemmed : move
# Original : to --------> Stemmed : to
# Original : sidebar --------> Stemmed : sidebar
# Original : hide --------> Stemmed : hide
# Original : ( --------> Stemmed : (
# Original : Top --------> Stemmed : top
# Original : ) --------> Stemmed : )
# Original : 1 --------> Stemmed : 1
# Original : History --------> Stemmed : histori
# Original : 2 --------> Stemmed : 2
# Original : Research --------> Stemmed : research
# Original : activities --------> Stemmed : activ
# Original : 3 --------> Stemmed : 3
# Original : Centres --------> Stemmed : centr
# Original : 4 --------> Stemmed : 4
# Original : Education --------> Stemmed : educ
# Original : and --------> Stemmed : and
# Original : training --------> Stemmed : train
# Original : 5 --------> Stemmed : 5
# Original : Commercialization --------> Stemmed : commerci
# Original : 6 --------> Stemmed : 6
# Original : Products --------> Stemmed : product
# Original : and --------> Stemmed : and
# Original : developments --------> Stemmed : develop
# Original : 7 --------> Stemmed : 7
# Original : Notable --------> Stemmed : notabl
# Original : researchers --------> Stemmed : research
# Original : and --------> Stemmed : and
# Original : alumnus --------> Stemmed : alumnu
# Original : 8 --------> Stemmed : 8
# Original : Notable --------> Stemmed : notabl
# Original : awards --------> Stemmed : award
# Original : and --------> Stemmed : and
# Original : accolades --------> Stemmed : accolad
# Original : 9 --------> Stemmed : 9
# Original : Other --------> Stemmed : other
# Original : projects --------> Stemmed : project
# Original : 10 --------> Stemmed : 10
# Original : See --------> Stemmed : see
# Original : also --------> Stemmed : also
# Original : 11 --------> Stemmed : 11
# Original : References --------> Stemmed : refer
# Original : Toggle --------> Stemmed : toggl
# Original : the --------> Stemmed : the
# Original : table --------> Stemmed : tabl
# Original : of --------> Stemmed : of
# Original : contents --------> Stemmed : content
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : 6 --------> Stemmed : 6
# Original : languages --------> Stemmed : languag
# Original : हिन्दीമലയാളംमराठीРусскийதமிழ்Українська --------> Stemmed : हिन्दीമലയാളംमराठीрусскийதமிழ்українська
# Original : Edit --------> Stemmed : edit
# Original : links --------> Stemmed : link
# Original : ArticleTalk --------> Stemmed : articletalk
# Original : English --------> Stemmed : english
# Original : ReadEditView --------> Stemmed : readeditview
# Original : history --------> Stemmed : histori
# Original : Tools --------> Stemmed : tool
# Original : Tools --------> Stemmed : tool
# Original : move --------> Stemmed : move
# Original : to --------> Stemmed : to
# Original : sidebar --------> Stemmed : sidebar
# Original : hide --------> Stemmed : hide
# Original : Actions --------> Stemmed : action
# Original : ReadEditView --------> Stemmed : readeditview
# Original : history --------> Stemmed : histori
# Original : General --------> Stemmed : gener
# Original : What --------> Stemmed : what
# Original : links --------> Stemmed : link
# Original : hereRelated --------> Stemmed : hererel
# Original : changesUpload --------> Stemmed : changesupload
# Original : filePermanent --------> Stemmed : fileperman
# Original : linkPage --------> Stemmed : linkpag
# Original : informationCite --------> Stemmed : informationcit
# Original : this --------> Stemmed : thi
# Original : pageGet --------> Stemmed : pageget
# Original : shortened --------> Stemmed : shorten
# Original : URLDownload --------> Stemmed : urldownload
# Original : QR --------> Stemmed : qr
# Original : code --------> Stemmed : code
# Original : Print/export --------> Stemmed : print/export
# Original : Download --------> Stemmed : download
# Original : as --------> Stemmed : as
# Original : PDFPrintable --------> Stemmed : pdfprintabl
# Original : version --------> Stemmed : version
# Original : In --------> Stemmed : in
# Original : other --------> Stemmed : other
# Original : projects --------> Stemmed : project
# Original : Wikidata --------> Stemmed : wikidata
# Original : item --------> Stemmed : item
# Original : Appearance --------> Stemmed : appear
# Original : move --------> Stemmed : move
# Original : to --------> Stemmed : to
# Original : sidebar --------> Stemmed : sidebar
# Original : hide --------> Stemmed : hide
# Original : Coordinates --------> Stemmed : coordin
# Original : : --------> Stemmed : :
# Original : 18°33′06″N --------> Stemmed : 18°33′06″n
# Original : 73°49′26″E﻿ --------> Stemmed : 73°49′26″e﻿
# Original : / --------> Stemmed : /
# Original : ﻿18.551747°N --------> Stemmed : ﻿18.551747°n
# Original : 73.823750°E﻿ --------> Stemmed : 73.823750°e﻿
# Original : / --------> Stemmed : /
# Original : 18.551747 --------> Stemmed : 18.551747
# Original : ; --------> Stemmed : ;
# Original : 73.823750 --------> Stemmed : 73.823750
# Original : From --------> Stemmed : from
# Original : Wikipedia --------> Stemmed : wikipedia
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : free --------> Stemmed : free
# Original : encyclopedia --------> Stemmed : encyclopedia
# Original : Autonomous --------> Stemmed : autonom
# Original : scientific --------> Stemmed : scientif
# Original : society --------> Stemmed : societi
# Original : 18°33′06″N --------> Stemmed : 18°33′06″n
# Original : 73°49′26″E﻿ --------> Stemmed : 73°49′26″e﻿
# Original : / --------> Stemmed : /
# Original : ﻿18.551747°N --------> Stemmed : ﻿18.551747°n
# Original : 73.823750°E﻿ --------> Stemmed : 73.823750°e﻿
# Original : / --------> Stemmed : /
# Original : 18.551747 --------> Stemmed : 18.551747
# Original : ; --------> Stemmed : ;
# Original : 73.823750 --------> Stemmed : 73.823750
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : ComputingMottoज्ञानादेव --------> Stemmed : computingmottoज्ञानादेव
# Original : तु --------> Stemmed : तु
# Original : कैवल्यम् --------> Stemmed : कैवल्यम्
# Original : ( --------> Stemmed : (
# Original : Sanskrit --------> Stemmed : sanskrit
# Original : ) --------> Stemmed : )
# Original : Only --------> Stemmed : onli
# Original : through --------> Stemmed : through
# Original : knowledge --------> Stemmed : knowledg
# Original : one --------> Stemmed : one
# Original : attains --------> Stemmed : attain
# Original : liberation --------> Stemmed : liber
# Original : ( --------> Stemmed : (
# Original : English --------> Stemmed : english
# Original : translated --------> Stemmed : translat
# Original : ) --------> Stemmed : )
# Original : Established1988 --------> Stemmed : established1988
# Original : ; --------> Stemmed : ;
# Original : 37 --------> Stemmed : 37
# Original : years --------> Stemmed : year
# Original : ago --------> Stemmed : ago
# Original : ( --------> Stemmed : (
# Original : 1988 --------> Stemmed : 1988
# Original : ) --------> Stemmed : )
# Original : Field --------> Stemmed : field
# Original : of --------> Stemmed : of
# Original : researchHigh --------> Stemmed : researchhigh
# Original : Performance --------> Stemmed : perform
# Original : Computing --------> Stemmed : comput
# Original : , --------> Stemmed : ,
# Original : Multi-lingual --------> Stemmed : multi-lingu
# Original : Computing --------> Stemmed : comput
# Original : and --------> Stemmed : and
# Original : Heritage --------> Stemmed : heritag
# Original : Computing --------> Stemmed : comput
# Original : , --------> Stemmed : ,
# Original : Professional --------> Stemmed : profession
# Original : Electronics --------> Stemmed : electron
# Original : , --------> Stemmed : ,
# Original : Software --------> Stemmed : softwar
# Original : Technologies --------> Stemmed : technolog
# Original : , --------> Stemmed : ,
# Original : Cyber --------> Stemmed : cyber
# Original : Security --------> Stemmed : secur
# Original : , --------> Stemmed : ,
# Original : Blockchain --------> Stemmed : blockchain
# Original : , --------> Stemmed : ,
# Original : Data --------> Stemmed : data
# Original : Science --------> Stemmed : scienc
# Original : , --------> Stemmed : ,
# Original : Health --------> Stemmed : health
# Original : InformaticsDirectorMagesh --------> Stemmed : informaticsdirectormagesh
# Original : Ethirajan --------> Stemmed : ethirajan
# Original : [ --------> Stemmed : [
# Original : 1 --------> Stemmed : 1
# Original : ] --------> Stemmed : ]
# Original : ( --------> Stemmed : (
# Original : Director --------> Stemmed : director
# Original : General --------> Stemmed : gener
# Original : ) --------> Stemmed : )
# Original : AddressC-DAC --------> Stemmed : addressc-dac
# Original : Innovation --------> Stemmed : innov
# Original : Park --------> Stemmed : park
# Original : , --------> Stemmed : ,
# Original : Panchavati --------> Stemmed : panchavati
# Original : , --------> Stemmed : ,
# Original : Pashan --------> Stemmed : pashan
# Original : , --------> Stemmed : ,
# Original : Pune --------> Stemmed : pune
# Original : - --------> Stemmed : -
# Original : 411 --------> Stemmed : 411
# Original : 008 --------> Stemmed : 008
# Original : , --------> Stemmed : ,
# Original : Maharashtra --------> Stemmed : maharashtra
# Original : , --------> Stemmed : ,
# Original : IndiaLocationPune --------> Stemmed : indialocationpun
# Original : , --------> Stemmed : ,
# Original : India --------> Stemmed : india
# Original : ( --------> Stemmed : (
# Original : headquarters --------> Stemmed : headquart
# Original : ) --------> Stemmed : )
# Original : NicknameC-DACOperating --------> Stemmed : nicknamec-dacoper
# Original : agencyMinistry --------> Stemmed : agencyministri
# Original : of --------> Stemmed : of
# Original : Electronics --------> Stemmed : electron
# Original : and --------> Stemmed : and
# Original : Information --------> Stemmed : inform
# Original : Technology --------> Stemmed : technolog
# Original : , --------> Stemmed : ,
# Original : Government --------> Stemmed : govern
# Original : of --------> Stemmed : of
# Original : IndiaWebsitewww.cdac.in --------> Stemmed : indiawebsitewww.cdac.in
# Original : The --------> Stemmed : the
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : ( --------> Stemmed : (
# Original : C-DAC --------> Stemmed : c-dac
# Original : ) --------> Stemmed : )
# Original : is --------> Stemmed : is
# Original : an --------> Stemmed : an
# Original : Indian --------> Stemmed : indian
# Original : autonomous --------> Stemmed : autonom
# Original : scientific --------> Stemmed : scientif
# Original : society --------> Stemmed : societi
# Original : , --------> Stemmed : ,
# Original : operating --------> Stemmed : oper
# Original : under --------> Stemmed : under
# Original : the --------> Stemmed : the
# Original : Ministry --------> Stemmed : ministri
# Original : of --------> Stemmed : of
# Original : Electronics --------> Stemmed : electron
# Original : and --------> Stemmed : and
# Original : Information --------> Stemmed : inform
# Original : Technology --------> Stemmed : technolog
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 2 --------> Stemmed : 2
# Original : ] --------> Stemmed : ]
# Original : History --------> Stemmed : histori
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : Further --------> Stemmed : further
# Original : information --------> Stemmed : inform
# Original : : --------> Stemmed : :
# Original : Supercomputing --------> Stemmed : supercomput
# Original : in --------> Stemmed : in
# Original : India --------> Stemmed : india
# Original : and --------> Stemmed : and
# Original : PARAM --------> Stemmed : param
# Original : C-DAC --------> Stemmed : c-dac
# Original : was --------> Stemmed : wa
# Original : created --------> Stemmed : creat
# Original : in --------> Stemmed : in
# Original : November --------> Stemmed : novemb
# Original : 1987 --------> Stemmed : 1987
# Original : , --------> Stemmed : ,
# Original : [ --------> Stemmed : [
# Original : 3 --------> Stemmed : 3
# Original : ] --------> Stemmed : ]
# Original : initially --------> Stemmed : initi
# Original : as --------> Stemmed : as
# Original : the --------> Stemmed : the
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : C-DACT --------> Stemmed : c-dact
# Original : ) --------> Stemmed : )
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 4 --------> Stemmed : 4
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 3 --------> Stemmed : 3
# Original : ] --------> Stemmed : ]
# Original : In --------> Stemmed : in
# Original : 1988 --------> Stemmed : 1988
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : US --------> Stemmed : us
# Original : Government --------> Stemmed : govern
# Original : refused --------> Stemmed : refus
# Original : to --------> Stemmed : to
# Original : sell --------> Stemmed : sell
# Original : India --------> Stemmed : india
# Original : a --------> Stemmed : a
# Original : Cray --------> Stemmed : cray
# Original : supercomputer --------> Stemmed : supercomput
# Original : due --------> Stemmed : due
# Original : to --------> Stemmed : to
# Original : concerns --------> Stemmed : concern
# Original : about --------> Stemmed : about
# Original : India --------> Stemmed : india
# Original : using --------> Stemmed : use
# Original : it --------> Stemmed : it
# Original : to --------> Stemmed : to
# Original : develop --------> Stemmed : develop
# Original : nuclear --------> Stemmed : nuclear
# Original : weapons --------> Stemmed : weapon
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 5 --------> Stemmed : 5
# Original : ] --------> Stemmed : ]
# Original : In --------> Stemmed : in
# Original : response --------> Stemmed : respons
# Original : India --------> Stemmed : india
# Original : started --------> Stemmed : start
# Original : development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : its --------> Stemmed : it
# Original : own --------> Stemmed : own
# Original : supercomputer --------> Stemmed : supercomput
# Original : , --------> Stemmed : ,
# Original : and --------> Stemmed : and
# Original : C-DACT --------> Stemmed : c-dact
# Original : was --------> Stemmed : wa
# Original : created --------> Stemmed : creat
# Original : as --------> Stemmed : as
# Original : part --------> Stemmed : part
# Original : of --------> Stemmed : of
# Original : this --------> Stemmed : thi
# Original : programme --------> Stemmed : programm
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 6 --------> Stemmed : 6
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 7 --------> Stemmed : 7
# Original : ] --------> Stemmed : ]
# Original : Dr --------> Stemmed : dr
# Original : Vijay --------> Stemmed : vijay
# Original : Bhatkar --------> Stemmed : bhatkar
# Original : was --------> Stemmed : wa
# Original : hired --------> Stemmed : hire
# Original : as --------> Stemmed : as
# Original : the --------> Stemmed : the
# Original : director --------> Stemmed : director
# Original : of --------> Stemmed : of
# Original : C-DACT --------> Stemmed : c-dact
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 7 --------> Stemmed : 7
# Original : ] --------> Stemmed : ]
# Original : The --------> Stemmed : the
# Original : project --------> Stemmed : project
# Original : was --------> Stemmed : wa
# Original : given --------> Stemmed : given
# Original : an --------> Stemmed : an
# Original : initial --------> Stemmed : initi
# Original : run --------> Stemmed : run
# Original : of --------> Stemmed : of
# Original : three --------> Stemmed : three
# Original : years --------> Stemmed : year
# Original : and --------> Stemmed : and
# Original : an --------> Stemmed : an
# Original : initial --------> Stemmed : initi
# Original : funding --------> Stemmed : fund
# Original : of --------> Stemmed : of
# Original : ₹30,00,00,000 --------> Stemmed : ₹30,00,00,000
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : cost --------> Stemmed : cost
# Original : of --------> Stemmed : of
# Original : a --------> Stemmed : a
# Original : Cray --------> Stemmed : cray
# Original : supercomputer --------> Stemmed : supercomput
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 7 --------> Stemmed : 7
# Original : ] --------> Stemmed : ]
# Original : A --------> Stemmed : a
# Original : prototype --------> Stemmed : prototyp
# Original : computer --------> Stemmed : comput
# Original : was --------> Stemmed : wa
# Original : benchmarked --------> Stemmed : benchmark
# Original : at --------> Stemmed : at
# Original : the --------> Stemmed : the
# Original : 1990 --------> Stemmed : 1990
# Original : Zurich --------> Stemmed : zurich
# Original : Super-computing --------> Stemmed : super-comput
# Original : Show --------> Stemmed : show
# Original : . --------> Stemmed : .
# Original : It --------> Stemmed : it
# Original : demonstrated --------> Stemmed : demonstr
# Original : that --------> Stemmed : that
# Original : India --------> Stemmed : india
# Original : had --------> Stemmed : had
# Original : the --------> Stemmed : the
# Original : second --------> Stemmed : second
# Original : most --------> Stemmed : most
# Original : powerful --------> Stemmed : power
# Original : , --------> Stemmed : ,
# Original : publicly --------> Stemmed : publicli
# Original : demonstrated --------> Stemmed : demonstr
# Original : , --------> Stemmed : ,
# Original : supercomputer --------> Stemmed : supercomput
# Original : in --------> Stemmed : in
# Original : the --------> Stemmed : the
# Original : world --------> Stemmed : world
# Original : after --------> Stemmed : after
# Original : the --------> Stemmed : the
# Original : United --------> Stemmed : unit
# Original : States --------> Stemmed : state
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 7 --------> Stemmed : 7
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 8 --------> Stemmed : 8
# Original : ] --------> Stemmed : ]
# Original : The --------> Stemmed : the
# Original : final --------> Stemmed : final
# Original : result --------> Stemmed : result
# Original : of --------> Stemmed : of
# Original : the --------> Stemmed : the
# Original : effort --------> Stemmed : effort
# Original : was --------> Stemmed : wa
# Original : the --------> Stemmed : the
# Original : PARAM --------> Stemmed : param
# Original : 8000 --------> Stemmed : 8000
# Original : , --------> Stemmed : ,
# Original : released --------> Stemmed : releas
# Original : in --------> Stemmed : in
# Original : 1991 --------> Stemmed : 1991
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 9 --------> Stemmed : 9
# Original : ] --------> Stemmed : ]
# Original : The --------> Stemmed : the
# Original : National --------> Stemmed : nation
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Software --------> Stemmed : softwar
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : NCST --------> Stemmed : ncst
# Original : ) --------> Stemmed : )
# Original : , --------> Stemmed : ,
# Original : Electronic --------> Stemmed : electron
# Original : Research --------> Stemmed : research
# Original : and --------> Stemmed : and
# Original : Development --------> Stemmed : develop
# Original : Centre --------> Stemmed : centr
# Original : ( --------> Stemmed : (
# Original : ER --------> Stemmed : er
# Original : & --------> Stemmed : &
# Original : DC --------> Stemmed : dc
# Original : ) --------> Stemmed : )
# Original : and --------> Stemmed : and
# Original : CEDTI --------> Stemmed : cedti
# Original : were --------> Stemmed : were
# Original : merged --------> Stemmed : merg
# Original : into --------> Stemmed : into
# Original : C-DAC --------> Stemmed : c-dac
# Original : in --------> Stemmed : in
# Original : 2003 --------> Stemmed : 2003
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 10 --------> Stemmed : 10
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 11 --------> Stemmed : 11
# Original : ] --------> Stemmed : ]
# Original : Research --------> Stemmed : research
# Original : activities --------> Stemmed : activ
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : Originally --------> Stemmed : origin
# Original : established --------> Stemmed : establish
# Original : to --------> Stemmed : to
# Original : research --------> Stemmed : research
# Original : and --------> Stemmed : and
# Original : assemble --------> Stemmed : assembl
# Original : High --------> Stemmed : high
# Original : Performance --------> Stemmed : perform
# Original : Computers --------> Stemmed : comput
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : research --------> Stemmed : research
# Original : of --------> Stemmed : of
# Original : C-DAC --------> Stemmed : c-dac
# Original : now --------> Stemmed : now
# Original : includes --------> Stemmed : includ
# Original : : --------> Stemmed : :
# Original : High --------> Stemmed : high
# Original : Performance --------> Stemmed : perform
# Original : Computing --------> Stemmed : comput
# Original : Grid --------> Stemmed : grid
# Original : Computing --------> Stemmed : comput
# Original : Cloud --------> Stemmed : cloud
# Original : Computing --------> Stemmed : comput
# Original : Multilingual --------> Stemmed : multilingu
# Original : and --------> Stemmed : and
# Original : Heritage --------> Stemmed : heritag
# Original : Computing --------> Stemmed : comput
# Original : VLSI --------> Stemmed : vlsi
# Original : and --------> Stemmed : and
# Original : Processor --------> Stemmed : processor
# Original : design --------> Stemmed : design
# Original : Embedded --------> Stemmed : embed
# Original : Systems --------> Stemmed : system
# Original : Speech --------> Stemmed : speech
# Original : and --------> Stemmed : and
# Original : Natural --------> Stemmed : natur
# Original : Language --------> Stemmed : languag
# Original : Processing --------> Stemmed : process
# Original : Information --------> Stemmed : inform
# Original : and --------> Stemmed : and
# Original : Cyber --------> Stemmed : cyber
# Original : Security --------> Stemmed : secur
# Original : Ubiquitous --------> Stemmed : ubiquit
# Original : Computing --------> Stemmed : comput
# Original : Bioinformatics --------> Stemmed : bioinformat
# Original : Geomatics --------> Stemmed : geomat
# Original : Digital --------> Stemmed : digit
# Original : forensics --------> Stemmed : forens
# Original : Big --------> Stemmed : big
# Original : data --------> Stemmed : data
# Original : analytics --------> Stemmed : analyt
# Original : Blockchain --------> Stemmed : blockchain
# Original : Health --------> Stemmed : health
# Original : Informatics --------> Stemmed : informat
# Original : Quantum --------> Stemmed : quantum
# Original : computing --------> Stemmed : comput
# Original : Centres --------> Stemmed : centr
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : C-DAC --------> Stemmed : c-dac
# Original : branches --------> Stemmed : branch
# Original : and --------> Stemmed : and
# Original : training --------> Stemmed : train
# Original : centres --------> Stemmed : centr
# Original : include --------> Stemmed : includ
# Original : : --------> Stemmed : :
# Original : [ --------> Stemmed : [
# Original : 12 --------> Stemmed : 12
# Original : ] --------> Stemmed : ]
# Original : C-DAC --------> Stemmed : c-dac
# Original : Pune --------> Stemmed : pune
# Original : ( --------> Stemmed : (
# Original : Headquarters --------> Stemmed : headquart
# Original : ) --------> Stemmed : )
# Original : C-DAC --------> Stemmed : c-dac
# Original : Mumbai --------> Stemmed : mumbai
# Original : C-DAC --------> Stemmed : c-dac
# Original : Bangalore --------> Stemmed : bangalor
# Original : C-DAC --------> Stemmed : c-dac
# Original : Chennai --------> Stemmed : chennai
# Original : C-DAC --------> Stemmed : c-dac
# Original : Delhi --------> Stemmed : delhi
# Original : C-DAC --------> Stemmed : c-dac
# Original : Kolkata --------> Stemmed : kolkata
# Original : C-DAC --------> Stemmed : c-dac
# Original : Patna --------> Stemmed : patna
# Original : C-DAC --------> Stemmed : c-dac
# Original : Mohali --------> Stemmed : mohali
# Original : C-DAC --------> Stemmed : c-dac
# Original : Noida --------> Stemmed : noida
# Original : C-DAC --------> Stemmed : c-dac
# Original : Hyderabad --------> Stemmed : hyderabad
# Original : C-DAC --------> Stemmed : c-dac
# Original : Thiruvananthapuram --------> Stemmed : thiruvananthapuram
# Original : C-DAC --------> Stemmed : c-dac
# Original : Silchar --------> Stemmed : silchar
# Original : Education --------> Stemmed : educ
# Original : and --------> Stemmed : and
# Original : training --------> Stemmed : train
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : C-DAC --------> Stemmed : c-dac
# Original : provides --------> Stemmed : provid
# Original : several --------> Stemmed : sever
# Original : courses --------> Stemmed : cours
# Original : in --------> Stemmed : in
# Original : the --------> Stemmed : the
# Original : field --------> Stemmed : field
# Original : of --------> Stemmed : of
# Original : advanced --------> Stemmed : advanc
# Original : computing --------> Stemmed : comput
# Original : and --------> Stemmed : and
# Original : software --------> Stemmed : softwar
# Original : development --------> Stemmed : develop
# Original : . --------> Stemmed : .
# Original : Among --------> Stemmed : among
# Original : these --------> Stemmed : these
# Original : are --------> Stemmed : are
# Original : the --------> Stemmed : the
# Original : HPC --------> Stemmed : hpc
# Original : certification --------> Stemmed : certif
# Original : course- --------> Stemmed : course-
# Original : C-DAC --------> Stemmed : c-dac
# Original : Certified --------> Stemmed : certifi
# Original : HPC --------> Stemmed : hpc
# Original : Professional --------> Stemmed : profession
# Original : Certification --------> Stemmed : certif
# Original : Programme --------> Stemmed : programm
# Original : ( --------> Stemmed : (
# Original : CCHPCP --------> Stemmed : cchpcp
# Original : ) --------> Stemmed : )
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 13 --------> Stemmed : 13
# Original : ] --------> Stemmed : ]
# Original : C-DAC --------> Stemmed : c-dac
# Original : organises --------> Stemmed : organis
# Original : advanced --------> Stemmed : advanc
# Original : computing --------> Stemmed : comput
# Original : diploma --------> Stemmed : diploma
# Original : programmes --------> Stemmed : programm
# Original : through --------> Stemmed : through
# Original : the --------> Stemmed : the
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : Training --------> Stemmed : train
# Original : School --------> Stemmed : school
# Original : ( --------> Stemmed : (
# Original : ACTS --------> Stemmed : act
# Original : ) --------> Stemmed : )
# Original : located --------> Stemmed : locat
# Original : all --------> Stemmed : all
# Original : over --------> Stemmed : over
# Original : India --------> Stemmed : india
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 14 --------> Stemmed : 14
# Original : ] --------> Stemmed : ]
# Original : The --------> Stemmed : the
# Original : PG --------> Stemmed : pg
# Original : Diploma --------> Stemmed : diploma
# Original : courses --------> Stemmed : cours
# Original : include --------> Stemmed : includ
# Original : Specialisations --------> Stemmed : specialis
# Original : in --------> Stemmed : in
# Original : Embedded --------> Stemmed : embed
# Original : System --------> Stemmed : system
# Original : Design --------> Stemmed : design
# Original : , --------> Stemmed : ,
# Original : VLSI --------> Stemmed : vlsi
# Original : , --------> Stemmed : ,
# Original : Big --------> Stemmed : big
# Original : Data --------> Stemmed : data
# Original : Analytics --------> Stemmed : analyt
# Original : , --------> Stemmed : ,
# Original : Geoinformatics --------> Stemmed : geoinformat
# Original : , --------> Stemmed : ,
# Original : Artificial --------> Stemmed : artifici
# Original : Intelligence --------> Stemmed : intellig
# Original : C-DAC --------> Stemmed : c-dac
# Original : has --------> Stemmed : ha
# Original : also --------> Stemmed : also
# Original : established --------> Stemmed : establish
# Original : Centres --------> Stemmed : centr
# Original : of --------> Stemmed : of
# Original : Excellence --------> Stemmed : excel
# Original : in --------> Stemmed : in
# Original : Information --------> Stemmed : inform
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : CEIT --------> Stemmed : ceit
# Original : ) --------> Stemmed : )
# Original : abroad --------> Stemmed : abroad
# Original : under --------> Stemmed : under
# Original : the --------> Stemmed : the
# Original : Ministry --------> Stemmed : ministri
# Original : of --------> Stemmed : of
# Original : External --------> Stemmed : extern
# Original : Affairs --------> Stemmed : affair
# Original : ' --------> Stemmed : '
# Original : s --------> Stemmed : s
# Original : development --------> Stemmed : develop
# Original : partnership --------> Stemmed : partnership
# Original : projects --------> Stemmed : project
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 15 --------> Stemmed : 15
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 16 --------> Stemmed : 16
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 17 --------> Stemmed : 17
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 18 --------> Stemmed : 18
# Original : ] --------> Stemmed : ]
# Original : Commercialization --------> Stemmed : commerci
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : This --------> Stemmed : thi
# Original : article --------> Stemmed : articl
# Original : appears --------> Stemmed : appear
# Original : to --------> Stemmed : to
# Original : contain --------> Stemmed : contain
# Original : a --------> Stemmed : a
# Original : large --------> Stemmed : larg
# Original : number --------> Stemmed : number
# Original : of --------> Stemmed : of
# Original : buzzwords --------> Stemmed : buzzword
# Original : . --------> Stemmed : .
# Original : There --------> Stemmed : there
# Original : might --------> Stemmed : might
# Original : be --------> Stemmed : be
# Original : a --------> Stemmed : a
# Original : discussion --------> Stemmed : discuss
# Original : about --------> Stemmed : about
# Original : this --------> Stemmed : thi
# Original : on --------> Stemmed : on
# Original : the --------> Stemmed : the
# Original : talk --------> Stemmed : talk
# Original : page --------> Stemmed : page
# Original : . --------> Stemmed : .
# Original : Please --------> Stemmed : pleas
# Original : help --------> Stemmed : help
# Original : improve --------> Stemmed : improv
# Original : this --------> Stemmed : thi
# Original : article --------> Stemmed : articl
# Original : if --------> Stemmed : if
# Original : you --------> Stemmed : you
# Original : can --------> Stemmed : can
# Original : . --------> Stemmed : .
# Original : ( --------> Stemmed : (
# Original : April --------> Stemmed : april
# Original : 2025 --------> Stemmed : 2025
# Original : ) --------> Stemmed : )
# Original : On --------> Stemmed : on
# Original : August --------> Stemmed : august
# Original : 28 --------> Stemmed : 28
# Original : , --------> Stemmed : ,
# Original : 2024 --------> Stemmed : 2024
# Original : , --------> Stemmed : ,
# Original : C-DAC --------> Stemmed : c-dac
# Original : and --------> Stemmed : and
# Original : L --------> Stemmed : l
# Original : & --------> Stemmed : &
# Original : T --------> Stemmed : t
# Original : Semiconductor --------> Stemmed : semiconductor
# Original : Technologies --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : LTSCT --------> Stemmed : ltsct
# Original : ) --------> Stemmed : )
# Original : signed --------> Stemmed : sign
# Original : a --------> Stemmed : a
# Original : Memorandum --------> Stemmed : memorandum
# Original : of --------> Stemmed : of
# Original : Understanding --------> Stemmed : understand
# Original : ( --------> Stemmed : (
# Original : MoU --------> Stemmed : mou
# Original : ) --------> Stemmed : )
# Original : . --------> Stemmed : .
# Original : It --------> Stemmed : it
# Original : will --------> Stemmed : will
# Original : establish --------> Stemmed : establish
# Original : a --------> Stemmed : a
# Original : program --------> Stemmed : program
# Original : for --------> Stemmed : for
# Original : the --------> Stemmed : the
# Original : commercialization --------> Stemmed : commerci
# Original : of --------> Stemmed : of
# Original : cutting-edge --------> Stemmed : cutting-edg
# Original : technologies --------> Stemmed : technolog
# Original : created --------> Stemmed : creat
# Original : by --------> Stemmed : by
# Original : C-DAC --------> Stemmed : c-dac
# Original : in --------> Stemmed : in
# Original : the --------> Stemmed : the
# Original : areas --------> Stemmed : area
# Original : of --------> Stemmed : of
# Original : power --------> Stemmed : power
# Original : systems --------> Stemmed : system
# Original : , --------> Stemmed : ,
# Original : embedded --------> Stemmed : embed
# Original : software --------> Stemmed : softwar
# Original : , --------> Stemmed : ,
# Original : open-source --------> Stemmed : open-sourc
# Original : operating --------> Stemmed : oper
# Original : systems --------> Stemmed : system
# Original : , --------> Stemmed : ,
# Original : high --------> Stemmed : high
# Original : performance --------> Stemmed : perform
# Original : computing --------> Stemmed : comput
# Original : , --------> Stemmed : ,
# Original : and --------> Stemmed : and
# Original : semiconductor --------> Stemmed : semiconductor
# Original : design --------> Stemmed : design
# Original : and --------> Stemmed : and
# Original : development --------> Stemmed : develop
# Original : . --------> Stemmed : .
# Original : LTSCT --------> Stemmed : ltsct
# Original : will --------> Stemmed : will
# Original : leverage --------> Stemmed : leverag
# Original : C-DAC --------> Stemmed : c-dac
# Original : 's --------> Stemmed : 's
# Original : extensive --------> Stemmed : extens
# Original : pipeline --------> Stemmed : pipelin
# Original : of --------> Stemmed : of
# Original : in-house --------> Stemmed : in-hous
# Original : intellectual --------> Stemmed : intellectu
# Original : property --------> Stemmed : properti
# Original : ( --------> Stemmed : (
# Original : IPs --------> Stemmed : ip
# Original : ) --------> Stemmed : )
# Original : , --------> Stemmed : ,
# Original : which --------> Stemmed : which
# Original : includes --------> Stemmed : includ
# Original : the --------> Stemmed : the
# Original : VEGA --------> Stemmed : vega
# Original : processor --------> Stemmed : processor
# Original : , --------> Stemmed : ,
# Original : to --------> Stemmed : to
# Original : create --------> Stemmed : creat
# Original : global --------> Stemmed : global
# Original : product --------> Stemmed : product
# Original : prospects --------> Stemmed : prospect
# Original : through --------> Stemmed : through
# Original : application --------> Stemmed : applic
# Original : design --------> Stemmed : design
# Original : and --------> Stemmed : and
# Original : validation --------> Stemmed : valid
# Original : for --------> Stemmed : for
# Original : Field --------> Stemmed : field
# Original : Programmable --------> Stemmed : programm
# Original : Gate --------> Stemmed : gate
# Original : Arrays --------> Stemmed : array
# Original : . --------> Stemmed : .
# Original : By --------> Stemmed : by
# Original : facilitating --------> Stemmed : facilit
# Original : the --------> Stemmed : the
# Original : creation --------> Stemmed : creation
# Original : of --------> Stemmed : of
# Original : cutting-edge --------> Stemmed : cutting-edg
# Original : goods --------> Stemmed : good
# Original : and --------> Stemmed : and
# Original : solutions --------> Stemmed : solut
# Original : for --------> Stemmed : for
# Original : the --------> Stemmed : the
# Original : automotive --------> Stemmed : automot
# Original : , --------> Stemmed : ,
# Original : industrial --------> Stemmed : industri
# Original : , --------> Stemmed : ,
# Original : information --------> Stemmed : inform
# Original : and --------> Stemmed : and
# Original : communications --------> Stemmed : commun
# Original : technology --------> Stemmed : technolog
# Original : infrastructure --------> Stemmed : infrastructur
# Original : , --------> Stemmed : ,
# Original : and --------> Stemmed : and
# Original : energy --------> Stemmed : energi
# Original : sectors --------> Stemmed : sector
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : collaboration --------> Stemmed : collabor
# Original : to --------> Stemmed : to
# Original : create --------> Stemmed : creat
# Original : indigenous --------> Stemmed : indigen
# Original : ICs --------> Stemmed : ic
# Original : and --------> Stemmed : and
# Original : SoCs --------> Stemmed : soc
# Original : based --------> Stemmed : base
# Original : in --------> Stemmed : in
# Original : Vega --------> Stemmed : vega
# Original : is --------> Stemmed : is
# Original : expected --------> Stemmed : expect
# Original : to --------> Stemmed : to
# Original : pick --------> Stemmed : pick
# Original : up --------> Stemmed : up
# Original : speed --------> Stemmed : speed
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 19 --------> Stemmed : 19
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 20 --------> Stemmed : 20
# Original : ] --------> Stemmed : ]
# Original : Products --------> Stemmed : product
# Original : and --------> Stemmed : and
# Original : developments --------> Stemmed : develop
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : PARAM --------> Stemmed : param
# Original : series --------> Stemmed : seri
# Original : of --------> Stemmed : of
# Original : supercomputers --------> Stemmed : supercomput
# Original : [ --------> Stemmed : [
# Original : 21 --------> Stemmed : 21
# Original : ] --------> Stemmed : ]
# Original : VEGA --------> Stemmed : vega
# Original : Microprocessors --------> Stemmed : microprocessor
# Original : , --------> Stemmed : ,
# Original : India --------> Stemmed : india
# Original : 's --------> Stemmed : 's
# Original : first --------> Stemmed : first
# Original : indigenous --------> Stemmed : indigen
# Original : 64-bit --------> Stemmed : 64-bit
# Original : Multi-core --------> Stemmed : multi-cor
# Original : Superscalar --------> Stemmed : superscalar
# Original : Out-of-Order --------> Stemmed : out-of-ord
# Original : RISC-V --------> Stemmed : risc-v
# Original : Processor --------> Stemmed : processor
# Original : [ --------> Stemmed : [
# Original : 22 --------> Stemmed : 22
# Original : ] --------> Stemmed : ]
# Original : M-Kavach --------> Stemmed : m-kavach
# Original : 2 --------> Stemmed : 2
# Original : , --------> Stemmed : ,
# Original : an --------> Stemmed : an
# Original : android-based --------> Stemmed : android-bas
# Original : mobile --------> Stemmed : mobil
# Original : device --------> Stemmed : devic
# Original : security --------> Stemmed : secur
# Original : solution --------> Stemmed : solut
# Original : addressing --------> Stemmed : address
# Original : emerging --------> Stemmed : emerg
# Original : threats --------> Stemmed : threat
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 23 --------> Stemmed : 23
# Original : ] --------> Stemmed : ]
# Original : Mobile --------> Stemmed : mobil
# Original : Seva --------> Stemmed : seva
# Original : AppStore --------> Stemmed : appstor
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : mobile --------> Stemmed : mobil
# Original : app --------> Stemmed : app
# Original : marketplace --------> Stemmed : marketplac
# Original : [ --------> Stemmed : [
# Original : 24 --------> Stemmed : 24
# Original : ] --------> Stemmed : ]
# Original : Bharat --------> Stemmed : bharat
# Original : Operating --------> Stemmed : oper
# Original : System --------> Stemmed : system
# Original : Solutions --------> Stemmed : solut
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : Linux-based --------> Stemmed : linux-bas
# Original : general --------> Stemmed : gener
# Original : purpose --------> Stemmed : purpos
# Original : operating --------> Stemmed : oper
# Original : system --------> Stemmed : system
# Original : [ --------> Stemmed : [
# Original : 25 --------> Stemmed : 25
# Original : ] --------> Stemmed : ]
# Original : Anvaya --------> Stemmed : anvaya
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : workflow --------> Stemmed : workflow
# Original : environment --------> Stemmed : environ
# Original : for --------> Stemmed : for
# Original : automated --------> Stemmed : autom
# Original : genome --------> Stemmed : genom
# Original : analysis --------> Stemmed : analysi
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 26 --------> Stemmed : 26
# Original : ] --------> Stemmed : ]
# Original : Namescape --------> Stemmed : namescap
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : search --------> Stemmed : search
# Original : engine --------> Stemmed : engin
# Original : for --------> Stemmed : for
# Original : the --------> Stemmed : the
# Original : Aadhaar --------> Stemmed : aadhaar
# Original : unique-ID --------> Stemmed : unique-id
# Original : project --------> Stemmed : project
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 27 --------> Stemmed : 27
# Original : ] --------> Stemmed : ]
# Original : GARUDA --------> Stemmed : garuda
# Original : , --------> Stemmed : ,
# Original : India --------> Stemmed : india
# Original : 's --------> Stemmed : 's
# Original : National --------> Stemmed : nation
# Original : Grid --------> Stemmed : grid
# Original : Computing --------> Stemmed : comput
# Original : Initiative --------> Stemmed : initi
# Original : [ --------> Stemmed : [
# Original : 28 --------> Stemmed : 28
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 29 --------> Stemmed : 29
# Original : ] --------> Stemmed : ]
# Original : TaxoGrid --------> Stemmed : taxogrid
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : grid-based --------> Stemmed : grid-bas
# Original : molecular --------> Stemmed : molecular
# Original : phylogenetics --------> Stemmed : phylogenet
# Original : and --------> Stemmed : and
# Original : drug --------> Stemmed : drug
# Original : discovery --------> Stemmed : discoveri
# Original : system --------> Stemmed : system
# Original : [ --------> Stemmed : [
# Original : 30 --------> Stemmed : 30
# Original : ] --------> Stemmed : ]
# Original : GIST --------> Stemmed : gist
# Original : , --------> Stemmed : ,
# Original : Graphics --------> Stemmed : graphic
# Original : and --------> Stemmed : and
# Original : Intelligence --------> Stemmed : intellig
# Original : based --------> Stemmed : base
# Original : Script --------> Stemmed : script
# Original : Technology --------> Stemmed : technolog
# Original : [ --------> Stemmed : [
# Original : 31 --------> Stemmed : 31
# Original : ] --------> Stemmed : ]
# Original : DARPAN --------> Stemmed : darpan
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : real --------> Stemmed : real
# Original : time --------> Stemmed : time
# Original : network --------> Stemmed : network
# Original : monitoring --------> Stemmed : monitor
# Original : , --------> Stemmed : ,
# Original : visualization --------> Stemmed : visual
# Original : and --------> Stemmed : and
# Original : Service --------> Stemmed : servic
# Original : Level --------> Stemmed : level
# Original : Agreement --------> Stemmed : agreement
# Original : monitoring --------> Stemmed : monitor
# Original : tool --------> Stemmed : tool
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 32 --------> Stemmed : 32
# Original : ] --------> Stemmed : ]
# Original : OLabs --------> Stemmed : olab
# Original : , --------> Stemmed : ,
# Original : an --------> Stemmed : an
# Original : internet --------> Stemmed : internet
# Original : based --------> Stemmed : base
# Original : platform --------> Stemmed : platform
# Original : for --------> Stemmed : for
# Original : conduct --------> Stemmed : conduct
# Original : of --------> Stemmed : of
# Original : school --------> Stemmed : school
# Original : laboratory --------> Stemmed : laboratori
# ...
# Original : . --------> Stemmed : .
# Original : The --------> Stemmed : the
# Original : Indian --------> Stemmed : indian
# Original : Express --------> Stemmed : express
# Original : . --------> Stemmed : .
# Original : 13 --------> Stemmed : 13
# Original : September --------> Stemmed : septemb
# Original : 2011. --------> Stemmed : 2011.
# Original : vte --------> Stemmed : vte
# Original : Ministry --------> Stemmed : ministri
# Original : of --------> Stemmed : of
# Original : Electronics --------> Stemmed : electron
# Original : and --------> Stemmed : and
# Original : Information --------> Stemmed : inform
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : India --------> Stemmed : india
# Original : ) --------> Stemmed : )
# Original : AgenciesNIC --------> Stemmed : agenciesn
# Original : Network --------> Stemmed : network
# Original : Data --------> Stemmed : data
# Original : Centers --------> Stemmed : center
# Original : DigiLocker --------> Stemmed : digilock
# Original : MyGov.in --------> Stemmed : mygov.in
# Original : National --------> Stemmed : nation
# Original : Portal --------> Stemmed : portal
# Original : of --------> Stemmed : of
# Original : India --------> Stemmed : india
# Original : IN --------> Stemmed : in
# Original : Registry --------> Stemmed : registri
# Original : .in --------> Stemmed : .in
# Original : .भारत --------> Stemmed : .भारत
# Original : Other --------> Stemmed : other
# Original : Standardisation --------> Stemmed : standardis
# Original : Testing --------> Stemmed : test
# Original : and --------> Stemmed : and
# Original : Quality --------> Stemmed : qualiti
# Original : Certification --------> Stemmed : certif
# Original : Directorate --------> Stemmed : director
# Original : ( --------> Stemmed : (
# Original : STQC --------> Stemmed : stqc
# Original : ) --------> Stemmed : )
# Original : Controller --------> Stemmed : control
# Original : of --------> Stemmed : of
# Original : Certifying --------> Stemmed : certifi
# Original : Authorities --------> Stemmed : author
# Original : ( --------> Stemmed : (
# Original : CCA --------> Stemmed : cca
# Original : ) --------> Stemmed : )
# Original : Cyber --------> Stemmed : cyber
# Original : Appellate --------> Stemmed : appel
# Original : Tribunal --------> Stemmed : tribun
# Original : ( --------> Stemmed : (
# Original : CAT --------> Stemmed : cat
# Original : ) --------> Stemmed : )
# Original : Indian --------> Stemmed : indian
# Original : Computer --------> Stemmed : comput
# Original : Emergency --------> Stemmed : emerg
# Original : Response --------> Stemmed : respons
# Original : Team --------> Stemmed : team
# Original : ( --------> Stemmed : (
# Original : ICERT --------> Stemmed : icert
# Original : ) --------> Stemmed : )
# Original : Companies --------> Stemmed : compani
# Original : CSC --------> Stemmed : csc
# Original : e-Governance --------> Stemmed : e-govern
# Original : Services --------> Stemmed : servic
# Original : India --------> Stemmed : india
# Original : Limited --------> Stemmed : limit
# Original : Media --------> Stemmed : media
# Original : Lab --------> Stemmed : lab
# Original : Asia --------> Stemmed : asia
# Original : ( --------> Stemmed : (
# Original : MLAsia --------> Stemmed : mlasia
# Original : ) --------> Stemmed : )
# Original : National --------> Stemmed : nation
# Original : Informatics --------> Stemmed : informat
# Original : Centre --------> Stemmed : centr
# Original : Services --------> Stemmed : servic
# Original : Incorporated --------> Stemmed : incorpor
# Original : ( --------> Stemmed : (
# Original : NICSI --------> Stemmed : nicsi
# Original : ) --------> Stemmed : )
# Original : — --------> Stemmed : —
# Original : PSE --------> Stemmed : pse
# Original : under --------> Stemmed : under
# Original : National --------> Stemmed : nation
# Original : Informatics --------> Stemmed : informat
# Original : Centre --------> Stemmed : centr
# Original : National --------> Stemmed : nation
# Original : Internet --------> Stemmed : internet
# Original : Exchange --------> Stemmed : exchang
# Original : of --------> Stemmed : of
# Original : India --------> Stemmed : india
# Original : ( --------> Stemmed : (
# Original : NIXI --------> Stemmed : nixi
# Original : ) --------> Stemmed : )
# Original : STPI --------> Stemmed : stpi
# Original : Unique --------> Stemmed : uniqu
# Original : Identification --------> Stemmed : identif
# Original : Authority --------> Stemmed : author
# Original : of --------> Stemmed : of
# Original : India --------> Stemmed : india
# Original : ( --------> Stemmed : (
# Original : UIDAI --------> Stemmed : uidai
# Original : ) --------> Stemmed : )
# Original : AutonomousSocieties --------> Stemmed : autonomoussocieti
# Original : Education --------> Stemmed : educ
# Original : and --------> Stemmed : and
# Original : Research --------> Stemmed : research
# Original : in --------> Stemmed : in
# Original : Computer --------> Stemmed : comput
# Original : Networking --------> Stemmed : network
# Original : ( --------> Stemmed : (
# Original : ERNET --------> Stemmed : ernet
# Original : ) --------> Stemmed : )
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : ( --------> Stemmed : (
# Original : C-DAC --------> Stemmed : c-dac
# Original : ) --------> Stemmed : )
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Materials --------> Stemmed : materi
# Original : for --------> Stemmed : for
# Original : Electronics --------> Stemmed : electron
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : C-MET --------> Stemmed : c-met
# Original : ) --------> Stemmed : )
# Original : National --------> Stemmed : nation
# Original : Institute --------> Stemmed : institut
# Original : of --------> Stemmed : of
# Original : Electronics --------> Stemmed : electron
# Original : and --------> Stemmed : and
# Original : Information --------> Stemmed : inform
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : NIELIT --------> Stemmed : nielit
# Original : ) --------> Stemmed : )
# Original : — --------> Stemmed : —
# Original : Formerly --------> Stemmed : formerli
# Original : DOEACC --------> Stemmed : doeacc
# Original : Society --------> Stemmed : societi
# Original : Society --------> Stemmed : societi
# Original : for --------> Stemmed : for
# Original : Applied --------> Stemmed : appli
# Original : Microwave --------> Stemmed : microwav
# Original : Electronics --------> Stemmed : electron
# Original : Engineering --------> Stemmed : engin
# Original : and --------> Stemmed : and
# Original : Research --------> Stemmed : research
# Original : ( --------> Stemmed : (
# Original : SAMEER --------> Stemmed : sameer
# Original : ) --------> Stemmed : )
# Original : Software --------> Stemmed : softwar
# Original : Technology --------> Stemmed : technolog
# Original : Parks --------> Stemmed : park
# Original : of --------> Stemmed : of
# Original : India --------> Stemmed : india
# Original : ( --------> Stemmed : (
# Original : STPI --------> Stemmed : stpi
# Original : ) --------> Stemmed : )
# Original : Electronics --------> Stemmed : electron
# Original : and --------> Stemmed : and
# Original : Computer --------> Stemmed : comput
# Original : Software --------> Stemmed : softwar
# Original : Export --------> Stemmed : export
# Original : Promotion --------> Stemmed : promot
# Original : Council --------> Stemmed : council
# Original : ( --------> Stemmed : (
# Original : ESC --------> Stemmed : esc
# Original : ) --------> Stemmed : )
# Original : Semi-Conductor --------> Stemmed : semi-conductor
# Original : Laboratory --------> Stemmed : laboratori
# Original : ( --------> Stemmed : (
# Original : SCL --------> Stemmed : scl
# Original : ) --------> Stemmed : )
# Original : Ministers --------> Stemmed : minist
# Original : Ashwini --------> Stemmed : ashwini
# Original : Vaishnaw --------> Stemmed : vaishnaw
# Original : ( --------> Stemmed : (
# Original : incumbent --------> Stemmed : incumb
# Original : ) --------> Stemmed : )
# Original : Ministers --------> Stemmed : minist
# Original : of --------> Stemmed : of
# Original : State --------> Stemmed : state
# Original : Jitin --------> Stemmed : jitin
# Original : Prasada --------> Stemmed : prasada
# Original : ( --------> Stemmed : (
# Original : incumbent --------> Stemmed : incumb
# Original : ) --------> Stemmed : )
# Original : Authority --------> Stemmed : author
# Original : control --------> Stemmed : control
# Original : databases --------> Stemmed : databas
# Original : InternationalISNIVIAFNationalGermanyUnited --------> Stemmed : internationalisniviafnationalgermanyunit
# Original : StatesIsrael --------> Stemmed : statesisrael
# Original : Retrieved --------> Stemmed : retriev
# Original : from --------> Stemmed : from
# Original : `` --------> Stemmed : ``
# Original : https --------> Stemmed : http
# Original : : --------> Stemmed : :
# Original : //en.wikipedia.org/w/index.php --------> Stemmed : //en.wikipedia.org/w/index.php
# Original : ? --------> Stemmed : ?
# Original : title=Centre_for_Development_of_Advanced_Computing --------> Stemmed : title=centre_for_development_of_advanced_comput
# Original : & --------> Stemmed : &
# Original : oldid=1285579997 --------> Stemmed : oldid=1285579997
# Original : '' --------> Stemmed : ''
# Original : Categories --------> Stemmed : categori
# Original : : --------> Stemmed : :
# Original : Research --------> Stemmed : research
# Original : institutes --------> Stemmed : institut
# Original : in --------> Stemmed : in
# Original : PuneInformation --------> Stemmed : puneinform
# Original : technology --------> Stemmed : technolog
# Original : organisations --------> Stemmed : organis
# Original : based --------> Stemmed : base
# Original : in --------> Stemmed : in
# Original : India1988 --------> Stemmed : india1988
# Original : establishments --------> Stemmed : establish
# Original : in --------> Stemmed : in
# Original : MaharashtraResearch --------> Stemmed : maharashtraresearch
# Original : institutes --------> Stemmed : institut
# Original : established --------> Stemmed : establish
# Original : in --------> Stemmed : in
# Original : 1988Hidden --------> Stemmed : 1988hidden
# Original : categories --------> Stemmed : categori
# Original : : --------> Stemmed : :
# Original : Pages --------> Stemmed : page
# Original : using --------> Stemmed : use
# Original : gadget --------> Stemmed : gadget
# Original : WikiMiniAtlasArticles --------> Stemmed : wikiminiatlasarticl
# Original : with --------> Stemmed : with
# Original : short --------> Stemmed : short
# Original : descriptionShort --------> Stemmed : descriptionshort
# Original : description --------> Stemmed : descript
# Original : matches --------> Stemmed : match
# Original : WikidataEngvarB --------> Stemmed : wikidataengvarb
# Original : from --------> Stemmed : from
# Original : July --------> Stemmed : juli
# Original : 2015Use --------> Stemmed : 2015use
# Original : dmy --------> Stemmed : dmi
# Original : dates --------> Stemmed : date
# Original : from --------> Stemmed : from
# Original : July --------> Stemmed : juli
# Original : 2015Coordinates --------> Stemmed : 2015coordin
# Original : on --------> Stemmed : on
# Original : WikidataArticles --------> Stemmed : wikidataarticl
# Original : containing --------> Stemmed : contain
# Original : Sanskrit-language --------> Stemmed : sanskrit-languag
# Original : textWikipedia --------> Stemmed : textwikipedia
# Original : articles --------> Stemmed : articl
# Original : containing --------> Stemmed : contain
# Original : buzzwords --------> Stemmed : buzzword
# Original : from --------> Stemmed : from
# Original : April --------> Stemmed : april
# Original : 2025 --------> Stemmed : 2025
# Original : This --------> Stemmed : thi
# Original : page --------> Stemmed : page
# Original : was --------> Stemmed : wa
# Original : last --------> Stemmed : last
# Original : edited --------> Stemmed : edit
# Original : on --------> Stemmed : on
# Original : 14 --------> Stemmed : 14
# Original : April --------> Stemmed : april
# Original : 2025 --------> Stemmed : 2025
# Original : , --------> Stemmed : ,
# Original : at --------> Stemmed : at
# Original : 14:34 --------> Stemmed : 14:34
# Original : ( --------> Stemmed : (
# Original : UTC --------> Stemmed : utc
# Original : ) --------> Stemmed : )
# Original : . --------> Stemmed : .
# Original : Text --------> Stemmed : text
# Original : is --------> Stemmed : is
# Original : available --------> Stemmed : avail
# Original : under --------> Stemmed : under
# Original : the --------> Stemmed : the
# Original : Creative --------> Stemmed : creativ
# Original : Commons --------> Stemmed : common
# Original : Attribution-ShareAlike --------> Stemmed : attribution-sharealik
# Original : 4.0 --------> Stemmed : 4.0
# Original : License --------> Stemmed : licens
# Original : ; --------> Stemmed : ;
# Original : additional --------> Stemmed : addit
# Original : terms --------> Stemmed : term
# Original : may --------> Stemmed : may
# Original : apply --------> Stemmed : appli
# Original : . --------> Stemmed : .
# Original : By --------> Stemmed : by
# Original : using --------> Stemmed : use
# Original : this --------> Stemmed : thi
# Original : site --------> Stemmed : site
# Original : , --------> Stemmed : ,
# Original : you --------> Stemmed : you
# Original : agree --------> Stemmed : agre
# Original : to --------> Stemmed : to
# Original : the --------> Stemmed : the
# Original : Terms --------> Stemmed : term
# Original : of --------> Stemmed : of
# Original : Use --------> Stemmed : use
# Original : and --------> Stemmed : and
# Original : Privacy --------> Stemmed : privaci
# Original : Policy --------> Stemmed : polici
# Original : . --------> Stemmed : .
# Original : Wikipedia® --------> Stemmed : wikipedia®
# Original : is --------> Stemmed : is
# Original : a --------> Stemmed : a
# Original : registered --------> Stemmed : regist
# Original : trademark --------> Stemmed : trademark
# Original : of --------> Stemmed : of
# Original : the --------> Stemmed : the
# Original : Wikimedia --------> Stemmed : wikimedia
# Original : Foundation --------> Stemmed : foundat
# Original : , --------> Stemmed : ,
# Original : Inc. --------> Stemmed : inc.
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : non-profit --------> Stemmed : non-profit
# Original : organization --------> Stemmed : organ
# Original : . --------> Stemmed : .
# Original : Privacy --------> Stemmed : privaci
# Original : policy --------> Stemmed : polici
# Original : About --------> Stemmed : about
# Original : Wikipedia --------> Stemmed : wikipedia
# Original : Disclaimers --------> Stemmed : disclaim
# Original : Contact --------> Stemmed : contact
# Original : Wikipedia --------> Stemmed : wikipedia
# Original : Code --------> Stemmed : code
# Original : of --------> Stemmed : of
# Original : Conduct --------> Stemmed : conduct
# Original : Developers --------> Stemmed : develop
# Original : Statistics --------> Stemmed : statist
# Original : Cookie --------> Stemmed : cooki
# Original : statement --------> Stemmed : statement
# Original : Mobile --------> Stemmed : mobil
# Original : view --------> Stemmed : view
# Original : Search --------> Stemmed : search
# Original : Search --------> Stemmed : search
# Original : Toggle --------> Stemmed : toggl
# Original : the --------> Stemmed : the
# Original : table --------> Stemmed : tabl
# Original : of --------> Stemmed : of
# Original : contents --------> Stemmed : content
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : 6 --------> Stemmed : 6
# Original : languages --------> Stemmed : languag
# Original : Add --------> Stemmed : add
# Original : topic --------> Stemmed : topic
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Snowball Stemmer

from nltk.stem import SnowballStemmer

snowball_stemmer = SnowballStemmer(language='english')

with open('cdac_article.txt', encoding='utf-8') as f:
    text = f.read()

words = word_tokenize(text)

for word in words:

    print(f"Original : {word} --------> Stemmed : {snowball_stemmer.stem(word)}")
# Out:
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : - --------> Stemmed : -
# Original : Wikipedia --------> Stemmed : wikipedia
# Original : Jump --------> Stemmed : jump
# Original : to --------> Stemmed : to
# Original : content --------> Stemmed : content
# Original : Main --------> Stemmed : main
# Original : menu --------> Stemmed : menu
# Original : Main --------> Stemmed : main
# Original : menu --------> Stemmed : menu
# Original : move --------> Stemmed : move
# Original : to --------> Stemmed : to
# Original : sidebar --------> Stemmed : sidebar
# Original : hide --------> Stemmed : hide
# Original : Navigation --------> Stemmed : navig
# Original : Main --------> Stemmed : main
# Original : pageContentsCurrent --------> Stemmed : pagecontentscurr
# Original : eventsRandom --------> Stemmed : eventsrandom
# Original : articleAbout --------> Stemmed : articleabout
# Original : WikipediaContact --------> Stemmed : wikipediacontact
# Original : us --------> Stemmed : us
# Original : Contribute --------> Stemmed : contribut
# Original : HelpLearn --------> Stemmed : helplearn
# Original : to --------> Stemmed : to
# Original : editCommunity --------> Stemmed : editcommun
# Original : portalRecent --------> Stemmed : portalrec
# Original : changesUpload --------> Stemmed : changesupload
# Original : fileSpecial --------> Stemmed : filespeci
# Original : pages --------> Stemmed : page
# Original : Search --------> Stemmed : search
# Original : Search --------> Stemmed : search
# Original : Appearance --------> Stemmed : appear
# Original : Donate --------> Stemmed : donat
# Original : Create --------> Stemmed : creat
# Original : account --------> Stemmed : account
# Original : Log --------> Stemmed : log
# Original : in --------> Stemmed : in
# Original : Personal --------> Stemmed : person
# Original : tools --------> Stemmed : tool
# Original : Donate --------> Stemmed : donat
# Original : Create --------> Stemmed : creat
# Original : account --------> Stemmed : account
# Original : Log --------> Stemmed : log
# Original : in --------> Stemmed : in
# Original : Pages --------> Stemmed : page
# Original : for --------> Stemmed : for
# Original : logged --------> Stemmed : log
# Original : out --------> Stemmed : out
# Original : editors --------> Stemmed : editor
# Original : learn --------> Stemmed : learn
# Original : more --------> Stemmed : more
# Original : ContributionsTalk --------> Stemmed : contributionstalk
# Original : Contents --------> Stemmed : content
# Original : move --------> Stemmed : move
# Original : to --------> Stemmed : to
# Original : sidebar --------> Stemmed : sidebar
# Original : hide --------> Stemmed : hide
# Original : ( --------> Stemmed : (
# Original : Top --------> Stemmed : top
# Original : ) --------> Stemmed : )
# Original : 1 --------> Stemmed : 1
# Original : History --------> Stemmed : histori
# Original : 2 --------> Stemmed : 2
# Original : Research --------> Stemmed : research
# Original : activities --------> Stemmed : activ
# Original : 3 --------> Stemmed : 3
# Original : Centres --------> Stemmed : centr
# Original : 4 --------> Stemmed : 4
# Original : Education --------> Stemmed : educ
# Original : and --------> Stemmed : and
# Original : training --------> Stemmed : train
# Original : 5 --------> Stemmed : 5
# Original : Commercialization --------> Stemmed : commerci
# Original : 6 --------> Stemmed : 6
# Original : Products --------> Stemmed : product
# Original : and --------> Stemmed : and
# Original : developments --------> Stemmed : develop
# Original : 7 --------> Stemmed : 7
# Original : Notable --------> Stemmed : notabl
# Original : researchers --------> Stemmed : research
# Original : and --------> Stemmed : and
# Original : alumnus --------> Stemmed : alumnus
# Original : 8 --------> Stemmed : 8
# Original : Notable --------> Stemmed : notabl
# Original : awards --------> Stemmed : award
# Original : and --------> Stemmed : and
# Original : accolades --------> Stemmed : accolad
# Original : 9 --------> Stemmed : 9
# Original : Other --------> Stemmed : other
# Original : projects --------> Stemmed : project
# Original : 10 --------> Stemmed : 10
# Original : See --------> Stemmed : see
# Original : also --------> Stemmed : also
# Original : 11 --------> Stemmed : 11
# Original : References --------> Stemmed : refer
# Original : Toggle --------> Stemmed : toggl
# Original : the --------> Stemmed : the
# Original : table --------> Stemmed : tabl
# Original : of --------> Stemmed : of
# Original : contents --------> Stemmed : content
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : 6 --------> Stemmed : 6
# Original : languages --------> Stemmed : languag
# Original : हिन्दीമലയാളംमराठीРусскийதமிழ்Українська --------> Stemmed : हिन्दीമലയാളംमराठीрусскийதமிழ்українська
# Original : Edit --------> Stemmed : edit
# Original : links --------> Stemmed : link
# Original : ArticleTalk --------> Stemmed : articletalk
# Original : English --------> Stemmed : english
# Original : ReadEditView --------> Stemmed : readeditview
# Original : history --------> Stemmed : histori
# Original : Tools --------> Stemmed : tool
# Original : Tools --------> Stemmed : tool
# Original : move --------> Stemmed : move
# Original : to --------> Stemmed : to
# Original : sidebar --------> Stemmed : sidebar
# Original : hide --------> Stemmed : hide
# Original : Actions --------> Stemmed : action
# Original : ReadEditView --------> Stemmed : readeditview
# Original : history --------> Stemmed : histori
# Original : General --------> Stemmed : general
# Original : What --------> Stemmed : what
# Original : links --------> Stemmed : link
# Original : hereRelated --------> Stemmed : hererel
# Original : changesUpload --------> Stemmed : changesupload
# Original : filePermanent --------> Stemmed : fileperman
# Original : linkPage --------> Stemmed : linkpag
# Original : informationCite --------> Stemmed : informationcit
# Original : this --------> Stemmed : this
# Original : pageGet --------> Stemmed : pageget
# Original : shortened --------> Stemmed : shorten
# Original : URLDownload --------> Stemmed : urldownload
# Original : QR --------> Stemmed : qr
# Original : code --------> Stemmed : code
# Original : Print/export --------> Stemmed : print/export
# Original : Download --------> Stemmed : download
# Original : as --------> Stemmed : as
# Original : PDFPrintable --------> Stemmed : pdfprintabl
# Original : version --------> Stemmed : version
# Original : In --------> Stemmed : in
# Original : other --------> Stemmed : other
# Original : projects --------> Stemmed : project
# Original : Wikidata --------> Stemmed : wikidata
# Original : item --------> Stemmed : item
# Original : Appearance --------> Stemmed : appear
# Original : move --------> Stemmed : move
# Original : to --------> Stemmed : to
# Original : sidebar --------> Stemmed : sidebar
# Original : hide --------> Stemmed : hide
# Original : Coordinates --------> Stemmed : coordin
# Original : : --------> Stemmed : :
# Original : 18°33′06″N --------> Stemmed : 18°33′06″n
# Original : 73°49′26″E﻿ --------> Stemmed : 73°49′26″e﻿
# Original : / --------> Stemmed : /
# Original : ﻿18.551747°N --------> Stemmed : ﻿18.551747°n
# Original : 73.823750°E﻿ --------> Stemmed : 73.823750°e﻿
# Original : / --------> Stemmed : /
# Original : 18.551747 --------> Stemmed : 18.551747
# Original : ; --------> Stemmed : ;
# Original : 73.823750 --------> Stemmed : 73.823750
# Original : From --------> Stemmed : from
# Original : Wikipedia --------> Stemmed : wikipedia
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : free --------> Stemmed : free
# Original : encyclopedia --------> Stemmed : encyclopedia
# Original : Autonomous --------> Stemmed : autonom
# Original : scientific --------> Stemmed : scientif
# Original : society --------> Stemmed : societi
# Original : 18°33′06″N --------> Stemmed : 18°33′06″n
# Original : 73°49′26″E﻿ --------> Stemmed : 73°49′26″e﻿
# Original : / --------> Stemmed : /
# Original : ﻿18.551747°N --------> Stemmed : ﻿18.551747°n
# Original : 73.823750°E﻿ --------> Stemmed : 73.823750°e﻿
# Original : / --------> Stemmed : /
# Original : 18.551747 --------> Stemmed : 18.551747
# Original : ; --------> Stemmed : ;
# Original : 73.823750 --------> Stemmed : 73.823750
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : ComputingMottoज्ञानादेव --------> Stemmed : computingmottoज्ञानादेव
# Original : तु --------> Stemmed : तु
# Original : कैवल्यम् --------> Stemmed : कैवल्यम्
# Original : ( --------> Stemmed : (
# Original : Sanskrit --------> Stemmed : sanskrit
# Original : ) --------> Stemmed : )
# Original : Only --------> Stemmed : onli
# Original : through --------> Stemmed : through
# Original : knowledge --------> Stemmed : knowledg
# Original : one --------> Stemmed : one
# Original : attains --------> Stemmed : attain
# Original : liberation --------> Stemmed : liber
# Original : ( --------> Stemmed : (
# Original : English --------> Stemmed : english
# Original : translated --------> Stemmed : translat
# Original : ) --------> Stemmed : )
# Original : Established1988 --------> Stemmed : established1988
# Original : ; --------> Stemmed : ;
# Original : 37 --------> Stemmed : 37
# Original : years --------> Stemmed : year
# Original : ago --------> Stemmed : ago
# Original : ( --------> Stemmed : (
# Original : 1988 --------> Stemmed : 1988
# Original : ) --------> Stemmed : )
# Original : Field --------> Stemmed : field
# Original : of --------> Stemmed : of
# Original : researchHigh --------> Stemmed : researchhigh
# Original : Performance --------> Stemmed : perform
# Original : Computing --------> Stemmed : comput
# Original : , --------> Stemmed : ,
# Original : Multi-lingual --------> Stemmed : multi-lingu
# Original : Computing --------> Stemmed : comput
# Original : and --------> Stemmed : and
# Original : Heritage --------> Stemmed : heritag
# Original : Computing --------> Stemmed : comput
# Original : , --------> Stemmed : ,
# Original : Professional --------> Stemmed : profession
# Original : Electronics --------> Stemmed : electron
# Original : , --------> Stemmed : ,
# Original : Software --------> Stemmed : softwar
# Original : Technologies --------> Stemmed : technolog
# Original : , --------> Stemmed : ,
# Original : Cyber --------> Stemmed : cyber
# Original : Security --------> Stemmed : secur
# Original : , --------> Stemmed : ,
# Original : Blockchain --------> Stemmed : blockchain
# Original : , --------> Stemmed : ,
# Original : Data --------> Stemmed : data
# Original : Science --------> Stemmed : scienc
# Original : , --------> Stemmed : ,
# Original : Health --------> Stemmed : health
# Original : InformaticsDirectorMagesh --------> Stemmed : informaticsdirectormagesh
# Original : Ethirajan --------> Stemmed : ethirajan
# Original : [ --------> Stemmed : [
# Original : 1 --------> Stemmed : 1
# Original : ] --------> Stemmed : ]
# Original : ( --------> Stemmed : (
# Original : Director --------> Stemmed : director
# Original : General --------> Stemmed : general
# Original : ) --------> Stemmed : )
# Original : AddressC-DAC --------> Stemmed : addressc-dac
# Original : Innovation --------> Stemmed : innov
# Original : Park --------> Stemmed : park
# Original : , --------> Stemmed : ,
# Original : Panchavati --------> Stemmed : panchavati
# Original : , --------> Stemmed : ,
# Original : Pashan --------> Stemmed : pashan
# Original : , --------> Stemmed : ,
# Original : Pune --------> Stemmed : pune
# Original : - --------> Stemmed : -
# Original : 411 --------> Stemmed : 411
# Original : 008 --------> Stemmed : 008
# Original : , --------> Stemmed : ,
# Original : Maharashtra --------> Stemmed : maharashtra
# Original : , --------> Stemmed : ,
# Original : IndiaLocationPune --------> Stemmed : indialocationpun
# Original : , --------> Stemmed : ,
# Original : India --------> Stemmed : india
# Original : ( --------> Stemmed : (
# Original : headquarters --------> Stemmed : headquart
# Original : ) --------> Stemmed : )
# Original : NicknameC-DACOperating --------> Stemmed : nicknamec-dacoper
# Original : agencyMinistry --------> Stemmed : agencyministri
# Original : of --------> Stemmed : of
# Original : Electronics --------> Stemmed : electron
# Original : and --------> Stemmed : and
# Original : Information --------> Stemmed : inform
# Original : Technology --------> Stemmed : technolog
# Original : , --------> Stemmed : ,
# Original : Government --------> Stemmed : govern
# Original : of --------> Stemmed : of
# Original : IndiaWebsitewww.cdac.in --------> Stemmed : indiawebsitewww.cdac.in
# Original : The --------> Stemmed : the
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : ( --------> Stemmed : (
# Original : C-DAC --------> Stemmed : c-dac
# Original : ) --------> Stemmed : )
# Original : is --------> Stemmed : is
# Original : an --------> Stemmed : an
# Original : Indian --------> Stemmed : indian
# Original : autonomous --------> Stemmed : autonom
# Original : scientific --------> Stemmed : scientif
# Original : society --------> Stemmed : societi
# Original : , --------> Stemmed : ,
# Original : operating --------> Stemmed : oper
# Original : under --------> Stemmed : under
# Original : the --------> Stemmed : the
# Original : Ministry --------> Stemmed : ministri
# Original : of --------> Stemmed : of
# Original : Electronics --------> Stemmed : electron
# Original : and --------> Stemmed : and
# Original : Information --------> Stemmed : inform
# Original : Technology --------> Stemmed : technolog
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 2 --------> Stemmed : 2
# Original : ] --------> Stemmed : ]
# Original : History --------> Stemmed : histori
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : Further --------> Stemmed : further
# Original : information --------> Stemmed : inform
# Original : : --------> Stemmed : :
# Original : Supercomputing --------> Stemmed : supercomput
# Original : in --------> Stemmed : in
# Original : India --------> Stemmed : india
# Original : and --------> Stemmed : and
# Original : PARAM --------> Stemmed : param
# Original : C-DAC --------> Stemmed : c-dac
# Original : was --------> Stemmed : was
# Original : created --------> Stemmed : creat
# Original : in --------> Stemmed : in
# Original : November --------> Stemmed : novemb
# Original : 1987 --------> Stemmed : 1987
# Original : , --------> Stemmed : ,
# Original : [ --------> Stemmed : [
# Original : 3 --------> Stemmed : 3
# Original : ] --------> Stemmed : ]
# Original : initially --------> Stemmed : initi
# Original : as --------> Stemmed : as
# Original : the --------> Stemmed : the
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : C-DACT --------> Stemmed : c-dact
# Original : ) --------> Stemmed : )
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 4 --------> Stemmed : 4
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 3 --------> Stemmed : 3
# Original : ] --------> Stemmed : ]
# Original : In --------> Stemmed : in
# Original : 1988 --------> Stemmed : 1988
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : US --------> Stemmed : us
# Original : Government --------> Stemmed : govern
# Original : refused --------> Stemmed : refus
# Original : to --------> Stemmed : to
# Original : sell --------> Stemmed : sell
# Original : India --------> Stemmed : india
# Original : a --------> Stemmed : a
# Original : Cray --------> Stemmed : cray
# Original : supercomputer --------> Stemmed : supercomput
# Original : due --------> Stemmed : due
# Original : to --------> Stemmed : to
# Original : concerns --------> Stemmed : concern
# Original : about --------> Stemmed : about
# Original : India --------> Stemmed : india
# Original : using --------> Stemmed : use
# Original : it --------> Stemmed : it
# Original : to --------> Stemmed : to
# Original : develop --------> Stemmed : develop
# Original : nuclear --------> Stemmed : nuclear
# Original : weapons --------> Stemmed : weapon
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 5 --------> Stemmed : 5
# Original : ] --------> Stemmed : ]
# Original : In --------> Stemmed : in
# Original : response --------> Stemmed : respons
# Original : India --------> Stemmed : india
# Original : started --------> Stemmed : start
# Original : development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : its --------> Stemmed : it
# Original : own --------> Stemmed : own
# Original : supercomputer --------> Stemmed : supercomput
# Original : , --------> Stemmed : ,
# Original : and --------> Stemmed : and
# Original : C-DACT --------> Stemmed : c-dact
# Original : was --------> Stemmed : was
# Original : created --------> Stemmed : creat
# Original : as --------> Stemmed : as
# Original : part --------> Stemmed : part
# Original : of --------> Stemmed : of
# Original : this --------> Stemmed : this
# Original : programme --------> Stemmed : programm
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 6 --------> Stemmed : 6
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 7 --------> Stemmed : 7
# Original : ] --------> Stemmed : ]
# Original : Dr --------> Stemmed : dr
# Original : Vijay --------> Stemmed : vijay
# Original : Bhatkar --------> Stemmed : bhatkar
# Original : was --------> Stemmed : was
# Original : hired --------> Stemmed : hire
# Original : as --------> Stemmed : as
# Original : the --------> Stemmed : the
# Original : director --------> Stemmed : director
# Original : of --------> Stemmed : of
# Original : C-DACT --------> Stemmed : c-dact
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 7 --------> Stemmed : 7
# Original : ] --------> Stemmed : ]
# Original : The --------> Stemmed : the
# Original : project --------> Stemmed : project
# Original : was --------> Stemmed : was
# Original : given --------> Stemmed : given
# Original : an --------> Stemmed : an
# Original : initial --------> Stemmed : initi
# Original : run --------> Stemmed : run
# Original : of --------> Stemmed : of
# Original : three --------> Stemmed : three
# Original : years --------> Stemmed : year
# Original : and --------> Stemmed : and
# Original : an --------> Stemmed : an
# Original : initial --------> Stemmed : initi
# Original : funding --------> Stemmed : fund
# Original : of --------> Stemmed : of
# Original : ₹30,00,00,000 --------> Stemmed : ₹30,00,00,000
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : cost --------> Stemmed : cost
# Original : of --------> Stemmed : of
# Original : a --------> Stemmed : a
# Original : Cray --------> Stemmed : cray
# Original : supercomputer --------> Stemmed : supercomput
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 7 --------> Stemmed : 7
# Original : ] --------> Stemmed : ]
# Original : A --------> Stemmed : a
# Original : prototype --------> Stemmed : prototyp
# Original : computer --------> Stemmed : comput
# Original : was --------> Stemmed : was
# Original : benchmarked --------> Stemmed : benchmark
# Original : at --------> Stemmed : at
# Original : the --------> Stemmed : the
# Original : 1990 --------> Stemmed : 1990
# Original : Zurich --------> Stemmed : zurich
# Original : Super-computing --------> Stemmed : super-comput
# Original : Show --------> Stemmed : show
# Original : . --------> Stemmed : .
# Original : It --------> Stemmed : it
# Original : demonstrated --------> Stemmed : demonstr
# Original : that --------> Stemmed : that
# Original : India --------> Stemmed : india
# Original : had --------> Stemmed : had
# Original : the --------> Stemmed : the
# Original : second --------> Stemmed : second
# Original : most --------> Stemmed : most
# Original : powerful --------> Stemmed : power
# Original : , --------> Stemmed : ,
# Original : publicly --------> Stemmed : public
# Original : demonstrated --------> Stemmed : demonstr
# Original : , --------> Stemmed : ,
# Original : supercomputer --------> Stemmed : supercomput
# Original : in --------> Stemmed : in
# Original : the --------> Stemmed : the
# Original : world --------> Stemmed : world
# Original : after --------> Stemmed : after
# Original : the --------> Stemmed : the
# Original : United --------> Stemmed : unit
# Original : States --------> Stemmed : state
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 7 --------> Stemmed : 7
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 8 --------> Stemmed : 8
# Original : ] --------> Stemmed : ]
# Original : The --------> Stemmed : the
# Original : final --------> Stemmed : final
# Original : result --------> Stemmed : result
# Original : of --------> Stemmed : of
# Original : the --------> Stemmed : the
# Original : effort --------> Stemmed : effort
# Original : was --------> Stemmed : was
# Original : the --------> Stemmed : the
# Original : PARAM --------> Stemmed : param
# Original : 8000 --------> Stemmed : 8000
# Original : , --------> Stemmed : ,
# Original : released --------> Stemmed : releas
# Original : in --------> Stemmed : in
# Original : 1991 --------> Stemmed : 1991
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 9 --------> Stemmed : 9
# Original : ] --------> Stemmed : ]
# Original : The --------> Stemmed : the
# Original : National --------> Stemmed : nation
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Software --------> Stemmed : softwar
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : NCST --------> Stemmed : ncst
# Original : ) --------> Stemmed : )
# Original : , --------> Stemmed : ,
# Original : Electronic --------> Stemmed : electron
# Original : Research --------> Stemmed : research
# Original : and --------> Stemmed : and
# Original : Development --------> Stemmed : develop
# Original : Centre --------> Stemmed : centr
# Original : ( --------> Stemmed : (
# Original : ER --------> Stemmed : er
# Original : & --------> Stemmed : &
# Original : DC --------> Stemmed : dc
# Original : ) --------> Stemmed : )
# Original : and --------> Stemmed : and
# Original : CEDTI --------> Stemmed : cedti
# Original : were --------> Stemmed : were
# Original : merged --------> Stemmed : merg
# Original : into --------> Stemmed : into
# Original : C-DAC --------> Stemmed : c-dac
# Original : in --------> Stemmed : in
# Original : 2003 --------> Stemmed : 2003
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 10 --------> Stemmed : 10
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 11 --------> Stemmed : 11
# Original : ] --------> Stemmed : ]
# Original : Research --------> Stemmed : research
# Original : activities --------> Stemmed : activ
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : Originally --------> Stemmed : origin
# Original : established --------> Stemmed : establish
# Original : to --------> Stemmed : to
# Original : research --------> Stemmed : research
# Original : and --------> Stemmed : and
# Original : assemble --------> Stemmed : assembl
# Original : High --------> Stemmed : high
# Original : Performance --------> Stemmed : perform
# Original : Computers --------> Stemmed : comput
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : research --------> Stemmed : research
# Original : of --------> Stemmed : of
# Original : C-DAC --------> Stemmed : c-dac
# Original : now --------> Stemmed : now
# Original : includes --------> Stemmed : includ
# Original : : --------> Stemmed : :
# Original : High --------> Stemmed : high
# Original : Performance --------> Stemmed : perform
# Original : Computing --------> Stemmed : comput
# Original : Grid --------> Stemmed : grid
# Original : Computing --------> Stemmed : comput
# Original : Cloud --------> Stemmed : cloud
# Original : Computing --------> Stemmed : comput
# Original : Multilingual --------> Stemmed : multilingu
# Original : and --------> Stemmed : and
# Original : Heritage --------> Stemmed : heritag
# Original : Computing --------> Stemmed : comput
# Original : VLSI --------> Stemmed : vlsi
# Original : and --------> Stemmed : and
# Original : Processor --------> Stemmed : processor
# Original : design --------> Stemmed : design
# Original : Embedded --------> Stemmed : embed
# Original : Systems --------> Stemmed : system
# Original : Speech --------> Stemmed : speech
# Original : and --------> Stemmed : and
# Original : Natural --------> Stemmed : natur
# Original : Language --------> Stemmed : languag
# Original : Processing --------> Stemmed : process
# Original : Information --------> Stemmed : inform
# Original : and --------> Stemmed : and
# Original : Cyber --------> Stemmed : cyber
# Original : Security --------> Stemmed : secur
# Original : Ubiquitous --------> Stemmed : ubiquit
# Original : Computing --------> Stemmed : comput
# Original : Bioinformatics --------> Stemmed : bioinformat
# Original : Geomatics --------> Stemmed : geomat
# Original : Digital --------> Stemmed : digit
# Original : forensics --------> Stemmed : forens
# Original : Big --------> Stemmed : big
# Original : data --------> Stemmed : data
# Original : analytics --------> Stemmed : analyt
# Original : Blockchain --------> Stemmed : blockchain
# Original : Health --------> Stemmed : health
# Original : Informatics --------> Stemmed : informat
# Original : Quantum --------> Stemmed : quantum
# Original : computing --------> Stemmed : comput
# Original : Centres --------> Stemmed : centr
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : C-DAC --------> Stemmed : c-dac
# Original : branches --------> Stemmed : branch
# Original : and --------> Stemmed : and
# Original : training --------> Stemmed : train
# Original : centres --------> Stemmed : centr
# Original : include --------> Stemmed : includ
# Original : : --------> Stemmed : :
# Original : [ --------> Stemmed : [
# Original : 12 --------> Stemmed : 12
# Original : ] --------> Stemmed : ]
# Original : C-DAC --------> Stemmed : c-dac
# Original : Pune --------> Stemmed : pune
# Original : ( --------> Stemmed : (
# Original : Headquarters --------> Stemmed : headquart
# Original : ) --------> Stemmed : )
# Original : C-DAC --------> Stemmed : c-dac
# Original : Mumbai --------> Stemmed : mumbai
# Original : C-DAC --------> Stemmed : c-dac
# Original : Bangalore --------> Stemmed : bangalor
# Original : C-DAC --------> Stemmed : c-dac
# Original : Chennai --------> Stemmed : chennai
# Original : C-DAC --------> Stemmed : c-dac
# Original : Delhi --------> Stemmed : delhi
# Original : C-DAC --------> Stemmed : c-dac
# Original : Kolkata --------> Stemmed : kolkata
# Original : C-DAC --------> Stemmed : c-dac
# Original : Patna --------> Stemmed : patna
# Original : C-DAC --------> Stemmed : c-dac
# Original : Mohali --------> Stemmed : mohali
# Original : C-DAC --------> Stemmed : c-dac
# Original : Noida --------> Stemmed : noida
# Original : C-DAC --------> Stemmed : c-dac
# Original : Hyderabad --------> Stemmed : hyderabad
# Original : C-DAC --------> Stemmed : c-dac
# Original : Thiruvananthapuram --------> Stemmed : thiruvananthapuram
# Original : C-DAC --------> Stemmed : c-dac
# Original : Silchar --------> Stemmed : silchar
# Original : Education --------> Stemmed : educ
# Original : and --------> Stemmed : and
# Original : training --------> Stemmed : train
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : C-DAC --------> Stemmed : c-dac
# Original : provides --------> Stemmed : provid
# Original : several --------> Stemmed : sever
# Original : courses --------> Stemmed : cours
# Original : in --------> Stemmed : in
# Original : the --------> Stemmed : the
# Original : field --------> Stemmed : field
# Original : of --------> Stemmed : of
# Original : advanced --------> Stemmed : advanc
# Original : computing --------> Stemmed : comput
# Original : and --------> Stemmed : and
# Original : software --------> Stemmed : softwar
# Original : development --------> Stemmed : develop
# Original : . --------> Stemmed : .
# Original : Among --------> Stemmed : among
# Original : these --------> Stemmed : these
# Original : are --------> Stemmed : are
# Original : the --------> Stemmed : the
# Original : HPC --------> Stemmed : hpc
# Original : certification --------> Stemmed : certif
# Original : course- --------> Stemmed : course-
# Original : C-DAC --------> Stemmed : c-dac
# Original : Certified --------> Stemmed : certifi
# Original : HPC --------> Stemmed : hpc
# Original : Professional --------> Stemmed : profession
# Original : Certification --------> Stemmed : certif
# Original : Programme --------> Stemmed : programm
# Original : ( --------> Stemmed : (
# Original : CCHPCP --------> Stemmed : cchpcp
# Original : ) --------> Stemmed : )
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 13 --------> Stemmed : 13
# Original : ] --------> Stemmed : ]
# Original : C-DAC --------> Stemmed : c-dac
# Original : organises --------> Stemmed : organis
# Original : advanced --------> Stemmed : advanc
# Original : computing --------> Stemmed : comput
# Original : diploma --------> Stemmed : diploma
# Original : programmes --------> Stemmed : programm
# Original : through --------> Stemmed : through
# Original : the --------> Stemmed : the
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : Training --------> Stemmed : train
# Original : School --------> Stemmed : school
# Original : ( --------> Stemmed : (
# Original : ACTS --------> Stemmed : act
# Original : ) --------> Stemmed : )
# Original : located --------> Stemmed : locat
# Original : all --------> Stemmed : all
# Original : over --------> Stemmed : over
# Original : India --------> Stemmed : india
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 14 --------> Stemmed : 14
# Original : ] --------> Stemmed : ]
# Original : The --------> Stemmed : the
# Original : PG --------> Stemmed : pg
# Original : Diploma --------> Stemmed : diploma
# Original : courses --------> Stemmed : cours
# Original : include --------> Stemmed : includ
# Original : Specialisations --------> Stemmed : specialis
# Original : in --------> Stemmed : in
# Original : Embedded --------> Stemmed : embed
# Original : System --------> Stemmed : system
# Original : Design --------> Stemmed : design
# Original : , --------> Stemmed : ,
# Original : VLSI --------> Stemmed : vlsi
# Original : , --------> Stemmed : ,
# Original : Big --------> Stemmed : big
# Original : Data --------> Stemmed : data
# Original : Analytics --------> Stemmed : analyt
# Original : , --------> Stemmed : ,
# Original : Geoinformatics --------> Stemmed : geoinformat
# Original : , --------> Stemmed : ,
# Original : Artificial --------> Stemmed : artifici
# Original : Intelligence --------> Stemmed : intellig
# Original : C-DAC --------> Stemmed : c-dac
# Original : has --------> Stemmed : has
# Original : also --------> Stemmed : also
# Original : established --------> Stemmed : establish
# Original : Centres --------> Stemmed : centr
# Original : of --------> Stemmed : of
# Original : Excellence --------> Stemmed : excel
# Original : in --------> Stemmed : in
# Original : Information --------> Stemmed : inform
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : CEIT --------> Stemmed : ceit
# Original : ) --------> Stemmed : )
# Original : abroad --------> Stemmed : abroad
# Original : under --------> Stemmed : under
# Original : the --------> Stemmed : the
# Original : Ministry --------> Stemmed : ministri
# Original : of --------> Stemmed : of
# Original : External --------> Stemmed : extern
# Original : Affairs --------> Stemmed : affair
# Original : ' --------> Stemmed : '
# Original : s --------> Stemmed : s
# Original : development --------> Stemmed : develop
# Original : partnership --------> Stemmed : partnership
# Original : projects --------> Stemmed : project
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 15 --------> Stemmed : 15
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 16 --------> Stemmed : 16
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 17 --------> Stemmed : 17
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 18 --------> Stemmed : 18
# Original : ] --------> Stemmed : ]
# Original : Commercialization --------> Stemmed : commerci
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : This --------> Stemmed : this
# Original : article --------> Stemmed : articl
# Original : appears --------> Stemmed : appear
# Original : to --------> Stemmed : to
# Original : contain --------> Stemmed : contain
# Original : a --------> Stemmed : a
# Original : large --------> Stemmed : larg
# Original : number --------> Stemmed : number
# Original : of --------> Stemmed : of
# Original : buzzwords --------> Stemmed : buzzword
# Original : . --------> Stemmed : .
# Original : There --------> Stemmed : there
# Original : might --------> Stemmed : might
# Original : be --------> Stemmed : be
# Original : a --------> Stemmed : a
# Original : discussion --------> Stemmed : discuss
# Original : about --------> Stemmed : about
# Original : this --------> Stemmed : this
# Original : on --------> Stemmed : on
# Original : the --------> Stemmed : the
# Original : talk --------> Stemmed : talk
# Original : page --------> Stemmed : page
# Original : . --------> Stemmed : .
# Original : Please --------> Stemmed : pleas
# Original : help --------> Stemmed : help
# Original : improve --------> Stemmed : improv
# Original : this --------> Stemmed : this
# Original : article --------> Stemmed : articl
# Original : if --------> Stemmed : if
# Original : you --------> Stemmed : you
# Original : can --------> Stemmed : can
# Original : . --------> Stemmed : .
# Original : ( --------> Stemmed : (
# Original : April --------> Stemmed : april
# Original : 2025 --------> Stemmed : 2025
# Original : ) --------> Stemmed : )
# Original : On --------> Stemmed : on
# Original : August --------> Stemmed : august
# Original : 28 --------> Stemmed : 28
# Original : , --------> Stemmed : ,
# Original : 2024 --------> Stemmed : 2024
# Original : , --------> Stemmed : ,
# Original : C-DAC --------> Stemmed : c-dac
# Original : and --------> Stemmed : and
# Original : L --------> Stemmed : l
# Original : & --------> Stemmed : &
# Original : T --------> Stemmed : t
# Original : Semiconductor --------> Stemmed : semiconductor
# Original : Technologies --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : LTSCT --------> Stemmed : ltsct
# Original : ) --------> Stemmed : )
# Original : signed --------> Stemmed : sign
# Original : a --------> Stemmed : a
# Original : Memorandum --------> Stemmed : memorandum
# Original : of --------> Stemmed : of
# Original : Understanding --------> Stemmed : understand
# Original : ( --------> Stemmed : (
# Original : MoU --------> Stemmed : mou
# Original : ) --------> Stemmed : )
# Original : . --------> Stemmed : .
# Original : It --------> Stemmed : it
# Original : will --------> Stemmed : will
# Original : establish --------> Stemmed : establish
# Original : a --------> Stemmed : a
# Original : program --------> Stemmed : program
# Original : for --------> Stemmed : for
# Original : the --------> Stemmed : the
# Original : commercialization --------> Stemmed : commerci
# Original : of --------> Stemmed : of
# Original : cutting-edge --------> Stemmed : cutting-edg
# Original : technologies --------> Stemmed : technolog
# Original : created --------> Stemmed : creat
# Original : by --------> Stemmed : by
# Original : C-DAC --------> Stemmed : c-dac
# Original : in --------> Stemmed : in
# Original : the --------> Stemmed : the
# Original : areas --------> Stemmed : area
# Original : of --------> Stemmed : of
# Original : power --------> Stemmed : power
# Original : systems --------> Stemmed : system
# Original : , --------> Stemmed : ,
# Original : embedded --------> Stemmed : embed
# Original : software --------> Stemmed : softwar
# Original : , --------> Stemmed : ,
# Original : open-source --------> Stemmed : open-sourc
# Original : operating --------> Stemmed : oper
# Original : systems --------> Stemmed : system
# Original : , --------> Stemmed : ,
# Original : high --------> Stemmed : high
# Original : performance --------> Stemmed : perform
# Original : computing --------> Stemmed : comput
# Original : , --------> Stemmed : ,
# Original : and --------> Stemmed : and
# Original : semiconductor --------> Stemmed : semiconductor
# Original : design --------> Stemmed : design
# Original : and --------> Stemmed : and
# Original : development --------> Stemmed : develop
# Original : . --------> Stemmed : .
# Original : LTSCT --------> Stemmed : ltsct
# Original : will --------> Stemmed : will
# Original : leverage --------> Stemmed : leverag
# Original : C-DAC --------> Stemmed : c-dac
# Original : 's --------> Stemmed : 's
# Original : extensive --------> Stemmed : extens
# Original : pipeline --------> Stemmed : pipelin
# Original : of --------> Stemmed : of
# Original : in-house --------> Stemmed : in-hous
# Original : intellectual --------> Stemmed : intellectu
# Original : property --------> Stemmed : properti
# Original : ( --------> Stemmed : (
# Original : IPs --------> Stemmed : ip
# Original : ) --------> Stemmed : )
# Original : , --------> Stemmed : ,
# Original : which --------> Stemmed : which
# Original : includes --------> Stemmed : includ
# Original : the --------> Stemmed : the
# Original : VEGA --------> Stemmed : vega
# Original : processor --------> Stemmed : processor
# Original : , --------> Stemmed : ,
# Original : to --------> Stemmed : to
# Original : create --------> Stemmed : creat
# Original : global --------> Stemmed : global
# Original : product --------> Stemmed : product
# Original : prospects --------> Stemmed : prospect
# Original : through --------> Stemmed : through
# Original : application --------> Stemmed : applic
# Original : design --------> Stemmed : design
# Original : and --------> Stemmed : and
# Original : validation --------> Stemmed : valid
# Original : for --------> Stemmed : for
# Original : Field --------> Stemmed : field
# Original : Programmable --------> Stemmed : programm
# Original : Gate --------> Stemmed : gate
# Original : Arrays --------> Stemmed : array
# Original : . --------> Stemmed : .
# Original : By --------> Stemmed : by
# Original : facilitating --------> Stemmed : facilit
# Original : the --------> Stemmed : the
# Original : creation --------> Stemmed : creation
# Original : of --------> Stemmed : of
# Original : cutting-edge --------> Stemmed : cutting-edg
# Original : goods --------> Stemmed : good
# Original : and --------> Stemmed : and
# Original : solutions --------> Stemmed : solut
# Original : for --------> Stemmed : for
# Original : the --------> Stemmed : the
# Original : automotive --------> Stemmed : automot
# Original : , --------> Stemmed : ,
# Original : industrial --------> Stemmed : industri
# Original : , --------> Stemmed : ,
# Original : information --------> Stemmed : inform
# Original : and --------> Stemmed : and
# Original : communications --------> Stemmed : communic
# Original : technology --------> Stemmed : technolog
# Original : infrastructure --------> Stemmed : infrastructur
# Original : , --------> Stemmed : ,
# Original : and --------> Stemmed : and
# Original : energy --------> Stemmed : energi
# Original : sectors --------> Stemmed : sector
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : collaboration --------> Stemmed : collabor
# Original : to --------> Stemmed : to
# Original : create --------> Stemmed : creat
# Original : indigenous --------> Stemmed : indigen
# Original : ICs --------> Stemmed : ic
# Original : and --------> Stemmed : and
# Original : SoCs --------> Stemmed : soc
# Original : based --------> Stemmed : base
# Original : in --------> Stemmed : in
# Original : Vega --------> Stemmed : vega
# Original : is --------> Stemmed : is
# Original : expected --------> Stemmed : expect
# Original : to --------> Stemmed : to
# Original : pick --------> Stemmed : pick
# Original : up --------> Stemmed : up
# Original : speed --------> Stemmed : speed
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 19 --------> Stemmed : 19
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 20 --------> Stemmed : 20
# Original : ] --------> Stemmed : ]
# Original : Products --------> Stemmed : product
# Original : and --------> Stemmed : and
# Original : developments --------> Stemmed : develop
# Original : [ --------> Stemmed : [
# Original : edit --------> Stemmed : edit
# Original : ] --------> Stemmed : ]
# Original : PARAM --------> Stemmed : param
# Original : series --------> Stemmed : seri
# Original : of --------> Stemmed : of
# Original : supercomputers --------> Stemmed : supercomput
# Original : [ --------> Stemmed : [
# Original : 21 --------> Stemmed : 21
# Original : ] --------> Stemmed : ]
# Original : VEGA --------> Stemmed : vega
# Original : Microprocessors --------> Stemmed : microprocessor
# Original : , --------> Stemmed : ,
# Original : India --------> Stemmed : india
# Original : 's --------> Stemmed : 's
# Original : first --------> Stemmed : first
# Original : indigenous --------> Stemmed : indigen
# Original : 64-bit --------> Stemmed : 64-bit
# Original : Multi-core --------> Stemmed : multi-cor
# Original : Superscalar --------> Stemmed : superscalar
# Original : Out-of-Order --------> Stemmed : out-of-ord
# Original : RISC-V --------> Stemmed : risc-v
# Original : Processor --------> Stemmed : processor
# Original : [ --------> Stemmed : [
# Original : 22 --------> Stemmed : 22
# Original : ] --------> Stemmed : ]
# Original : M-Kavach --------> Stemmed : m-kavach
# Original : 2 --------> Stemmed : 2
# Original : , --------> Stemmed : ,
# Original : an --------> Stemmed : an
# Original : android-based --------> Stemmed : android-bas
# Original : mobile --------> Stemmed : mobil
# Original : device --------> Stemmed : devic
# Original : security --------> Stemmed : secur
# Original : solution --------> Stemmed : solut
# Original : addressing --------> Stemmed : address
# Original : emerging --------> Stemmed : emerg
# Original : threats --------> Stemmed : threat
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 23 --------> Stemmed : 23
# Original : ] --------> Stemmed : ]
# Original : Mobile --------> Stemmed : mobil
# Original : Seva --------> Stemmed : seva
# Original : AppStore --------> Stemmed : appstor
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : mobile --------> Stemmed : mobil
# Original : app --------> Stemmed : app
# Original : marketplace --------> Stemmed : marketplac
# Original : [ --------> Stemmed : [
# Original : 24 --------> Stemmed : 24
# Original : ] --------> Stemmed : ]
# Original : Bharat --------> Stemmed : bharat
# Original : Operating --------> Stemmed : oper
# Original : System --------> Stemmed : system
# Original : Solutions --------> Stemmed : solut
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : Linux-based --------> Stemmed : linux-bas
# Original : general --------> Stemmed : general
# Original : purpose --------> Stemmed : purpos
# Original : operating --------> Stemmed : oper
# Original : system --------> Stemmed : system
# Original : [ --------> Stemmed : [
# Original : 25 --------> Stemmed : 25
# Original : ] --------> Stemmed : ]
# Original : Anvaya --------> Stemmed : anvaya
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : workflow --------> Stemmed : workflow
# Original : environment --------> Stemmed : environ
# Original : for --------> Stemmed : for
# Original : automated --------> Stemmed : autom
# Original : genome --------> Stemmed : genom
# Original : analysis --------> Stemmed : analysi
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 26 --------> Stemmed : 26
# Original : ] --------> Stemmed : ]
# Original : Namescape --------> Stemmed : namescap
# Original : , --------> Stemmed : ,
# Original : the --------> Stemmed : the
# Original : search --------> Stemmed : search
# Original : engine --------> Stemmed : engin
# Original : for --------> Stemmed : for
# Original : the --------> Stemmed : the
# Original : Aadhaar --------> Stemmed : aadhaar
# Original : unique-ID --------> Stemmed : unique-id
# Original : project --------> Stemmed : project
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 27 --------> Stemmed : 27
# Original : ] --------> Stemmed : ]
# Original : GARUDA --------> Stemmed : garuda
# Original : , --------> Stemmed : ,
# Original : India --------> Stemmed : india
# Original : 's --------> Stemmed : 's
# Original : National --------> Stemmed : nation
# Original : Grid --------> Stemmed : grid
# Original : Computing --------> Stemmed : comput
# Original : Initiative --------> Stemmed : initi
# Original : [ --------> Stemmed : [
# Original : 28 --------> Stemmed : 28
# Original : ] --------> Stemmed : ]
# Original : [ --------> Stemmed : [
# Original : 29 --------> Stemmed : 29
# Original : ] --------> Stemmed : ]
# Original : TaxoGrid --------> Stemmed : taxogrid
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : grid-based --------> Stemmed : grid-bas
# Original : molecular --------> Stemmed : molecular
# Original : phylogenetics --------> Stemmed : phylogenet
# Original : and --------> Stemmed : and
# Original : drug --------> Stemmed : drug
# Original : discovery --------> Stemmed : discoveri
# Original : system --------> Stemmed : system
# Original : [ --------> Stemmed : [
# Original : 30 --------> Stemmed : 30
# Original : ] --------> Stemmed : ]
# Original : GIST --------> Stemmed : gist
# Original : , --------> Stemmed : ,
# Original : Graphics --------> Stemmed : graphic
# Original : and --------> Stemmed : and
# Original : Intelligence --------> Stemmed : intellig
# Original : based --------> Stemmed : base
# Original : Script --------> Stemmed : script
# Original : Technology --------> Stemmed : technolog
# Original : [ --------> Stemmed : [
# Original : 31 --------> Stemmed : 31
# Original : ] --------> Stemmed : ]
# Original : DARPAN --------> Stemmed : darpan
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : real --------> Stemmed : real
# Original : time --------> Stemmed : time
# Original : network --------> Stemmed : network
# Original : monitoring --------> Stemmed : monitor
# Original : , --------> Stemmed : ,
# Original : visualization --------> Stemmed : visual
# Original : and --------> Stemmed : and
# Original : Service --------> Stemmed : servic
# Original : Level --------> Stemmed : level
# Original : Agreement --------> Stemmed : agreement
# Original : monitoring --------> Stemmed : monitor
# Original : tool --------> Stemmed : tool
# Original : . --------> Stemmed : .
# Original : [ --------> Stemmed : [
# Original : 32 --------> Stemmed : 32
# Original : ] --------> Stemmed : ]
# Original : OLabs --------> Stemmed : olab
# Original : , --------> Stemmed : ,
# Original : an --------> Stemmed : an
# Original : internet --------> Stemmed : internet
# Original : based --------> Stemmed : base
# Original : platform --------> Stemmed : platform
# Original : for --------> Stemmed : for
# Original : conduct --------> Stemmed : conduct
# Original : of --------> Stemmed : of
# Original : school --------> Stemmed : school
# ...
# Original : two --------> Stemmed : two
# Original : projects --------> Stemmed : project
# Original : '' --------> Stemmed : ''
# Original : . --------> Stemmed : .
# Original : The --------> Stemmed : the
# Original : Indian --------> Stemmed : indian
# Original : Express --------> Stemmed : express
# Original : . --------> Stemmed : .
# Original : 13 --------> Stemmed : 13
# Original : September --------> Stemmed : septemb
# Original : 2011. --------> Stemmed : 2011.
# Original : vte --------> Stemmed : vte
# Original : Ministry --------> Stemmed : ministri
# Original : of --------> Stemmed : of
# Original : Electronics --------> Stemmed : electron
# Original : and --------> Stemmed : and
# Original : Information --------> Stemmed : inform
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : India --------> Stemmed : india
# Original : ) --------> Stemmed : )
# Original : AgenciesNIC --------> Stemmed : agenciesn
# Original : Network --------> Stemmed : network
# Original : Data --------> Stemmed : data
# Original : Centers --------> Stemmed : center
# Original : DigiLocker --------> Stemmed : digilock
# Original : MyGov.in --------> Stemmed : mygov.in
# Original : National --------> Stemmed : nation
# Original : Portal --------> Stemmed : portal
# Original : of --------> Stemmed : of
# Original : India --------> Stemmed : india
# Original : IN --------> Stemmed : in
# Original : Registry --------> Stemmed : registri
# Original : .in --------> Stemmed : .in
# Original : .भारत --------> Stemmed : .भारत
# Original : Other --------> Stemmed : other
# Original : Standardisation --------> Stemmed : standardis
# Original : Testing --------> Stemmed : test
# Original : and --------> Stemmed : and
# Original : Quality --------> Stemmed : qualiti
# Original : Certification --------> Stemmed : certif
# Original : Directorate --------> Stemmed : director
# Original : ( --------> Stemmed : (
# Original : STQC --------> Stemmed : stqc
# Original : ) --------> Stemmed : )
# Original : Controller --------> Stemmed : control
# Original : of --------> Stemmed : of
# Original : Certifying --------> Stemmed : certifi
# Original : Authorities --------> Stemmed : author
# Original : ( --------> Stemmed : (
# Original : CCA --------> Stemmed : cca
# Original : ) --------> Stemmed : )
# Original : Cyber --------> Stemmed : cyber
# Original : Appellate --------> Stemmed : appel
# Original : Tribunal --------> Stemmed : tribun
# Original : ( --------> Stemmed : (
# Original : CAT --------> Stemmed : cat
# Original : ) --------> Stemmed : )
# Original : Indian --------> Stemmed : indian
# Original : Computer --------> Stemmed : comput
# Original : Emergency --------> Stemmed : emerg
# Original : Response --------> Stemmed : respons
# Original : Team --------> Stemmed : team
# Original : ( --------> Stemmed : (
# Original : ICERT --------> Stemmed : icert
# Original : ) --------> Stemmed : )
# Original : Companies --------> Stemmed : compani
# Original : CSC --------> Stemmed : csc
# Original : e-Governance --------> Stemmed : e-govern
# Original : Services --------> Stemmed : servic
# Original : India --------> Stemmed : india
# Original : Limited --------> Stemmed : limit
# Original : Media --------> Stemmed : media
# Original : Lab --------> Stemmed : lab
# Original : Asia --------> Stemmed : asia
# Original : ( --------> Stemmed : (
# Original : MLAsia --------> Stemmed : mlasia
# Original : ) --------> Stemmed : )
# Original : National --------> Stemmed : nation
# Original : Informatics --------> Stemmed : informat
# Original : Centre --------> Stemmed : centr
# Original : Services --------> Stemmed : servic
# Original : Incorporated --------> Stemmed : incorpor
# Original : ( --------> Stemmed : (
# Original : NICSI --------> Stemmed : nicsi
# Original : ) --------> Stemmed : )
# Original : — --------> Stemmed : —
# Original : PSE --------> Stemmed : pse
# Original : under --------> Stemmed : under
# Original : National --------> Stemmed : nation
# Original : Informatics --------> Stemmed : informat
# Original : Centre --------> Stemmed : centr
# Original : National --------> Stemmed : nation
# Original : Internet --------> Stemmed : internet
# Original : Exchange --------> Stemmed : exchang
# Original : of --------> Stemmed : of
# Original : India --------> Stemmed : india
# Original : ( --------> Stemmed : (
# Original : NIXI --------> Stemmed : nixi
# Original : ) --------> Stemmed : )
# Original : STPI --------> Stemmed : stpi
# Original : Unique --------> Stemmed : uniqu
# Original : Identification --------> Stemmed : identif
# Original : Authority --------> Stemmed : author
# Original : of --------> Stemmed : of
# Original : India --------> Stemmed : india
# Original : ( --------> Stemmed : (
# Original : UIDAI --------> Stemmed : uidai
# Original : ) --------> Stemmed : )
# Original : AutonomousSocieties --------> Stemmed : autonomoussocieti
# Original : Education --------> Stemmed : educ
# Original : and --------> Stemmed : and
# Original : Research --------> Stemmed : research
# Original : in --------> Stemmed : in
# Original : Computer --------> Stemmed : comput
# Original : Networking --------> Stemmed : network
# Original : ( --------> Stemmed : (
# Original : ERNET --------> Stemmed : ernet
# Original : ) --------> Stemmed : )
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : ( --------> Stemmed : (
# Original : C-DAC --------> Stemmed : c-dac
# Original : ) --------> Stemmed : )
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Materials --------> Stemmed : materi
# Original : for --------> Stemmed : for
# Original : Electronics --------> Stemmed : electron
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : C-MET --------> Stemmed : c-met
# Original : ) --------> Stemmed : )
# Original : National --------> Stemmed : nation
# Original : Institute --------> Stemmed : institut
# Original : of --------> Stemmed : of
# Original : Electronics --------> Stemmed : electron
# Original : and --------> Stemmed : and
# Original : Information --------> Stemmed : inform
# Original : Technology --------> Stemmed : technolog
# Original : ( --------> Stemmed : (
# Original : NIELIT --------> Stemmed : nielit
# Original : ) --------> Stemmed : )
# Original : — --------> Stemmed : —
# Original : Formerly --------> Stemmed : former
# Original : DOEACC --------> Stemmed : doeacc
# Original : Society --------> Stemmed : societi
# Original : Society --------> Stemmed : societi
# Original : for --------> Stemmed : for
# Original : Applied --------> Stemmed : appli
# Original : Microwave --------> Stemmed : microwav
# Original : Electronics --------> Stemmed : electron
# Original : Engineering --------> Stemmed : engin
# Original : and --------> Stemmed : and
# Original : Research --------> Stemmed : research
# Original : ( --------> Stemmed : (
# Original : SAMEER --------> Stemmed : sameer
# Original : ) --------> Stemmed : )
# Original : Software --------> Stemmed : softwar
# Original : Technology --------> Stemmed : technolog
# Original : Parks --------> Stemmed : park
# Original : of --------> Stemmed : of
# Original : India --------> Stemmed : india
# Original : ( --------> Stemmed : (
# Original : STPI --------> Stemmed : stpi
# Original : ) --------> Stemmed : )
# Original : Electronics --------> Stemmed : electron
# Original : and --------> Stemmed : and
# Original : Computer --------> Stemmed : comput
# Original : Software --------> Stemmed : softwar
# Original : Export --------> Stemmed : export
# Original : Promotion --------> Stemmed : promot
# Original : Council --------> Stemmed : council
# Original : ( --------> Stemmed : (
# Original : ESC --------> Stemmed : esc
# Original : ) --------> Stemmed : )
# Original : Semi-Conductor --------> Stemmed : semi-conductor
# Original : Laboratory --------> Stemmed : laboratori
# Original : ( --------> Stemmed : (
# Original : SCL --------> Stemmed : scl
# Original : ) --------> Stemmed : )
# Original : Ministers --------> Stemmed : minist
# Original : Ashwini --------> Stemmed : ashwini
# Original : Vaishnaw --------> Stemmed : vaishnaw
# Original : ( --------> Stemmed : (
# Original : incumbent --------> Stemmed : incumb
# Original : ) --------> Stemmed : )
# Original : Ministers --------> Stemmed : minist
# Original : of --------> Stemmed : of
# Original : State --------> Stemmed : state
# Original : Jitin --------> Stemmed : jitin
# Original : Prasada --------> Stemmed : prasada
# Original : ( --------> Stemmed : (
# Original : incumbent --------> Stemmed : incumb
# Original : ) --------> Stemmed : )
# Original : Authority --------> Stemmed : author
# Original : control --------> Stemmed : control
# Original : databases --------> Stemmed : databas
# Original : InternationalISNIVIAFNationalGermanyUnited --------> Stemmed : internationalisniviafnationalgermanyunit
# Original : StatesIsrael --------> Stemmed : statesisrael
# Original : Retrieved --------> Stemmed : retriev
# Original : from --------> Stemmed : from
# Original : `` --------> Stemmed : ``
# Original : https --------> Stemmed : https
# Original : : --------> Stemmed : :
# Original : //en.wikipedia.org/w/index.php --------> Stemmed : //en.wikipedia.org/w/index.php
# Original : ? --------> Stemmed : ?
# Original : title=Centre_for_Development_of_Advanced_Computing --------> Stemmed : title=centre_for_development_of_advanced_comput
# Original : & --------> Stemmed : &
# Original : oldid=1285579997 --------> Stemmed : oldid=1285579997
# Original : '' --------> Stemmed : ''
# Original : Categories --------> Stemmed : categori
# Original : : --------> Stemmed : :
# Original : Research --------> Stemmed : research
# Original : institutes --------> Stemmed : institut
# Original : in --------> Stemmed : in
# Original : PuneInformation --------> Stemmed : puneinform
# Original : technology --------> Stemmed : technolog
# Original : organisations --------> Stemmed : organis
# Original : based --------> Stemmed : base
# Original : in --------> Stemmed : in
# Original : India1988 --------> Stemmed : india1988
# Original : establishments --------> Stemmed : establish
# Original : in --------> Stemmed : in
# Original : MaharashtraResearch --------> Stemmed : maharashtraresearch
# Original : institutes --------> Stemmed : institut
# Original : established --------> Stemmed : establish
# Original : in --------> Stemmed : in
# Original : 1988Hidden --------> Stemmed : 1988hidden
# Original : categories --------> Stemmed : categori
# Original : : --------> Stemmed : :
# Original : Pages --------> Stemmed : page
# Original : using --------> Stemmed : use
# Original : gadget --------> Stemmed : gadget
# Original : WikiMiniAtlasArticles --------> Stemmed : wikiminiatlasarticl
# Original : with --------> Stemmed : with
# Original : short --------> Stemmed : short
# Original : descriptionShort --------> Stemmed : descriptionshort
# Original : description --------> Stemmed : descript
# Original : matches --------> Stemmed : match
# Original : WikidataEngvarB --------> Stemmed : wikidataengvarb
# Original : from --------> Stemmed : from
# Original : July --------> Stemmed : juli
# Original : 2015Use --------> Stemmed : 2015use
# Original : dmy --------> Stemmed : dmi
# Original : dates --------> Stemmed : date
# Original : from --------> Stemmed : from
# Original : July --------> Stemmed : juli
# Original : 2015Coordinates --------> Stemmed : 2015coordin
# Original : on --------> Stemmed : on
# Original : WikidataArticles --------> Stemmed : wikidataarticl
# Original : containing --------> Stemmed : contain
# Original : Sanskrit-language --------> Stemmed : sanskrit-languag
# Original : textWikipedia --------> Stemmed : textwikipedia
# Original : articles --------> Stemmed : articl
# Original : containing --------> Stemmed : contain
# Original : buzzwords --------> Stemmed : buzzword
# Original : from --------> Stemmed : from
# Original : April --------> Stemmed : april
# Original : 2025 --------> Stemmed : 2025
# Original : This --------> Stemmed : this
# Original : page --------> Stemmed : page
# Original : was --------> Stemmed : was
# Original : last --------> Stemmed : last
# Original : edited --------> Stemmed : edit
# Original : on --------> Stemmed : on
# Original : 14 --------> Stemmed : 14
# Original : April --------> Stemmed : april
# Original : 2025 --------> Stemmed : 2025
# Original : , --------> Stemmed : ,
# Original : at --------> Stemmed : at
# Original : 14:34 --------> Stemmed : 14:34
# Original : ( --------> Stemmed : (
# Original : UTC --------> Stemmed : utc
# Original : ) --------> Stemmed : )
# Original : . --------> Stemmed : .
# Original : Text --------> Stemmed : text
# Original : is --------> Stemmed : is
# Original : available --------> Stemmed : avail
# Original : under --------> Stemmed : under
# Original : the --------> Stemmed : the
# Original : Creative --------> Stemmed : creativ
# Original : Commons --------> Stemmed : common
# Original : Attribution-ShareAlike --------> Stemmed : attribution-sharealik
# Original : 4.0 --------> Stemmed : 4.0
# Original : License --------> Stemmed : licens
# Original : ; --------> Stemmed : ;
# Original : additional --------> Stemmed : addit
# Original : terms --------> Stemmed : term
# Original : may --------> Stemmed : may
# Original : apply --------> Stemmed : appli
# Original : . --------> Stemmed : .
# Original : By --------> Stemmed : by
# Original : using --------> Stemmed : use
# Original : this --------> Stemmed : this
# Original : site --------> Stemmed : site
# Original : , --------> Stemmed : ,
# Original : you --------> Stemmed : you
# Original : agree --------> Stemmed : agre
# Original : to --------> Stemmed : to
# Original : the --------> Stemmed : the
# Original : Terms --------> Stemmed : term
# Original : of --------> Stemmed : of
# Original : Use --------> Stemmed : use
# Original : and --------> Stemmed : and
# Original : Privacy --------> Stemmed : privaci
# Original : Policy --------> Stemmed : polici
# Original : . --------> Stemmed : .
# Original : Wikipedia® --------> Stemmed : wikipedia®
# Original : is --------> Stemmed : is
# Original : a --------> Stemmed : a
# Original : registered --------> Stemmed : regist
# Original : trademark --------> Stemmed : trademark
# Original : of --------> Stemmed : of
# Original : the --------> Stemmed : the
# Original : Wikimedia --------> Stemmed : wikimedia
# Original : Foundation --------> Stemmed : foundat
# Original : , --------> Stemmed : ,
# Original : Inc. --------> Stemmed : inc.
# Original : , --------> Stemmed : ,
# Original : a --------> Stemmed : a
# Original : non-profit --------> Stemmed : non-profit
# Original : organization --------> Stemmed : organ
# Original : . --------> Stemmed : .
# Original : Privacy --------> Stemmed : privaci
# Original : policy --------> Stemmed : polici
# Original : About --------> Stemmed : about
# Original : Wikipedia --------> Stemmed : wikipedia
# Original : Disclaimers --------> Stemmed : disclaim
# Original : Contact --------> Stemmed : contact
# Original : Wikipedia --------> Stemmed : wikipedia
# Original : Code --------> Stemmed : code
# Original : of --------> Stemmed : of
# Original : Conduct --------> Stemmed : conduct
# Original : Developers --------> Stemmed : develop
# Original : Statistics --------> Stemmed : statist
# Original : Cookie --------> Stemmed : cooki
# Original : statement --------> Stemmed : statement
# Original : Mobile --------> Stemmed : mobil
# Original : view --------> Stemmed : view
# Original : Search --------> Stemmed : search
# Original : Search --------> Stemmed : search
# Original : Toggle --------> Stemmed : toggl
# Original : the --------> Stemmed : the
# Original : table --------> Stemmed : tabl
# Original : of --------> Stemmed : of
# Original : contents --------> Stemmed : content
# Original : Centre --------> Stemmed : centr
# Original : for --------> Stemmed : for
# Original : Development --------> Stemmed : develop
# Original : of --------> Stemmed : of
# Original : Advanced --------> Stemmed : advanc
# Original : Computing --------> Stemmed : comput
# Original : 6 --------> Stemmed : 6
# Original : languages --------> Stemmed : languag
# Original : Add --------> Stemmed : add
# Original : topic --------> Stemmed : topic

# %%
# NLTK lemma

from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

with open('cdac_article.txt', encoding='utf-8') as f:
    text = f.read()

text = word_tokenize(text)

for word in text:

    print(f"Original : {word} --------> Lemmatized : {lemmatizer.lemmatize(word)}")
# Out:
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : - --------> Lemmatized : -
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : Jump --------> Lemmatized : Jump
# Original : to --------> Lemmatized : to
# Original : content --------> Lemmatized : content
# Original : Main --------> Lemmatized : Main
# Original : menu --------> Lemmatized : menu
# Original : Main --------> Lemmatized : Main
# Original : menu --------> Lemmatized : menu
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : Navigation --------> Lemmatized : Navigation
# Original : Main --------> Lemmatized : Main
# Original : pageContentsCurrent --------> Lemmatized : pageContentsCurrent
# Original : eventsRandom --------> Lemmatized : eventsRandom
# Original : articleAbout --------> Lemmatized : articleAbout
# Original : WikipediaContact --------> Lemmatized : WikipediaContact
# Original : us --------> Lemmatized : u
# Original : Contribute --------> Lemmatized : Contribute
# Original : HelpLearn --------> Lemmatized : HelpLearn
# Original : to --------> Lemmatized : to
# Original : editCommunity --------> Lemmatized : editCommunity
# Original : portalRecent --------> Lemmatized : portalRecent
# Original : changesUpload --------> Lemmatized : changesUpload
# Original : fileSpecial --------> Lemmatized : fileSpecial
# Original : pages --------> Lemmatized : page
# Original : Search --------> Lemmatized : Search
# Original : Search --------> Lemmatized : Search
# Original : Appearance --------> Lemmatized : Appearance
# Original : Donate --------> Lemmatized : Donate
# Original : Create --------> Lemmatized : Create
# Original : account --------> Lemmatized : account
# Original : Log --------> Lemmatized : Log
# Original : in --------> Lemmatized : in
# Original : Personal --------> Lemmatized : Personal
# Original : tools --------> Lemmatized : tool
# Original : Donate --------> Lemmatized : Donate
# Original : Create --------> Lemmatized : Create
# Original : account --------> Lemmatized : account
# Original : Log --------> Lemmatized : Log
# Original : in --------> Lemmatized : in
# Original : Pages --------> Lemmatized : Pages
# Original : for --------> Lemmatized : for
# Original : logged --------> Lemmatized : logged
# Original : out --------> Lemmatized : out
# Original : editors --------> Lemmatized : editor
# Original : learn --------> Lemmatized : learn
# Original : more --------> Lemmatized : more
# Original : ContributionsTalk --------> Lemmatized : ContributionsTalk
# Original : Contents --------> Lemmatized : Contents
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : ( --------> Lemmatized : (
# Original : Top --------> Lemmatized : Top
# Original : ) --------> Lemmatized : )
# Original : 1 --------> Lemmatized : 1
# Original : History --------> Lemmatized : History
# Original : 2 --------> Lemmatized : 2
# Original : Research --------> Lemmatized : Research
# Original : activities --------> Lemmatized : activity
# Original : 3 --------> Lemmatized : 3
# Original : Centres --------> Lemmatized : Centres
# Original : 4 --------> Lemmatized : 4
# Original : Education --------> Lemmatized : Education
# Original : and --------> Lemmatized : and
# Original : training --------> Lemmatized : training
# Original : 5 --------> Lemmatized : 5
# Original : Commercialization --------> Lemmatized : Commercialization
# Original : 6 --------> Lemmatized : 6
# Original : Products --------> Lemmatized : Products
# Original : and --------> Lemmatized : and
# Original : developments --------> Lemmatized : development
# Original : 7 --------> Lemmatized : 7
# Original : Notable --------> Lemmatized : Notable
# Original : researchers --------> Lemmatized : researcher
# Original : and --------> Lemmatized : and
# Original : alumnus --------> Lemmatized : alumnus
# Original : 8 --------> Lemmatized : 8
# Original : Notable --------> Lemmatized : Notable
# Original : awards --------> Lemmatized : award
# Original : and --------> Lemmatized : and
# Original : accolades --------> Lemmatized : accolade
# Original : 9 --------> Lemmatized : 9
# Original : Other --------> Lemmatized : Other
# Original : projects --------> Lemmatized : project
# Original : 10 --------> Lemmatized : 10
# Original : See --------> Lemmatized : See
# Original : also --------> Lemmatized : also
# Original : 11 --------> Lemmatized : 11
# Original : References --------> Lemmatized : References
# Original : Toggle --------> Lemmatized : Toggle
# Original : the --------> Lemmatized : the
# Original : table --------> Lemmatized : table
# Original : of --------> Lemmatized : of
# Original : contents --------> Lemmatized : content
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : 6 --------> Lemmatized : 6
# Original : languages --------> Lemmatized : language
# Original : हिन्दीമലയാളംमराठीРусскийதமிழ்Українська --------> Lemmatized : हिन्दीമലയാളംमराठीРусскийதமிழ்Українська
# Original : Edit --------> Lemmatized : Edit
# Original : links --------> Lemmatized : link
# Original : ArticleTalk --------> Lemmatized : ArticleTalk
# Original : English --------> Lemmatized : English
# Original : ReadEditView --------> Lemmatized : ReadEditView
# Original : history --------> Lemmatized : history
# Original : Tools --------> Lemmatized : Tools
# Original : Tools --------> Lemmatized : Tools
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : Actions --------> Lemmatized : Actions
# Original : ReadEditView --------> Lemmatized : ReadEditView
# Original : history --------> Lemmatized : history
# Original : General --------> Lemmatized : General
# Original : What --------> Lemmatized : What
# Original : links --------> Lemmatized : link
# Original : hereRelated --------> Lemmatized : hereRelated
# Original : changesUpload --------> Lemmatized : changesUpload
# Original : filePermanent --------> Lemmatized : filePermanent
# Original : linkPage --------> Lemmatized : linkPage
# Original : informationCite --------> Lemmatized : informationCite
# Original : this --------> Lemmatized : this
# Original : pageGet --------> Lemmatized : pageGet
# Original : shortened --------> Lemmatized : shortened
# Original : URLDownload --------> Lemmatized : URLDownload
# Original : QR --------> Lemmatized : QR
# Original : code --------> Lemmatized : code
# Original : Print/export --------> Lemmatized : Print/export
# Original : Download --------> Lemmatized : Download
# Original : as --------> Lemmatized : a
# Original : PDFPrintable --------> Lemmatized : PDFPrintable
# Original : version --------> Lemmatized : version
# Original : In --------> Lemmatized : In
# Original : other --------> Lemmatized : other
# Original : projects --------> Lemmatized : project
# Original : Wikidata --------> Lemmatized : Wikidata
# Original : item --------> Lemmatized : item
# Original : Appearance --------> Lemmatized : Appearance
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : Coordinates --------> Lemmatized : Coordinates
# Original : : --------> Lemmatized : :
# Original : 18°33′06″N --------> Lemmatized : 18°33′06″N
# Original : 73°49′26″E﻿ --------> Lemmatized : 73°49′26″E﻿
# Original : / --------> Lemmatized : /
# Original : ﻿18.551747°N --------> Lemmatized : ﻿18.551747°N
# Original : 73.823750°E﻿ --------> Lemmatized : 73.823750°E﻿
# Original : / --------> Lemmatized : /
# Original : 18.551747 --------> Lemmatized : 18.551747
# Original : ; --------> Lemmatized : ;
# Original : 73.823750 --------> Lemmatized : 73.823750
# Original : From --------> Lemmatized : From
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : free --------> Lemmatized : free
# Original : encyclopedia --------> Lemmatized : encyclopedia
# Original : Autonomous --------> Lemmatized : Autonomous
# Original : scientific --------> Lemmatized : scientific
# Original : society --------> Lemmatized : society
# Original : 18°33′06″N --------> Lemmatized : 18°33′06″N
# Original : 73°49′26″E﻿ --------> Lemmatized : 73°49′26″E﻿
# Original : / --------> Lemmatized : /
# Original : ﻿18.551747°N --------> Lemmatized : ﻿18.551747°N
# Original : 73.823750°E﻿ --------> Lemmatized : 73.823750°E﻿
# Original : / --------> Lemmatized : /
# Original : 18.551747 --------> Lemmatized : 18.551747
# Original : ; --------> Lemmatized : ;
# Original : 73.823750 --------> Lemmatized : 73.823750
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : ComputingMottoज्ञानादेव --------> Lemmatized : ComputingMottoज्ञानादेव
# Original : तु --------> Lemmatized : तु
# Original : कैवल्यम् --------> Lemmatized : कैवल्यम्
# Original : ( --------> Lemmatized : (
# Original : Sanskrit --------> Lemmatized : Sanskrit
# Original : ) --------> Lemmatized : )
# Original : Only --------> Lemmatized : Only
# Original : through --------> Lemmatized : through
# Original : knowledge --------> Lemmatized : knowledge
# Original : one --------> Lemmatized : one
# Original : attains --------> Lemmatized : attains
# Original : liberation --------> Lemmatized : liberation
# Original : ( --------> Lemmatized : (
# Original : English --------> Lemmatized : English
# Original : translated --------> Lemmatized : translated
# Original : ) --------> Lemmatized : )
# Original : Established1988 --------> Lemmatized : Established1988
# Original : ; --------> Lemmatized : ;
# Original : 37 --------> Lemmatized : 37
# Original : years --------> Lemmatized : year
# Original : ago --------> Lemmatized : ago
# Original : ( --------> Lemmatized : (
# Original : 1988 --------> Lemmatized : 1988
# Original : ) --------> Lemmatized : )
# Original : Field --------> Lemmatized : Field
# Original : of --------> Lemmatized : of
# Original : researchHigh --------> Lemmatized : researchHigh
# Original : Performance --------> Lemmatized : Performance
# Original : Computing --------> Lemmatized : Computing
# Original : , --------> Lemmatized : ,
# Original : Multi-lingual --------> Lemmatized : Multi-lingual
# Original : Computing --------> Lemmatized : Computing
# Original : and --------> Lemmatized : and
# Original : Heritage --------> Lemmatized : Heritage
# Original : Computing --------> Lemmatized : Computing
# Original : , --------> Lemmatized : ,
# Original : Professional --------> Lemmatized : Professional
# Original : Electronics --------> Lemmatized : Electronics
# Original : , --------> Lemmatized : ,
# Original : Software --------> Lemmatized : Software
# Original : Technologies --------> Lemmatized : Technologies
# Original : , --------> Lemmatized : ,
# Original : Cyber --------> Lemmatized : Cyber
# Original : Security --------> Lemmatized : Security
# Original : , --------> Lemmatized : ,
# Original : Blockchain --------> Lemmatized : Blockchain
# Original : , --------> Lemmatized : ,
# Original : Data --------> Lemmatized : Data
# Original : Science --------> Lemmatized : Science
# Original : , --------> Lemmatized : ,
# Original : Health --------> Lemmatized : Health
# Original : InformaticsDirectorMagesh --------> Lemmatized : InformaticsDirectorMagesh
# Original : Ethirajan --------> Lemmatized : Ethirajan
# Original : [ --------> Lemmatized : [
# Original : 1 --------> Lemmatized : 1
# Original : ] --------> Lemmatized : ]
# Original : ( --------> Lemmatized : (
# Original : Director --------> Lemmatized : Director
# Original : General --------> Lemmatized : General
# Original : ) --------> Lemmatized : )
# Original : AddressC-DAC --------> Lemmatized : AddressC-DAC
# Original : Innovation --------> Lemmatized : Innovation
# Original : Park --------> Lemmatized : Park
# Original : , --------> Lemmatized : ,
# Original : Panchavati --------> Lemmatized : Panchavati
# Original : , --------> Lemmatized : ,
# Original : Pashan --------> Lemmatized : Pashan
# Original : , --------> Lemmatized : ,
# Original : Pune --------> Lemmatized : Pune
# Original : - --------> Lemmatized : -
# Original : 411 --------> Lemmatized : 411
# Original : 008 --------> Lemmatized : 008
# Original : , --------> Lemmatized : ,
# Original : Maharashtra --------> Lemmatized : Maharashtra
# Original : , --------> Lemmatized : ,
# Original : IndiaLocationPune --------> Lemmatized : IndiaLocationPune
# Original : , --------> Lemmatized : ,
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : headquarters --------> Lemmatized : headquarters
# Original : ) --------> Lemmatized : )
# Original : NicknameC-DACOperating --------> Lemmatized : NicknameC-DACOperating
# Original : agencyMinistry --------> Lemmatized : agencyMinistry
# Original : of --------> Lemmatized : of
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : , --------> Lemmatized : ,
# Original : Government --------> Lemmatized : Government
# Original : of --------> Lemmatized : of
# Original : IndiaWebsitewww.cdac.in --------> Lemmatized : IndiaWebsitewww.cdac.in
# Original : The --------> Lemmatized : The
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : ( --------> Lemmatized : (
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : ) --------> Lemmatized : )
# Original : is --------> Lemmatized : is
# Original : an --------> Lemmatized : an
# Original : Indian --------> Lemmatized : Indian
# Original : autonomous --------> Lemmatized : autonomous
# Original : scientific --------> Lemmatized : scientific
# Original : society --------> Lemmatized : society
# Original : , --------> Lemmatized : ,
# Original : operating --------> Lemmatized : operating
# Original : under --------> Lemmatized : under
# Original : the --------> Lemmatized : the
# Original : Ministry --------> Lemmatized : Ministry
# Original : of --------> Lemmatized : of
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 2 --------> Lemmatized : 2
# Original : ] --------> Lemmatized : ]
# Original : History --------> Lemmatized : History
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : Further --------> Lemmatized : Further
# Original : information --------> Lemmatized : information
# Original : : --------> Lemmatized : :
# Original : Supercomputing --------> Lemmatized : Supercomputing
# Original : in --------> Lemmatized : in
# Original : India --------> Lemmatized : India
# Original : and --------> Lemmatized : and
# Original : PARAM --------> Lemmatized : PARAM
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : was --------> Lemmatized : wa
# Original : created --------> Lemmatized : created
# Original : in --------> Lemmatized : in
# Original : November --------> Lemmatized : November
# Original : 1987 --------> Lemmatized : 1987
# Original : , --------> Lemmatized : ,
# Original : [ --------> Lemmatized : [
# Original : 3 --------> Lemmatized : 3
# Original : ] --------> Lemmatized : ]
# Original : initially --------> Lemmatized : initially
# Original : as --------> Lemmatized : a
# Original : the --------> Lemmatized : the
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : C-DACT --------> Lemmatized : C-DACT
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 4 --------> Lemmatized : 4
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 3 --------> Lemmatized : 3
# Original : ] --------> Lemmatized : ]
# Original : In --------> Lemmatized : In
# Original : 1988 --------> Lemmatized : 1988
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : US --------> Lemmatized : US
# Original : Government --------> Lemmatized : Government
# Original : refused --------> Lemmatized : refused
# Original : to --------> Lemmatized : to
# Original : sell --------> Lemmatized : sell
# Original : India --------> Lemmatized : India
# Original : a --------> Lemmatized : a
# Original : Cray --------> Lemmatized : Cray
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : due --------> Lemmatized : due
# Original : to --------> Lemmatized : to
# Original : concerns --------> Lemmatized : concern
# Original : about --------> Lemmatized : about
# Original : India --------> Lemmatized : India
# Original : using --------> Lemmatized : using
# Original : it --------> Lemmatized : it
# Original : to --------> Lemmatized : to
# Original : develop --------> Lemmatized : develop
# Original : nuclear --------> Lemmatized : nuclear
# Original : weapons --------> Lemmatized : weapon
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 5 --------> Lemmatized : 5
# Original : ] --------> Lemmatized : ]
# Original : In --------> Lemmatized : In
# Original : response --------> Lemmatized : response
# Original : India --------> Lemmatized : India
# Original : started --------> Lemmatized : started
# Original : development --------> Lemmatized : development
# Original : of --------> Lemmatized : of
# Original : its --------> Lemmatized : it
# Original : own --------> Lemmatized : own
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : , --------> Lemmatized : ,
# Original : and --------> Lemmatized : and
# Original : C-DACT --------> Lemmatized : C-DACT
# Original : was --------> Lemmatized : wa
# Original : created --------> Lemmatized : created
# Original : as --------> Lemmatized : a
# Original : part --------> Lemmatized : part
# Original : of --------> Lemmatized : of
# Original : this --------> Lemmatized : this
# Original : programme --------> Lemmatized : programme
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 6 --------> Lemmatized : 6
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : Dr --------> Lemmatized : Dr
# Original : Vijay --------> Lemmatized : Vijay
# Original : Bhatkar --------> Lemmatized : Bhatkar
# Original : was --------> Lemmatized : wa
# Original : hired --------> Lemmatized : hired
# Original : as --------> Lemmatized : a
# Original : the --------> Lemmatized : the
# Original : director --------> Lemmatized : director
# Original : of --------> Lemmatized : of
# Original : C-DACT --------> Lemmatized : C-DACT
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : project --------> Lemmatized : project
# Original : was --------> Lemmatized : wa
# Original : given --------> Lemmatized : given
# Original : an --------> Lemmatized : an
# Original : initial --------> Lemmatized : initial
# Original : run --------> Lemmatized : run
# Original : of --------> Lemmatized : of
# Original : three --------> Lemmatized : three
# Original : years --------> Lemmatized : year
# Original : and --------> Lemmatized : and
# Original : an --------> Lemmatized : an
# Original : initial --------> Lemmatized : initial
# Original : funding --------> Lemmatized : funding
# Original : of --------> Lemmatized : of
# Original : ₹30,00,00,000 --------> Lemmatized : ₹30,00,00,000
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : cost --------> Lemmatized : cost
# Original : of --------> Lemmatized : of
# Original : a --------> Lemmatized : a
# Original : Cray --------> Lemmatized : Cray
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : A --------> Lemmatized : A
# Original : prototype --------> Lemmatized : prototype
# Original : computer --------> Lemmatized : computer
# Original : was --------> Lemmatized : wa
# Original : benchmarked --------> Lemmatized : benchmarked
# Original : at --------> Lemmatized : at
# Original : the --------> Lemmatized : the
# Original : 1990 --------> Lemmatized : 1990
# Original : Zurich --------> Lemmatized : Zurich
# Original : Super-computing --------> Lemmatized : Super-computing
# Original : Show --------> Lemmatized : Show
# Original : . --------> Lemmatized : .
# Original : It --------> Lemmatized : It
# Original : demonstrated --------> Lemmatized : demonstrated
# Original : that --------> Lemmatized : that
# Original : India --------> Lemmatized : India
# Original : had --------> Lemmatized : had
# Original : the --------> Lemmatized : the
# Original : second --------> Lemmatized : second
# Original : most --------> Lemmatized : most
# Original : powerful --------> Lemmatized : powerful
# Original : , --------> Lemmatized : ,
# Original : publicly --------> Lemmatized : publicly
# Original : demonstrated --------> Lemmatized : demonstrated
# Original : , --------> Lemmatized : ,
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : in --------> Lemmatized : in
# Original : the --------> Lemmatized : the
# Original : world --------> Lemmatized : world
# Original : after --------> Lemmatized : after
# Original : the --------> Lemmatized : the
# Original : United --------> Lemmatized : United
# Original : States --------> Lemmatized : States
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 8 --------> Lemmatized : 8
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : final --------> Lemmatized : final
# Original : result --------> Lemmatized : result
# Original : of --------> Lemmatized : of
# Original : the --------> Lemmatized : the
# Original : effort --------> Lemmatized : effort
# Original : was --------> Lemmatized : wa
# Original : the --------> Lemmatized : the
# Original : PARAM --------> Lemmatized : PARAM
# Original : 8000 --------> Lemmatized : 8000
# Original : , --------> Lemmatized : ,
# Original : released --------> Lemmatized : released
# Original : in --------> Lemmatized : in
# Original : 1991 --------> Lemmatized : 1991
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 9 --------> Lemmatized : 9
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : National --------> Lemmatized : National
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Software --------> Lemmatized : Software
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : NCST --------> Lemmatized : NCST
# Original : ) --------> Lemmatized : )
# Original : , --------> Lemmatized : ,
# Original : Electronic --------> Lemmatized : Electronic
# Original : Research --------> Lemmatized : Research
# Original : and --------> Lemmatized : and
# Original : Development --------> Lemmatized : Development
# Original : Centre --------> Lemmatized : Centre
# Original : ( --------> Lemmatized : (
# Original : ER --------> Lemmatized : ER
# Original : & --------> Lemmatized : &
# Original : DC --------> Lemmatized : DC
# Original : ) --------> Lemmatized : )
# Original : and --------> Lemmatized : and
# Original : CEDTI --------> Lemmatized : CEDTI
# Original : were --------> Lemmatized : were
# Original : merged --------> Lemmatized : merged
# Original : into --------> Lemmatized : into
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : in --------> Lemmatized : in
# Original : 2003 --------> Lemmatized : 2003
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 10 --------> Lemmatized : 10
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 11 --------> Lemmatized : 11
# Original : ] --------> Lemmatized : ]
# Original : Research --------> Lemmatized : Research
# Original : activities --------> Lemmatized : activity
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : Originally --------> Lemmatized : Originally
# Original : established --------> Lemmatized : established
# Original : to --------> Lemmatized : to
# Original : research --------> Lemmatized : research
# Original : and --------> Lemmatized : and
# Original : assemble --------> Lemmatized : assemble
# Original : High --------> Lemmatized : High
# Original : Performance --------> Lemmatized : Performance
# Original : Computers --------> Lemmatized : Computers
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : research --------> Lemmatized : research
# Original : of --------> Lemmatized : of
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : now --------> Lemmatized : now
# Original : includes --------> Lemmatized : includes
# Original : : --------> Lemmatized : :
# Original : High --------> Lemmatized : High
# Original : Performance --------> Lemmatized : Performance
# Original : Computing --------> Lemmatized : Computing
# Original : Grid --------> Lemmatized : Grid
# Original : Computing --------> Lemmatized : Computing
# Original : Cloud --------> Lemmatized : Cloud
# Original : Computing --------> Lemmatized : Computing
# Original : Multilingual --------> Lemmatized : Multilingual
# Original : and --------> Lemmatized : and
# Original : Heritage --------> Lemmatized : Heritage
# Original : Computing --------> Lemmatized : Computing
# Original : VLSI --------> Lemmatized : VLSI
# Original : and --------> Lemmatized : and
# Original : Processor --------> Lemmatized : Processor
# Original : design --------> Lemmatized : design
# Original : Embedded --------> Lemmatized : Embedded
# Original : Systems --------> Lemmatized : Systems
# Original : Speech --------> Lemmatized : Speech
# Original : and --------> Lemmatized : and
# Original : Natural --------> Lemmatized : Natural
# Original : Language --------> Lemmatized : Language
# Original : Processing --------> Lemmatized : Processing
# Original : Information --------> Lemmatized : Information
# Original : and --------> Lemmatized : and
# Original : Cyber --------> Lemmatized : Cyber
# Original : Security --------> Lemmatized : Security
# Original : Ubiquitous --------> Lemmatized : Ubiquitous
# Original : Computing --------> Lemmatized : Computing
# Original : Bioinformatics --------> Lemmatized : Bioinformatics
# Original : Geomatics --------> Lemmatized : Geomatics
# Original : Digital --------> Lemmatized : Digital
# Original : forensics --------> Lemmatized : forensics
# Original : Big --------> Lemmatized : Big
# Original : data --------> Lemmatized : data
# Original : analytics --------> Lemmatized : analytics
# Original : Blockchain --------> Lemmatized : Blockchain
# Original : Health --------> Lemmatized : Health
# Original : Informatics --------> Lemmatized : Informatics
# Original : Quantum --------> Lemmatized : Quantum
# Original : computing --------> Lemmatized : computing
# Original : Centres --------> Lemmatized : Centres
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : branches --------> Lemmatized : branch
# Original : and --------> Lemmatized : and
# Original : training --------> Lemmatized : training
# Original : centres --------> Lemmatized : centre
# Original : include --------> Lemmatized : include
# Original : : --------> Lemmatized : :
# Original : [ --------> Lemmatized : [
# Original : 12 --------> Lemmatized : 12
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Pune --------> Lemmatized : Pune
# Original : ( --------> Lemmatized : (
# Original : Headquarters --------> Lemmatized : Headquarters
# Original : ) --------> Lemmatized : )
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Mumbai --------> Lemmatized : Mumbai
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Bangalore --------> Lemmatized : Bangalore
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Chennai --------> Lemmatized : Chennai
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Delhi --------> Lemmatized : Delhi
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Kolkata --------> Lemmatized : Kolkata
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Patna --------> Lemmatized : Patna
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Mohali --------> Lemmatized : Mohali
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Noida --------> Lemmatized : Noida
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Hyderabad --------> Lemmatized : Hyderabad
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Thiruvananthapuram --------> Lemmatized : Thiruvananthapuram
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Silchar --------> Lemmatized : Silchar
# Original : Education --------> Lemmatized : Education
# Original : and --------> Lemmatized : and
# Original : training --------> Lemmatized : training
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : provides --------> Lemmatized : provides
# Original : several --------> Lemmatized : several
# Original : courses --------> Lemmatized : course
# Original : in --------> Lemmatized : in
# Original : the --------> Lemmatized : the
# Original : field --------> Lemmatized : field
# Original : of --------> Lemmatized : of
# Original : advanced --------> Lemmatized : advanced
# Original : computing --------> Lemmatized : computing
# Original : and --------> Lemmatized : and
# Original : software --------> Lemmatized : software
# Original : development --------> Lemmatized : development
# Original : . --------> Lemmatized : .
# Original : Among --------> Lemmatized : Among
# Original : these --------> Lemmatized : these
# Original : are --------> Lemmatized : are
# Original : the --------> Lemmatized : the
# Original : HPC --------> Lemmatized : HPC
# Original : certification --------> Lemmatized : certification
# Original : course- --------> Lemmatized : course-
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Certified --------> Lemmatized : Certified
# Original : HPC --------> Lemmatized : HPC
# Original : Professional --------> Lemmatized : Professional
# Original : Certification --------> Lemmatized : Certification
# Original : Programme --------> Lemmatized : Programme
# Original : ( --------> Lemmatized : (
# Original : CCHPCP --------> Lemmatized : CCHPCP
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 13 --------> Lemmatized : 13
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : organises --------> Lemmatized : organises
# Original : advanced --------> Lemmatized : advanced
# Original : computing --------> Lemmatized : computing
# Original : diploma --------> Lemmatized : diploma
# Original : programmes --------> Lemmatized : programme
# Original : through --------> Lemmatized : through
# Original : the --------> Lemmatized : the
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : Training --------> Lemmatized : Training
# Original : School --------> Lemmatized : School
# Original : ( --------> Lemmatized : (
# Original : ACTS --------> Lemmatized : ACTS
# Original : ) --------> Lemmatized : )
# Original : located --------> Lemmatized : located
# Original : all --------> Lemmatized : all
# Original : over --------> Lemmatized : over
# Original : India --------> Lemmatized : India
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 14 --------> Lemmatized : 14
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : PG --------> Lemmatized : PG
# Original : Diploma --------> Lemmatized : Diploma
# Original : courses --------> Lemmatized : course
# Original : include --------> Lemmatized : include
# Original : Specialisations --------> Lemmatized : Specialisations
# Original : in --------> Lemmatized : in
# Original : Embedded --------> Lemmatized : Embedded
# Original : System --------> Lemmatized : System
# Original : Design --------> Lemmatized : Design
# Original : , --------> Lemmatized : ,
# Original : VLSI --------> Lemmatized : VLSI
# Original : , --------> Lemmatized : ,
# Original : Big --------> Lemmatized : Big
# Original : Data --------> Lemmatized : Data
# Original : Analytics --------> Lemmatized : Analytics
# Original : , --------> Lemmatized : ,
# Original : Geoinformatics --------> Lemmatized : Geoinformatics
# Original : , --------> Lemmatized : ,
# Original : Artificial --------> Lemmatized : Artificial
# Original : Intelligence --------> Lemmatized : Intelligence
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : has --------> Lemmatized : ha
# Original : also --------> Lemmatized : also
# Original : established --------> Lemmatized : established
# Original : Centres --------> Lemmatized : Centres
# Original : of --------> Lemmatized : of
# Original : Excellence --------> Lemmatized : Excellence
# Original : in --------> Lemmatized : in
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : CEIT --------> Lemmatized : CEIT
# Original : ) --------> Lemmatized : )
# Original : abroad --------> Lemmatized : abroad
# Original : under --------> Lemmatized : under
# Original : the --------> Lemmatized : the
# Original : Ministry --------> Lemmatized : Ministry
# Original : of --------> Lemmatized : of
# Original : External --------> Lemmatized : External
# Original : Affairs --------> Lemmatized : Affairs
# Original : ' --------> Lemmatized : '
# Original : s --------> Lemmatized : s
# Original : development --------> Lemmatized : development
# Original : partnership --------> Lemmatized : partnership
# Original : projects --------> Lemmatized : project
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 15 --------> Lemmatized : 15
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 16 --------> Lemmatized : 16
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 17 --------> Lemmatized : 17
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 18 --------> Lemmatized : 18
# Original : ] --------> Lemmatized : ]
# Original : Commercialization --------> Lemmatized : Commercialization
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : This --------> Lemmatized : This
# Original : article --------> Lemmatized : article
# Original : appears --------> Lemmatized : appears
# Original : to --------> Lemmatized : to
# Original : contain --------> Lemmatized : contain
# Original : a --------> Lemmatized : a
# Original : large --------> Lemmatized : large
# Original : number --------> Lemmatized : number
# Original : of --------> Lemmatized : of
# Original : buzzwords --------> Lemmatized : buzzword
# Original : . --------> Lemmatized : .
# Original : There --------> Lemmatized : There
# Original : might --------> Lemmatized : might
# Original : be --------> Lemmatized : be
# Original : a --------> Lemmatized : a
# Original : discussion --------> Lemmatized : discussion
# Original : about --------> Lemmatized : about
# Original : this --------> Lemmatized : this
# Original : on --------> Lemmatized : on
# Original : the --------> Lemmatized : the
# Original : talk --------> Lemmatized : talk
# Original : page --------> Lemmatized : page
# Original : . --------> Lemmatized : .
# Original : Please --------> Lemmatized : Please
# Original : help --------> Lemmatized : help
# Original : improve --------> Lemmatized : improve
# Original : this --------> Lemmatized : this
# Original : article --------> Lemmatized : article
# Original : if --------> Lemmatized : if
# Original : you --------> Lemmatized : you
# Original : can --------> Lemmatized : can
# Original : . --------> Lemmatized : .
# Original : ( --------> Lemmatized : (
# Original : April --------> Lemmatized : April
# Original : 2025 --------> Lemmatized : 2025
# Original : ) --------> Lemmatized : )
# Original : On --------> Lemmatized : On
# Original : August --------> Lemmatized : August
# Original : 28 --------> Lemmatized : 28
# Original : , --------> Lemmatized : ,
# Original : 2024 --------> Lemmatized : 2024
# Original : , --------> Lemmatized : ,
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : and --------> Lemmatized : and
# Original : L --------> Lemmatized : L
# Original : & --------> Lemmatized : &
# Original : T --------> Lemmatized : T
# Original : Semiconductor --------> Lemmatized : Semiconductor
# Original : Technologies --------> Lemmatized : Technologies
# Original : ( --------> Lemmatized : (
# Original : LTSCT --------> Lemmatized : LTSCT
# Original : ) --------> Lemmatized : )
# Original : signed --------> Lemmatized : signed
# Original : a --------> Lemmatized : a
# Original : Memorandum --------> Lemmatized : Memorandum
# Original : of --------> Lemmatized : of
# Original : Understanding --------> Lemmatized : Understanding
# Original : ( --------> Lemmatized : (
# Original : MoU --------> Lemmatized : MoU
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : It --------> Lemmatized : It
# Original : will --------> Lemmatized : will
# Original : establish --------> Lemmatized : establish
# Original : a --------> Lemmatized : a
# Original : program --------> Lemmatized : program
# Original : for --------> Lemmatized : for
# Original : the --------> Lemmatized : the
# Original : commercialization --------> Lemmatized : commercialization
# Original : of --------> Lemmatized : of
# Original : cutting-edge --------> Lemmatized : cutting-edge
# Original : technologies --------> Lemmatized : technology
# Original : created --------> Lemmatized : created
# Original : by --------> Lemmatized : by
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : in --------> Lemmatized : in
# Original : the --------> Lemmatized : the
# Original : areas --------> Lemmatized : area
# Original : of --------> Lemmatized : of
# Original : power --------> Lemmatized : power
# Original : systems --------> Lemmatized : system
# Original : , --------> Lemmatized : ,
# Original : embedded --------> Lemmatized : embedded
# Original : software --------> Lemmatized : software
# Original : , --------> Lemmatized : ,
# Original : open-source --------> Lemmatized : open-source
# Original : operating --------> Lemmatized : operating
# Original : systems --------> Lemmatized : system
# Original : , --------> Lemmatized : ,
# Original : high --------> Lemmatized : high
# Original : performance --------> Lemmatized : performance
# Original : computing --------> Lemmatized : computing
# Original : , --------> Lemmatized : ,
# Original : and --------> Lemmatized : and
# Original : semiconductor --------> Lemmatized : semiconductor
# Original : design --------> Lemmatized : design
# Original : and --------> Lemmatized : and
# Original : development --------> Lemmatized : development
# Original : . --------> Lemmatized : .
# Original : LTSCT --------> Lemmatized : LTSCT
# Original : will --------> Lemmatized : will
# Original : leverage --------> Lemmatized : leverage
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : 's --------> Lemmatized : 's
# Original : extensive --------> Lemmatized : extensive
# Original : pipeline --------> Lemmatized : pipeline
# Original : of --------> Lemmatized : of
# Original : in-house --------> Lemmatized : in-house
# Original : intellectual --------> Lemmatized : intellectual
# Original : property --------> Lemmatized : property
# Original : ( --------> Lemmatized : (
# Original : IPs --------> Lemmatized : IPs
# Original : ) --------> Lemmatized : )
# Original : , --------> Lemmatized : ,
# Original : which --------> Lemmatized : which
# Original : includes --------> Lemmatized : includes
# Original : the --------> Lemmatized : the
# Original : VEGA --------> Lemmatized : VEGA
# Original : processor --------> Lemmatized : processor
# Original : , --------> Lemmatized : ,
# Original : to --------> Lemmatized : to
# Original : create --------> Lemmatized : create
# Original : global --------> Lemmatized : global
# Original : product --------> Lemmatized : product
# Original : prospects --------> Lemmatized : prospect
# Original : through --------> Lemmatized : through
# Original : application --------> Lemmatized : application
# Original : design --------> Lemmatized : design
# Original : and --------> Lemmatized : and
# Original : validation --------> Lemmatized : validation
# Original : for --------> Lemmatized : for
# Original : Field --------> Lemmatized : Field
# Original : Programmable --------> Lemmatized : Programmable
# Original : Gate --------> Lemmatized : Gate
# Original : Arrays --------> Lemmatized : Arrays
# Original : . --------> Lemmatized : .
# Original : By --------> Lemmatized : By
# Original : facilitating --------> Lemmatized : facilitating
# Original : the --------> Lemmatized : the
# Original : creation --------> Lemmatized : creation
# Original : of --------> Lemmatized : of
# Original : cutting-edge --------> Lemmatized : cutting-edge
# Original : goods --------> Lemmatized : good
# Original : and --------> Lemmatized : and
# Original : solutions --------> Lemmatized : solution
# Original : for --------> Lemmatized : for
# Original : the --------> Lemmatized : the
# Original : automotive --------> Lemmatized : automotive
# Original : , --------> Lemmatized : ,
# Original : industrial --------> Lemmatized : industrial
# Original : , --------> Lemmatized : ,
# Original : information --------> Lemmatized : information
# Original : and --------> Lemmatized : and
# Original : communications --------> Lemmatized : communication
# Original : technology --------> Lemmatized : technology
# Original : infrastructure --------> Lemmatized : infrastructure
# Original : , --------> Lemmatized : ,
# Original : and --------> Lemmatized : and
# Original : energy --------> Lemmatized : energy
# Original : sectors --------> Lemmatized : sector
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : collaboration --------> Lemmatized : collaboration
# Original : to --------> Lemmatized : to
# Original : create --------> Lemmatized : create
# Original : indigenous --------> Lemmatized : indigenous
# Original : ICs --------> Lemmatized : ICs
# Original : and --------> Lemmatized : and
# Original : SoCs --------> Lemmatized : SoCs
# Original : based --------> Lemmatized : based
# Original : in --------> Lemmatized : in
# Original : Vega --------> Lemmatized : Vega
# Original : is --------> Lemmatized : is
# Original : expected --------> Lemmatized : expected
# Original : to --------> Lemmatized : to
# Original : pick --------> Lemmatized : pick
# Original : up --------> Lemmatized : up
# Original : speed --------> Lemmatized : speed
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 19 --------> Lemmatized : 19
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 20 --------> Lemmatized : 20
# Original : ] --------> Lemmatized : ]
# Original : Products --------> Lemmatized : Products
# Original : and --------> Lemmatized : and
# Original : developments --------> Lemmatized : development
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : PARAM --------> Lemmatized : PARAM
# Original : series --------> Lemmatized : series
# Original : of --------> Lemmatized : of
# Original : supercomputers --------> Lemmatized : supercomputer
# Original : [ --------> Lemmatized : [
# Original : 21 --------> Lemmatized : 21
# Original : ] --------> Lemmatized : ]
# Original : VEGA --------> Lemmatized : VEGA
# Original : Microprocessors --------> Lemmatized : Microprocessors
# Original : , --------> Lemmatized : ,
# Original : India --------> Lemmatized : India
# Original : 's --------> Lemmatized : 's
# Original : first --------> Lemmatized : first
# Original : indigenous --------> Lemmatized : indigenous
# Original : 64-bit --------> Lemmatized : 64-bit
# Original : Multi-core --------> Lemmatized : Multi-core
# Original : Superscalar --------> Lemmatized : Superscalar
# Original : Out-of-Order --------> Lemmatized : Out-of-Order
# Original : RISC-V --------> Lemmatized : RISC-V
# Original : Processor --------> Lemmatized : Processor
# Original : [ --------> Lemmatized : [
# Original : 22 --------> Lemmatized : 22
# Original : ] --------> Lemmatized : ]
# Original : M-Kavach --------> Lemmatized : M-Kavach
# Original : 2 --------> Lemmatized : 2
# Original : , --------> Lemmatized : ,
# Original : an --------> Lemmatized : an
# Original : android-based --------> Lemmatized : android-based
# Original : mobile --------> Lemmatized : mobile
# Original : device --------> Lemmatized : device
# Original : security --------> Lemmatized : security
# Original : solution --------> Lemmatized : solution
# Original : addressing --------> Lemmatized : addressing
# Original : emerging --------> Lemmatized : emerging
# Original : threats --------> Lemmatized : threat
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 23 --------> Lemmatized : 23
# Original : ] --------> Lemmatized : ]
# Original : Mobile --------> Lemmatized : Mobile
# Original : Seva --------> Lemmatized : Seva
# Original : AppStore --------> Lemmatized : AppStore
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : mobile --------> Lemmatized : mobile
# Original : app --------> Lemmatized : app
# Original : marketplace --------> Lemmatized : marketplace
# Original : [ --------> Lemmatized : [
# Original : 24 --------> Lemmatized : 24
# Original : ] --------> Lemmatized : ]
# Original : Bharat --------> Lemmatized : Bharat
# Original : Operating --------> Lemmatized : Operating
# Original : System --------> Lemmatized : System
# Original : Solutions --------> Lemmatized : Solutions
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : Linux-based --------> Lemmatized : Linux-based
# Original : general --------> Lemmatized : general
# Original : purpose --------> Lemmatized : purpose
# Original : operating --------> Lemmatized : operating
# Original : system --------> Lemmatized : system
# Original : [ --------> Lemmatized : [
# Original : 25 --------> Lemmatized : 25
# Original : ] --------> Lemmatized : ]
# Original : Anvaya --------> Lemmatized : Anvaya
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : workflow --------> Lemmatized : workflow
# ...
# Original : Registry --------> Lemmatized : Registry
# Original : .in --------> Lemmatized : .in
# Original : .भारत --------> Lemmatized : .भारत
# Original : Other --------> Lemmatized : Other
# Original : Standardisation --------> Lemmatized : Standardisation
# Original : Testing --------> Lemmatized : Testing
# Original : and --------> Lemmatized : and
# Original : Quality --------> Lemmatized : Quality
# Original : Certification --------> Lemmatized : Certification
# Original : Directorate --------> Lemmatized : Directorate
# Original : ( --------> Lemmatized : (
# Original : STQC --------> Lemmatized : STQC
# Original : ) --------> Lemmatized : )
# Original : Controller --------> Lemmatized : Controller
# Original : of --------> Lemmatized : of
# Original : Certifying --------> Lemmatized : Certifying
# Original : Authorities --------> Lemmatized : Authorities
# Original : ( --------> Lemmatized : (
# Original : CCA --------> Lemmatized : CCA
# Original : ) --------> Lemmatized : )
# Original : Cyber --------> Lemmatized : Cyber
# Original : Appellate --------> Lemmatized : Appellate
# Original : Tribunal --------> Lemmatized : Tribunal
# Original : ( --------> Lemmatized : (
# Original : CAT --------> Lemmatized : CAT
# Original : ) --------> Lemmatized : )
# Original : Indian --------> Lemmatized : Indian
# Original : Computer --------> Lemmatized : Computer
# Original : Emergency --------> Lemmatized : Emergency
# Original : Response --------> Lemmatized : Response
# Original : Team --------> Lemmatized : Team
# Original : ( --------> Lemmatized : (
# Original : ICERT --------> Lemmatized : ICERT
# Original : ) --------> Lemmatized : )
# Original : Companies --------> Lemmatized : Companies
# Original : CSC --------> Lemmatized : CSC
# Original : e-Governance --------> Lemmatized : e-Governance
# Original : Services --------> Lemmatized : Services
# Original : India --------> Lemmatized : India
# Original : Limited --------> Lemmatized : Limited
# Original : Media --------> Lemmatized : Media
# Original : Lab --------> Lemmatized : Lab
# Original : Asia --------> Lemmatized : Asia
# Original : ( --------> Lemmatized : (
# Original : MLAsia --------> Lemmatized : MLAsia
# Original : ) --------> Lemmatized : )
# Original : National --------> Lemmatized : National
# Original : Informatics --------> Lemmatized : Informatics
# Original : Centre --------> Lemmatized : Centre
# Original : Services --------> Lemmatized : Services
# Original : Incorporated --------> Lemmatized : Incorporated
# Original : ( --------> Lemmatized : (
# Original : NICSI --------> Lemmatized : NICSI
# Original : ) --------> Lemmatized : )
# Original : — --------> Lemmatized : —
# Original : PSE --------> Lemmatized : PSE
# Original : under --------> Lemmatized : under
# Original : National --------> Lemmatized : National
# Original : Informatics --------> Lemmatized : Informatics
# Original : Centre --------> Lemmatized : Centre
# Original : National --------> Lemmatized : National
# Original : Internet --------> Lemmatized : Internet
# Original : Exchange --------> Lemmatized : Exchange
# Original : of --------> Lemmatized : of
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : NIXI --------> Lemmatized : NIXI
# Original : ) --------> Lemmatized : )
# Original : STPI --------> Lemmatized : STPI
# Original : Unique --------> Lemmatized : Unique
# Original : Identification --------> Lemmatized : Identification
# Original : Authority --------> Lemmatized : Authority
# Original : of --------> Lemmatized : of
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : UIDAI --------> Lemmatized : UIDAI
# Original : ) --------> Lemmatized : )
# Original : AutonomousSocieties --------> Lemmatized : AutonomousSocieties
# Original : Education --------> Lemmatized : Education
# Original : and --------> Lemmatized : and
# Original : Research --------> Lemmatized : Research
# Original : in --------> Lemmatized : in
# Original : Computer --------> Lemmatized : Computer
# Original : Networking --------> Lemmatized : Networking
# Original : ( --------> Lemmatized : (
# Original : ERNET --------> Lemmatized : ERNET
# Original : ) --------> Lemmatized : )
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : ( --------> Lemmatized : (
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : ) --------> Lemmatized : )
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Materials --------> Lemmatized : Materials
# Original : for --------> Lemmatized : for
# Original : Electronics --------> Lemmatized : Electronics
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : C-MET --------> Lemmatized : C-MET
# Original : ) --------> Lemmatized : )
# Original : National --------> Lemmatized : National
# Original : Institute --------> Lemmatized : Institute
# Original : of --------> Lemmatized : of
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : NIELIT --------> Lemmatized : NIELIT
# Original : ) --------> Lemmatized : )
# Original : — --------> Lemmatized : —
# Original : Formerly --------> Lemmatized : Formerly
# Original : DOEACC --------> Lemmatized : DOEACC
# Original : Society --------> Lemmatized : Society
# Original : Society --------> Lemmatized : Society
# Original : for --------> Lemmatized : for
# Original : Applied --------> Lemmatized : Applied
# Original : Microwave --------> Lemmatized : Microwave
# Original : Electronics --------> Lemmatized : Electronics
# Original : Engineering --------> Lemmatized : Engineering
# Original : and --------> Lemmatized : and
# Original : Research --------> Lemmatized : Research
# Original : ( --------> Lemmatized : (
# Original : SAMEER --------> Lemmatized : SAMEER
# Original : ) --------> Lemmatized : )
# Original : Software --------> Lemmatized : Software
# Original : Technology --------> Lemmatized : Technology
# Original : Parks --------> Lemmatized : Parks
# Original : of --------> Lemmatized : of
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : STPI --------> Lemmatized : STPI
# Original : ) --------> Lemmatized : )
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Computer --------> Lemmatized : Computer
# Original : Software --------> Lemmatized : Software
# Original : Export --------> Lemmatized : Export
# Original : Promotion --------> Lemmatized : Promotion
# Original : Council --------> Lemmatized : Council
# Original : ( --------> Lemmatized : (
# Original : ESC --------> Lemmatized : ESC
# Original : ) --------> Lemmatized : )
# Original : Semi-Conductor --------> Lemmatized : Semi-Conductor
# Original : Laboratory --------> Lemmatized : Laboratory
# Original : ( --------> Lemmatized : (
# Original : SCL --------> Lemmatized : SCL
# Original : ) --------> Lemmatized : )
# Original : Ministers --------> Lemmatized : Ministers
# Original : Ashwini --------> Lemmatized : Ashwini
# Original : Vaishnaw --------> Lemmatized : Vaishnaw
# Original : ( --------> Lemmatized : (
# Original : incumbent --------> Lemmatized : incumbent
# Original : ) --------> Lemmatized : )
# Original : Ministers --------> Lemmatized : Ministers
# Original : of --------> Lemmatized : of
# Original : State --------> Lemmatized : State
# Original : Jitin --------> Lemmatized : Jitin
# Original : Prasada --------> Lemmatized : Prasada
# Original : ( --------> Lemmatized : (
# Original : incumbent --------> Lemmatized : incumbent
# Original : ) --------> Lemmatized : )
# Original : Authority --------> Lemmatized : Authority
# Original : control --------> Lemmatized : control
# Original : databases --------> Lemmatized : database
# Original : InternationalISNIVIAFNationalGermanyUnited --------> Lemmatized : InternationalISNIVIAFNationalGermanyUnited
# Original : StatesIsrael --------> Lemmatized : StatesIsrael
# Original : Retrieved --------> Lemmatized : Retrieved
# Original : from --------> Lemmatized : from
# Original : `` --------> Lemmatized : ``
# Original : https --------> Lemmatized : http
# Original : : --------> Lemmatized : :
# Original : //en.wikipedia.org/w/index.php --------> Lemmatized : //en.wikipedia.org/w/index.php
# Original : ? --------> Lemmatized : ?
# Original : title=Centre_for_Development_of_Advanced_Computing --------> Lemmatized : title=Centre_for_Development_of_Advanced_Computing
# Original : & --------> Lemmatized : &
# Original : oldid=1285579997 --------> Lemmatized : oldid=1285579997
# Original : '' --------> Lemmatized : ''
# Original : Categories --------> Lemmatized : Categories
# Original : : --------> Lemmatized : :
# Original : Research --------> Lemmatized : Research
# Original : institutes --------> Lemmatized : institute
# Original : in --------> Lemmatized : in
# Original : PuneInformation --------> Lemmatized : PuneInformation
# Original : technology --------> Lemmatized : technology
# Original : organisations --------> Lemmatized : organisation
# Original : based --------> Lemmatized : based
# Original : in --------> Lemmatized : in
# Original : India1988 --------> Lemmatized : India1988
# Original : establishments --------> Lemmatized : establishment
# Original : in --------> Lemmatized : in
# Original : MaharashtraResearch --------> Lemmatized : MaharashtraResearch
# Original : institutes --------> Lemmatized : institute
# Original : established --------> Lemmatized : established
# Original : in --------> Lemmatized : in
# Original : 1988Hidden --------> Lemmatized : 1988Hidden
# Original : categories --------> Lemmatized : category
# Original : : --------> Lemmatized : :
# Original : Pages --------> Lemmatized : Pages
# Original : using --------> Lemmatized : using
# Original : gadget --------> Lemmatized : gadget
# Original : WikiMiniAtlasArticles --------> Lemmatized : WikiMiniAtlasArticles
# Original : with --------> Lemmatized : with
# Original : short --------> Lemmatized : short
# Original : descriptionShort --------> Lemmatized : descriptionShort
# Original : description --------> Lemmatized : description
# Original : matches --------> Lemmatized : match
# Original : WikidataEngvarB --------> Lemmatized : WikidataEngvarB
# Original : from --------> Lemmatized : from
# Original : July --------> Lemmatized : July
# Original : 2015Use --------> Lemmatized : 2015Use
# Original : dmy --------> Lemmatized : dmy
# Original : dates --------> Lemmatized : date
# Original : from --------> Lemmatized : from
# Original : July --------> Lemmatized : July
# Original : 2015Coordinates --------> Lemmatized : 2015Coordinates
# Original : on --------> Lemmatized : on
# Original : WikidataArticles --------> Lemmatized : WikidataArticles
# Original : containing --------> Lemmatized : containing
# Original : Sanskrit-language --------> Lemmatized : Sanskrit-language
# Original : textWikipedia --------> Lemmatized : textWikipedia
# Original : articles --------> Lemmatized : article
# Original : containing --------> Lemmatized : containing
# Original : buzzwords --------> Lemmatized : buzzword
# Original : from --------> Lemmatized : from
# Original : April --------> Lemmatized : April
# Original : 2025 --------> Lemmatized : 2025
# Original : This --------> Lemmatized : This
# Original : page --------> Lemmatized : page
# Original : was --------> Lemmatized : wa
# Original : last --------> Lemmatized : last
# Original : edited --------> Lemmatized : edited
# Original : on --------> Lemmatized : on
# Original : 14 --------> Lemmatized : 14
# Original : April --------> Lemmatized : April
# Original : 2025 --------> Lemmatized : 2025
# Original : , --------> Lemmatized : ,
# Original : at --------> Lemmatized : at
# Original : 14:34 --------> Lemmatized : 14:34
# Original : ( --------> Lemmatized : (
# Original : UTC --------> Lemmatized : UTC
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : Text --------> Lemmatized : Text
# Original : is --------> Lemmatized : is
# Original : available --------> Lemmatized : available
# Original : under --------> Lemmatized : under
# Original : the --------> Lemmatized : the
# Original : Creative --------> Lemmatized : Creative
# Original : Commons --------> Lemmatized : Commons
# Original : Attribution-ShareAlike --------> Lemmatized : Attribution-ShareAlike
# Original : 4.0 --------> Lemmatized : 4.0
# Original : License --------> Lemmatized : License
# Original : ; --------> Lemmatized : ;
# Original : additional --------> Lemmatized : additional
# Original : terms --------> Lemmatized : term
# Original : may --------> Lemmatized : may
# Original : apply --------> Lemmatized : apply
# Original : . --------> Lemmatized : .
# Original : By --------> Lemmatized : By
# Original : using --------> Lemmatized : using
# Original : this --------> Lemmatized : this
# Original : site --------> Lemmatized : site
# Original : , --------> Lemmatized : ,
# Original : you --------> Lemmatized : you
# Original : agree --------> Lemmatized : agree
# Original : to --------> Lemmatized : to
# Original : the --------> Lemmatized : the
# Original : Terms --------> Lemmatized : Terms
# Original : of --------> Lemmatized : of
# Original : Use --------> Lemmatized : Use
# Original : and --------> Lemmatized : and
# Original : Privacy --------> Lemmatized : Privacy
# Original : Policy --------> Lemmatized : Policy
# Original : . --------> Lemmatized : .
# Original : Wikipedia® --------> Lemmatized : Wikipedia®
# Original : is --------> Lemmatized : is
# Original : a --------> Lemmatized : a
# Original : registered --------> Lemmatized : registered
# Original : trademark --------> Lemmatized : trademark
# Original : of --------> Lemmatized : of
# Original : the --------> Lemmatized : the
# Original : Wikimedia --------> Lemmatized : Wikimedia
# Original : Foundation --------> Lemmatized : Foundation
# Original : , --------> Lemmatized : ,
# Original : Inc. --------> Lemmatized : Inc.
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : non-profit --------> Lemmatized : non-profit
# Original : organization --------> Lemmatized : organization
# Original : . --------> Lemmatized : .
# Original : Privacy --------> Lemmatized : Privacy
# Original : policy --------> Lemmatized : policy
# Original : About --------> Lemmatized : About
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : Disclaimers --------> Lemmatized : Disclaimers
# Original : Contact --------> Lemmatized : Contact
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : Code --------> Lemmatized : Code
# Original : of --------> Lemmatized : of
# Original : Conduct --------> Lemmatized : Conduct
# Original : Developers --------> Lemmatized : Developers
# Original : Statistics --------> Lemmatized : Statistics
# Original : Cookie --------> Lemmatized : Cookie
# Original : statement --------> Lemmatized : statement
# Original : Mobile --------> Lemmatized : Mobile
# Original : view --------> Lemmatized : view
# Original : Search --------> Lemmatized : Search
# Original : Search --------> Lemmatized : Search
# Original : Toggle --------> Lemmatized : Toggle
# Original : the --------> Lemmatized : the
# Original : table --------> Lemmatized : table
# Original : of --------> Lemmatized : of
# Original : contents --------> Lemmatized : content
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : 6 --------> Lemmatized : 6
# Original : languages --------> Lemmatized : language
# Original : Add --------> Lemmatized : Add
# Original : topic --------> Lemmatized : topic
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
for word in text:

    print(f"Original : {word} --------> Lemmatized : {lemmatizer.lemmatize(word, pos='n')}")
# Out:
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : - --------> Lemmatized : -
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : Jump --------> Lemmatized : Jump
# Original : to --------> Lemmatized : to
# Original : content --------> Lemmatized : content
# Original : Main --------> Lemmatized : Main
# Original : menu --------> Lemmatized : menu
# Original : Main --------> Lemmatized : Main
# Original : menu --------> Lemmatized : menu
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : Navigation --------> Lemmatized : Navigation
# Original : Main --------> Lemmatized : Main
# Original : pageContentsCurrent --------> Lemmatized : pageContentsCurrent
# Original : eventsRandom --------> Lemmatized : eventsRandom
# Original : articleAbout --------> Lemmatized : articleAbout
# Original : WikipediaContact --------> Lemmatized : WikipediaContact
# Original : us --------> Lemmatized : u
# Original : Contribute --------> Lemmatized : Contribute
# Original : HelpLearn --------> Lemmatized : HelpLearn
# Original : to --------> Lemmatized : to
# Original : editCommunity --------> Lemmatized : editCommunity
# Original : portalRecent --------> Lemmatized : portalRecent
# Original : changesUpload --------> Lemmatized : changesUpload
# Original : fileSpecial --------> Lemmatized : fileSpecial
# Original : pages --------> Lemmatized : page
# Original : Search --------> Lemmatized : Search
# Original : Search --------> Lemmatized : Search
# Original : Appearance --------> Lemmatized : Appearance
# Original : Donate --------> Lemmatized : Donate
# Original : Create --------> Lemmatized : Create
# Original : account --------> Lemmatized : account
# Original : Log --------> Lemmatized : Log
# Original : in --------> Lemmatized : in
# Original : Personal --------> Lemmatized : Personal
# Original : tools --------> Lemmatized : tool
# Original : Donate --------> Lemmatized : Donate
# Original : Create --------> Lemmatized : Create
# Original : account --------> Lemmatized : account
# Original : Log --------> Lemmatized : Log
# Original : in --------> Lemmatized : in
# Original : Pages --------> Lemmatized : Pages
# Original : for --------> Lemmatized : for
# Original : logged --------> Lemmatized : logged
# Original : out --------> Lemmatized : out
# Original : editors --------> Lemmatized : editor
# Original : learn --------> Lemmatized : learn
# Original : more --------> Lemmatized : more
# Original : ContributionsTalk --------> Lemmatized : ContributionsTalk
# Original : Contents --------> Lemmatized : Contents
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : ( --------> Lemmatized : (
# Original : Top --------> Lemmatized : Top
# Original : ) --------> Lemmatized : )
# Original : 1 --------> Lemmatized : 1
# Original : History --------> Lemmatized : History
# Original : 2 --------> Lemmatized : 2
# Original : Research --------> Lemmatized : Research
# Original : activities --------> Lemmatized : activity
# Original : 3 --------> Lemmatized : 3
# Original : Centres --------> Lemmatized : Centres
# Original : 4 --------> Lemmatized : 4
# Original : Education --------> Lemmatized : Education
# Original : and --------> Lemmatized : and
# Original : training --------> Lemmatized : training
# Original : 5 --------> Lemmatized : 5
# Original : Commercialization --------> Lemmatized : Commercialization
# Original : 6 --------> Lemmatized : 6
# Original : Products --------> Lemmatized : Products
# Original : and --------> Lemmatized : and
# Original : developments --------> Lemmatized : development
# Original : 7 --------> Lemmatized : 7
# Original : Notable --------> Lemmatized : Notable
# Original : researchers --------> Lemmatized : researcher
# Original : and --------> Lemmatized : and
# Original : alumnus --------> Lemmatized : alumnus
# Original : 8 --------> Lemmatized : 8
# Original : Notable --------> Lemmatized : Notable
# Original : awards --------> Lemmatized : award
# Original : and --------> Lemmatized : and
# Original : accolades --------> Lemmatized : accolade
# Original : 9 --------> Lemmatized : 9
# Original : Other --------> Lemmatized : Other
# Original : projects --------> Lemmatized : project
# Original : 10 --------> Lemmatized : 10
# Original : See --------> Lemmatized : See
# Original : also --------> Lemmatized : also
# Original : 11 --------> Lemmatized : 11
# Original : References --------> Lemmatized : References
# Original : Toggle --------> Lemmatized : Toggle
# Original : the --------> Lemmatized : the
# Original : table --------> Lemmatized : table
# Original : of --------> Lemmatized : of
# Original : contents --------> Lemmatized : content
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : 6 --------> Lemmatized : 6
# Original : languages --------> Lemmatized : language
# Original : हिन्दीമലയാളംमराठीРусскийதமிழ்Українська --------> Lemmatized : हिन्दीമലയാളംमराठीРусскийதமிழ்Українська
# Original : Edit --------> Lemmatized : Edit
# Original : links --------> Lemmatized : link
# Original : ArticleTalk --------> Lemmatized : ArticleTalk
# Original : English --------> Lemmatized : English
# Original : ReadEditView --------> Lemmatized : ReadEditView
# Original : history --------> Lemmatized : history
# Original : Tools --------> Lemmatized : Tools
# Original : Tools --------> Lemmatized : Tools
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : Actions --------> Lemmatized : Actions
# Original : ReadEditView --------> Lemmatized : ReadEditView
# Original : history --------> Lemmatized : history
# Original : General --------> Lemmatized : General
# Original : What --------> Lemmatized : What
# Original : links --------> Lemmatized : link
# Original : hereRelated --------> Lemmatized : hereRelated
# Original : changesUpload --------> Lemmatized : changesUpload
# Original : filePermanent --------> Lemmatized : filePermanent
# Original : linkPage --------> Lemmatized : linkPage
# Original : informationCite --------> Lemmatized : informationCite
# Original : this --------> Lemmatized : this
# Original : pageGet --------> Lemmatized : pageGet
# Original : shortened --------> Lemmatized : shortened
# Original : URLDownload --------> Lemmatized : URLDownload
# Original : QR --------> Lemmatized : QR
# Original : code --------> Lemmatized : code
# Original : Print/export --------> Lemmatized : Print/export
# Original : Download --------> Lemmatized : Download
# Original : as --------> Lemmatized : a
# Original : PDFPrintable --------> Lemmatized : PDFPrintable
# Original : version --------> Lemmatized : version
# Original : In --------> Lemmatized : In
# Original : other --------> Lemmatized : other
# Original : projects --------> Lemmatized : project
# Original : Wikidata --------> Lemmatized : Wikidata
# Original : item --------> Lemmatized : item
# Original : Appearance --------> Lemmatized : Appearance
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : Coordinates --------> Lemmatized : Coordinates
# Original : : --------> Lemmatized : :
# Original : 18°33′06″N --------> Lemmatized : 18°33′06″N
# Original : 73°49′26″E﻿ --------> Lemmatized : 73°49′26″E﻿
# Original : / --------> Lemmatized : /
# Original : ﻿18.551747°N --------> Lemmatized : ﻿18.551747°N
# Original : 73.823750°E﻿ --------> Lemmatized : 73.823750°E﻿
# Original : / --------> Lemmatized : /
# Original : 18.551747 --------> Lemmatized : 18.551747
# Original : ; --------> Lemmatized : ;
# Original : 73.823750 --------> Lemmatized : 73.823750
# Original : From --------> Lemmatized : From
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : free --------> Lemmatized : free
# Original : encyclopedia --------> Lemmatized : encyclopedia
# Original : Autonomous --------> Lemmatized : Autonomous
# Original : scientific --------> Lemmatized : scientific
# Original : society --------> Lemmatized : society
# Original : 18°33′06″N --------> Lemmatized : 18°33′06″N
# Original : 73°49′26″E﻿ --------> Lemmatized : 73°49′26″E﻿
# Original : / --------> Lemmatized : /
# Original : ﻿18.551747°N --------> Lemmatized : ﻿18.551747°N
# Original : 73.823750°E﻿ --------> Lemmatized : 73.823750°E﻿
# Original : / --------> Lemmatized : /
# Original : 18.551747 --------> Lemmatized : 18.551747
# Original : ; --------> Lemmatized : ;
# Original : 73.823750 --------> Lemmatized : 73.823750
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : ComputingMottoज्ञानादेव --------> Lemmatized : ComputingMottoज्ञानादेव
# Original : तु --------> Lemmatized : तु
# Original : कैवल्यम् --------> Lemmatized : कैवल्यम्
# Original : ( --------> Lemmatized : (
# Original : Sanskrit --------> Lemmatized : Sanskrit
# Original : ) --------> Lemmatized : )
# Original : Only --------> Lemmatized : Only
# Original : through --------> Lemmatized : through
# Original : knowledge --------> Lemmatized : knowledge
# Original : one --------> Lemmatized : one
# Original : attains --------> Lemmatized : attains
# Original : liberation --------> Lemmatized : liberation
# Original : ( --------> Lemmatized : (
# Original : English --------> Lemmatized : English
# Original : translated --------> Lemmatized : translated
# Original : ) --------> Lemmatized : )
# Original : Established1988 --------> Lemmatized : Established1988
# Original : ; --------> Lemmatized : ;
# Original : 37 --------> Lemmatized : 37
# Original : years --------> Lemmatized : year
# Original : ago --------> Lemmatized : ago
# Original : ( --------> Lemmatized : (
# Original : 1988 --------> Lemmatized : 1988
# Original : ) --------> Lemmatized : )
# Original : Field --------> Lemmatized : Field
# Original : of --------> Lemmatized : of
# Original : researchHigh --------> Lemmatized : researchHigh
# Original : Performance --------> Lemmatized : Performance
# Original : Computing --------> Lemmatized : Computing
# Original : , --------> Lemmatized : ,
# Original : Multi-lingual --------> Lemmatized : Multi-lingual
# Original : Computing --------> Lemmatized : Computing
# Original : and --------> Lemmatized : and
# Original : Heritage --------> Lemmatized : Heritage
# Original : Computing --------> Lemmatized : Computing
# Original : , --------> Lemmatized : ,
# Original : Professional --------> Lemmatized : Professional
# Original : Electronics --------> Lemmatized : Electronics
# Original : , --------> Lemmatized : ,
# Original : Software --------> Lemmatized : Software
# Original : Technologies --------> Lemmatized : Technologies
# Original : , --------> Lemmatized : ,
# Original : Cyber --------> Lemmatized : Cyber
# Original : Security --------> Lemmatized : Security
# Original : , --------> Lemmatized : ,
# Original : Blockchain --------> Lemmatized : Blockchain
# Original : , --------> Lemmatized : ,
# Original : Data --------> Lemmatized : Data
# Original : Science --------> Lemmatized : Science
# Original : , --------> Lemmatized : ,
# Original : Health --------> Lemmatized : Health
# Original : InformaticsDirectorMagesh --------> Lemmatized : InformaticsDirectorMagesh
# Original : Ethirajan --------> Lemmatized : Ethirajan
# Original : [ --------> Lemmatized : [
# Original : 1 --------> Lemmatized : 1
# Original : ] --------> Lemmatized : ]
# Original : ( --------> Lemmatized : (
# Original : Director --------> Lemmatized : Director
# Original : General --------> Lemmatized : General
# Original : ) --------> Lemmatized : )
# Original : AddressC-DAC --------> Lemmatized : AddressC-DAC
# Original : Innovation --------> Lemmatized : Innovation
# Original : Park --------> Lemmatized : Park
# Original : , --------> Lemmatized : ,
# Original : Panchavati --------> Lemmatized : Panchavati
# Original : , --------> Lemmatized : ,
# Original : Pashan --------> Lemmatized : Pashan
# Original : , --------> Lemmatized : ,
# Original : Pune --------> Lemmatized : Pune
# Original : - --------> Lemmatized : -
# Original : 411 --------> Lemmatized : 411
# Original : 008 --------> Lemmatized : 008
# Original : , --------> Lemmatized : ,
# Original : Maharashtra --------> Lemmatized : Maharashtra
# Original : , --------> Lemmatized : ,
# Original : IndiaLocationPune --------> Lemmatized : IndiaLocationPune
# Original : , --------> Lemmatized : ,
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : headquarters --------> Lemmatized : headquarters
# Original : ) --------> Lemmatized : )
# Original : NicknameC-DACOperating --------> Lemmatized : NicknameC-DACOperating
# Original : agencyMinistry --------> Lemmatized : agencyMinistry
# Original : of --------> Lemmatized : of
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : , --------> Lemmatized : ,
# Original : Government --------> Lemmatized : Government
# Original : of --------> Lemmatized : of
# Original : IndiaWebsitewww.cdac.in --------> Lemmatized : IndiaWebsitewww.cdac.in
# Original : The --------> Lemmatized : The
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : ( --------> Lemmatized : (
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : ) --------> Lemmatized : )
# Original : is --------> Lemmatized : is
# Original : an --------> Lemmatized : an
# Original : Indian --------> Lemmatized : Indian
# Original : autonomous --------> Lemmatized : autonomous
# Original : scientific --------> Lemmatized : scientific
# Original : society --------> Lemmatized : society
# Original : , --------> Lemmatized : ,
# Original : operating --------> Lemmatized : operating
# Original : under --------> Lemmatized : under
# Original : the --------> Lemmatized : the
# Original : Ministry --------> Lemmatized : Ministry
# Original : of --------> Lemmatized : of
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 2 --------> Lemmatized : 2
# Original : ] --------> Lemmatized : ]
# Original : History --------> Lemmatized : History
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : Further --------> Lemmatized : Further
# Original : information --------> Lemmatized : information
# Original : : --------> Lemmatized : :
# Original : Supercomputing --------> Lemmatized : Supercomputing
# Original : in --------> Lemmatized : in
# Original : India --------> Lemmatized : India
# Original : and --------> Lemmatized : and
# Original : PARAM --------> Lemmatized : PARAM
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : was --------> Lemmatized : wa
# Original : created --------> Lemmatized : created
# Original : in --------> Lemmatized : in
# Original : November --------> Lemmatized : November
# Original : 1987 --------> Lemmatized : 1987
# Original : , --------> Lemmatized : ,
# Original : [ --------> Lemmatized : [
# Original : 3 --------> Lemmatized : 3
# Original : ] --------> Lemmatized : ]
# Original : initially --------> Lemmatized : initially
# Original : as --------> Lemmatized : a
# Original : the --------> Lemmatized : the
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : C-DACT --------> Lemmatized : C-DACT
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 4 --------> Lemmatized : 4
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 3 --------> Lemmatized : 3
# Original : ] --------> Lemmatized : ]
# Original : In --------> Lemmatized : In
# Original : 1988 --------> Lemmatized : 1988
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : US --------> Lemmatized : US
# Original : Government --------> Lemmatized : Government
# Original : refused --------> Lemmatized : refused
# Original : to --------> Lemmatized : to
# Original : sell --------> Lemmatized : sell
# Original : India --------> Lemmatized : India
# Original : a --------> Lemmatized : a
# Original : Cray --------> Lemmatized : Cray
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : due --------> Lemmatized : due
# Original : to --------> Lemmatized : to
# Original : concerns --------> Lemmatized : concern
# Original : about --------> Lemmatized : about
# Original : India --------> Lemmatized : India
# Original : using --------> Lemmatized : using
# Original : it --------> Lemmatized : it
# Original : to --------> Lemmatized : to
# Original : develop --------> Lemmatized : develop
# Original : nuclear --------> Lemmatized : nuclear
# Original : weapons --------> Lemmatized : weapon
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 5 --------> Lemmatized : 5
# Original : ] --------> Lemmatized : ]
# Original : In --------> Lemmatized : In
# Original : response --------> Lemmatized : response
# Original : India --------> Lemmatized : India
# Original : started --------> Lemmatized : started
# Original : development --------> Lemmatized : development
# Original : of --------> Lemmatized : of
# Original : its --------> Lemmatized : it
# Original : own --------> Lemmatized : own
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : , --------> Lemmatized : ,
# Original : and --------> Lemmatized : and
# Original : C-DACT --------> Lemmatized : C-DACT
# Original : was --------> Lemmatized : wa
# Original : created --------> Lemmatized : created
# Original : as --------> Lemmatized : a
# Original : part --------> Lemmatized : part
# Original : of --------> Lemmatized : of
# Original : this --------> Lemmatized : this
# Original : programme --------> Lemmatized : programme
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 6 --------> Lemmatized : 6
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : Dr --------> Lemmatized : Dr
# Original : Vijay --------> Lemmatized : Vijay
# Original : Bhatkar --------> Lemmatized : Bhatkar
# Original : was --------> Lemmatized : wa
# Original : hired --------> Lemmatized : hired
# Original : as --------> Lemmatized : a
# Original : the --------> Lemmatized : the
# Original : director --------> Lemmatized : director
# Original : of --------> Lemmatized : of
# Original : C-DACT --------> Lemmatized : C-DACT
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : project --------> Lemmatized : project
# Original : was --------> Lemmatized : wa
# Original : given --------> Lemmatized : given
# Original : an --------> Lemmatized : an
# Original : initial --------> Lemmatized : initial
# Original : run --------> Lemmatized : run
# Original : of --------> Lemmatized : of
# Original : three --------> Lemmatized : three
# Original : years --------> Lemmatized : year
# Original : and --------> Lemmatized : and
# Original : an --------> Lemmatized : an
# Original : initial --------> Lemmatized : initial
# Original : funding --------> Lemmatized : funding
# Original : of --------> Lemmatized : of
# Original : ₹30,00,00,000 --------> Lemmatized : ₹30,00,00,000
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : cost --------> Lemmatized : cost
# Original : of --------> Lemmatized : of
# Original : a --------> Lemmatized : a
# Original : Cray --------> Lemmatized : Cray
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : A --------> Lemmatized : A
# Original : prototype --------> Lemmatized : prototype
# Original : computer --------> Lemmatized : computer
# Original : was --------> Lemmatized : wa
# Original : benchmarked --------> Lemmatized : benchmarked
# Original : at --------> Lemmatized : at
# Original : the --------> Lemmatized : the
# Original : 1990 --------> Lemmatized : 1990
# Original : Zurich --------> Lemmatized : Zurich
# Original : Super-computing --------> Lemmatized : Super-computing
# Original : Show --------> Lemmatized : Show
# Original : . --------> Lemmatized : .
# Original : It --------> Lemmatized : It
# Original : demonstrated --------> Lemmatized : demonstrated
# Original : that --------> Lemmatized : that
# Original : India --------> Lemmatized : India
# Original : had --------> Lemmatized : had
# Original : the --------> Lemmatized : the
# Original : second --------> Lemmatized : second
# Original : most --------> Lemmatized : most
# Original : powerful --------> Lemmatized : powerful
# Original : , --------> Lemmatized : ,
# Original : publicly --------> Lemmatized : publicly
# Original : demonstrated --------> Lemmatized : demonstrated
# Original : , --------> Lemmatized : ,
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : in --------> Lemmatized : in
# Original : the --------> Lemmatized : the
# Original : world --------> Lemmatized : world
# Original : after --------> Lemmatized : after
# Original : the --------> Lemmatized : the
# Original : United --------> Lemmatized : United
# Original : States --------> Lemmatized : States
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 8 --------> Lemmatized : 8
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : final --------> Lemmatized : final
# Original : result --------> Lemmatized : result
# Original : of --------> Lemmatized : of
# Original : the --------> Lemmatized : the
# Original : effort --------> Lemmatized : effort
# Original : was --------> Lemmatized : wa
# Original : the --------> Lemmatized : the
# Original : PARAM --------> Lemmatized : PARAM
# Original : 8000 --------> Lemmatized : 8000
# Original : , --------> Lemmatized : ,
# Original : released --------> Lemmatized : released
# Original : in --------> Lemmatized : in
# Original : 1991 --------> Lemmatized : 1991
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 9 --------> Lemmatized : 9
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : National --------> Lemmatized : National
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Software --------> Lemmatized : Software
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : NCST --------> Lemmatized : NCST
# Original : ) --------> Lemmatized : )
# Original : , --------> Lemmatized : ,
# Original : Electronic --------> Lemmatized : Electronic
# Original : Research --------> Lemmatized : Research
# Original : and --------> Lemmatized : and
# Original : Development --------> Lemmatized : Development
# Original : Centre --------> Lemmatized : Centre
# Original : ( --------> Lemmatized : (
# Original : ER --------> Lemmatized : ER
# Original : & --------> Lemmatized : &
# Original : DC --------> Lemmatized : DC
# Original : ) --------> Lemmatized : )
# Original : and --------> Lemmatized : and
# Original : CEDTI --------> Lemmatized : CEDTI
# Original : were --------> Lemmatized : were
# Original : merged --------> Lemmatized : merged
# Original : into --------> Lemmatized : into
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : in --------> Lemmatized : in
# Original : 2003 --------> Lemmatized : 2003
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 10 --------> Lemmatized : 10
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 11 --------> Lemmatized : 11
# Original : ] --------> Lemmatized : ]
# Original : Research --------> Lemmatized : Research
# Original : activities --------> Lemmatized : activity
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : Originally --------> Lemmatized : Originally
# Original : established --------> Lemmatized : established
# Original : to --------> Lemmatized : to
# Original : research --------> Lemmatized : research
# Original : and --------> Lemmatized : and
# Original : assemble --------> Lemmatized : assemble
# Original : High --------> Lemmatized : High
# Original : Performance --------> Lemmatized : Performance
# Original : Computers --------> Lemmatized : Computers
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : research --------> Lemmatized : research
# Original : of --------> Lemmatized : of
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : now --------> Lemmatized : now
# Original : includes --------> Lemmatized : includes
# Original : : --------> Lemmatized : :
# Original : High --------> Lemmatized : High
# Original : Performance --------> Lemmatized : Performance
# Original : Computing --------> Lemmatized : Computing
# Original : Grid --------> Lemmatized : Grid
# Original : Computing --------> Lemmatized : Computing
# Original : Cloud --------> Lemmatized : Cloud
# Original : Computing --------> Lemmatized : Computing
# Original : Multilingual --------> Lemmatized : Multilingual
# Original : and --------> Lemmatized : and
# Original : Heritage --------> Lemmatized : Heritage
# Original : Computing --------> Lemmatized : Computing
# Original : VLSI --------> Lemmatized : VLSI
# Original : and --------> Lemmatized : and
# Original : Processor --------> Lemmatized : Processor
# Original : design --------> Lemmatized : design
# Original : Embedded --------> Lemmatized : Embedded
# Original : Systems --------> Lemmatized : Systems
# Original : Speech --------> Lemmatized : Speech
# Original : and --------> Lemmatized : and
# Original : Natural --------> Lemmatized : Natural
# Original : Language --------> Lemmatized : Language
# Original : Processing --------> Lemmatized : Processing
# Original : Information --------> Lemmatized : Information
# Original : and --------> Lemmatized : and
# Original : Cyber --------> Lemmatized : Cyber
# Original : Security --------> Lemmatized : Security
# Original : Ubiquitous --------> Lemmatized : Ubiquitous
# Original : Computing --------> Lemmatized : Computing
# Original : Bioinformatics --------> Lemmatized : Bioinformatics
# Original : Geomatics --------> Lemmatized : Geomatics
# Original : Digital --------> Lemmatized : Digital
# Original : forensics --------> Lemmatized : forensics
# Original : Big --------> Lemmatized : Big
# Original : data --------> Lemmatized : data
# Original : analytics --------> Lemmatized : analytics
# Original : Blockchain --------> Lemmatized : Blockchain
# Original : Health --------> Lemmatized : Health
# Original : Informatics --------> Lemmatized : Informatics
# Original : Quantum --------> Lemmatized : Quantum
# Original : computing --------> Lemmatized : computing
# Original : Centres --------> Lemmatized : Centres
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : branches --------> Lemmatized : branch
# Original : and --------> Lemmatized : and
# Original : training --------> Lemmatized : training
# Original : centres --------> Lemmatized : centre
# Original : include --------> Lemmatized : include
# Original : : --------> Lemmatized : :
# Original : [ --------> Lemmatized : [
# Original : 12 --------> Lemmatized : 12
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Pune --------> Lemmatized : Pune
# Original : ( --------> Lemmatized : (
# Original : Headquarters --------> Lemmatized : Headquarters
# Original : ) --------> Lemmatized : )
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Mumbai --------> Lemmatized : Mumbai
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Bangalore --------> Lemmatized : Bangalore
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Chennai --------> Lemmatized : Chennai
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Delhi --------> Lemmatized : Delhi
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Kolkata --------> Lemmatized : Kolkata
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Patna --------> Lemmatized : Patna
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Mohali --------> Lemmatized : Mohali
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Noida --------> Lemmatized : Noida
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Hyderabad --------> Lemmatized : Hyderabad
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Thiruvananthapuram --------> Lemmatized : Thiruvananthapuram
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Silchar --------> Lemmatized : Silchar
# Original : Education --------> Lemmatized : Education
# Original : and --------> Lemmatized : and
# Original : training --------> Lemmatized : training
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : provides --------> Lemmatized : provides
# Original : several --------> Lemmatized : several
# Original : courses --------> Lemmatized : course
# Original : in --------> Lemmatized : in
# Original : the --------> Lemmatized : the
# Original : field --------> Lemmatized : field
# Original : of --------> Lemmatized : of
# Original : advanced --------> Lemmatized : advanced
# Original : computing --------> Lemmatized : computing
# Original : and --------> Lemmatized : and
# Original : software --------> Lemmatized : software
# Original : development --------> Lemmatized : development
# Original : . --------> Lemmatized : .
# Original : Among --------> Lemmatized : Among
# Original : these --------> Lemmatized : these
# Original : are --------> Lemmatized : are
# Original : the --------> Lemmatized : the
# Original : HPC --------> Lemmatized : HPC
# Original : certification --------> Lemmatized : certification
# Original : course- --------> Lemmatized : course-
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Certified --------> Lemmatized : Certified
# Original : HPC --------> Lemmatized : HPC
# Original : Professional --------> Lemmatized : Professional
# Original : Certification --------> Lemmatized : Certification
# Original : Programme --------> Lemmatized : Programme
# Original : ( --------> Lemmatized : (
# Original : CCHPCP --------> Lemmatized : CCHPCP
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 13 --------> Lemmatized : 13
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : organises --------> Lemmatized : organises
# Original : advanced --------> Lemmatized : advanced
# Original : computing --------> Lemmatized : computing
# Original : diploma --------> Lemmatized : diploma
# Original : programmes --------> Lemmatized : programme
# Original : through --------> Lemmatized : through
# Original : the --------> Lemmatized : the
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : Training --------> Lemmatized : Training
# Original : School --------> Lemmatized : School
# Original : ( --------> Lemmatized : (
# Original : ACTS --------> Lemmatized : ACTS
# Original : ) --------> Lemmatized : )
# Original : located --------> Lemmatized : located
# Original : all --------> Lemmatized : all
# Original : over --------> Lemmatized : over
# Original : India --------> Lemmatized : India
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 14 --------> Lemmatized : 14
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : PG --------> Lemmatized : PG
# Original : Diploma --------> Lemmatized : Diploma
# Original : courses --------> Lemmatized : course
# Original : include --------> Lemmatized : include
# Original : Specialisations --------> Lemmatized : Specialisations
# Original : in --------> Lemmatized : in
# Original : Embedded --------> Lemmatized : Embedded
# Original : System --------> Lemmatized : System
# Original : Design --------> Lemmatized : Design
# Original : , --------> Lemmatized : ,
# Original : VLSI --------> Lemmatized : VLSI
# Original : , --------> Lemmatized : ,
# Original : Big --------> Lemmatized : Big
# Original : Data --------> Lemmatized : Data
# Original : Analytics --------> Lemmatized : Analytics
# Original : , --------> Lemmatized : ,
# Original : Geoinformatics --------> Lemmatized : Geoinformatics
# Original : , --------> Lemmatized : ,
# Original : Artificial --------> Lemmatized : Artificial
# Original : Intelligence --------> Lemmatized : Intelligence
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : has --------> Lemmatized : ha
# Original : also --------> Lemmatized : also
# Original : established --------> Lemmatized : established
# Original : Centres --------> Lemmatized : Centres
# Original : of --------> Lemmatized : of
# Original : Excellence --------> Lemmatized : Excellence
# Original : in --------> Lemmatized : in
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : CEIT --------> Lemmatized : CEIT
# Original : ) --------> Lemmatized : )
# Original : abroad --------> Lemmatized : abroad
# Original : under --------> Lemmatized : under
# Original : the --------> Lemmatized : the
# Original : Ministry --------> Lemmatized : Ministry
# Original : of --------> Lemmatized : of
# Original : External --------> Lemmatized : External
# Original : Affairs --------> Lemmatized : Affairs
# Original : ' --------> Lemmatized : '
# Original : s --------> Lemmatized : s
# Original : development --------> Lemmatized : development
# Original : partnership --------> Lemmatized : partnership
# Original : projects --------> Lemmatized : project
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 15 --------> Lemmatized : 15
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 16 --------> Lemmatized : 16
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 17 --------> Lemmatized : 17
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 18 --------> Lemmatized : 18
# Original : ] --------> Lemmatized : ]
# Original : Commercialization --------> Lemmatized : Commercialization
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : This --------> Lemmatized : This
# Original : article --------> Lemmatized : article
# Original : appears --------> Lemmatized : appears
# Original : to --------> Lemmatized : to
# Original : contain --------> Lemmatized : contain
# Original : a --------> Lemmatized : a
# Original : large --------> Lemmatized : large
# Original : number --------> Lemmatized : number
# Original : of --------> Lemmatized : of
# Original : buzzwords --------> Lemmatized : buzzword
# Original : . --------> Lemmatized : .
# Original : There --------> Lemmatized : There
# Original : might --------> Lemmatized : might
# Original : be --------> Lemmatized : be
# Original : a --------> Lemmatized : a
# Original : discussion --------> Lemmatized : discussion
# Original : about --------> Lemmatized : about
# Original : this --------> Lemmatized : this
# Original : on --------> Lemmatized : on
# Original : the --------> Lemmatized : the
# Original : talk --------> Lemmatized : talk
# Original : page --------> Lemmatized : page
# Original : . --------> Lemmatized : .
# Original : Please --------> Lemmatized : Please
# Original : help --------> Lemmatized : help
# Original : improve --------> Lemmatized : improve
# Original : this --------> Lemmatized : this
# Original : article --------> Lemmatized : article
# Original : if --------> Lemmatized : if
# Original : you --------> Lemmatized : you
# Original : can --------> Lemmatized : can
# Original : . --------> Lemmatized : .
# Original : ( --------> Lemmatized : (
# Original : April --------> Lemmatized : April
# Original : 2025 --------> Lemmatized : 2025
# Original : ) --------> Lemmatized : )
# Original : On --------> Lemmatized : On
# Original : August --------> Lemmatized : August
# Original : 28 --------> Lemmatized : 28
# Original : , --------> Lemmatized : ,
# Original : 2024 --------> Lemmatized : 2024
# Original : , --------> Lemmatized : ,
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : and --------> Lemmatized : and
# Original : L --------> Lemmatized : L
# Original : & --------> Lemmatized : &
# Original : T --------> Lemmatized : T
# Original : Semiconductor --------> Lemmatized : Semiconductor
# Original : Technologies --------> Lemmatized : Technologies
# Original : ( --------> Lemmatized : (
# Original : LTSCT --------> Lemmatized : LTSCT
# Original : ) --------> Lemmatized : )
# Original : signed --------> Lemmatized : signed
# Original : a --------> Lemmatized : a
# Original : Memorandum --------> Lemmatized : Memorandum
# Original : of --------> Lemmatized : of
# Original : Understanding --------> Lemmatized : Understanding
# Original : ( --------> Lemmatized : (
# Original : MoU --------> Lemmatized : MoU
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : It --------> Lemmatized : It
# Original : will --------> Lemmatized : will
# Original : establish --------> Lemmatized : establish
# Original : a --------> Lemmatized : a
# Original : program --------> Lemmatized : program
# Original : for --------> Lemmatized : for
# Original : the --------> Lemmatized : the
# Original : commercialization --------> Lemmatized : commercialization
# Original : of --------> Lemmatized : of
# Original : cutting-edge --------> Lemmatized : cutting-edge
# Original : technologies --------> Lemmatized : technology
# Original : created --------> Lemmatized : created
# Original : by --------> Lemmatized : by
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : in --------> Lemmatized : in
# Original : the --------> Lemmatized : the
# Original : areas --------> Lemmatized : area
# Original : of --------> Lemmatized : of
# Original : power --------> Lemmatized : power
# Original : systems --------> Lemmatized : system
# Original : , --------> Lemmatized : ,
# Original : embedded --------> Lemmatized : embedded
# Original : software --------> Lemmatized : software
# Original : , --------> Lemmatized : ,
# Original : open-source --------> Lemmatized : open-source
# Original : operating --------> Lemmatized : operating
# Original : systems --------> Lemmatized : system
# Original : , --------> Lemmatized : ,
# Original : high --------> Lemmatized : high
# Original : performance --------> Lemmatized : performance
# Original : computing --------> Lemmatized : computing
# Original : , --------> Lemmatized : ,
# Original : and --------> Lemmatized : and
# Original : semiconductor --------> Lemmatized : semiconductor
# Original : design --------> Lemmatized : design
# Original : and --------> Lemmatized : and
# Original : development --------> Lemmatized : development
# Original : . --------> Lemmatized : .
# Original : LTSCT --------> Lemmatized : LTSCT
# Original : will --------> Lemmatized : will
# Original : leverage --------> Lemmatized : leverage
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : 's --------> Lemmatized : 's
# Original : extensive --------> Lemmatized : extensive
# Original : pipeline --------> Lemmatized : pipeline
# Original : of --------> Lemmatized : of
# Original : in-house --------> Lemmatized : in-house
# Original : intellectual --------> Lemmatized : intellectual
# Original : property --------> Lemmatized : property
# Original : ( --------> Lemmatized : (
# Original : IPs --------> Lemmatized : IPs
# Original : ) --------> Lemmatized : )
# Original : , --------> Lemmatized : ,
# Original : which --------> Lemmatized : which
# Original : includes --------> Lemmatized : includes
# Original : the --------> Lemmatized : the
# Original : VEGA --------> Lemmatized : VEGA
# Original : processor --------> Lemmatized : processor
# Original : , --------> Lemmatized : ,
# Original : to --------> Lemmatized : to
# Original : create --------> Lemmatized : create
# Original : global --------> Lemmatized : global
# Original : product --------> Lemmatized : product
# Original : prospects --------> Lemmatized : prospect
# Original : through --------> Lemmatized : through
# Original : application --------> Lemmatized : application
# Original : design --------> Lemmatized : design
# Original : and --------> Lemmatized : and
# Original : validation --------> Lemmatized : validation
# Original : for --------> Lemmatized : for
# Original : Field --------> Lemmatized : Field
# Original : Programmable --------> Lemmatized : Programmable
# Original : Gate --------> Lemmatized : Gate
# Original : Arrays --------> Lemmatized : Arrays
# Original : . --------> Lemmatized : .
# Original : By --------> Lemmatized : By
# Original : facilitating --------> Lemmatized : facilitating
# Original : the --------> Lemmatized : the
# Original : creation --------> Lemmatized : creation
# Original : of --------> Lemmatized : of
# Original : cutting-edge --------> Lemmatized : cutting-edge
# Original : goods --------> Lemmatized : good
# Original : and --------> Lemmatized : and
# Original : solutions --------> Lemmatized : solution
# Original : for --------> Lemmatized : for
# Original : the --------> Lemmatized : the
# Original : automotive --------> Lemmatized : automotive
# Original : , --------> Lemmatized : ,
# Original : industrial --------> Lemmatized : industrial
# Original : , --------> Lemmatized : ,
# Original : information --------> Lemmatized : information
# Original : and --------> Lemmatized : and
# Original : communications --------> Lemmatized : communication
# Original : technology --------> Lemmatized : technology
# Original : infrastructure --------> Lemmatized : infrastructure
# Original : , --------> Lemmatized : ,
# Original : and --------> Lemmatized : and
# Original : energy --------> Lemmatized : energy
# Original : sectors --------> Lemmatized : sector
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : collaboration --------> Lemmatized : collaboration
# Original : to --------> Lemmatized : to
# Original : create --------> Lemmatized : create
# Original : indigenous --------> Lemmatized : indigenous
# Original : ICs --------> Lemmatized : ICs
# Original : and --------> Lemmatized : and
# Original : SoCs --------> Lemmatized : SoCs
# Original : based --------> Lemmatized : based
# Original : in --------> Lemmatized : in
# Original : Vega --------> Lemmatized : Vega
# Original : is --------> Lemmatized : is
# Original : expected --------> Lemmatized : expected
# Original : to --------> Lemmatized : to
# Original : pick --------> Lemmatized : pick
# Original : up --------> Lemmatized : up
# Original : speed --------> Lemmatized : speed
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 19 --------> Lemmatized : 19
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 20 --------> Lemmatized : 20
# Original : ] --------> Lemmatized : ]
# Original : Products --------> Lemmatized : Products
# Original : and --------> Lemmatized : and
# Original : developments --------> Lemmatized : development
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : PARAM --------> Lemmatized : PARAM
# Original : series --------> Lemmatized : series
# Original : of --------> Lemmatized : of
# Original : supercomputers --------> Lemmatized : supercomputer
# Original : [ --------> Lemmatized : [
# Original : 21 --------> Lemmatized : 21
# Original : ] --------> Lemmatized : ]
# Original : VEGA --------> Lemmatized : VEGA
# Original : Microprocessors --------> Lemmatized : Microprocessors
# Original : , --------> Lemmatized : ,
# Original : India --------> Lemmatized : India
# Original : 's --------> Lemmatized : 's
# Original : first --------> Lemmatized : first
# Original : indigenous --------> Lemmatized : indigenous
# Original : 64-bit --------> Lemmatized : 64-bit
# Original : Multi-core --------> Lemmatized : Multi-core
# Original : Superscalar --------> Lemmatized : Superscalar
# Original : Out-of-Order --------> Lemmatized : Out-of-Order
# Original : RISC-V --------> Lemmatized : RISC-V
# Original : Processor --------> Lemmatized : Processor
# Original : [ --------> Lemmatized : [
# Original : 22 --------> Lemmatized : 22
# Original : ] --------> Lemmatized : ]
# Original : M-Kavach --------> Lemmatized : M-Kavach
# Original : 2 --------> Lemmatized : 2
# Original : , --------> Lemmatized : ,
# Original : an --------> Lemmatized : an
# Original : android-based --------> Lemmatized : android-based
# Original : mobile --------> Lemmatized : mobile
# Original : device --------> Lemmatized : device
# Original : security --------> Lemmatized : security
# Original : solution --------> Lemmatized : solution
# Original : addressing --------> Lemmatized : addressing
# Original : emerging --------> Lemmatized : emerging
# Original : threats --------> Lemmatized : threat
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 23 --------> Lemmatized : 23
# Original : ] --------> Lemmatized : ]
# Original : Mobile --------> Lemmatized : Mobile
# Original : Seva --------> Lemmatized : Seva
# Original : AppStore --------> Lemmatized : AppStore
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : mobile --------> Lemmatized : mobile
# Original : app --------> Lemmatized : app
# Original : marketplace --------> Lemmatized : marketplace
# Original : [ --------> Lemmatized : [
# Original : 24 --------> Lemmatized : 24
# Original : ] --------> Lemmatized : ]
# Original : Bharat --------> Lemmatized : Bharat
# Original : Operating --------> Lemmatized : Operating
# Original : System --------> Lemmatized : System
# Original : Solutions --------> Lemmatized : Solutions
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : Linux-based --------> Lemmatized : Linux-based
# Original : general --------> Lemmatized : general
# Original : purpose --------> Lemmatized : purpose
# Original : operating --------> Lemmatized : operating
# Original : system --------> Lemmatized : system
# Original : [ --------> Lemmatized : [
# Original : 25 --------> Lemmatized : 25
# Original : ] --------> Lemmatized : ]
# Original : Anvaya --------> Lemmatized : Anvaya
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : workflow --------> Lemmatized : workflow
# ...
# Original : India --------> Lemmatized : India
# Original : IN --------> Lemmatized : IN
# Original : Registry --------> Lemmatized : Registry
# Original : .in --------> Lemmatized : .in
# Original : .भारत --------> Lemmatized : .भारत
# Original : Other --------> Lemmatized : Other
# Original : Standardisation --------> Lemmatized : Standardisation
# Original : Testing --------> Lemmatized : Testing
# Original : and --------> Lemmatized : and
# Original : Quality --------> Lemmatized : Quality
# Original : Certification --------> Lemmatized : Certification
# Original : Directorate --------> Lemmatized : Directorate
# Original : ( --------> Lemmatized : (
# Original : STQC --------> Lemmatized : STQC
# Original : ) --------> Lemmatized : )
# Original : Controller --------> Lemmatized : Controller
# Original : of --------> Lemmatized : of
# Original : Certifying --------> Lemmatized : Certifying
# Original : Authorities --------> Lemmatized : Authorities
# Original : ( --------> Lemmatized : (
# Original : CCA --------> Lemmatized : CCA
# Original : ) --------> Lemmatized : )
# Original : Cyber --------> Lemmatized : Cyber
# Original : Appellate --------> Lemmatized : Appellate
# Original : Tribunal --------> Lemmatized : Tribunal
# Original : ( --------> Lemmatized : (
# Original : CAT --------> Lemmatized : CAT
# Original : ) --------> Lemmatized : )
# Original : Indian --------> Lemmatized : Indian
# Original : Computer --------> Lemmatized : Computer
# Original : Emergency --------> Lemmatized : Emergency
# Original : Response --------> Lemmatized : Response
# Original : Team --------> Lemmatized : Team
# Original : ( --------> Lemmatized : (
# Original : ICERT --------> Lemmatized : ICERT
# Original : ) --------> Lemmatized : )
# Original : Companies --------> Lemmatized : Companies
# Original : CSC --------> Lemmatized : CSC
# Original : e-Governance --------> Lemmatized : e-Governance
# Original : Services --------> Lemmatized : Services
# Original : India --------> Lemmatized : India
# Original : Limited --------> Lemmatized : Limited
# Original : Media --------> Lemmatized : Media
# Original : Lab --------> Lemmatized : Lab
# Original : Asia --------> Lemmatized : Asia
# Original : ( --------> Lemmatized : (
# Original : MLAsia --------> Lemmatized : MLAsia
# Original : ) --------> Lemmatized : )
# Original : National --------> Lemmatized : National
# Original : Informatics --------> Lemmatized : Informatics
# Original : Centre --------> Lemmatized : Centre
# Original : Services --------> Lemmatized : Services
# Original : Incorporated --------> Lemmatized : Incorporated
# Original : ( --------> Lemmatized : (
# Original : NICSI --------> Lemmatized : NICSI
# Original : ) --------> Lemmatized : )
# Original : — --------> Lemmatized : —
# Original : PSE --------> Lemmatized : PSE
# Original : under --------> Lemmatized : under
# Original : National --------> Lemmatized : National
# Original : Informatics --------> Lemmatized : Informatics
# Original : Centre --------> Lemmatized : Centre
# Original : National --------> Lemmatized : National
# Original : Internet --------> Lemmatized : Internet
# Original : Exchange --------> Lemmatized : Exchange
# Original : of --------> Lemmatized : of
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : NIXI --------> Lemmatized : NIXI
# Original : ) --------> Lemmatized : )
# Original : STPI --------> Lemmatized : STPI
# Original : Unique --------> Lemmatized : Unique
# Original : Identification --------> Lemmatized : Identification
# Original : Authority --------> Lemmatized : Authority
# Original : of --------> Lemmatized : of
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : UIDAI --------> Lemmatized : UIDAI
# Original : ) --------> Lemmatized : )
# Original : AutonomousSocieties --------> Lemmatized : AutonomousSocieties
# Original : Education --------> Lemmatized : Education
# Original : and --------> Lemmatized : and
# Original : Research --------> Lemmatized : Research
# Original : in --------> Lemmatized : in
# Original : Computer --------> Lemmatized : Computer
# Original : Networking --------> Lemmatized : Networking
# Original : ( --------> Lemmatized : (
# Original : ERNET --------> Lemmatized : ERNET
# Original : ) --------> Lemmatized : )
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : ( --------> Lemmatized : (
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : ) --------> Lemmatized : )
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Materials --------> Lemmatized : Materials
# Original : for --------> Lemmatized : for
# Original : Electronics --------> Lemmatized : Electronics
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : C-MET --------> Lemmatized : C-MET
# Original : ) --------> Lemmatized : )
# Original : National --------> Lemmatized : National
# Original : Institute --------> Lemmatized : Institute
# Original : of --------> Lemmatized : of
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : NIELIT --------> Lemmatized : NIELIT
# Original : ) --------> Lemmatized : )
# Original : — --------> Lemmatized : —
# Original : Formerly --------> Lemmatized : Formerly
# Original : DOEACC --------> Lemmatized : DOEACC
# Original : Society --------> Lemmatized : Society
# Original : Society --------> Lemmatized : Society
# Original : for --------> Lemmatized : for
# Original : Applied --------> Lemmatized : Applied
# Original : Microwave --------> Lemmatized : Microwave
# Original : Electronics --------> Lemmatized : Electronics
# Original : Engineering --------> Lemmatized : Engineering
# Original : and --------> Lemmatized : and
# Original : Research --------> Lemmatized : Research
# Original : ( --------> Lemmatized : (
# Original : SAMEER --------> Lemmatized : SAMEER
# Original : ) --------> Lemmatized : )
# Original : Software --------> Lemmatized : Software
# Original : Technology --------> Lemmatized : Technology
# Original : Parks --------> Lemmatized : Parks
# Original : of --------> Lemmatized : of
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : STPI --------> Lemmatized : STPI
# Original : ) --------> Lemmatized : )
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Computer --------> Lemmatized : Computer
# Original : Software --------> Lemmatized : Software
# Original : Export --------> Lemmatized : Export
# Original : Promotion --------> Lemmatized : Promotion
# Original : Council --------> Lemmatized : Council
# Original : ( --------> Lemmatized : (
# Original : ESC --------> Lemmatized : ESC
# Original : ) --------> Lemmatized : )
# Original : Semi-Conductor --------> Lemmatized : Semi-Conductor
# Original : Laboratory --------> Lemmatized : Laboratory
# Original : ( --------> Lemmatized : (
# Original : SCL --------> Lemmatized : SCL
# Original : ) --------> Lemmatized : )
# Original : Ministers --------> Lemmatized : Ministers
# Original : Ashwini --------> Lemmatized : Ashwini
# Original : Vaishnaw --------> Lemmatized : Vaishnaw
# Original : ( --------> Lemmatized : (
# Original : incumbent --------> Lemmatized : incumbent
# Original : ) --------> Lemmatized : )
# Original : Ministers --------> Lemmatized : Ministers
# Original : of --------> Lemmatized : of
# Original : State --------> Lemmatized : State
# Original : Jitin --------> Lemmatized : Jitin
# Original : Prasada --------> Lemmatized : Prasada
# Original : ( --------> Lemmatized : (
# Original : incumbent --------> Lemmatized : incumbent
# Original : ) --------> Lemmatized : )
# Original : Authority --------> Lemmatized : Authority
# Original : control --------> Lemmatized : control
# Original : databases --------> Lemmatized : database
# Original : InternationalISNIVIAFNationalGermanyUnited --------> Lemmatized : InternationalISNIVIAFNationalGermanyUnited
# Original : StatesIsrael --------> Lemmatized : StatesIsrael
# Original : Retrieved --------> Lemmatized : Retrieved
# Original : from --------> Lemmatized : from
# Original : `` --------> Lemmatized : ``
# Original : https --------> Lemmatized : http
# Original : : --------> Lemmatized : :
# Original : //en.wikipedia.org/w/index.php --------> Lemmatized : //en.wikipedia.org/w/index.php
# Original : ? --------> Lemmatized : ?
# Original : title=Centre_for_Development_of_Advanced_Computing --------> Lemmatized : title=Centre_for_Development_of_Advanced_Computing
# Original : & --------> Lemmatized : &
# Original : oldid=1285579997 --------> Lemmatized : oldid=1285579997
# Original : '' --------> Lemmatized : ''
# Original : Categories --------> Lemmatized : Categories
# Original : : --------> Lemmatized : :
# Original : Research --------> Lemmatized : Research
# Original : institutes --------> Lemmatized : institute
# Original : in --------> Lemmatized : in
# Original : PuneInformation --------> Lemmatized : PuneInformation
# Original : technology --------> Lemmatized : technology
# Original : organisations --------> Lemmatized : organisation
# Original : based --------> Lemmatized : based
# Original : in --------> Lemmatized : in
# Original : India1988 --------> Lemmatized : India1988
# Original : establishments --------> Lemmatized : establishment
# Original : in --------> Lemmatized : in
# Original : MaharashtraResearch --------> Lemmatized : MaharashtraResearch
# Original : institutes --------> Lemmatized : institute
# Original : established --------> Lemmatized : established
# Original : in --------> Lemmatized : in
# Original : 1988Hidden --------> Lemmatized : 1988Hidden
# Original : categories --------> Lemmatized : category
# Original : : --------> Lemmatized : :
# Original : Pages --------> Lemmatized : Pages
# Original : using --------> Lemmatized : using
# Original : gadget --------> Lemmatized : gadget
# Original : WikiMiniAtlasArticles --------> Lemmatized : WikiMiniAtlasArticles
# Original : with --------> Lemmatized : with
# Original : short --------> Lemmatized : short
# Original : descriptionShort --------> Lemmatized : descriptionShort
# Original : description --------> Lemmatized : description
# Original : matches --------> Lemmatized : match
# Original : WikidataEngvarB --------> Lemmatized : WikidataEngvarB
# Original : from --------> Lemmatized : from
# Original : July --------> Lemmatized : July
# Original : 2015Use --------> Lemmatized : 2015Use
# Original : dmy --------> Lemmatized : dmy
# Original : dates --------> Lemmatized : date
# Original : from --------> Lemmatized : from
# Original : July --------> Lemmatized : July
# Original : 2015Coordinates --------> Lemmatized : 2015Coordinates
# Original : on --------> Lemmatized : on
# Original : WikidataArticles --------> Lemmatized : WikidataArticles
# Original : containing --------> Lemmatized : containing
# Original : Sanskrit-language --------> Lemmatized : Sanskrit-language
# Original : textWikipedia --------> Lemmatized : textWikipedia
# Original : articles --------> Lemmatized : article
# Original : containing --------> Lemmatized : containing
# Original : buzzwords --------> Lemmatized : buzzword
# Original : from --------> Lemmatized : from
# Original : April --------> Lemmatized : April
# Original : 2025 --------> Lemmatized : 2025
# Original : This --------> Lemmatized : This
# Original : page --------> Lemmatized : page
# Original : was --------> Lemmatized : wa
# Original : last --------> Lemmatized : last
# Original : edited --------> Lemmatized : edited
# Original : on --------> Lemmatized : on
# Original : 14 --------> Lemmatized : 14
# Original : April --------> Lemmatized : April
# Original : 2025 --------> Lemmatized : 2025
# Original : , --------> Lemmatized : ,
# Original : at --------> Lemmatized : at
# Original : 14:34 --------> Lemmatized : 14:34
# Original : ( --------> Lemmatized : (
# Original : UTC --------> Lemmatized : UTC
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : Text --------> Lemmatized : Text
# Original : is --------> Lemmatized : is
# Original : available --------> Lemmatized : available
# Original : under --------> Lemmatized : under
# Original : the --------> Lemmatized : the
# Original : Creative --------> Lemmatized : Creative
# Original : Commons --------> Lemmatized : Commons
# Original : Attribution-ShareAlike --------> Lemmatized : Attribution-ShareAlike
# Original : 4.0 --------> Lemmatized : 4.0
# Original : License --------> Lemmatized : License
# Original : ; --------> Lemmatized : ;
# Original : additional --------> Lemmatized : additional
# Original : terms --------> Lemmatized : term
# Original : may --------> Lemmatized : may
# Original : apply --------> Lemmatized : apply
# Original : . --------> Lemmatized : .
# Original : By --------> Lemmatized : By
# Original : using --------> Lemmatized : using
# Original : this --------> Lemmatized : this
# Original : site --------> Lemmatized : site
# Original : , --------> Lemmatized : ,
# Original : you --------> Lemmatized : you
# Original : agree --------> Lemmatized : agree
# Original : to --------> Lemmatized : to
# Original : the --------> Lemmatized : the
# Original : Terms --------> Lemmatized : Terms
# Original : of --------> Lemmatized : of
# Original : Use --------> Lemmatized : Use
# Original : and --------> Lemmatized : and
# Original : Privacy --------> Lemmatized : Privacy
# Original : Policy --------> Lemmatized : Policy
# Original : . --------> Lemmatized : .
# Original : Wikipedia® --------> Lemmatized : Wikipedia®
# Original : is --------> Lemmatized : is
# Original : a --------> Lemmatized : a
# Original : registered --------> Lemmatized : registered
# Original : trademark --------> Lemmatized : trademark
# Original : of --------> Lemmatized : of
# Original : the --------> Lemmatized : the
# Original : Wikimedia --------> Lemmatized : Wikimedia
# Original : Foundation --------> Lemmatized : Foundation
# Original : , --------> Lemmatized : ,
# Original : Inc. --------> Lemmatized : Inc.
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : non-profit --------> Lemmatized : non-profit
# Original : organization --------> Lemmatized : organization
# Original : . --------> Lemmatized : .
# Original : Privacy --------> Lemmatized : Privacy
# Original : policy --------> Lemmatized : policy
# Original : About --------> Lemmatized : About
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : Disclaimers --------> Lemmatized : Disclaimers
# Original : Contact --------> Lemmatized : Contact
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : Code --------> Lemmatized : Code
# Original : of --------> Lemmatized : of
# Original : Conduct --------> Lemmatized : Conduct
# Original : Developers --------> Lemmatized : Developers
# Original : Statistics --------> Lemmatized : Statistics
# Original : Cookie --------> Lemmatized : Cookie
# Original : statement --------> Lemmatized : statement
# Original : Mobile --------> Lemmatized : Mobile
# Original : view --------> Lemmatized : view
# Original : Search --------> Lemmatized : Search
# Original : Search --------> Lemmatized : Search
# Original : Toggle --------> Lemmatized : Toggle
# Original : the --------> Lemmatized : the
# Original : table --------> Lemmatized : table
# Original : of --------> Lemmatized : of
# Original : contents --------> Lemmatized : content
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : 6 --------> Lemmatized : 6
# Original : languages --------> Lemmatized : language
# Original : Add --------> Lemmatized : Add
# Original : topic --------> Lemmatized : topic

# %%
for word in text:

    print(f"Original : {word} --------> Lemmatized : {lemmatizer.lemmatize(word, pos='v')}")
# Out:
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : - --------> Lemmatized : -
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : Jump --------> Lemmatized : Jump
# Original : to --------> Lemmatized : to
# Original : content --------> Lemmatized : content
# Original : Main --------> Lemmatized : Main
# Original : menu --------> Lemmatized : menu
# Original : Main --------> Lemmatized : Main
# Original : menu --------> Lemmatized : menu
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : Navigation --------> Lemmatized : Navigation
# Original : Main --------> Lemmatized : Main
# Original : pageContentsCurrent --------> Lemmatized : pageContentsCurrent
# Original : eventsRandom --------> Lemmatized : eventsRandom
# Original : articleAbout --------> Lemmatized : articleAbout
# Original : WikipediaContact --------> Lemmatized : WikipediaContact
# Original : us --------> Lemmatized : us
# Original : Contribute --------> Lemmatized : Contribute
# Original : HelpLearn --------> Lemmatized : HelpLearn
# Original : to --------> Lemmatized : to
# Original : editCommunity --------> Lemmatized : editCommunity
# Original : portalRecent --------> Lemmatized : portalRecent
# Original : changesUpload --------> Lemmatized : changesUpload
# Original : fileSpecial --------> Lemmatized : fileSpecial
# Original : pages --------> Lemmatized : page
# Original : Search --------> Lemmatized : Search
# Original : Search --------> Lemmatized : Search
# Original : Appearance --------> Lemmatized : Appearance
# Original : Donate --------> Lemmatized : Donate
# Original : Create --------> Lemmatized : Create
# Original : account --------> Lemmatized : account
# Original : Log --------> Lemmatized : Log
# Original : in --------> Lemmatized : in
# Original : Personal --------> Lemmatized : Personal
# Original : tools --------> Lemmatized : tool
# Original : Donate --------> Lemmatized : Donate
# Original : Create --------> Lemmatized : Create
# Original : account --------> Lemmatized : account
# Original : Log --------> Lemmatized : Log
# Original : in --------> Lemmatized : in
# Original : Pages --------> Lemmatized : Pages
# Original : for --------> Lemmatized : for
# Original : logged --------> Lemmatized : log
# Original : out --------> Lemmatized : out
# Original : editors --------> Lemmatized : editors
# Original : learn --------> Lemmatized : learn
# Original : more --------> Lemmatized : more
# Original : ContributionsTalk --------> Lemmatized : ContributionsTalk
# Original : Contents --------> Lemmatized : Contents
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : ( --------> Lemmatized : (
# Original : Top --------> Lemmatized : Top
# Original : ) --------> Lemmatized : )
# Original : 1 --------> Lemmatized : 1
# Original : History --------> Lemmatized : History
# Original : 2 --------> Lemmatized : 2
# Original : Research --------> Lemmatized : Research
# Original : activities --------> Lemmatized : activities
# Original : 3 --------> Lemmatized : 3
# Original : Centres --------> Lemmatized : Centres
# Original : 4 --------> Lemmatized : 4
# Original : Education --------> Lemmatized : Education
# Original : and --------> Lemmatized : and
# Original : training --------> Lemmatized : train
# Original : 5 --------> Lemmatized : 5
# Original : Commercialization --------> Lemmatized : Commercialization
# Original : 6 --------> Lemmatized : 6
# Original : Products --------> Lemmatized : Products
# Original : and --------> Lemmatized : and
# Original : developments --------> Lemmatized : developments
# Original : 7 --------> Lemmatized : 7
# Original : Notable --------> Lemmatized : Notable
# Original : researchers --------> Lemmatized : researchers
# Original : and --------> Lemmatized : and
# Original : alumnus --------> Lemmatized : alumnus
# Original : 8 --------> Lemmatized : 8
# Original : Notable --------> Lemmatized : Notable
# Original : awards --------> Lemmatized : award
# Original : and --------> Lemmatized : and
# Original : accolades --------> Lemmatized : accolades
# Original : 9 --------> Lemmatized : 9
# Original : Other --------> Lemmatized : Other
# Original : projects --------> Lemmatized : project
# Original : 10 --------> Lemmatized : 10
# Original : See --------> Lemmatized : See
# Original : also --------> Lemmatized : also
# Original : 11 --------> Lemmatized : 11
# Original : References --------> Lemmatized : References
# Original : Toggle --------> Lemmatized : Toggle
# Original : the --------> Lemmatized : the
# Original : table --------> Lemmatized : table
# Original : of --------> Lemmatized : of
# Original : contents --------> Lemmatized : content
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : 6 --------> Lemmatized : 6
# Original : languages --------> Lemmatized : languages
# Original : हिन्दीമലയാളംमराठीРусскийதமிழ்Українська --------> Lemmatized : हिन्दीമലയാളംमराठीРусскийதமிழ்Українська
# Original : Edit --------> Lemmatized : Edit
# Original : links --------> Lemmatized : link
# Original : ArticleTalk --------> Lemmatized : ArticleTalk
# Original : English --------> Lemmatized : English
# Original : ReadEditView --------> Lemmatized : ReadEditView
# Original : history --------> Lemmatized : history
# Original : Tools --------> Lemmatized : Tools
# Original : Tools --------> Lemmatized : Tools
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : Actions --------> Lemmatized : Actions
# Original : ReadEditView --------> Lemmatized : ReadEditView
# Original : history --------> Lemmatized : history
# Original : General --------> Lemmatized : General
# Original : What --------> Lemmatized : What
# Original : links --------> Lemmatized : link
# Original : hereRelated --------> Lemmatized : hereRelated
# Original : changesUpload --------> Lemmatized : changesUpload
# Original : filePermanent --------> Lemmatized : filePermanent
# Original : linkPage --------> Lemmatized : linkPage
# Original : informationCite --------> Lemmatized : informationCite
# Original : this --------> Lemmatized : this
# Original : pageGet --------> Lemmatized : pageGet
# Original : shortened --------> Lemmatized : shorten
# Original : URLDownload --------> Lemmatized : URLDownload
# Original : QR --------> Lemmatized : QR
# Original : code --------> Lemmatized : code
# Original : Print/export --------> Lemmatized : Print/export
# Original : Download --------> Lemmatized : Download
# Original : as --------> Lemmatized : as
# Original : PDFPrintable --------> Lemmatized : PDFPrintable
# Original : version --------> Lemmatized : version
# Original : In --------> Lemmatized : In
# Original : other --------> Lemmatized : other
# Original : projects --------> Lemmatized : project
# Original : Wikidata --------> Lemmatized : Wikidata
# Original : item --------> Lemmatized : item
# Original : Appearance --------> Lemmatized : Appearance
# Original : move --------> Lemmatized : move
# Original : to --------> Lemmatized : to
# Original : sidebar --------> Lemmatized : sidebar
# Original : hide --------> Lemmatized : hide
# Original : Coordinates --------> Lemmatized : Coordinates
# Original : : --------> Lemmatized : :
# Original : 18°33′06″N --------> Lemmatized : 18°33′06″N
# Original : 73°49′26″E﻿ --------> Lemmatized : 73°49′26″E﻿
# Original : / --------> Lemmatized : /
# Original : ﻿18.551747°N --------> Lemmatized : ﻿18.551747°N
# Original : 73.823750°E﻿ --------> Lemmatized : 73.823750°E﻿
# Original : / --------> Lemmatized : /
# Original : 18.551747 --------> Lemmatized : 18.551747
# Original : ; --------> Lemmatized : ;
# Original : 73.823750 --------> Lemmatized : 73.823750
# Original : From --------> Lemmatized : From
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : free --------> Lemmatized : free
# Original : encyclopedia --------> Lemmatized : encyclopedia
# Original : Autonomous --------> Lemmatized : Autonomous
# Original : scientific --------> Lemmatized : scientific
# Original : society --------> Lemmatized : society
# Original : 18°33′06″N --------> Lemmatized : 18°33′06″N
# Original : 73°49′26″E﻿ --------> Lemmatized : 73°49′26″E﻿
# Original : / --------> Lemmatized : /
# Original : ﻿18.551747°N --------> Lemmatized : ﻿18.551747°N
# Original : 73.823750°E﻿ --------> Lemmatized : 73.823750°E﻿
# Original : / --------> Lemmatized : /
# Original : 18.551747 --------> Lemmatized : 18.551747
# Original : ; --------> Lemmatized : ;
# Original : 73.823750 --------> Lemmatized : 73.823750
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : ComputingMottoज्ञानादेव --------> Lemmatized : ComputingMottoज्ञानादेव
# Original : तु --------> Lemmatized : तु
# Original : कैवल्यम् --------> Lemmatized : कैवल्यम्
# Original : ( --------> Lemmatized : (
# Original : Sanskrit --------> Lemmatized : Sanskrit
# Original : ) --------> Lemmatized : )
# Original : Only --------> Lemmatized : Only
# Original : through --------> Lemmatized : through
# Original : knowledge --------> Lemmatized : knowledge
# Original : one --------> Lemmatized : one
# Original : attains --------> Lemmatized : attain
# Original : liberation --------> Lemmatized : liberation
# Original : ( --------> Lemmatized : (
# Original : English --------> Lemmatized : English
# Original : translated --------> Lemmatized : translate
# Original : ) --------> Lemmatized : )
# Original : Established1988 --------> Lemmatized : Established1988
# Original : ; --------> Lemmatized : ;
# Original : 37 --------> Lemmatized : 37
# Original : years --------> Lemmatized : years
# Original : ago --------> Lemmatized : ago
# Original : ( --------> Lemmatized : (
# Original : 1988 --------> Lemmatized : 1988
# Original : ) --------> Lemmatized : )
# Original : Field --------> Lemmatized : Field
# Original : of --------> Lemmatized : of
# Original : researchHigh --------> Lemmatized : researchHigh
# Original : Performance --------> Lemmatized : Performance
# Original : Computing --------> Lemmatized : Computing
# Original : , --------> Lemmatized : ,
# Original : Multi-lingual --------> Lemmatized : Multi-lingual
# Original : Computing --------> Lemmatized : Computing
# Original : and --------> Lemmatized : and
# Original : Heritage --------> Lemmatized : Heritage
# Original : Computing --------> Lemmatized : Computing
# Original : , --------> Lemmatized : ,
# Original : Professional --------> Lemmatized : Professional
# Original : Electronics --------> Lemmatized : Electronics
# Original : , --------> Lemmatized : ,
# Original : Software --------> Lemmatized : Software
# Original : Technologies --------> Lemmatized : Technologies
# Original : , --------> Lemmatized : ,
# Original : Cyber --------> Lemmatized : Cyber
# Original : Security --------> Lemmatized : Security
# Original : , --------> Lemmatized : ,
# Original : Blockchain --------> Lemmatized : Blockchain
# Original : , --------> Lemmatized : ,
# Original : Data --------> Lemmatized : Data
# Original : Science --------> Lemmatized : Science
# Original : , --------> Lemmatized : ,
# Original : Health --------> Lemmatized : Health
# Original : InformaticsDirectorMagesh --------> Lemmatized : InformaticsDirectorMagesh
# Original : Ethirajan --------> Lemmatized : Ethirajan
# Original : [ --------> Lemmatized : [
# Original : 1 --------> Lemmatized : 1
# Original : ] --------> Lemmatized : ]
# Original : ( --------> Lemmatized : (
# Original : Director --------> Lemmatized : Director
# Original : General --------> Lemmatized : General
# Original : ) --------> Lemmatized : )
# Original : AddressC-DAC --------> Lemmatized : AddressC-DAC
# Original : Innovation --------> Lemmatized : Innovation
# Original : Park --------> Lemmatized : Park
# Original : , --------> Lemmatized : ,
# Original : Panchavati --------> Lemmatized : Panchavati
# Original : , --------> Lemmatized : ,
# Original : Pashan --------> Lemmatized : Pashan
# Original : , --------> Lemmatized : ,
# Original : Pune --------> Lemmatized : Pune
# Original : - --------> Lemmatized : -
# Original : 411 --------> Lemmatized : 411
# Original : 008 --------> Lemmatized : 008
# Original : , --------> Lemmatized : ,
# Original : Maharashtra --------> Lemmatized : Maharashtra
# Original : , --------> Lemmatized : ,
# Original : IndiaLocationPune --------> Lemmatized : IndiaLocationPune
# Original : , --------> Lemmatized : ,
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : headquarters --------> Lemmatized : headquarter
# Original : ) --------> Lemmatized : )
# Original : NicknameC-DACOperating --------> Lemmatized : NicknameC-DACOperating
# Original : agencyMinistry --------> Lemmatized : agencyMinistry
# Original : of --------> Lemmatized : of
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : , --------> Lemmatized : ,
# Original : Government --------> Lemmatized : Government
# Original : of --------> Lemmatized : of
# Original : IndiaWebsitewww.cdac.in --------> Lemmatized : IndiaWebsitewww.cdac.in
# Original : The --------> Lemmatized : The
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : ( --------> Lemmatized : (
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : ) --------> Lemmatized : )
# Original : is --------> Lemmatized : be
# Original : an --------> Lemmatized : an
# Original : Indian --------> Lemmatized : Indian
# Original : autonomous --------> Lemmatized : autonomous
# Original : scientific --------> Lemmatized : scientific
# Original : society --------> Lemmatized : society
# Original : , --------> Lemmatized : ,
# Original : operating --------> Lemmatized : operate
# Original : under --------> Lemmatized : under
# Original : the --------> Lemmatized : the
# Original : Ministry --------> Lemmatized : Ministry
# Original : of --------> Lemmatized : of
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 2 --------> Lemmatized : 2
# Original : ] --------> Lemmatized : ]
# Original : History --------> Lemmatized : History
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : Further --------> Lemmatized : Further
# Original : information --------> Lemmatized : information
# Original : : --------> Lemmatized : :
# Original : Supercomputing --------> Lemmatized : Supercomputing
# Original : in --------> Lemmatized : in
# Original : India --------> Lemmatized : India
# Original : and --------> Lemmatized : and
# Original : PARAM --------> Lemmatized : PARAM
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : was --------> Lemmatized : be
# Original : created --------> Lemmatized : create
# Original : in --------> Lemmatized : in
# Original : November --------> Lemmatized : November
# Original : 1987 --------> Lemmatized : 1987
# Original : , --------> Lemmatized : ,
# Original : [ --------> Lemmatized : [
# Original : 3 --------> Lemmatized : 3
# Original : ] --------> Lemmatized : ]
# Original : initially --------> Lemmatized : initially
# Original : as --------> Lemmatized : as
# Original : the --------> Lemmatized : the
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : C-DACT --------> Lemmatized : C-DACT
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 4 --------> Lemmatized : 4
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 3 --------> Lemmatized : 3
# Original : ] --------> Lemmatized : ]
# Original : In --------> Lemmatized : In
# Original : 1988 --------> Lemmatized : 1988
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : US --------> Lemmatized : US
# Original : Government --------> Lemmatized : Government
# Original : refused --------> Lemmatized : refuse
# Original : to --------> Lemmatized : to
# Original : sell --------> Lemmatized : sell
# Original : India --------> Lemmatized : India
# Original : a --------> Lemmatized : a
# Original : Cray --------> Lemmatized : Cray
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : due --------> Lemmatized : due
# Original : to --------> Lemmatized : to
# Original : concerns --------> Lemmatized : concern
# Original : about --------> Lemmatized : about
# Original : India --------> Lemmatized : India
# Original : using --------> Lemmatized : use
# Original : it --------> Lemmatized : it
# Original : to --------> Lemmatized : to
# Original : develop --------> Lemmatized : develop
# Original : nuclear --------> Lemmatized : nuclear
# Original : weapons --------> Lemmatized : weapons
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 5 --------> Lemmatized : 5
# Original : ] --------> Lemmatized : ]
# Original : In --------> Lemmatized : In
# Original : response --------> Lemmatized : response
# Original : India --------> Lemmatized : India
# Original : started --------> Lemmatized : start
# Original : development --------> Lemmatized : development
# Original : of --------> Lemmatized : of
# Original : its --------> Lemmatized : its
# Original : own --------> Lemmatized : own
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : , --------> Lemmatized : ,
# Original : and --------> Lemmatized : and
# Original : C-DACT --------> Lemmatized : C-DACT
# Original : was --------> Lemmatized : be
# Original : created --------> Lemmatized : create
# Original : as --------> Lemmatized : as
# Original : part --------> Lemmatized : part
# Original : of --------> Lemmatized : of
# Original : this --------> Lemmatized : this
# Original : programme --------> Lemmatized : programme
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 6 --------> Lemmatized : 6
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : Dr --------> Lemmatized : Dr
# Original : Vijay --------> Lemmatized : Vijay
# Original : Bhatkar --------> Lemmatized : Bhatkar
# Original : was --------> Lemmatized : be
# Original : hired --------> Lemmatized : hire
# Original : as --------> Lemmatized : as
# Original : the --------> Lemmatized : the
# Original : director --------> Lemmatized : director
# Original : of --------> Lemmatized : of
# Original : C-DACT --------> Lemmatized : C-DACT
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : project --------> Lemmatized : project
# Original : was --------> Lemmatized : be
# Original : given --------> Lemmatized : give
# Original : an --------> Lemmatized : an
# Original : initial --------> Lemmatized : initial
# Original : run --------> Lemmatized : run
# Original : of --------> Lemmatized : of
# Original : three --------> Lemmatized : three
# Original : years --------> Lemmatized : years
# Original : and --------> Lemmatized : and
# Original : an --------> Lemmatized : an
# Original : initial --------> Lemmatized : initial
# Original : funding --------> Lemmatized : fund
# Original : of --------> Lemmatized : of
# Original : ₹30,00,00,000 --------> Lemmatized : ₹30,00,00,000
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : cost --------> Lemmatized : cost
# Original : of --------> Lemmatized : of
# Original : a --------> Lemmatized : a
# Original : Cray --------> Lemmatized : Cray
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : A --------> Lemmatized : A
# Original : prototype --------> Lemmatized : prototype
# Original : computer --------> Lemmatized : computer
# Original : was --------> Lemmatized : be
# Original : benchmarked --------> Lemmatized : benchmarked
# Original : at --------> Lemmatized : at
# Original : the --------> Lemmatized : the
# Original : 1990 --------> Lemmatized : 1990
# Original : Zurich --------> Lemmatized : Zurich
# Original : Super-computing --------> Lemmatized : Super-computing
# Original : Show --------> Lemmatized : Show
# Original : . --------> Lemmatized : .
# Original : It --------> Lemmatized : It
# Original : demonstrated --------> Lemmatized : demonstrate
# Original : that --------> Lemmatized : that
# Original : India --------> Lemmatized : India
# Original : had --------> Lemmatized : have
# Original : the --------> Lemmatized : the
# Original : second --------> Lemmatized : second
# Original : most --------> Lemmatized : most
# Original : powerful --------> Lemmatized : powerful
# Original : , --------> Lemmatized : ,
# Original : publicly --------> Lemmatized : publicly
# Original : demonstrated --------> Lemmatized : demonstrate
# Original : , --------> Lemmatized : ,
# Original : supercomputer --------> Lemmatized : supercomputer
# Original : in --------> Lemmatized : in
# Original : the --------> Lemmatized : the
# Original : world --------> Lemmatized : world
# Original : after --------> Lemmatized : after
# Original : the --------> Lemmatized : the
# Original : United --------> Lemmatized : United
# Original : States --------> Lemmatized : States
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 7 --------> Lemmatized : 7
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 8 --------> Lemmatized : 8
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : final --------> Lemmatized : final
# Original : result --------> Lemmatized : result
# Original : of --------> Lemmatized : of
# Original : the --------> Lemmatized : the
# Original : effort --------> Lemmatized : effort
# Original : was --------> Lemmatized : be
# Original : the --------> Lemmatized : the
# Original : PARAM --------> Lemmatized : PARAM
# Original : 8000 --------> Lemmatized : 8000
# Original : , --------> Lemmatized : ,
# Original : released --------> Lemmatized : release
# Original : in --------> Lemmatized : in
# Original : 1991 --------> Lemmatized : 1991
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 9 --------> Lemmatized : 9
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : National --------> Lemmatized : National
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Software --------> Lemmatized : Software
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : NCST --------> Lemmatized : NCST
# Original : ) --------> Lemmatized : )
# Original : , --------> Lemmatized : ,
# Original : Electronic --------> Lemmatized : Electronic
# Original : Research --------> Lemmatized : Research
# Original : and --------> Lemmatized : and
# Original : Development --------> Lemmatized : Development
# Original : Centre --------> Lemmatized : Centre
# Original : ( --------> Lemmatized : (
# Original : ER --------> Lemmatized : ER
# Original : & --------> Lemmatized : &
# Original : DC --------> Lemmatized : DC
# Original : ) --------> Lemmatized : )
# Original : and --------> Lemmatized : and
# Original : CEDTI --------> Lemmatized : CEDTI
# Original : were --------> Lemmatized : be
# Original : merged --------> Lemmatized : merge
# Original : into --------> Lemmatized : into
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : in --------> Lemmatized : in
# Original : 2003 --------> Lemmatized : 2003
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 10 --------> Lemmatized : 10
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 11 --------> Lemmatized : 11
# Original : ] --------> Lemmatized : ]
# Original : Research --------> Lemmatized : Research
# Original : activities --------> Lemmatized : activities
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : Originally --------> Lemmatized : Originally
# Original : established --------> Lemmatized : establish
# Original : to --------> Lemmatized : to
# Original : research --------> Lemmatized : research
# Original : and --------> Lemmatized : and
# Original : assemble --------> Lemmatized : assemble
# Original : High --------> Lemmatized : High
# Original : Performance --------> Lemmatized : Performance
# Original : Computers --------> Lemmatized : Computers
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : research --------> Lemmatized : research
# Original : of --------> Lemmatized : of
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : now --------> Lemmatized : now
# Original : includes --------> Lemmatized : include
# Original : : --------> Lemmatized : :
# Original : High --------> Lemmatized : High
# Original : Performance --------> Lemmatized : Performance
# Original : Computing --------> Lemmatized : Computing
# Original : Grid --------> Lemmatized : Grid
# Original : Computing --------> Lemmatized : Computing
# Original : Cloud --------> Lemmatized : Cloud
# Original : Computing --------> Lemmatized : Computing
# Original : Multilingual --------> Lemmatized : Multilingual
# Original : and --------> Lemmatized : and
# Original : Heritage --------> Lemmatized : Heritage
# Original : Computing --------> Lemmatized : Computing
# Original : VLSI --------> Lemmatized : VLSI
# Original : and --------> Lemmatized : and
# Original : Processor --------> Lemmatized : Processor
# Original : design --------> Lemmatized : design
# Original : Embedded --------> Lemmatized : Embedded
# Original : Systems --------> Lemmatized : Systems
# Original : Speech --------> Lemmatized : Speech
# Original : and --------> Lemmatized : and
# Original : Natural --------> Lemmatized : Natural
# Original : Language --------> Lemmatized : Language
# Original : Processing --------> Lemmatized : Processing
# Original : Information --------> Lemmatized : Information
# Original : and --------> Lemmatized : and
# Original : Cyber --------> Lemmatized : Cyber
# Original : Security --------> Lemmatized : Security
# Original : Ubiquitous --------> Lemmatized : Ubiquitous
# Original : Computing --------> Lemmatized : Computing
# Original : Bioinformatics --------> Lemmatized : Bioinformatics
# Original : Geomatics --------> Lemmatized : Geomatics
# Original : Digital --------> Lemmatized : Digital
# Original : forensics --------> Lemmatized : forensics
# Original : Big --------> Lemmatized : Big
# Original : data --------> Lemmatized : data
# Original : analytics --------> Lemmatized : analytics
# Original : Blockchain --------> Lemmatized : Blockchain
# Original : Health --------> Lemmatized : Health
# Original : Informatics --------> Lemmatized : Informatics
# Original : Quantum --------> Lemmatized : Quantum
# Original : computing --------> Lemmatized : compute
# Original : Centres --------> Lemmatized : Centres
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : branches --------> Lemmatized : branch
# Original : and --------> Lemmatized : and
# Original : training --------> Lemmatized : train
# Original : centres --------> Lemmatized : centre
# Original : include --------> Lemmatized : include
# Original : : --------> Lemmatized : :
# Original : [ --------> Lemmatized : [
# Original : 12 --------> Lemmatized : 12
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Pune --------> Lemmatized : Pune
# Original : ( --------> Lemmatized : (
# Original : Headquarters --------> Lemmatized : Headquarters
# Original : ) --------> Lemmatized : )
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Mumbai --------> Lemmatized : Mumbai
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Bangalore --------> Lemmatized : Bangalore
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Chennai --------> Lemmatized : Chennai
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Delhi --------> Lemmatized : Delhi
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Kolkata --------> Lemmatized : Kolkata
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Patna --------> Lemmatized : Patna
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Mohali --------> Lemmatized : Mohali
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Noida --------> Lemmatized : Noida
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Hyderabad --------> Lemmatized : Hyderabad
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Thiruvananthapuram --------> Lemmatized : Thiruvananthapuram
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Silchar --------> Lemmatized : Silchar
# Original : Education --------> Lemmatized : Education
# Original : and --------> Lemmatized : and
# Original : training --------> Lemmatized : train
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : provides --------> Lemmatized : provide
# Original : several --------> Lemmatized : several
# Original : courses --------> Lemmatized : course
# Original : in --------> Lemmatized : in
# Original : the --------> Lemmatized : the
# Original : field --------> Lemmatized : field
# Original : of --------> Lemmatized : of
# Original : advanced --------> Lemmatized : advance
# Original : computing --------> Lemmatized : compute
# Original : and --------> Lemmatized : and
# Original : software --------> Lemmatized : software
# Original : development --------> Lemmatized : development
# Original : . --------> Lemmatized : .
# Original : Among --------> Lemmatized : Among
# Original : these --------> Lemmatized : these
# Original : are --------> Lemmatized : be
# Original : the --------> Lemmatized : the
# Original : HPC --------> Lemmatized : HPC
# Original : certification --------> Lemmatized : certification
# Original : course- --------> Lemmatized : course-
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : Certified --------> Lemmatized : Certified
# Original : HPC --------> Lemmatized : HPC
# Original : Professional --------> Lemmatized : Professional
# Original : Certification --------> Lemmatized : Certification
# Original : Programme --------> Lemmatized : Programme
# Original : ( --------> Lemmatized : (
# Original : CCHPCP --------> Lemmatized : CCHPCP
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 13 --------> Lemmatized : 13
# Original : ] --------> Lemmatized : ]
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : organises --------> Lemmatized : organise
# Original : advanced --------> Lemmatized : advance
# Original : computing --------> Lemmatized : compute
# Original : diploma --------> Lemmatized : diploma
# Original : programmes --------> Lemmatized : program
# Original : through --------> Lemmatized : through
# Original : the --------> Lemmatized : the
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : Training --------> Lemmatized : Training
# Original : School --------> Lemmatized : School
# Original : ( --------> Lemmatized : (
# Original : ACTS --------> Lemmatized : ACTS
# Original : ) --------> Lemmatized : )
# Original : located --------> Lemmatized : locate
# Original : all --------> Lemmatized : all
# Original : over --------> Lemmatized : over
# Original : India --------> Lemmatized : India
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 14 --------> Lemmatized : 14
# Original : ] --------> Lemmatized : ]
# Original : The --------> Lemmatized : The
# Original : PG --------> Lemmatized : PG
# Original : Diploma --------> Lemmatized : Diploma
# Original : courses --------> Lemmatized : course
# Original : include --------> Lemmatized : include
# Original : Specialisations --------> Lemmatized : Specialisations
# Original : in --------> Lemmatized : in
# Original : Embedded --------> Lemmatized : Embedded
# Original : System --------> Lemmatized : System
# Original : Design --------> Lemmatized : Design
# Original : , --------> Lemmatized : ,
# Original : VLSI --------> Lemmatized : VLSI
# Original : , --------> Lemmatized : ,
# Original : Big --------> Lemmatized : Big
# Original : Data --------> Lemmatized : Data
# Original : Analytics --------> Lemmatized : Analytics
# Original : , --------> Lemmatized : ,
# Original : Geoinformatics --------> Lemmatized : Geoinformatics
# Original : , --------> Lemmatized : ,
# Original : Artificial --------> Lemmatized : Artificial
# Original : Intelligence --------> Lemmatized : Intelligence
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : has --------> Lemmatized : have
# Original : also --------> Lemmatized : also
# Original : established --------> Lemmatized : establish
# Original : Centres --------> Lemmatized : Centres
# Original : of --------> Lemmatized : of
# Original : Excellence --------> Lemmatized : Excellence
# Original : in --------> Lemmatized : in
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : CEIT --------> Lemmatized : CEIT
# Original : ) --------> Lemmatized : )
# Original : abroad --------> Lemmatized : abroad
# Original : under --------> Lemmatized : under
# Original : the --------> Lemmatized : the
# Original : Ministry --------> Lemmatized : Ministry
# Original : of --------> Lemmatized : of
# Original : External --------> Lemmatized : External
# Original : Affairs --------> Lemmatized : Affairs
# Original : ' --------> Lemmatized : '
# Original : s --------> Lemmatized : s
# Original : development --------> Lemmatized : development
# Original : partnership --------> Lemmatized : partnership
# Original : projects --------> Lemmatized : project
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 15 --------> Lemmatized : 15
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 16 --------> Lemmatized : 16
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 17 --------> Lemmatized : 17
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 18 --------> Lemmatized : 18
# Original : ] --------> Lemmatized : ]
# Original : Commercialization --------> Lemmatized : Commercialization
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : This --------> Lemmatized : This
# Original : article --------> Lemmatized : article
# Original : appears --------> Lemmatized : appear
# Original : to --------> Lemmatized : to
# Original : contain --------> Lemmatized : contain
# Original : a --------> Lemmatized : a
# Original : large --------> Lemmatized : large
# Original : number --------> Lemmatized : number
# Original : of --------> Lemmatized : of
# Original : buzzwords --------> Lemmatized : buzzwords
# Original : . --------> Lemmatized : .
# Original : There --------> Lemmatized : There
# Original : might --------> Lemmatized : might
# Original : be --------> Lemmatized : be
# Original : a --------> Lemmatized : a
# Original : discussion --------> Lemmatized : discussion
# Original : about --------> Lemmatized : about
# Original : this --------> Lemmatized : this
# Original : on --------> Lemmatized : on
# Original : the --------> Lemmatized : the
# Original : talk --------> Lemmatized : talk
# Original : page --------> Lemmatized : page
# Original : . --------> Lemmatized : .
# Original : Please --------> Lemmatized : Please
# Original : help --------> Lemmatized : help
# Original : improve --------> Lemmatized : improve
# Original : this --------> Lemmatized : this
# Original : article --------> Lemmatized : article
# Original : if --------> Lemmatized : if
# Original : you --------> Lemmatized : you
# Original : can --------> Lemmatized : can
# Original : . --------> Lemmatized : .
# Original : ( --------> Lemmatized : (
# Original : April --------> Lemmatized : April
# Original : 2025 --------> Lemmatized : 2025
# Original : ) --------> Lemmatized : )
# Original : On --------> Lemmatized : On
# Original : August --------> Lemmatized : August
# Original : 28 --------> Lemmatized : 28
# Original : , --------> Lemmatized : ,
# Original : 2024 --------> Lemmatized : 2024
# Original : , --------> Lemmatized : ,
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : and --------> Lemmatized : and
# Original : L --------> Lemmatized : L
# Original : & --------> Lemmatized : &
# Original : T --------> Lemmatized : T
# Original : Semiconductor --------> Lemmatized : Semiconductor
# Original : Technologies --------> Lemmatized : Technologies
# Original : ( --------> Lemmatized : (
# Original : LTSCT --------> Lemmatized : LTSCT
# Original : ) --------> Lemmatized : )
# Original : signed --------> Lemmatized : sign
# Original : a --------> Lemmatized : a
# Original : Memorandum --------> Lemmatized : Memorandum
# Original : of --------> Lemmatized : of
# Original : Understanding --------> Lemmatized : Understanding
# Original : ( --------> Lemmatized : (
# Original : MoU --------> Lemmatized : MoU
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : It --------> Lemmatized : It
# Original : will --------> Lemmatized : will
# Original : establish --------> Lemmatized : establish
# Original : a --------> Lemmatized : a
# Original : program --------> Lemmatized : program
# Original : for --------> Lemmatized : for
# Original : the --------> Lemmatized : the
# Original : commercialization --------> Lemmatized : commercialization
# Original : of --------> Lemmatized : of
# Original : cutting-edge --------> Lemmatized : cutting-edge
# Original : technologies --------> Lemmatized : technologies
# Original : created --------> Lemmatized : create
# Original : by --------> Lemmatized : by
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : in --------> Lemmatized : in
# Original : the --------> Lemmatized : the
# Original : areas --------> Lemmatized : areas
# Original : of --------> Lemmatized : of
# Original : power --------> Lemmatized : power
# Original : systems --------> Lemmatized : systems
# Original : , --------> Lemmatized : ,
# Original : embedded --------> Lemmatized : embed
# Original : software --------> Lemmatized : software
# Original : , --------> Lemmatized : ,
# Original : open-source --------> Lemmatized : open-source
# Original : operating --------> Lemmatized : operate
# Original : systems --------> Lemmatized : systems
# Original : , --------> Lemmatized : ,
# Original : high --------> Lemmatized : high
# Original : performance --------> Lemmatized : performance
# Original : computing --------> Lemmatized : compute
# Original : , --------> Lemmatized : ,
# Original : and --------> Lemmatized : and
# Original : semiconductor --------> Lemmatized : semiconductor
# Original : design --------> Lemmatized : design
# Original : and --------> Lemmatized : and
# Original : development --------> Lemmatized : development
# Original : . --------> Lemmatized : .
# Original : LTSCT --------> Lemmatized : LTSCT
# Original : will --------> Lemmatized : will
# Original : leverage --------> Lemmatized : leverage
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : 's --------> Lemmatized : 's
# Original : extensive --------> Lemmatized : extensive
# Original : pipeline --------> Lemmatized : pipeline
# Original : of --------> Lemmatized : of
# Original : in-house --------> Lemmatized : in-house
# Original : intellectual --------> Lemmatized : intellectual
# Original : property --------> Lemmatized : property
# Original : ( --------> Lemmatized : (
# Original : IPs --------> Lemmatized : IPs
# Original : ) --------> Lemmatized : )
# Original : , --------> Lemmatized : ,
# Original : which --------> Lemmatized : which
# Original : includes --------> Lemmatized : include
# Original : the --------> Lemmatized : the
# Original : VEGA --------> Lemmatized : VEGA
# Original : processor --------> Lemmatized : processor
# Original : , --------> Lemmatized : ,
# Original : to --------> Lemmatized : to
# Original : create --------> Lemmatized : create
# Original : global --------> Lemmatized : global
# Original : product --------> Lemmatized : product
# Original : prospects --------> Lemmatized : prospect
# Original : through --------> Lemmatized : through
# Original : application --------> Lemmatized : application
# Original : design --------> Lemmatized : design
# Original : and --------> Lemmatized : and
# Original : validation --------> Lemmatized : validation
# Original : for --------> Lemmatized : for
# Original : Field --------> Lemmatized : Field
# Original : Programmable --------> Lemmatized : Programmable
# Original : Gate --------> Lemmatized : Gate
# Original : Arrays --------> Lemmatized : Arrays
# Original : . --------> Lemmatized : .
# Original : By --------> Lemmatized : By
# Original : facilitating --------> Lemmatized : facilitate
# Original : the --------> Lemmatized : the
# Original : creation --------> Lemmatized : creation
# Original : of --------> Lemmatized : of
# Original : cutting-edge --------> Lemmatized : cutting-edge
# Original : goods --------> Lemmatized : goods
# Original : and --------> Lemmatized : and
# Original : solutions --------> Lemmatized : solutions
# Original : for --------> Lemmatized : for
# Original : the --------> Lemmatized : the
# Original : automotive --------> Lemmatized : automotive
# Original : , --------> Lemmatized : ,
# Original : industrial --------> Lemmatized : industrial
# Original : , --------> Lemmatized : ,
# Original : information --------> Lemmatized : information
# Original : and --------> Lemmatized : and
# Original : communications --------> Lemmatized : communications
# Original : technology --------> Lemmatized : technology
# Original : infrastructure --------> Lemmatized : infrastructure
# Original : , --------> Lemmatized : ,
# Original : and --------> Lemmatized : and
# Original : energy --------> Lemmatized : energy
# Original : sectors --------> Lemmatized : sectors
# Original : , --------> Lemmatized : ,
# Original : the --------> Lemmatized : the
# Original : collaboration --------> Lemmatized : collaboration
# Original : to --------> Lemmatized : to
# Original : create --------> Lemmatized : create
# Original : indigenous --------> Lemmatized : indigenous
# Original : ICs --------> Lemmatized : ICs
# Original : and --------> Lemmatized : and
# Original : SoCs --------> Lemmatized : SoCs
# Original : based --------> Lemmatized : base
# Original : in --------> Lemmatized : in
# Original : Vega --------> Lemmatized : Vega
# Original : is --------> Lemmatized : be
# Original : expected --------> Lemmatized : expect
# Original : to --------> Lemmatized : to
# Original : pick --------> Lemmatized : pick
# Original : up --------> Lemmatized : up
# Original : speed --------> Lemmatized : speed
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 19 --------> Lemmatized : 19
# Original : ] --------> Lemmatized : ]
# Original : [ --------> Lemmatized : [
# Original : 20 --------> Lemmatized : 20
# Original : ] --------> Lemmatized : ]
# Original : Products --------> Lemmatized : Products
# Original : and --------> Lemmatized : and
# Original : developments --------> Lemmatized : developments
# Original : [ --------> Lemmatized : [
# Original : edit --------> Lemmatized : edit
# Original : ] --------> Lemmatized : ]
# Original : PARAM --------> Lemmatized : PARAM
# Original : series --------> Lemmatized : series
# Original : of --------> Lemmatized : of
# Original : supercomputers --------> Lemmatized : supercomputers
# Original : [ --------> Lemmatized : [
# Original : 21 --------> Lemmatized : 21
# Original : ] --------> Lemmatized : ]
# Original : VEGA --------> Lemmatized : VEGA
# Original : Microprocessors --------> Lemmatized : Microprocessors
# Original : , --------> Lemmatized : ,
# Original : India --------> Lemmatized : India
# Original : 's --------> Lemmatized : 's
# Original : first --------> Lemmatized : first
# Original : indigenous --------> Lemmatized : indigenous
# Original : 64-bit --------> Lemmatized : 64-bit
# Original : Multi-core --------> Lemmatized : Multi-core
# Original : Superscalar --------> Lemmatized : Superscalar
# Original : Out-of-Order --------> Lemmatized : Out-of-Order
# Original : RISC-V --------> Lemmatized : RISC-V
# Original : Processor --------> Lemmatized : Processor
# Original : [ --------> Lemmatized : [
# Original : 22 --------> Lemmatized : 22
# Original : ] --------> Lemmatized : ]
# Original : M-Kavach --------> Lemmatized : M-Kavach
# Original : 2 --------> Lemmatized : 2
# Original : , --------> Lemmatized : ,
# Original : an --------> Lemmatized : an
# Original : android-based --------> Lemmatized : android-based
# Original : mobile --------> Lemmatized : mobile
# Original : device --------> Lemmatized : device
# Original : security --------> Lemmatized : security
# Original : solution --------> Lemmatized : solution
# Original : addressing --------> Lemmatized : address
# Original : emerging --------> Lemmatized : emerge
# Original : threats --------> Lemmatized : threats
# Original : . --------> Lemmatized : .
# Original : [ --------> Lemmatized : [
# Original : 23 --------> Lemmatized : 23
# Original : ] --------> Lemmatized : ]
# Original : Mobile --------> Lemmatized : Mobile
# Original : Seva --------> Lemmatized : Seva
# Original : AppStore --------> Lemmatized : AppStore
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : mobile --------> Lemmatized : mobile
# Original : app --------> Lemmatized : app
# Original : marketplace --------> Lemmatized : marketplace
# Original : [ --------> Lemmatized : [
# Original : 24 --------> Lemmatized : 24
# Original : ] --------> Lemmatized : ]
# Original : Bharat --------> Lemmatized : Bharat
# Original : Operating --------> Lemmatized : Operating
# Original : System --------> Lemmatized : System
# Original : Solutions --------> Lemmatized : Solutions
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : Linux-based --------> Lemmatized : Linux-based
# Original : general --------> Lemmatized : general
# Original : purpose --------> Lemmatized : purpose
# Original : operating --------> Lemmatized : operate
# Original : system --------> Lemmatized : system
# Original : [ --------> Lemmatized : [
# Original : 25 --------> Lemmatized : 25
# Original : ] --------> Lemmatized : ]
# Original : Anvaya --------> Lemmatized : Anvaya
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : workflow --------> Lemmatized : workflow
# ...
# Original : of --------> Lemmatized : of
# Original : India --------> Lemmatized : India
# Original : IN --------> Lemmatized : IN
# Original : Registry --------> Lemmatized : Registry
# Original : .in --------> Lemmatized : .in
# Original : .भारत --------> Lemmatized : .भारत
# Original : Other --------> Lemmatized : Other
# Original : Standardisation --------> Lemmatized : Standardisation
# Original : Testing --------> Lemmatized : Testing
# Original : and --------> Lemmatized : and
# Original : Quality --------> Lemmatized : Quality
# Original : Certification --------> Lemmatized : Certification
# Original : Directorate --------> Lemmatized : Directorate
# Original : ( --------> Lemmatized : (
# Original : STQC --------> Lemmatized : STQC
# Original : ) --------> Lemmatized : )
# Original : Controller --------> Lemmatized : Controller
# Original : of --------> Lemmatized : of
# Original : Certifying --------> Lemmatized : Certifying
# Original : Authorities --------> Lemmatized : Authorities
# Original : ( --------> Lemmatized : (
# Original : CCA --------> Lemmatized : CCA
# Original : ) --------> Lemmatized : )
# Original : Cyber --------> Lemmatized : Cyber
# Original : Appellate --------> Lemmatized : Appellate
# Original : Tribunal --------> Lemmatized : Tribunal
# Original : ( --------> Lemmatized : (
# Original : CAT --------> Lemmatized : CAT
# Original : ) --------> Lemmatized : )
# Original : Indian --------> Lemmatized : Indian
# Original : Computer --------> Lemmatized : Computer
# Original : Emergency --------> Lemmatized : Emergency
# Original : Response --------> Lemmatized : Response
# Original : Team --------> Lemmatized : Team
# Original : ( --------> Lemmatized : (
# Original : ICERT --------> Lemmatized : ICERT
# Original : ) --------> Lemmatized : )
# Original : Companies --------> Lemmatized : Companies
# Original : CSC --------> Lemmatized : CSC
# Original : e-Governance --------> Lemmatized : e-Governance
# Original : Services --------> Lemmatized : Services
# Original : India --------> Lemmatized : India
# Original : Limited --------> Lemmatized : Limited
# Original : Media --------> Lemmatized : Media
# Original : Lab --------> Lemmatized : Lab
# Original : Asia --------> Lemmatized : Asia
# Original : ( --------> Lemmatized : (
# Original : MLAsia --------> Lemmatized : MLAsia
# Original : ) --------> Lemmatized : )
# Original : National --------> Lemmatized : National
# Original : Informatics --------> Lemmatized : Informatics
# Original : Centre --------> Lemmatized : Centre
# Original : Services --------> Lemmatized : Services
# Original : Incorporated --------> Lemmatized : Incorporated
# Original : ( --------> Lemmatized : (
# Original : NICSI --------> Lemmatized : NICSI
# Original : ) --------> Lemmatized : )
# Original : — --------> Lemmatized : —
# Original : PSE --------> Lemmatized : PSE
# Original : under --------> Lemmatized : under
# Original : National --------> Lemmatized : National
# Original : Informatics --------> Lemmatized : Informatics
# Original : Centre --------> Lemmatized : Centre
# Original : National --------> Lemmatized : National
# Original : Internet --------> Lemmatized : Internet
# Original : Exchange --------> Lemmatized : Exchange
# Original : of --------> Lemmatized : of
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : NIXI --------> Lemmatized : NIXI
# Original : ) --------> Lemmatized : )
# Original : STPI --------> Lemmatized : STPI
# Original : Unique --------> Lemmatized : Unique
# Original : Identification --------> Lemmatized : Identification
# Original : Authority --------> Lemmatized : Authority
# Original : of --------> Lemmatized : of
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : UIDAI --------> Lemmatized : UIDAI
# Original : ) --------> Lemmatized : )
# Original : AutonomousSocieties --------> Lemmatized : AutonomousSocieties
# Original : Education --------> Lemmatized : Education
# Original : and --------> Lemmatized : and
# Original : Research --------> Lemmatized : Research
# Original : in --------> Lemmatized : in
# Original : Computer --------> Lemmatized : Computer
# Original : Networking --------> Lemmatized : Networking
# Original : ( --------> Lemmatized : (
# Original : ERNET --------> Lemmatized : ERNET
# Original : ) --------> Lemmatized : )
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : ( --------> Lemmatized : (
# Original : C-DAC --------> Lemmatized : C-DAC
# Original : ) --------> Lemmatized : )
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Materials --------> Lemmatized : Materials
# Original : for --------> Lemmatized : for
# Original : Electronics --------> Lemmatized : Electronics
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : C-MET --------> Lemmatized : C-MET
# Original : ) --------> Lemmatized : )
# Original : National --------> Lemmatized : National
# Original : Institute --------> Lemmatized : Institute
# Original : of --------> Lemmatized : of
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Information --------> Lemmatized : Information
# Original : Technology --------> Lemmatized : Technology
# Original : ( --------> Lemmatized : (
# Original : NIELIT --------> Lemmatized : NIELIT
# Original : ) --------> Lemmatized : )
# Original : — --------> Lemmatized : —
# Original : Formerly --------> Lemmatized : Formerly
# Original : DOEACC --------> Lemmatized : DOEACC
# Original : Society --------> Lemmatized : Society
# Original : Society --------> Lemmatized : Society
# Original : for --------> Lemmatized : for
# Original : Applied --------> Lemmatized : Applied
# Original : Microwave --------> Lemmatized : Microwave
# Original : Electronics --------> Lemmatized : Electronics
# Original : Engineering --------> Lemmatized : Engineering
# Original : and --------> Lemmatized : and
# Original : Research --------> Lemmatized : Research
# Original : ( --------> Lemmatized : (
# Original : SAMEER --------> Lemmatized : SAMEER
# Original : ) --------> Lemmatized : )
# Original : Software --------> Lemmatized : Software
# Original : Technology --------> Lemmatized : Technology
# Original : Parks --------> Lemmatized : Parks
# Original : of --------> Lemmatized : of
# Original : India --------> Lemmatized : India
# Original : ( --------> Lemmatized : (
# Original : STPI --------> Lemmatized : STPI
# Original : ) --------> Lemmatized : )
# Original : Electronics --------> Lemmatized : Electronics
# Original : and --------> Lemmatized : and
# Original : Computer --------> Lemmatized : Computer
# Original : Software --------> Lemmatized : Software
# Original : Export --------> Lemmatized : Export
# Original : Promotion --------> Lemmatized : Promotion
# Original : Council --------> Lemmatized : Council
# Original : ( --------> Lemmatized : (
# Original : ESC --------> Lemmatized : ESC
# Original : ) --------> Lemmatized : )
# Original : Semi-Conductor --------> Lemmatized : Semi-Conductor
# Original : Laboratory --------> Lemmatized : Laboratory
# Original : ( --------> Lemmatized : (
# Original : SCL --------> Lemmatized : SCL
# Original : ) --------> Lemmatized : )
# Original : Ministers --------> Lemmatized : Ministers
# Original : Ashwini --------> Lemmatized : Ashwini
# Original : Vaishnaw --------> Lemmatized : Vaishnaw
# Original : ( --------> Lemmatized : (
# Original : incumbent --------> Lemmatized : incumbent
# Original : ) --------> Lemmatized : )
# Original : Ministers --------> Lemmatized : Ministers
# Original : of --------> Lemmatized : of
# Original : State --------> Lemmatized : State
# Original : Jitin --------> Lemmatized : Jitin
# Original : Prasada --------> Lemmatized : Prasada
# Original : ( --------> Lemmatized : (
# Original : incumbent --------> Lemmatized : incumbent
# Original : ) --------> Lemmatized : )
# Original : Authority --------> Lemmatized : Authority
# Original : control --------> Lemmatized : control
# Original : databases --------> Lemmatized : databases
# Original : InternationalISNIVIAFNationalGermanyUnited --------> Lemmatized : InternationalISNIVIAFNationalGermanyUnited
# Original : StatesIsrael --------> Lemmatized : StatesIsrael
# Original : Retrieved --------> Lemmatized : Retrieved
# Original : from --------> Lemmatized : from
# Original : `` --------> Lemmatized : ``
# Original : https --------> Lemmatized : https
# Original : : --------> Lemmatized : :
# Original : //en.wikipedia.org/w/index.php --------> Lemmatized : //en.wikipedia.org/w/index.php
# Original : ? --------> Lemmatized : ?
# Original : title=Centre_for_Development_of_Advanced_Computing --------> Lemmatized : title=Centre_for_Development_of_Advanced_Computing
# Original : & --------> Lemmatized : &
# Original : oldid=1285579997 --------> Lemmatized : oldid=1285579997
# Original : '' --------> Lemmatized : ''
# Original : Categories --------> Lemmatized : Categories
# Original : : --------> Lemmatized : :
# Original : Research --------> Lemmatized : Research
# Original : institutes --------> Lemmatized : institute
# Original : in --------> Lemmatized : in
# Original : PuneInformation --------> Lemmatized : PuneInformation
# Original : technology --------> Lemmatized : technology
# Original : organisations --------> Lemmatized : organisations
# Original : based --------> Lemmatized : base
# Original : in --------> Lemmatized : in
# Original : India1988 --------> Lemmatized : India1988
# Original : establishments --------> Lemmatized : establishments
# Original : in --------> Lemmatized : in
# Original : MaharashtraResearch --------> Lemmatized : MaharashtraResearch
# Original : institutes --------> Lemmatized : institute
# Original : established --------> Lemmatized : establish
# Original : in --------> Lemmatized : in
# Original : 1988Hidden --------> Lemmatized : 1988Hidden
# Original : categories --------> Lemmatized : categories
# Original : : --------> Lemmatized : :
# Original : Pages --------> Lemmatized : Pages
# Original : using --------> Lemmatized : use
# Original : gadget --------> Lemmatized : gadget
# Original : WikiMiniAtlasArticles --------> Lemmatized : WikiMiniAtlasArticles
# Original : with --------> Lemmatized : with
# Original : short --------> Lemmatized : short
# Original : descriptionShort --------> Lemmatized : descriptionShort
# Original : description --------> Lemmatized : description
# Original : matches --------> Lemmatized : match
# Original : WikidataEngvarB --------> Lemmatized : WikidataEngvarB
# Original : from --------> Lemmatized : from
# Original : July --------> Lemmatized : July
# Original : 2015Use --------> Lemmatized : 2015Use
# Original : dmy --------> Lemmatized : dmy
# Original : dates --------> Lemmatized : date
# Original : from --------> Lemmatized : from
# Original : July --------> Lemmatized : July
# Original : 2015Coordinates --------> Lemmatized : 2015Coordinates
# Original : on --------> Lemmatized : on
# Original : WikidataArticles --------> Lemmatized : WikidataArticles
# Original : containing --------> Lemmatized : contain
# Original : Sanskrit-language --------> Lemmatized : Sanskrit-language
# Original : textWikipedia --------> Lemmatized : textWikipedia
# Original : articles --------> Lemmatized : article
# Original : containing --------> Lemmatized : contain
# Original : buzzwords --------> Lemmatized : buzzwords
# Original : from --------> Lemmatized : from
# Original : April --------> Lemmatized : April
# Original : 2025 --------> Lemmatized : 2025
# Original : This --------> Lemmatized : This
# Original : page --------> Lemmatized : page
# Original : was --------> Lemmatized : be
# Original : last --------> Lemmatized : last
# Original : edited --------> Lemmatized : edit
# Original : on --------> Lemmatized : on
# Original : 14 --------> Lemmatized : 14
# Original : April --------> Lemmatized : April
# Original : 2025 --------> Lemmatized : 2025
# Original : , --------> Lemmatized : ,
# Original : at --------> Lemmatized : at
# Original : 14:34 --------> Lemmatized : 14:34
# Original : ( --------> Lemmatized : (
# Original : UTC --------> Lemmatized : UTC
# Original : ) --------> Lemmatized : )
# Original : . --------> Lemmatized : .
# Original : Text --------> Lemmatized : Text
# Original : is --------> Lemmatized : be
# Original : available --------> Lemmatized : available
# Original : under --------> Lemmatized : under
# Original : the --------> Lemmatized : the
# Original : Creative --------> Lemmatized : Creative
# Original : Commons --------> Lemmatized : Commons
# Original : Attribution-ShareAlike --------> Lemmatized : Attribution-ShareAlike
# Original : 4.0 --------> Lemmatized : 4.0
# Original : License --------> Lemmatized : License
# Original : ; --------> Lemmatized : ;
# Original : additional --------> Lemmatized : additional
# Original : terms --------> Lemmatized : term
# Original : may --------> Lemmatized : may
# Original : apply --------> Lemmatized : apply
# Original : . --------> Lemmatized : .
# Original : By --------> Lemmatized : By
# Original : using --------> Lemmatized : use
# Original : this --------> Lemmatized : this
# Original : site --------> Lemmatized : site
# Original : , --------> Lemmatized : ,
# Original : you --------> Lemmatized : you
# Original : agree --------> Lemmatized : agree
# Original : to --------> Lemmatized : to
# Original : the --------> Lemmatized : the
# Original : Terms --------> Lemmatized : Terms
# Original : of --------> Lemmatized : of
# Original : Use --------> Lemmatized : Use
# Original : and --------> Lemmatized : and
# Original : Privacy --------> Lemmatized : Privacy
# Original : Policy --------> Lemmatized : Policy
# Original : . --------> Lemmatized : .
# Original : Wikipedia® --------> Lemmatized : Wikipedia®
# Original : is --------> Lemmatized : be
# Original : a --------> Lemmatized : a
# Original : registered --------> Lemmatized : register
# Original : trademark --------> Lemmatized : trademark
# Original : of --------> Lemmatized : of
# Original : the --------> Lemmatized : the
# Original : Wikimedia --------> Lemmatized : Wikimedia
# Original : Foundation --------> Lemmatized : Foundation
# Original : , --------> Lemmatized : ,
# Original : Inc. --------> Lemmatized : Inc.
# Original : , --------> Lemmatized : ,
# Original : a --------> Lemmatized : a
# Original : non-profit --------> Lemmatized : non-profit
# Original : organization --------> Lemmatized : organization
# Original : . --------> Lemmatized : .
# Original : Privacy --------> Lemmatized : Privacy
# Original : policy --------> Lemmatized : policy
# Original : About --------> Lemmatized : About
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : Disclaimers --------> Lemmatized : Disclaimers
# Original : Contact --------> Lemmatized : Contact
# Original : Wikipedia --------> Lemmatized : Wikipedia
# Original : Code --------> Lemmatized : Code
# Original : of --------> Lemmatized : of
# Original : Conduct --------> Lemmatized : Conduct
# Original : Developers --------> Lemmatized : Developers
# Original : Statistics --------> Lemmatized : Statistics
# Original : Cookie --------> Lemmatized : Cookie
# Original : statement --------> Lemmatized : statement
# Original : Mobile --------> Lemmatized : Mobile
# Original : view --------> Lemmatized : view
# Original : Search --------> Lemmatized : Search
# Original : Search --------> Lemmatized : Search
# Original : Toggle --------> Lemmatized : Toggle
# Original : the --------> Lemmatized : the
# Original : table --------> Lemmatized : table
# Original : of --------> Lemmatized : of
# Original : contents --------> Lemmatized : content
# Original : Centre --------> Lemmatized : Centre
# Original : for --------> Lemmatized : for
# Original : Development --------> Lemmatized : Development
# Original : of --------> Lemmatized : of
# Original : Advanced --------> Lemmatized : Advanced
# Original : Computing --------> Lemmatized : Computing
# Original : 6 --------> Lemmatized : 6
# Original : languages --------> Lemmatized : languages
# Original : Add --------> Lemmatized : Add
# Original : topic --------> Lemmatized : topic

# %% [markdown]
# # Question 4
#
# perform stop word removal on a non-english wikipedia page content

# %%
# !pip install wikipedia

import wikipedia
# Out:
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from wikipedia) (4.13.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wikipedia) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->wikipedia) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->wikipedia) (4.12.2)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11679 sha256=aa08fc09a4607ebb977ec143e41e5317ff9f04c82ea5b09671abc7258ba5bea6
#   Stored in directory: /root/.cache/pip/wheels/8f/ab/cb/45ccc40522d3a1c41e1d2ad53b8f33a62f394011ec38cd71c6
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
wikipedia.set_lang("fr")

text = wikipedia.page("Intelligence_artificielle").content

with open('intelligence_artificielle.txt', 'w', encoding='utf-8') as f:
    f.write(text)

print("Article saved to intelligence_artificielle.txt")
# Out:
# Article saved to intelligence_artificielle.txt

# %%
# NLTK

from nltk.corpus import stopwords
nltk.download('stopwords')

with open('intelligence_artificielle.txt', encoding='utf-8') as f:
    text = f.read()

sentences = sent_tokenize(text, language='french')

french_stop_words = set(stopwords.words('french'))

stemmer = nltk.stem.snowball.FrenchStemmer()

for i in range(len(sentences)):

    words = nltk.word_tokenize(sentences[i])

    filtered_words = [word for word in words if word.lower() not in french_stop_words]

    stemmed_words = [stemmer.stem(word) for word in filtered_words]

    print(f"Original Sentence : {sentences[i]}")
    print(f"Filtered Words : {filtered_words}")
    print(f"Stemmed Words : {stemmed_words}")
    print()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Original Sentence : L'intelligence artificielle (IA) est la capacité des machines à effectuer des tâches typiquement associées à l'intelligence humaine, comme l'apprentissage, le raisonnement, la résolution de problème, la perception ou la prise de décision.
# Filtered Words : ["L'intelligence", 'artificielle', '(', 'IA', ')', 'capacité', 'machines', 'effectuer', 'tâches', 'typiquement', 'associées', "l'intelligence", 'humaine', ',', 'comme', "l'apprentissage", ',', 'raisonnement', ',', 'résolution', 'problème', ',', 'perception', 'prise', 'décision', '.']
# Stemmed Words : ["l'intelligent", 'artificiel', '(', 'ia', ')', 'capac', 'machin', 'effectu', 'tâch', 'typiqu', 'associ', "l'intelligent", 'humain', ',', 'comm', "l'apprentissag", ',', 'raison', ',', 'résolu', 'problem', ',', 'percept', 'pris', 'décis', '.']
#
# Original Sentence : L'intelligence artificielle est également le champ de recherche visant à développer de telles machines ainsi que les systèmes informatiques qui en résultent.
# Filtered Words : ["L'intelligence", 'artificielle', 'également', 'champ', 'recherche', 'visant', 'développer', 'telles', 'machines', 'ainsi', 'systèmes', 'informatiques', 'résultent', '.']
# Stemmed Words : ["l'intelligent", 'artificiel', 'égal', 'champ', 'recherch', 'vis', 'développ', 'tel', 'machin', 'ains', 'system', 'informat', 'résultent', '.']
#
# Original Sentence : Souvent classée dans le domaine des mathématiques et des sciences cognitives, l'IA fait appel à des disciplines telles que la neurobiologie computationnelle (qui a notamment inspiré les réseaux neuronaux artificiels), les statistiques, ou l'algèbre linéaire.
# Filtered Words : ['Souvent', 'classée', 'domaine', 'mathématiques', 'sciences', 'cognitives', ',', "l'IA", 'fait', 'appel', 'disciplines', 'telles', 'neurobiologie', 'computationnelle', '(', 'a', 'notamment', 'inspiré', 'réseaux', 'neuronaux', 'artificiels', ')', ',', 'statistiques', ',', "l'algèbre", 'linéaire', '.']
# Stemmed Words : ['souvent', 'class', 'domain', 'mathémat', 'scienc', 'cognit', ',', "l'i", 'fait', 'appel', 'disciplin', 'tel', 'neurobiolog', 'computationnel', '(', 'a', 'not', 'inspir', 'réseau', 'neuronal', 'artificiel', ')', ',', 'statist', ',', "l'algebr", 'linéair', '.']
#
# Original Sentence : Elle vise à résoudre des problèmes à forte complexité logique ou algorithmique.
# Filtered Words : ['vise', 'résoudre', 'problèmes', 'forte', 'complexité', 'logique', 'algorithmique', '.']
# Stemmed Words : ['vis', 'résoudr', 'problem', 'fort', 'complex', 'logiqu', 'algorithm', '.']
#
# Original Sentence : Par extension, dans le langage courant, l'IA inclut les dispositifs imitant ou remplaçant l'homme dans certaines mises en œuvre de ses fonctions cognitives.
# Filtered Words : ['extension', ',', 'langage', 'courant', ',', "l'IA", 'inclut', 'dispositifs', 'imitant', 'remplaçant', "l'homme", 'certaines', 'mises', 'œuvre', 'fonctions', 'cognitives', '.']
# Stemmed Words : ['extens', ',', 'langag', 'cour', ',', "l'i", 'inclut', 'disposit', 'imit', 'remplac', "l'homm", 'certain', 'mis', 'œuvr', 'fonction', 'cognit', '.']
#
# Original Sentence : Les applications de l'IA comprennent notamment les moteurs de recherche, les systèmes de recommandation, l'aide au diagnostic médical, la compréhension du langage naturel, les voitures autonomes, les chatbots, les outils de génération d'images, les outils de prise de décision automatisée, les programmes compétitifs dans des jeux de stratégie et certains personnages non-joueurs de jeu vidéo.
# Filtered Words : ['applications', "l'IA", 'comprennent', 'notamment', 'moteurs', 'recherche', ',', 'systèmes', 'recommandation', ',', "l'aide", 'diagnostic', 'médical', ',', 'compréhension', 'langage', 'naturel', ',', 'voitures', 'autonomes', ',', 'chatbots', ',', 'outils', 'génération', "d'images", ',', 'outils', 'prise', 'décision', 'automatisée', ',', 'programmes', 'compétitifs', 'jeux', 'stratégie', 'certains', 'personnages', 'non-joueurs', 'jeu', 'vidéo', '.']
# Stemmed Words : ['appliqu', "l'i", 'comprennent', 'not', 'moteur', 'recherch', ',', 'system', 'recommand', ',', "l'aid", 'diagnostic', 'médical', ',', 'compréhens', 'langag', 'naturel', ',', 'voitur', 'autonom', ',', 'chatbot', ',', 'outil', 'géner', "d'imag", ',', 'outil', 'pris', 'décis', 'automatis', ',', 'programm', 'compétit', 'jeux', 'strateg', 'certain', 'personnag', 'non-joueur', 'jeu', 'vidéo', '.']
#
# Original Sentence : Depuis l'apparition du concept, les finalités, les enjeux et le développement de l'IA suscitent de nombreuses interprétations, fantasmes ou inquiétudes, que l'on retrouve dans les récits ou films de science-fiction, dans les essais philosophiques ainsi que parmi des économistes.
# Filtered Words : ['Depuis', "l'apparition", 'concept', ',', 'finalités', ',', 'enjeux', 'développement', "l'IA", 'suscitent', 'nombreuses', 'interprétations', ',', 'fantasmes', 'inquiétudes', ',', "l'on", 'retrouve', 'récits', 'films', 'science-fiction', ',', 'essais', 'philosophiques', 'ainsi', 'parmi', 'économistes', '.']
# Stemmed Words : ['depuis', "l'apparit", 'concept', ',', 'final', ',', 'enjeux', 'développ', "l'i", 'suscitent', 'nombreux', 'interpret', ',', 'fantasm', 'inquiétud', ',', "l'on", 'retrouv', 'récit', 'film', 'science-fict', ',', 'essais', 'philosoph', 'ains', 'parm', 'économ', '.']
#
# Original Sentence : == Définition ==
#
# Le terme « intelligence artificielle », souvent abrégé par le sigle « IA » (ou « AI » en anglais, pour artificial intelligence) a été créé par John McCarthy, qui l'a défini comme « la science et l'ingénierie de la fabrication de machines intelligentes, en particulier de programmes informatiques intelligents.
# Filtered Words : ['==', 'Définition', '==', 'terme', '«', 'intelligence', 'artificielle', '»', ',', 'souvent', 'abrégé', 'sigle', '«', 'IA', '»', '(', '«', '»', 'anglais', ',', 'artificial', 'intelligence', ')', 'a', 'créé', 'John', 'McCarthy', ',', "'", 'a', 'défini', 'comme', '«', 'science', "l'ingénierie", 'fabrication', 'machines', 'intelligentes', ',', 'particulier', 'programmes', 'informatiques', 'intelligents', '.']
# Stemmed Words : ['==', 'définit', '==', 'term', '«', 'intelligent', 'artificiel', '»', ',', 'souvent', 'abreg', 'sigl', '«', 'ia', '»', '(', '«', '»', 'anglais', ',', 'artificial', 'intelligent', ')', 'a', 'cré', 'john', 'mccarthy', ',', "'", 'a', 'défin', 'comm', '«', 'scienc', "l'ingénier", 'fabriqu', 'machin', 'intelligent', ',', 'particuli', 'programm', 'informat', 'intelligent', '.']
#
# Original Sentence : Elle est liée à la tâche similaire qui consiste à utiliser des ordinateurs pour comprendre l'intelligence humaine, mais l'IA ne doit pas se limiter aux méthodes qui sont biologiquement observables ».
# Filtered Words : ['liée', 'tâche', 'similaire', 'consiste', 'utiliser', 'ordinateurs', 'comprendre', "l'intelligence", 'humaine', ',', "l'IA", 'doit', 'limiter', 'méthodes', 'biologiquement', 'observables', '»', '.']
# Stemmed Words : ['li', 'tâch', 'similair', 'consist', 'utilis', 'ordin', 'comprendr', "l'intelligent", 'humain', ',', "l'i", 'doit', 'limit', 'méthod', 'biolog', 'observ', '»', '.']
#
# Original Sentence : Pour Marvin Lee Minsky, l'un de ses créateurs, l'IA est « la construction de programmes informatiques qui s'adonnent à des tâches qui sont, pour l'instant, accomplies de façon plus satisfaisante par des êtres humains car elles demandent des processus mentaux de haut niveau tels que : l'apprentissage perceptuel, l'organisation de la mémoire et le raisonnement critique »,.
# Filtered Words : ['Marvin', 'Lee', 'Minsky', ',', "l'un", 'créateurs', ',', "l'IA", '«', 'construction', 'programmes', 'informatiques', "s'adonnent", 'tâches', ',', "l'instant", ',', 'accomplies', 'façon', 'plus', 'satisfaisante', 'êtres', 'humains', 'car', 'elles', 'demandent', 'processus', 'mentaux', 'haut', 'niveau', 'tels', ':', "l'apprentissage", 'perceptuel', ',', "l'organisation", 'mémoire', 'raisonnement', 'critique', '»', ',', '.']
# Stemmed Words : ['marvin', 'le', 'minsky', ',', "l'un", 'créateur', ',', "l'i", '«', 'construct', 'programm', 'informat', "s'adonnent", 'tâch', ',', "l'inst", ',', 'accompl', 'façon', 'plus', 'satisfais', 'être', 'humain', 'car', 'elle', 'demandent', 'processus', 'mental', 'haut', 'niveau', 'tel', ':', "l'apprentissag", 'perceptuel', ',', "l'organis", 'mémoir', 'raison', 'critiqu', '»', ',', '.']
#
# Original Sentence : Cette définition combine l'aspect « artificiel » des ordinateurs et des processus informatiques, aux aspects « intelligents » d'imitation de comportements humains, notamment de raisonnement et d'apprentissage.
# Filtered Words : ['Cette', 'définition', 'combine', "l'aspect", '«', 'artificiel', '»', 'ordinateurs', 'processus', 'informatiques', ',', 'aspects', '«', 'intelligents', '»', "d'imitation", 'comportements', 'humains', ',', 'notamment', 'raisonnement', "d'apprentissage", '.']
# Stemmed Words : ['cet', 'définit', 'combin', "l'aspect", '«', 'artificiel', '»', 'ordin', 'processus', 'informat', ',', 'aspect', '«', 'intelligent', '»', "d'imit", 'comport', 'humain', ',', 'not', 'raison', "d'apprentissag", '.']
#
# Original Sentence : Celui-ci est à l'œuvre dans les jeux, dans la pratique des mathématiques, dans la compréhension du langage naturel, dans la perception visuelle (interprétation des images et des scènes), auditive (compréhension du langage parlé) ou par d'autres capteurs, dans la commande d'un robot dans un milieu inconnu ou hostile.
# Filtered Words : ['Celui-ci', "l'œuvre", 'jeux', ',', 'pratique', 'mathématiques', ',', 'compréhension', 'langage', 'naturel', ',', 'perception', 'visuelle', '(', 'interprétation', 'images', 'scènes', ')', ',', 'auditive', '(', 'compréhension', 'langage', 'parlé', ')', "d'autres", 'capteurs', ',', 'commande', "d'un", 'robot', 'milieu', 'inconnu', 'hostile', '.']
# Stemmed Words : ['celui-c', "l'œuvr", 'jeux', ',', 'pratiqu', 'mathémat', ',', 'compréhens', 'langag', 'naturel', ',', 'percept', 'visuel', '(', 'interpret', 'imag', 'scen', ')', ',', 'audit', '(', 'compréhens', 'langag', 'parl', ')', "d'autr", 'capteur', ',', 'command', "d'un", 'robot', 'milieu', 'inconnu', 'hostil', '.']
#
# Original Sentence : Avant les années 2000, d'autres définitions sont proches de celle de Minsky, mais varient sur deux points fondamentaux :
#
# les définitions qui lient l'IA à un aspect humain de l'intelligence et celles qui la lient à un modèle idéal d'intelligence, non forcément humaine, nommée rationalité ;
# les définitions qui insistent sur le fait que l'IA a pour but d'avoir toutes les apparences de l'intelligence (humaine ou rationnelle), et celles qui insistent sur le fait que le fonctionnement interne du système d'IA doit ressembler également à celui de l'être humain et être au moins aussi rationnel.
# Filtered Words : ['Avant', 'années', '2000', ',', "d'autres", 'définitions', 'proches', 'celle', 'Minsky', ',', 'varient', 'deux', 'points', 'fondamentaux', ':', 'définitions', 'lient', "l'IA", 'aspect', 'humain', "l'intelligence", 'celles', 'lient', 'modèle', 'idéal', "d'intelligence", ',', 'non', 'forcément', 'humaine', ',', 'nommée', 'rationalité', ';', 'définitions', 'insistent', 'fait', "l'IA", 'a', 'but', "d'avoir", 'toutes', 'apparences', "l'intelligence", '(', 'humaine', 'rationnelle', ')', ',', 'celles', 'insistent', 'fait', 'fonctionnement', 'interne', 'système', "d'IA", 'doit', 'ressembler', 'également', 'celui', "l'être", 'humain', 'être', 'moins', 'aussi', 'rationnel', '.']
# Stemmed Words : ['avant', 'anné', '2000', ',', "d'autr", 'définit', 'proch', 'cel', 'minsky', ',', 'varient', 'deux', 'point', 'fondamental', ':', 'définit', 'lient', "l'i", 'aspect', 'humain', "l'intelligent", 'cel', 'lient', 'model', 'idéal', "d'intelligent", ',', 'non', 'forc', 'humain', ',', 'nomm', 'rational', ';', 'définit', 'insistent', 'fait', "l'i", 'a', 'but', "d'avoir", 'tout', 'apparent', "l'intelligent", '(', 'humain', 'rationnel', ')', ',', 'cel', 'insistent', 'fait', 'fonction', 'intern', 'system', "d'i", 'doit', 'ressembl', 'égal', 'celui', "l'êtr", 'humain', 'être', 'moin', 'auss', 'rationnel', '.']
#
# Original Sentence : Le grand public confond souvent l'intelligence artificielle avec l'apprentissage automatique (machine learning) et l'apprentissage profond (deep learning).
# Filtered Words : ['grand', 'public', 'confond', 'souvent', "l'intelligence", 'artificielle', "l'apprentissage", 'automatique', '(', 'machine', 'learning', ')', "l'apprentissage", 'profond', '(', 'deep', 'learning', ')', '.']
# Stemmed Words : ['grand', 'public', 'confond', 'souvent', "l'intelligent", 'artificiel', "l'apprentissag", 'automat', '(', 'machin', 'learning', ')', "l'apprentissag", 'profond', '(', 'deep', 'learning', ')', '.']
#
# Original Sentence : Ces trois notions diffèrent et sont en réalité imbriquées : l'intelligence artificielle englobe l'apprentissage automatique, qui lui-même englobe l'apprentissage profond.
# Filtered Words : ['trois', 'notions', 'diffèrent', 'réalité', 'imbriquées', ':', "l'intelligence", 'artificielle', 'englobe', "l'apprentissage", 'automatique', ',', 'lui-même', 'englobe', "l'apprentissage", 'profond', '.']
# Stemmed Words : ['trois', 'notion', 'diff', 'réalit', 'imbriqu', ':', "l'intelligent", 'artificiel', 'englob', "l'apprentissag", 'automat', ',', 'lui-mêm', 'englob', "l'apprentissag", 'profond', '.']
#
# Original Sentence : Les définitions font souvent intervenir, :
#
# une capacité à percevoir l'environnement et à prendre en compte la complexité du monde réel ;
# un traitement de l'information (collecter et interpréter des intrants, captés sous forme de données) ;
# des prises de décision (y compris dans le raisonnement et l'apprentissage), choix d'actions, exécution de tâches (dont d'adaptation, de réaction aux changements de contexte…), avec un certain niveau d'autonomie ;
# la réalisation d'objectifs spécifiques (raison ultime des systèmes d'IA).
# Filtered Words : ['définitions', 'font', 'souvent', 'intervenir', ',', ':', 'capacité', 'percevoir', "l'environnement", 'prendre', 'compte', 'complexité', 'monde', 'réel', ';', 'traitement', "l'information", '(', 'collecter', 'interpréter', 'intrants', ',', 'captés', 'sous', 'forme', 'données', ')', ';', 'prises', 'décision', '(', 'compris', 'raisonnement', "l'apprentissage", ')', ',', 'choix', "d'actions", ',', 'exécution', 'tâches', '(', 'dont', "d'adaptation", ',', 'réaction', 'changements', 'contexte…', ')', ',', 'certain', 'niveau', "d'autonomie", ';', 'réalisation', "d'objectifs", 'spécifiques', '(', 'raison', 'ultime', 'systèmes', "d'IA", ')', '.']
# Stemmed Words : ['définit', 'font', 'souvent', 'interven', ',', ':', 'capac', 'percevoir', "l'environ", 'prendr', 'compt', 'complex', 'mond', 'réel', ';', 'trait', "l'inform", '(', 'collect', 'interpret', 'intrant', ',', 'capt', 'sous', 'form', 'don', ')', ';', 'pris', 'décis', '(', 'compr', 'raison', "l'apprentissag", ')', ',', 'choix', "d'action", ',', 'exécu', 'tâch', '(', 'dont', "d'adapt", ',', 'réaction', 'chang', 'contexte…', ')', ',', 'certain', 'niveau', "d'autonom", ';', 'réalis', "d'object", 'spécif', '(', 'raison', 'ultim', 'system', "d'i", ')', '.']
#
# Original Sentence : Le groupe AI Watch note que les IA peuvent aussi être classées en fonction des familles d’algorithmes et/ou des modèles théoriques qui les sous-tendent, des capacités cognitives reproduites par l’IA, des fonctions exécutées par l’IA.
# Filtered Words : ['groupe', 'Watch', 'note', 'IA', 'peuvent', 'aussi', 'être', 'classées', 'fonction', 'familles', '’', 'algorithmes', 'et/ou', 'modèles', 'théoriques', 'sous-tendent', ',', 'capacités', 'cognitives', 'reproduites', '’', 'IA', ',', 'fonctions', 'exécutées', '’', 'IA', '.']
# Stemmed Words : ['group', 'watch', 'not', 'ia', 'peuvent', 'auss', 'être', 'class', 'fonction', 'famill', '’', 'algorithm', 'et/ou', 'model', 'théoriqu', 'sous-tendent', ',', 'capac', 'cognit', 'reproduit', '’', 'ia', ',', 'fonction', 'exécut', '’', 'ia', '.']
#
# Original Sentence : Les applications de l’IA peuvent, elles, être classées en fonction du secteur socioéconomique et/ou des fonctions qu'elles y remplissent.
# Filtered Words : ['applications', '’', 'IA', 'peuvent', ',', 'elles', ',', 'être', 'classées', 'fonction', 'secteur', 'socioéconomique', 'et/ou', 'fonctions', "qu'elles", 'remplissent', '.']
# Stemmed Words : ['appliqu', '’', 'ia', 'peuvent', ',', 'elle', ',', 'être', 'class', 'fonction', 'secteur', 'socioéconom', 'et/ou', 'fonction', "qu'el", 'rempl', '.']
#
# Original Sentence : Une manière de définir l'intelligence artificielle est de considérer ses applications et les types de tâches qu'elle résout.
# Filtered Words : ['manière', 'définir', "l'intelligence", 'artificielle', 'considérer', 'applications', 'types', 'tâches', "qu'elle", 'résout', '.']
# Stemmed Words : ['mani', 'défin', "l'intelligent", 'artificiel', 'consider', 'appliqu', 'typ', 'tâch', "qu'el", 'résout', '.']
#
# Original Sentence : Un rapport de la Commission européenne publié en 2020 présente une taxonomie classant les définitions de l'IA selon diverses tâches réalisées, telles que le raisonnement, l'apprentissage, la perception, etc..
# Filtered Words : ['rapport', 'Commission', 'européenne', 'publié', '2020', 'présente', 'taxonomie', 'classant', 'définitions', "l'IA", 'selon', 'diverses', 'tâches', 'réalisées', ',', 'telles', 'raisonnement', ',', "l'apprentissage", ',', 'perception', ',', 'etc', '..']
# Stemmed Words : ['rapport', 'commiss', 'européen', 'publi', '2020', 'présent', 'taxonom', 'class', 'définit', "l'i", 'selon', 'divers', 'tâch', 'réalis', ',', 'tel', 'raison', ',', "l'apprentissag", ',', 'percept', ',', 'etc', '..']
#
# Original Sentence : La même année, le professeur Jack Copeland propose une définition similaire, qui permet de distinguer plus clairement les facettes de l'IA, selon cinq catégories principales :
#
# L'apprentissage généralisé : l'IA apprend à partir de données diverses pour identifier des modèles et appliquer ces connaissances à de nouvelles situations, comme détecter des fraudes en ligne ;
# Le raisonnement : cette capacité permet à l'IA de faire des prédictions et tirer des conclusions à partir des données, aidant dans des décisions comme la prédiction de comportements d'achat ;
# La résolution de problèmes : l'IA trouve des solutions optimales pour des problèmes spécifiques, utilisée dans des contextes comme l'optimisation industrielle ou les stratégies de jeu ;
# La perception : elle permet à l'IA de reconnaître et interagir avec son environnement, utilisée dans la robotique avancée et les véhicules autonomes pour naviguer et accomplir des tâches ;
# La compréhension du langage : l'IA analyse et génère du langage à travers le NLP, utilisé dans des applications comme les assistants vocaux et les chatbots pour améliorer l'interaction utilisateur.
# Filtered Words : ['année', ',', 'professeur', 'Jack', 'Copeland', 'propose', 'définition', 'similaire', ',', 'permet', 'distinguer', 'plus', 'clairement', 'facettes', "l'IA", ',', 'selon', 'cinq', 'catégories', 'principales', ':', "L'apprentissage", 'généralisé', ':', "l'IA", 'apprend', 'partir', 'données', 'diverses', 'identifier', 'modèles', 'appliquer', 'connaissances', 'nouvelles', 'situations', ',', 'comme', 'détecter', 'fraudes', 'ligne', ';', 'raisonnement', ':', 'cette', 'capacité', 'permet', "l'IA", 'faire', 'prédictions', 'tirer', 'conclusions', 'partir', 'données', ',', 'aidant', 'décisions', 'comme', 'prédiction', 'comportements', "d'achat", ';', 'résolution', 'problèmes', ':', "l'IA", 'trouve', 'solutions', 'optimales', 'problèmes', 'spécifiques', ',', 'utilisée', 'contextes', 'comme', "l'optimisation", 'industrielle', 'stratégies', 'jeu', ';', 'perception', ':', 'permet', "l'IA", 'reconnaître', 'interagir', 'environnement', ',', 'utilisée', 'robotique', 'avancée', 'véhicules', 'autonomes', 'naviguer', 'accomplir', 'tâches', ';', 'compréhension', 'langage', ':', "l'IA", 'analyse', 'génère', 'langage', 'travers', 'NLP', ',', 'utilisé', 'applications', 'comme', 'assistants', 'vocaux', 'chatbots', 'améliorer', "l'interaction", 'utilisateur', '.']
# Stemmed Words : ['anné', ',', 'professeur', 'jack', 'copeland', 'propos', 'définit', 'similair', ',', 'permet', 'distingu', 'plus', 'clair', 'facet', "l'i", ',', 'selon', 'cinq', 'catégor', 'principal', ':', "l'apprentissag", 'généralis', ':', "l'i", 'apprend', 'part', 'don', 'divers', 'identifi', 'model', 'appliqu', 'connaiss', 'nouvel', 'situat', ',', 'comm', 'détect', 'fraud', 'lign', ';', 'raison', ':', 'cet', 'capac', 'permet', "l'i", 'fair', 'prédict', 'tir', 'conclus', 'part', 'don', ',', 'aid', 'décis', 'comm', 'prédict', 'comport', "d'achat", ';', 'résolu', 'problem', ':', "l'i", 'trouv', 'solut', 'optimal', 'problem', 'spécif', ',', 'utilis', 'context', 'comm', "l'optimis", 'industriel', 'strateg', 'jeu', ';', 'percept', ':', 'permet', "l'i", 'reconnaîtr', 'interag', 'environ', ',', 'utilis', 'robot', 'avanc', 'véhicul', 'autonom', 'navigu', 'accompl', 'tâch', ';', 'compréhens', 'langag', ':', "l'i", 'analys', 'géner', 'langag', 'traver', 'nlp', ',', 'utilis', 'appliqu', 'comm', 'assist', 'vocal', 'chatbot', 'amélior', "l'interact", 'utilis', '.']
#
# Original Sentence : == Techniques ==
#
#
# === Comportements prédéfinis (imitation d'intelligence) ===
#
# Pour les intelligences artificielles servant principalement à donner une impression d'intelligence dans un cadre contrôlé, notamment pour les personnages non-joueurs des jeux vidéo, il est courant que l'apprentissage automatique ne soit pas utilisé.
# Filtered Words : ['==', 'Techniques', '==', '===', 'Comportements', 'prédéfinis', '(', 'imitation', "d'intelligence", ')', '===', 'intelligences', 'artificielles', 'servant', 'principalement', 'donner', 'impression', "d'intelligence", 'cadre', 'contrôlé', ',', 'notamment', 'personnages', 'non-joueurs', 'jeux', 'vidéo', ',', 'courant', "l'apprentissage", 'automatique', 'utilisé', '.']
# Stemmed Words : ['==', 'techniqu', '==', '===', 'comport', 'prédéfin', '(', 'imit', "d'intelligent", ')', '===', 'intelligent', 'artificiel', 'serv', 'principal', 'don', 'impress', "d'intelligent", 'cadr', 'contrôl', ',', 'not', 'personnag', 'non-joueur', 'jeux', 'vidéo', ',', 'cour', "l'apprentissag", 'automat', 'utilis', '.']
#
# Original Sentence : Un ensemble de fonctions et comportements plus précises et moins flexibles sont alors implémentés.
# Filtered Words : ['ensemble', 'fonctions', 'comportements', 'plus', 'précises', 'moins', 'flexibles', 'alors', 'implémentés', '.']
# Stemmed Words : ['ensembl', 'fonction', 'comport', 'plus', 'précis', 'moin', 'flexibl', 'alor', 'implément', '.']
#
# Original Sentence : Il s'agit souvent de liste de textes ou paroles prédéfinis, aux déclenchements parfois conditionnels, par exemple un choix de mouvements suivant une série de règles et des déplacements de pathfinding.
# Filtered Words : ["s'agit", 'souvent', 'liste', 'textes', 'paroles', 'prédéfinis', ',', 'déclenchements', 'parfois', 'conditionnels', ',', 'exemple', 'choix', 'mouvements', 'suivant', 'série', 'règles', 'déplacements', 'pathfinding', '.']
# Stemmed Words : ["s'ag", 'souvent', 'list', 'text', 'parol', 'prédéfin', ',', 'déclench', 'parfois', 'conditionnel', ',', 'exempl', 'choix', 'mouv', 'suiv', 'ser', 'regl', 'déplac', 'pathfinding', '.']
#
# Original Sentence : === Apprentissage automatique ===
# L'apprentissage automatique consiste à permettre au modèle d'IA d'apprendre à effectuer une tâche au lieu de spécifier exactement comment il doit l'accomplir.
# Filtered Words : ['===', 'Apprentissage', 'automatique', '===', "L'apprentissage", 'automatique', 'consiste', 'permettre', 'modèle', "d'IA", "d'apprendre", 'effectuer', 'tâche', 'lieu', 'spécifier', 'exactement', 'comment', 'doit', "l'accomplir", '.']
# Stemmed Words : ['===', 'apprentissag', 'automat', '===', "l'apprentissag", 'automat', 'consist', 'permettr', 'model', "d'i", "d'apprendr", 'effectu', 'tâch', 'lieu', 'spécifi', 'exact', 'comment', 'doit', "l'accompl", '.']
#
# Original Sentence : Le modèle contient des paramètres dont les valeurs sont ajustées tout au long de l'apprentissage.
# Filtered Words : ['modèle', 'contient', 'paramètres', 'dont', 'valeurs', 'ajustées', 'tout', 'long', "l'apprentissage", '.']
# Stemmed Words : ['model', 'contient', 'parametr', 'dont', 'valeur', 'ajust', 'tout', 'long', "l'apprentissag", '.']
#
# Original Sentence : La méthode de la rétropropagation du gradient est capable de détecter, pour chaque paramètre, dans quelle mesure il a contribué à une bonne réponse ou à une erreur du modèle, et peut l'ajuster en conséquence.
# Filtered Words : ['méthode', 'rétropropagation', 'gradient', 'capable', 'détecter', ',', 'chaque', 'paramètre', ',', 'quelle', 'mesure', 'a', 'contribué', 'bonne', 'réponse', 'erreur', 'modèle', ',', 'peut', "l'ajuster", 'conséquence', '.']
# Stemmed Words : ['méthod', 'rétropropag', 'gradient', 'capabl', 'détect', ',', 'chaqu', 'parametr', ',', 'quel', 'mesur', 'a', 'contribu', 'bon', 'répons', 'erreur', 'model', ',', 'peut', "l'ajust", 'conséquent', '.']
#
# Original Sentence : L'apprentissage automatique nécessite un moyen d'évaluer la qualité des réponses fournies par le modèle.
# Filtered Words : ["L'apprentissage", 'automatique', 'nécessite', 'moyen', "d'évaluer", 'qualité', 'réponses', 'fournies', 'modèle', '.']
# Stemmed Words : ["l'apprentissag", 'automat', 'nécessit', 'moyen', "d'évalu", 'qualit', 'répons', 'fourn', 'model', '.']
#
# Original Sentence : Les principales méthodes d'apprentissage sont :
#
# Apprentissage supervisé
# Un jeu de données annoté est utilisé pour entraîner l'algorithme.
# Filtered Words : ['principales', 'méthodes', "d'apprentissage", ':', 'Apprentissage', 'supervisé', 'jeu', 'données', 'annoté', 'utilisé', 'entraîner', "l'algorithme", '.']
# Stemmed Words : ['principal', 'méthod', "d'apprentissag", ':', 'apprentissag', 'supervis', 'jeu', 'don', 'annot', 'utilis', 'entraîn', "l'algorithm", '.']
#
# Original Sentence : Il contient des données d'entrée fournies au modèle et les réponses correspondantes attendues, que le modèle est entraîné à produire.
# Filtered Words : ['contient', 'données', "d'entrée", 'fournies', 'modèle', 'réponses', 'correspondantes', 'attendues', ',', 'modèle', 'entraîné', 'produire', '.']
# Stemmed Words : ['contient', 'don', "d'entr", 'fourn', 'model', 'répons', 'correspond', 'attendu', ',', 'model', 'entraîn', 'produir', '.']
#
# Original Sentence : Il est parfois difficile de se procurer suffisamment de données annotées avec les réponses attendues.
# Filtered Words : ['parfois', 'difficile', 'procurer', 'suffisamment', 'données', 'annotées', 'réponses', 'attendues', '.']
# Stemmed Words : ['parfois', 'difficil', 'procur', 'suffis', 'don', 'annot', 'répons', 'attendu', '.']
#
# Original Sentence : Apprentissage non supervisé
# Un jeu de données est fourni au modèle, mais n'est pas annoté avec les réponses attendues.
# Filtered Words : ['Apprentissage', 'non', 'supervisé', 'jeu', 'données', 'fourni', 'modèle', ',', "n'est", 'annoté', 'réponses', 'attendues', '.']
# Stemmed Words : ['apprentissag', 'non', 'supervis', 'jeu', 'don', 'fourn', 'model', ',', "n'est", 'annot', 'répons', 'attendu', '.']
#
# Original Sentence : Le but peut par exemple être de regrouper les données similaires entre elles (clustering).
# Filtered Words : ['but', 'peut', 'exemple', 'être', 'regrouper', 'données', 'similaires', 'entre', 'elles', '(', 'clustering', ')', '.']
# Stemmed Words : ['but', 'peut', 'exempl', 'être', 'regroup', 'don', 'similair', 'entre', 'elle', '(', 'clustering', ')', '.']
#
# Original Sentence : Apprentissage auto-supervisé
# Un problème d'apprentissage supervisé est automatiquement généré à partir d'un jeu de données non annoté.
# Filtered Words : ['Apprentissage', 'auto-supervisé', 'problème', "d'apprentissage", 'supervisé', 'automatiquement', 'généré', 'partir', "d'un", 'jeu', 'données', 'non', 'annoté', '.']
# Stemmed Words : ['apprentissag', 'auto-supervis', 'problem', "d'apprentissag", 'supervis', 'automat', 'géner', 'part', "d'un", 'jeu', 'don', 'non', 'annot', '.']
#
# Original Sentence : Cela fonctionne souvent en cachant une partie des informations (des mots d'un texte, des morceaux d'images…) afin d'entraîner le modèle à les prédire.
# Filtered Words : ['Cela', 'fonctionne', 'souvent', 'cachant', 'partie', 'informations', '(', 'mots', "d'un", 'texte', ',', 'morceaux', "d'images…", ')', 'afin', "d'entraîner", 'modèle', 'prédire', '.']
# Stemmed Words : ['cel', 'fonction', 'souvent', 'cach', 'part', 'inform', '(', 'mot', "d'un", 'text', ',', 'morceau', "d'images…", ')', 'afin', "d'entraîn", 'model', 'prédir', '.']
#
# Original Sentence : Apprentissage par renforcement
# L'agent est plongé dans un environnement où ce qu'il fait est évalué.
# Filtered Words : ['Apprentissage', 'renforcement', "L'agent", 'plongé', 'environnement', 'où', "qu'il", 'fait', 'évalué', '.']
# Stemmed Words : ['apprentissag', 'renforc', "l'agent", 'plong', 'environ', 'où', "qu'il", 'fait', 'évalu', '.']
#
# Original Sentence : Par exemple, un agent peut apprendre à jouer aux échecs en jouant contre lui-même, et le résultat (victoire ou défaite) permet à chaque itération d'évaluer s'il a bien joué.
# Filtered Words : ['exemple', ',', 'agent', 'peut', 'apprendre', 'jouer', 'échecs', 'jouant', 'contre', 'lui-même', ',', 'résultat', '(', 'victoire', 'défaite', ')', 'permet', 'chaque', 'itération', "d'évaluer", "s'il", 'a', 'bien', 'joué', '.']
# Stemmed Words : ['exempl', ',', 'agent', 'peut', 'apprendr', 'jou', 'échec', 'jou', 'contr', 'lui-mêm', ',', 'résultat', '(', 'victoir', 'défait', ')', 'permet', 'chaqu', 'iter', "d'évalu", "s'il", 'a', 'bien', 'jou', '.']
#
# Original Sentence : Il n'y a dans ce cas pas besoin de jeu de données.
# Filtered Words : ["'", 'a', 'cas', 'besoin', 'jeu', 'données', '.']
# Stemmed Words : ["'", 'a', 'cas', 'besoin', 'jeu', 'don', '.']
#
# Original Sentence : ==== Réseaux de neurones ====
#
# Les réseaux de neurones artificiels sont inspirés du fonctionnement du cerveau humain : les neurones sont en général connectés à d'autres neurones en entrée et en sortie.
# Filtered Words : ['====', 'Réseaux', 'neurones', '====', 'réseaux', 'neurones', 'artificiels', 'inspirés', 'fonctionnement', 'cerveau', 'humain', ':', 'neurones', 'général', 'connectés', "d'autres", 'neurones', 'entrée', 'sortie', '.']
# Stemmed Words : ['====', 'réseau', 'neuron', '====', 'réseau', 'neuron', 'artificiel', 'inspir', 'fonction', 'cerveau', 'humain', ':', 'neuron', 'général', 'connect', "d'autr", 'neuron', 'entré', 'sort', '.']
#
# Original Sentence : Les neurones d'entrée, lorsqu'ils sont activés, agissent comme s'ils participaient à un vote pondéré pour déterminer si un neurone intermédiaire doit être activé et ainsi transmettre un signal vers les neurones de sortie.
# Filtered Words : ['neurones', "d'entrée", ',', "lorsqu'ils", 'activés', ',', 'agissent', 'comme', "s'ils", 'participaient', 'vote', 'pondéré', 'déterminer', 'si', 'neurone', 'intermédiaire', 'doit', 'être', 'activé', 'ainsi', 'transmettre', 'signal', 'vers', 'neurones', 'sortie', '.']
# Stemmed Words : ['neuron', "d'entr", ',', "lorsqu'il", 'activ', ',', 'agissent', 'comm', "s'il", 'particip', 'vot', 'ponder', 'détermin', 'si', 'neuron', 'intermédiair', 'doit', 'être', 'activ', 'ains', 'transmettr', 'signal', 'ver', 'neuron', 'sort', '.']
#
# Original Sentence : En pratique, pour l'équivalent artificiel, les « neurones d'entrée » ne sont que des nombres et les poids de ce « vote pondéré » sont des paramètres ajustés lors de l'apprentissage,.
# Filtered Words : ['pratique', ',', "l'équivalent", 'artificiel', ',', '«', 'neurones', "d'entrée", '»', 'nombres', 'poids', '«', 'vote', 'pondéré', '»', 'paramètres', 'ajustés', 'lors', "l'apprentissage", ',', '.']
# Stemmed Words : ['pratiqu', ',', "l'équivalent", 'artificiel', ',', '«', 'neuron', "d'entr", '»', 'nombr', 'poid', '«', 'vot', 'ponder', '»', 'parametr', 'ajust', 'lor', "l'apprentissag", ',', '.']
#
# Original Sentence : Hormis la fonction d'activation, les réseaux de neurones artificiels n'effectuent en pratique que des additions et des multiplications matricielles, ce qui fait qu'ils peuvent être accélérés par l'utilisation de processeurs graphiques.
# Filtered Words : ['Hormis', 'fonction', "d'activation", ',', 'réseaux', 'neurones', 'artificiels', "n'effectuent", 'pratique', 'additions', 'multiplications', 'matricielles', ',', 'fait', "qu'ils", 'peuvent', 'être', 'accélérés', "l'utilisation", 'processeurs', 'graphiques', '.']
# Stemmed Words : ['horm', 'fonction', "d'activ", ',', 'réseau', 'neuron', 'artificiel', "n'effectuent", 'pratiqu', 'addit', 'multipl', 'matriciel', ',', 'fait', "qu'il", 'peuvent', 'être', 'accéler', "l'utilis", 'processeur', 'graphiqu', '.']
#
# Original Sentence : En théorie, un réseau de neurones peut approximer n'importe quelle fonction.
# Filtered Words : ['théorie', ',', 'réseau', 'neurones', 'peut', 'approximer', "n'importe", 'quelle', 'fonction', '.']
# Stemmed Words : ['théor', ',', 'réseau', 'neuron', 'peut', 'approxim', "n'import", 'quel', 'fonction', '.']
#
# Original Sentence : Pour de simples réseaux de neurones à propagation avant (feedforward en anglais), le signal ne passe que dans une direction.
# Filtered Words : ['simples', 'réseaux', 'neurones', 'propagation', 'avant', '(', 'feedforward', 'anglais', ')', ',', 'signal', 'passe', 'direction', '.']
# Stemmed Words : ['simpl', 'réseau', 'neuron', 'propag', 'avant', '(', 'feedforward', 'anglais', ')', ',', 'signal', 'pass', 'direct', '.']
#
# Original Sentence : Avec les réseaux de neurones récurrents, le signal de sortie de chaque neurone est réinjecté en entrée de ce neurone, permettant d’implémenter un mécanisme de mémoire à court terme.
# Filtered Words : ['réseaux', 'neurones', 'récurrents', ',', 'signal', 'sortie', 'chaque', 'neurone', 'réinjecté', 'entrée', 'neurone', ',', 'permettant', '’', 'implémenter', 'mécanisme', 'mémoire', 'court', 'terme', '.']
# Stemmed Words : ['réseau', 'neuron', 'récurrent', ',', 'signal', 'sort', 'chaqu', 'neuron', 'réinject', 'entré', 'neuron', ',', 'permet', '’', 'implément', 'mécan', 'mémoir', 'court', 'term', '.']
#
# Original Sentence : Les réseaux neuronaux convolutifs, qui sont particulièrement utilisés en traitement d'images, introduisent une notion de localité.
# Filtered Words : ['réseaux', 'neuronaux', 'convolutifs', ',', 'particulièrement', 'utilisés', 'traitement', "d'images", ',', 'introduisent', 'notion', 'localité', '.']
# Stemmed Words : ['réseau', 'neuronal', 'convolut', ',', 'particuli', 'utilis', 'trait', "d'imag", ',', 'introduisent', 'notion', 'local', '.']
#
# Original Sentence : Leurs premières couches identifient des motifs relativement basiques et locaux comme des contours, là où les dernières couches traitent de motifs plus complexes et globaux.
# Filtered Words : ['Leurs', 'premières', 'couches', 'identifient', 'motifs', 'relativement', 'basiques', 'locaux', 'comme', 'contours', ',', 'là', 'où', 'dernières', 'couches', 'traitent', 'motifs', 'plus', 'complexes', 'globaux', '.']
# Stemmed Words : ['leur', 'premi', 'couch', 'identifient', 'motif', 'relat', 'basiqu', 'local', 'comm', 'contour', ',', 'là', 'où', 'derni', 'couch', 'traitent', 'motif', 'plus', 'complex', 'global', '.']
#
# Original Sentence : ===== Apprentissage profond =====
# L'apprentissage profond (deep learning en anglais) utilise de multiples couches de neurones entre les entrées et les sorties, d'où le terme « profond ».
# Filtered Words : ['=====', 'Apprentissage', 'profond', '=====', "L'apprentissage", 'profond', '(', 'deep', 'learning', 'anglais', ')', 'utilise', 'multiples', 'couches', 'neurones', 'entre', 'entrées', 'sorties', ',', "d'où", 'terme', '«', 'profond', '»', '.']
# Stemmed Words : ['=====', 'apprentissag', 'profond', '=====', "l'apprentissag", 'profond', '(', 'deep', 'learning', 'anglais', ')', 'utilis', 'multipl', 'couch', 'neuron', 'entre', 'entré', 'sort', ',', "d'où", 'term', '«', 'profond', '»', '.']
#
# Original Sentence : L'utilisation de processeurs graphiques pour accélérer les calculs et l'augmentation des données disponibles a contribué à la montée en popularité de l'apprentissage profond.
# Filtered Words : ["L'utilisation", 'processeurs', 'graphiques', 'accélérer', 'calculs', "l'augmentation", 'données', 'disponibles', 'a', 'contribué', 'montée', 'popularité', "l'apprentissage", 'profond', '.']
# Stemmed Words : ["l'utilis", 'processeur', 'graphiqu', 'accéler', 'calcul', "l'augment", 'don', 'disponibl', 'a', 'contribu', 'mont', 'popular', "l'apprentissag", 'profond', '.']
#
# Original Sentence : Il est utilisé notamment en vision par ordinateur, en reconnaissance automatique de la parole et en traitement automatique des langues (ce qui inclut les grands modèles de langage).
# Filtered Words : ['utilisé', 'notamment', 'vision', 'ordinateur', ',', 'reconnaissance', 'automatique', 'parole', 'traitement', 'automatique', 'langues', '(', 'inclut', 'grands', 'modèles', 'langage', ')', '.']
# Stemmed Words : ['utilis', 'not', 'vision', 'ordin', ',', 'reconnaiss', 'automat', 'parol', 'trait', 'automat', 'langu', '(', 'inclut', 'grand', 'model', 'langag', ')', '.']
#
# Original Sentence : ===== Grands modèles de langages =====
# Les grands modèles de langage sont des modèles de langage ayant des milliards de paramètres.
# Filtered Words : ['=====', 'Grands', 'modèles', 'langages', '=====', 'grands', 'modèles', 'langage', 'modèles', 'langage', 'milliards', 'paramètres', '.']
# Stemmed Words : ['=====', 'grand', 'model', 'langag', '=====', 'grand', 'model', 'langag', 'model', 'langag', 'milliard', 'parametr', '.']
#
# Original Sentence : Ils reposent très souvent sur l'architecture transformeur.
# Filtered Words : ['reposent', 'très', 'souvent', "l'architecture", 'transformeur', '.']
# Stemmed Words : ['reposent', 'tres', 'souvent', "l'architectur", 'transformeur', '.']
#
# Original Sentence : Les transformeurs génératifs préentraînés (Generative Pretrained Transformers ou GPT en anglais) sont un type particulièrement populaire de grand modèle de langage.
# Filtered Words : ['transformeurs', 'génératifs', 'préentraînés', '(', 'Generative', 'Pretrained', 'Transformers', 'GPT', 'anglais', ')', 'type', 'particulièrement', 'populaire', 'grand', 'modèle', 'langage', '.']
# Stemmed Words : ['transformeur', 'géner', 'préentraîn', '(', 'gener', 'pretrained', 'transformer', 'gpt', 'anglais', ')', 'typ', 'particuli', 'populair', 'grand', 'model', 'langag', '.']
#
# Original Sentence : Leur « pré-entraînement » consiste à prédire, étant donnée une partie d'un texte, le token suivant (un token étant une séquence de caractères, typiquement un mot, une partie d'un mot, ou de la ponctuation).
# Filtered Words : ['«', 'pré-entraînement', '»', 'consiste', 'prédire', ',', 'donnée', 'partie', "d'un", 'texte', ',', 'token', 'suivant', '(', 'token', 'séquence', 'caractères', ',', 'typiquement', 'mot', ',', 'partie', "d'un", 'mot', ',', 'ponctuation', ')', '.']
# Stemmed Words : ['«', 'pré-entraîn', '»', 'consist', 'prédir', ',', 'don', 'part', "d'un", 'text', ',', 'token', 'suiv', '(', 'token', 'séquenc', 'caracter', ',', 'typiqu', 'mot', ',', 'part', "d'un", 'mot', ',', 'ponctuat', ')', '.']
#
# Original Sentence : Cet entraînement à prédire ce qui va suivre, répété pour un grand nombre de textes, permet à ces modèles d'accumuler des connaissances sur le monde.
# Filtered Words : ['Cet', 'entraînement', 'prédire', 'va', 'suivre', ',', 'répété', 'grand', 'nombre', 'textes', ',', 'permet', 'modèles', "d'accumuler", 'connaissances', 'monde', '.']
# Stemmed Words : ['cet', 'entraîn', 'prédir', 'va', 'suivr', ',', 'répet', 'grand', 'nombr', 'text', ',', 'permet', 'model', "d'accumul", 'connaiss', 'mond', '.']
#
# Original Sentence : Ils peuvent ensuite générer du texte semblable à celui ayant servi au pré-entraînement, en prédisant un à un les tokens suivants.
# Filtered Words : ['peuvent', 'ensuite', 'générer', 'texte', 'semblable', 'celui', 'servi', 'pré-entraînement', ',', 'prédisant', 'tokens', 'suivants', '.']
# Stemmed Words : ['peuvent', 'ensuit', 'géner', 'text', 'semblabl', 'celui', 'serv', 'pré-entraîn', ',', 'prédis', 'token', 'suiv', '.']
#
# Original Sentence : En général, une autre phase d'entraînement est ensuite effectuée pour rendre le modèle plus véridique, utile et inoffensif.
# Filtered Words : ['général', ',', 'autre', 'phase', "d'entraînement", 'ensuite', 'effectuée', 'rendre', 'modèle', 'plus', 'véridique', ',', 'utile', 'inoffensif', '.']
# Stemmed Words : ['général', ',', 'autr', 'phas', "d'entraîn", 'ensuit', 'effectu', 'rendr', 'model', 'plus', 'vérid', ',', 'util', 'inoffens', '.']
#
# Original Sentence : Cette phase d'entraînement (utilisant souvent une technique appelée RLHF) permet notamment de réduire un phénomène appelé « hallucination », où le modèle génère des informations d'apparence plausible mais fausses.
# Filtered Words : ['Cette', 'phase', "d'entraînement", '(', 'utilisant', 'souvent', 'technique', 'appelée', 'RLHF', ')', 'permet', 'notamment', 'réduire', 'phénomène', 'appelé', '«', 'hallucination', '»', ',', 'où', 'modèle', 'génère', 'informations', "d'apparence", 'plausible', 'fausses', '.']
# Stemmed Words : ['cet', 'phas', "d'entraîn", '(', 'utilis', 'souvent', 'techniqu', 'appel', 'rlhf', ')', 'permet', 'not', 'réduir', 'phénomen', 'appel', '«', 'hallucin', '»', ',', 'où', 'model', 'géner', 'inform', "d'apparent", 'plausibl', 'fauss', '.']
#
# Original Sentence : Avant d'être fourni au modèle, le texte est découpé en tokens.
# Filtered Words : ['Avant', "d'être", 'fourni', 'modèle', ',', 'texte', 'découpé', 'tokens', '.']
# Stemmed Words : ['avant', "d'êtr", 'fourn', 'model', ',', 'text', 'découp', 'token', '.']
#
# Original Sentence : Ceux-ci sont convertis en vecteurs qui en encodent le sens ainsi que la position dans le texte.
# Filtered Words : ['Ceux-ci', 'convertis', 'vecteurs', 'encodent', 'sens', 'ainsi', 'position', 'texte', '.']
# Stemmed Words : ['ceux-c', 'convert', 'vecteur', 'encodent', 'sen', 'ains', 'posit', 'text', '.']
#
# Original Sentence : À l'intérieur de ces modèles se trouve une alternance de réseaux de neurones et de couches d'attention.
# Filtered Words : ["l'intérieur", 'modèles', 'trouve', 'alternance', 'réseaux', 'neurones', 'couches', "d'attention", '.']
# Stemmed Words : ["l'intérieur", 'model', 'trouv', 'altern', 'réseau', 'neuron', 'couch', "d'attent", '.']
#
# Original Sentence : Les couches d'attention combinent les concepts entre eux, permettant de tenir compte du contexte et de saisir des relations complexes.
# Filtered Words : ['couches', "d'attention", 'combinent', 'concepts', 'entre', ',', 'permettant', 'tenir', 'compte', 'contexte', 'saisir', 'relations', 'complexes', '.']
# Stemmed Words : ['couch', "d'attent", 'combinent', 'concept', 'entre', ',', 'permet', 'ten', 'compt', 'context', 'sais', 'relat', 'complex', '.']
#
# Original Sentence : Ces modèles sont souvent intégrés dans des agents conversationnels, aussi appelés chatbots, où le texte généré est formaté pour répondre à l'utilisateur.
# Filtered Words : ['modèles', 'souvent', 'intégrés', 'agents', 'conversationnels', ',', 'aussi', 'appelés', 'chatbots', ',', 'où', 'texte', 'généré', 'formaté', 'répondre', "l'utilisateur", '.']
# Stemmed Words : ['model', 'souvent', 'integr', 'agent', 'conversationnel', ',', 'auss', 'appel', 'chatbot', ',', 'où', 'text', 'géner', 'format', 'répondr', "l'utilis", '.']
#
# Original Sentence : Par exemple, l'agent conversationnel ChatGPT exploite les modèles GPT-3.5 et GPT-4.
# Filtered Words : ['exemple', ',', "l'agent", 'conversationnel', 'ChatGPT', 'exploite', 'modèles', 'GPT-3.5', 'GPT-4', '.']
# Stemmed Words : ['exempl', ',', "l'agent", 'conversationnel', 'chatgpt', 'exploit', 'model', 'gpt-3.5', 'gpt-4', '.']
#
# Original Sentence : En 2023 font leur apparition des modèles grand public pouvant traiter simultanément différents types de données comme le texte, le son, les images et les vidéos, tel Google Gemini.
# Filtered Words : ['2023', 'font', 'apparition', 'modèles', 'grand', 'public', 'pouvant', 'traiter', 'simultanément', 'différents', 'types', 'données', 'comme', 'texte', ',', ',', 'images', 'vidéos', ',', 'tel', 'Google', 'Gemini', '.']
# Stemmed Words : ['2023', 'font', 'apparit', 'model', 'grand', 'public', 'pouv', 'trait', 'simultan', 'différent', 'typ', 'don', 'comm', 'text', ',', ',', 'imag', 'vidéos', ',', 'tel', 'googl', 'gemin', '.']
#
# Original Sentence : === Recherche et optimisation ===
# Certains problèmes nécessitent de chercher intelligemment parmi de nombreuses solutions possibles.
# Filtered Words : ['===', 'Recherche', 'optimisation', '===', 'Certains', 'problèmes', 'nécessitent', 'chercher', 'intelligemment', 'parmi', 'nombreuses', 'solutions', 'possibles', '.']
# Stemmed Words : ['===', 'recherch', 'optimis', '===', 'certain', 'problem', 'nécessitent', 'cherch', 'intelligent', 'parm', 'nombreux', 'solut', 'possibl', '.']
#
# Original Sentence : ==== Recherche locale ====
#
# La recherche locale, ou recherche par optimisation, repose sur l'optimisation mathématique pour trouver une solution numérique à un problème, en améliorant progressivement la solution choisie.
# Filtered Words : ['====', 'Recherche', 'locale', '====', 'recherche', 'locale', ',', 'recherche', 'optimisation', ',', 'repose', "l'optimisation", 'mathématique', 'trouver', 'solution', 'numérique', 'problème', ',', 'améliorant', 'progressivement', 'solution', 'choisie', '.']
# Stemmed Words : ['====', 'recherch', 'local', '====', 'recherch', 'local', ',', 'recherch', 'optimis', ',', 'repos', "l'optimis", 'mathémat', 'trouv', 'solut', 'numer', 'problem', ',', 'amélior', 'progress', 'solut', 'chois', '.']
#
# Original Sentence : En particulier, en apprentissage automatique, la descente de gradient permet de trouver une solution localement optimale, étant donné une fonction de coût à minimiser en faisant varier les paramètres du modèle.
# Filtered Words : ['particulier', ',', 'apprentissage', 'automatique', ',', 'descente', 'gradient', 'permet', 'trouver', 'solution', 'localement', 'optimale', ',', 'donné', 'fonction', 'coût', 'minimiser', 'faisant', 'varier', 'paramètres', 'modèle', '.']
# Stemmed Words : ['particuli', ',', 'apprentissag', 'automat', ',', 'descent', 'gradient', 'permet', 'trouv', 'solut', 'local', 'optimal', ',', 'don', 'fonction', 'coût', 'minimis', 'fais', 'vari', 'parametr', 'model', '.']
#
# Original Sentence : Elle consiste, à chaque étape, à modifier les paramètres à optimiser dans la direction qui permet de réduire le mieux la fonction de coût.
# Filtered Words : ['consiste', ',', 'chaque', 'étape', ',', 'modifier', 'paramètres', 'optimiser', 'direction', 'permet', 'réduire', 'mieux', 'fonction', 'coût', '.']
# Stemmed Words : ['consist', ',', 'chaqu', 'étap', ',', 'modifi', 'parametr', 'optimis', 'direct', 'permet', 'réduir', 'mieux', 'fonction', 'coût', '.']
#
# Original Sentence : La solution obtenue est localement optimale, mais il se peut qu'il y ait globalement de meilleures solutions, qui auraient pu être obtenues avec différentes valeurs initiales de paramètres.
# Filtered Words : ['solution', 'obtenue', 'localement', 'optimale', ',', 'peut', "qu'il", 'globalement', 'meilleures', 'solutions', ',', 'pu', 'être', 'obtenues', 'différentes', 'valeurs', 'initiales', 'paramètres', '.']
# Stemmed Words : ['solut', 'obtenu', 'local', 'optimal', ',', 'peut', "qu'il", 'global', 'meilleur', 'solut', ',', 'pu', 'être', 'obtenu', 'différent', 'valeur', 'initial', 'parametr', '.']
#
# Original Sentence : Les modèles d'IA modernes peuvent avoir des milliards de paramètres à optimiser, et utilisent souvent des variantes plus complexes et efficaces de la descente de gradient.
# Filtered Words : ['modèles', "d'IA", 'modernes', 'peuvent', 'avoir', 'milliards', 'paramètres', 'optimiser', ',', 'utilisent', 'souvent', 'variantes', 'plus', 'complexes', 'efficaces', 'descente', 'gradient', '.']
# Stemmed Words : ['model', "d'i", 'modern', 'peuvent', 'avoir', 'milliard', 'parametr', 'optimis', ',', 'utilisent', 'souvent', 'vari', 'plus', 'complex', 'efficac', 'descent', 'gradient', '.']
#
# Original Sentence : Les algorithmes évolutionnistes, inspirés de la théorie de l'évolution, utilisent une forme de recherche par optimisation.
# ...
# Stemmed Words : ['gérard', 'sabah', ',', 'compréhens', 'langu', 'interact', '(', 'trait', 'ic2', ',', 'ser', 'cognit', 'trait', "l'inform", ')', ',', 'paris', ',', 'hermes', 'scienc', ':', 'lavoisi', ',', '2006', ',', '400', 'p.', '(', 'isbn', '2-7462-1256-0', ')', '.']
#
# Original Sentence : (en) Krzysztof Wołk, Machine learning in translation corpora processing, Boca Raton, FL, Taylor & Francis, 2019, 264 p. (ISBN 978-0-367-18673-9)
#
#
# ==== Histoire ====
# Daniel Crevier et Nathalie Bukcek (trad.
# Filtered Words : ['(', ')', 'Krzysztof', 'Wołk', ',', 'Machine', 'learning', 'in', 'translation', 'corpora', 'processing', ',', 'Boca', 'Raton', ',', 'FL', ',', 'Taylor', '&', 'Francis', ',', '2019', ',', '264', 'p.', '(', 'ISBN', '978-0-367-18673-9', ')', '====', 'Histoire', '====', 'Daniel', 'Crevier', 'Nathalie', 'Bukcek', '(', 'trad', '.']
# Stemmed Words : ['(', ')', 'krzysztof', 'wołk', ',', 'machin', 'learning', 'in', 'translat', 'corpor', 'processing', ',', 'boc', 'raton', ',', 'fl', ',', 'taylor', '&', 'franc', ',', '2019', ',', '264', 'p.', '(', 'isbn', '978-0-367-18673-9', ')', '====', 'histoir', '====', 'daniel', 'crevi', 'nathal', 'bukcek', '(', 'trad', '.']
#
# Original Sentence : de l'anglais), À la recherche de l'intelligence artificielle, Paris, Flammarion, 1997, 438 p. (ISBN 2-08-081428-1) (traduction de (en) The Tumultuous history of the search for artiticial intelligence).
# Filtered Words : ["l'anglais", ')', ',', 'recherche', "l'intelligence", 'artificielle', ',', 'Paris', ',', 'Flammarion', ',', '1997', ',', '438', 'p.', '(', 'ISBN', '2-08-081428-1', ')', '(', 'traduction', '(', ')', 'The', 'Tumultuous', 'history', 'of', 'the', 'search', 'for', 'artiticial', 'intelligence', ')', '.']
# Stemmed Words : ["l'angl", ')', ',', 'recherch', "l'intelligent", 'artificiel', ',', 'paris', ',', 'flammarion', ',', '1997', ',', '438', 'p.', '(', 'isbn', '2-08-081428-1', ')', '(', 'traduct', '(', ')', 'the', 'tumultuous', 'history', 'of', 'the', 'search', 'for', 'artiticial', 'intelligent', ')', '.']
#
# Original Sentence : Nicolas Neysen, Métamorphoses numériques : Explorations sur l'intelligence artificielle, le métavers, la blockchain et le marketing d'influence, Presses universitaires de Liège, 2025
# Yuval Noah Harari, Nexus.
# Filtered Words : ['Nicolas', 'Neysen', ',', 'Métamorphoses', 'numériques', ':', 'Explorations', "l'intelligence", 'artificielle', ',', 'métavers', ',', 'blockchain', 'marketing', "d'influence", ',', 'Presses', 'universitaires', 'Liège', ',', '2025', 'Yuval', 'Noah', 'Harari', ',', 'Nexus', '.']
# Stemmed Words : ['nicol', 'neysen', ',', 'métamorphos', 'numer', ':', 'explor', "l'intelligent", 'artificiel', ',', 'métaver', ',', 'blockchain', 'marketing', "d'influenc", ',', 'press', 'universitair', 'lieg', ',', '2025', 'yuval', 'noah', 'harar', ',', 'nexus', '.']
#
# Original Sentence : Une brève histoire des réseaux d'information de l'âge de pierre à l'IA., Albin Michel, 2024, 567 p. (ISBN 978-2-226-49488-7).
# Filtered Words : ['brève', 'histoire', 'réseaux', "d'information", "l'âge", 'pierre', "l'IA.", ',', 'Albin', 'Michel', ',', '2024', ',', '567', 'p.', '(', 'ISBN', '978-2-226-49488-7', ')', '.']
# Stemmed Words : ['brev', 'histoir', 'réseau', "d'inform", "l'âg", 'pierr', "l'ia.", ',', 'albin', 'michel', ',', '2024', ',', '567', 'p.', '(', 'isbn', '978-2-226-49488-7', ')', '.']
#
# Original Sentence : ==== Vulgarisation ====
# Gérard Tisseau et Jacques Pitrat, Intelligence artificielle : problèmes et méthodes, Paris, Presses universitaires de France, 1996, 255 p. (ISBN 2-13-047429-2).
# Filtered Words : ['====', 'Vulgarisation', '====', 'Gérard', 'Tisseau', 'Jacques', 'Pitrat', ',', 'Intelligence', 'artificielle', ':', 'problèmes', 'méthodes', ',', 'Paris', ',', 'Presses', 'universitaires', 'France', ',', '1996', ',', '255', 'p.', '(', 'ISBN', '2-13-047429-2', ')', '.']
# Stemmed Words : ['====', 'vulgaris', '====', 'gérard', 'tisseau', 'jacqu', 'pitrat', ',', 'intelligent', 'artificiel', ':', 'problem', 'méthod', ',', 'paris', ',', 'press', 'universitair', 'franc', ',', '1996', ',', '255', 'p.', '(', 'isbn', '2-13-047429-2', ')', '.']
#
# Original Sentence : Jack Challoner (trad.
# Filtered Words : ['Jack', 'Challoner', '(', 'trad', '.']
# Stemmed Words : ['jack', 'challon', '(', 'trad', '.']
#
# Original Sentence : de l'anglais), L'Intelligence artificielle : Un guide d'initiation au futur de l'informatique et de la robotique, Paris, Pearson Education, 2003, 72 p. (ISBN 2-7440-1600-4).
# Filtered Words : ["l'anglais", ')', ',', "L'Intelligence", 'artificielle', ':', 'guide', "d'initiation", 'futur', "l'informatique", 'robotique', ',', 'Paris', ',', 'Pearson', 'Education', ',', '2003', ',', '72', 'p.', '(', 'ISBN', '2-7440-1600-4', ')', '.']
# Stemmed Words : ["l'angl", ')', ',', "l'intelligent", 'artificiel', ':', 'guid', "d'initi", 'futur', "l'informat", 'robot', ',', 'paris', ',', 'pearson', 'educ', ',', '2003', ',', '72', 'p.', '(', 'isbn', '2-7440-1600-4', ')', '.']
#
# Original Sentence : Hugues Bersini, De l'intelligence humaine à l'intelligence artificielle, Paris, Ellipse, 2006, 192 p. (ISBN 2-7298-2813-3).
# Filtered Words : ['Hugues', 'Bersini', ',', "l'intelligence", 'humaine', "l'intelligence", 'artificielle', ',', 'Paris', ',', 'Ellipse', ',', '2006', ',', '192', 'p.', '(', 'ISBN', '2-7298-2813-3', ')', '.']
# Stemmed Words : ['hugu', 'bersin', ',', "l'intelligent", 'humain', "l'intelligent", 'artificiel', ',', 'paris', ',', 'ellips', ',', '2006', ',', '192', 'p.', '(', 'isbn', '2-7298-2813-3', ')', '.']
#
# Original Sentence : Jean-Gabriel Ganascia, L'Intelligence artificielle, Paris, Éditions du Cavalier bleu, coll.
# Filtered Words : ['Jean-Gabriel', 'Ganascia', ',', "L'Intelligence", 'artificielle', ',', 'Paris', ',', 'Éditions', 'Cavalier', 'bleu', ',', 'coll', '.']
# Stemmed Words : ['jean-gabriel', 'ganasci', ',', "l'intelligent", 'artificiel', ',', 'paris', ',', 'édit', 'cavali', 'bleu', ',', 'coll', '.']
#
# Original Sentence : « Idees recues », 2007, 127 p. (ISBN 978-2-84670-165-5).
# Filtered Words : ['«', 'Idees', 'recues', '»', ',', '2007', ',', '127', 'p.', '(', 'ISBN', '978-2-84670-165-5', ')', '.']
# Stemmed Words : ['«', 'ide', 'recu', '»', ',', '2007', ',', '127', 'p.', '(', 'isbn', '978-2-84670-165-5', ')', '.']
#
# Original Sentence : Howard Selina (illustrations) et Henry Brighton (texte) (trad.
# Filtered Words : ['Howard', 'Selina', '(', 'illustrations', ')', 'Henry', 'Brighton', '(', 'texte', ')', '(', 'trad', '.']
# Stemmed Words : ['howard', 'selin', '(', 'illustr', ')', 'henry', 'brighton', '(', 'text', ')', '(', 'trad', '.']
#
# Original Sentence : de l'anglais), L'Intelligence artificielle en images, Les Ulis, EDP Sciences, coll.
# Filtered Words : ["l'anglais", ')', ',', "L'Intelligence", 'artificielle', 'images', ',', 'Ulis', ',', 'EDP', 'Sciences', ',', 'coll', '.']
# Stemmed Words : ["l'angl", ')', ',', "l'intelligent", 'artificiel', 'imag', ',', 'ulis', ',', 'edp', 'scienc', ',', 'coll', '.']
#
# Original Sentence : « Aperçu », 2015, 176 p. (ISBN 978-2-7598-1772-6).
# Filtered Words : ['«', 'Aperçu', '»', ',', '2015', ',', '176', 'p.', '(', 'ISBN', '978-2-7598-1772-6', ')', '.']
# Stemmed Words : ['«', 'aperçu', '»', ',', '2015', ',', '176', 'p.', '(', 'isbn', '978-2-7598-1772-6', ')', '.']
#
# Original Sentence : Marion Montaigne (dessin) et Jean-Noël Lafargue (scénario), L'Intelligence artificielle : fantasmes et réalités, Bruxelles, Le Lombard, coll.
# Filtered Words : ['Marion', 'Montaigne', '(', 'dessin', ')', 'Jean-Noël', 'Lafargue', '(', 'scénario', ')', ',', "L'Intelligence", 'artificielle', ':', 'fantasmes', 'réalités', ',', 'Bruxelles', ',', 'Lombard', ',', 'coll', '.']
# Stemmed Words : ['marion', 'montaign', '(', 'dessin', ')', 'jean-noël', 'lafargu', '(', 'scénario', ')', ',', "l'intelligent", 'artificiel', ':', 'fantasm', 'réalit', ',', 'bruxel', ',', 'lombard', ',', 'coll', '.']
#
# Original Sentence : « La petite bédéthèque des savoirs », 2016, 72 p. (ISBN 978-2-8036-3638-9).
# Filtered Words : ['«', 'petite', 'bédéthèque', 'savoirs', '»', ',', '2016', ',', '72', 'p.', '(', 'ISBN', '978-2-8036-3638-9', ')', '.']
# Stemmed Words : ['«', 'petit', 'bédéthequ', 'savoir', '»', ',', '2016', ',', '72', 'p.', '(', 'isbn', '978-2-8036-3638-9', ')', '.']
#
# Original Sentence : Arnold Zéphir (scénariste), FibreTigre (scénariste) et Héloïse Chochois, Intelligences Artificielles : Miroirs de nos vies, Delcourt, coll.
# Filtered Words : ['Arnold', 'Zéphir', '(', 'scénariste', ')', ',', 'FibreTigre', '(', 'scénariste', ')', 'Héloïse', 'Chochois', ',', 'Intelligences', 'Artificielles', ':', 'Miroirs', 'vies', ',', 'Delcourt', ',', 'coll', '.']
# Stemmed Words : ['arnold', 'zeph', '(', 'scénar', ')', ',', 'fibretigr', '(', 'scénar', ')', 'héloïs', 'chochois', ',', 'intelligent', 'artificiel', ':', 'miroir', 'vi', ',', 'delcourt', ',', 'coll', '.']
#
# Original Sentence : « Octopus », 6 mars 2019 (ISBN 978-2413013143)
#  [vidéo] « L'IA et l'efficacité » sur Savoir média, 2021, 30 min (consulté le 31 mai 2022)
#
#
# ==== Politique, relations internationales ====
# Daniel Ventre, Intelligence artificielle, cybersécurité et cyberdéfense, Londres, ISTE, 2020, 246 p. (ISBN 978-1-78405-679-7 et 978-1-78406-679-6, SUDOC 248481614, présentation en ligne).
# Filtered Words : ['«', 'Octopus', '»', ',', '6', 'mars', '2019', '(', 'ISBN', '978-2413013143', ')', '[', 'vidéo', ']', '«', "L'IA", "l'efficacité", '»', 'Savoir', 'média', ',', '2021', ',', '30', 'min', '(', 'consulté', '31', 'mai', '2022', ')', '====', 'Politique', ',', 'relations', 'internationales', '====', 'Daniel', 'Ventre', ',', 'Intelligence', 'artificielle', ',', 'cybersécurité', 'cyberdéfense', ',', 'Londres', ',', 'ISTE', ',', '2020', ',', '246', 'p.', '(', 'ISBN', '978-1-78405-679-7', '978-1-78406-679-6', ',', 'SUDOC', '248481614', ',', 'présentation', 'ligne', ')', '.']
# Stemmed Words : ['«', 'octopus', '»', ',', '6', 'mar', '2019', '(', 'isbn', '978-2413013143', ')', '[', 'vidéo', ']', '«', "l'i", "l'efficac", '»', 'savoir', 'médi', ',', '2021', ',', '30', 'min', '(', 'consult', '31', 'mai', '2022', ')', '====', 'polit', ',', 'relat', 'international', '====', 'daniel', 'ventr', ',', 'intelligent', 'artificiel', ',', 'cybersécur', 'cyberdéfens', ',', 'londr', ',', 'iste', ',', '2020', ',', '246', 'p.', '(', 'isbn', '978-1-78405-679-7', '978-1-78406-679-6', ',', 'sudoc', '248481614', ',', 'présent', 'lign', ')', '.']
#
# Original Sentence : === Liens externes ===
# « IA militaire : drones de guerre », La Science, CQFD, France Culture, 25 juin 2024.
# Filtered Words : ['===', 'Liens', 'externes', '===', '«', 'IA', 'militaire', ':', 'drones', 'guerre', '»', ',', 'Science', ',', 'CQFD', ',', 'France', 'Culture', ',', '25', 'juin', '2024', '.']
# Stemmed Words : ['===', 'lien', 'extern', '===', '«', 'ia', 'militair', ':', 'dron', 'guerr', '»', ',', 'scienc', ',', 'cqfd', ',', 'franc', 'cultur', ',', '25', 'juin', '2024', '.']
#
# Original Sentence : « Intelligence artificielle », publications en ligne, Interstices, INRIA.
# Filtered Words : ['«', 'Intelligence', 'artificielle', '»', ',', 'publications', 'ligne', ',', 'Interstices', ',', 'INRIA', '.']
# Stemmed Words : ['«', 'intelligent', 'artificiel', '»', ',', 'publiqu', 'lign', ',', 'interstic', ',', 'inri', '.']
#
# Original Sentence : (en) European Association for Artificial Intelligence (EurAI) (Association européenne pour l'intelligence artificielle)
# Association française pour l'intelligence artificielle (AfIA).
# Filtered Words : ['(', ')', 'European', 'Association', 'for', 'Artificial', 'Intelligence', '(', 'EurAI', ')', '(', 'Association', 'européenne', "l'intelligence", 'artificielle', ')', 'Association', 'française', "l'intelligence", 'artificielle', '(', 'AfIA', ')', '.']
# Stemmed Words : ['(', ')', 'european', 'associ', 'for', 'artificial', 'intelligent', '(', 'eur', ')', '(', 'associ', 'européen', "l'intelligent", 'artificiel', ')', 'associ', 'français', "l'intelligent", 'artificiel', '(', 'afi', ')', '.']
#
# Original Sentence : GDR-Radia, groupement de recherche du CNRS sur les aspects formels et algorithmiques de l'intelligence artificielle.
# Filtered Words : ['GDR-Radia', ',', 'groupement', 'recherche', 'CNRS', 'aspects', 'formels', 'algorithmiques', "l'intelligence", 'artificielle', '.']
# Stemmed Words : ['gdr-radi', ',', 'group', 'recherch', 'cnr', 'aspect', 'formel', 'algorithm', "l'intelligent", 'artificiel', '.']
#
# Original Sentence : Dossier sur l'Intelligence artificielle, savoirs.ens.fr (conférences), École normale supérieure.
# Filtered Words : ['Dossier', "l'Intelligence", 'artificielle', ',', 'savoirs.ens.fr', '(', 'conférences', ')', ',', 'École', 'normale', 'supérieure', '.']
# Stemmed Words : ['dossi', "l'intelligent", 'artificiel', ',', 'savoirs.ens.fr', '(', 'conférent', ')', ',', 'écol', 'normal', 'supérieur', '.']
#
# Original Sentence : Sébastien Konieczny, « L'intelligence artificielle, menace ou avancée ?
# Filtered Words : ['Sébastien', 'Konieczny', ',', '«', "L'intelligence", 'artificielle', ',', 'menace', 'avancée', '?']
# Stemmed Words : ['sébastien', 'konieczny', ',', '«', "l'intelligent", 'artificiel', ',', 'menac', 'avanc', '?']
#
# Original Sentence : », Huffington Post, 9 mars 2016
# « Intelligence artificielle : en mon âme et conscience », La Science, CQFD, France Culture, 1er juin 2023.
# Filtered Words : ['»', ',', 'Huffington', 'Post', ',', '9', 'mars', '2016', '«', 'Intelligence', 'artificielle', ':', 'âme', 'conscience', '»', ',', 'Science', ',', 'CQFD', ',', 'France', 'Culture', ',', '1er', 'juin', '2023', '.']
# Stemmed Words : ['»', ',', 'huffington', 'post', ',', '9', 'mar', '2016', '«', 'intelligent', 'artificiel', ':', 'âme', 'conscienc', '»', ',', 'scienc', ',', 'cqfd', ',', 'franc', 'cultur', ',', '1er', 'juin', '2023', '.']
#
# Original Sentence : William Audureau, « Tout comprendre à l’intelligence artificielle, cette technologie source de nombreux malentendus », sur Les Décodeurs, Le Monde, 20 avril 2024
#
#
# ==== Bases de données et dictionnaires ====
#
# Ressources relatives à la recherche : Internet Encyclopedia of Philosophy JSTOR Stanford Encyclopedia of Philosophy
# Ressource relative à la santé : Medical Subject Headings
# Ressource relative à l'audiovisuel : France 24
#
#  Portail de l’intelligence artificielle   Portail de l’informatique   Portail de la robotique   Portail de la science-fiction   Portail du jeu vidéo   Portail de l’économie   Portail de la philosophie
# Filtered Words : ['William', 'Audureau', ',', '«', 'Tout', 'comprendre', '’', 'intelligence', 'artificielle', ',', 'cette', 'technologie', 'source', 'nombreux', 'malentendus', '»', ',', 'Décodeurs', ',', 'Monde', ',', '20', 'avril', '2024', '====', 'Bases', 'données', 'dictionnaires', '====', 'Ressources', 'relatives', 'recherche', ':', 'Internet', 'Encyclopedia', 'of', 'Philosophy', 'JSTOR', 'Stanford', 'Encyclopedia', 'of', 'Philosophy', 'Ressource', 'relative', 'santé', ':', 'Medical', 'Subject', 'Headings', 'Ressource', 'relative', "l'audiovisuel", ':', 'France', '24', 'Portail', '’', 'intelligence', 'artificielle', 'Portail', '’', 'informatique', 'Portail', 'robotique', 'Portail', 'science-fiction', 'Portail', 'jeu', 'vidéo', 'Portail', '’', 'économie', 'Portail', 'philosophie']
# Stemmed Words : ['william', 'audureau', ',', '«', 'tout', 'comprendr', '’', 'intelligent', 'artificiel', ',', 'cet', 'technolog', 'sourc', 'nombreux', 'malentendus', '»', ',', 'décodeur', ',', 'mond', ',', '20', 'avril', '2024', '====', 'bas', 'don', 'dictionnair', '====', 'ressourc', 'relat', 'recherch', ':', 'internet', 'encyclopedi', 'of', 'philosophy', 'jstor', 'stanford', 'encyclopedi', 'of', 'philosophy', 'ressourc', 'relat', 'sant', ':', 'medical', 'subject', 'heading', 'ressourc', 'relat', "l'audiovisuel", ':', 'franc', '24', 'portail', '’', 'intelligent', 'artificiel', 'portail', '’', 'informat', 'portail', 'robot', 'portail', 'science-fict', 'portail', 'jeu', 'vidéo', 'portail', '’', 'économ', 'portail', 'philosoph']

# %%
# !python -m spacy download fr_core_news_sm
# Out:
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 36.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from fr-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.2)
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# spaCy

import spacy

nlp = spacy.load('fr_core_news_sm')

with open('intelligence_artificielle.txt', encoding='utf-8') as f:
    sentences = f.read()



doc = nlp(sentences)

for token in doc:

    print(f"Word : {token.text} \t Is Stopword : {token.is_stop}")
# Out:
# Word : L' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : IA 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : est 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : capacité 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : machines 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : effectuer 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : tâches 	 Is Stopword : False
# Word : typiquement 	 Is Stopword : False
# Word : associées 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : humaine 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : comme 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : le 	 Is Stopword : True
# Word : raisonnement 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : la 	 Is Stopword : True
# Word : résolution 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : problème 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : la 	 Is Stopword : True
# Word : perception 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : prise 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : décision 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : L' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : est 	 Is Stopword : True
# Word : également 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : champ 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : recherche 	 Is Stopword : False
# Word : visant 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : développer 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : telles 	 Is Stopword : True
# Word : machines 	 Is Stopword : False
# Word : ainsi 	 Is Stopword : True
# Word : que 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : systèmes 	 Is Stopword : False
# Word : informatiques 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : en 	 Is Stopword : True
# Word : résultent 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Souvent 	 Is Stopword : True
# Word : classée 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : domaine 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : mathématiques 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : sciences 	 Is Stopword : False
# Word : cognitives 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : fait 	 Is Stopword : True
# Word : appel 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : disciplines 	 Is Stopword : False
# Word : telles 	 Is Stopword : True
# Word : que 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : neurobiologie 	 Is Stopword : False
# Word : computationnelle 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : a 	 Is Stopword : True
# Word : notamment 	 Is Stopword : True
# Word : inspiré 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : réseaux 	 Is Stopword : False
# Word : neuronaux 	 Is Stopword : False
# Word : artificiels 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : statistiques 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : algèbre 	 Is Stopword : False
# Word : linéaire 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Elle 	 Is Stopword : True
# Word : vise 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : résoudre 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : problèmes 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : forte 	 Is Stopword : False
# Word : complexité 	 Is Stopword : False
# Word : logique 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : algorithmique 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Par 	 Is Stopword : True
# Word : extension 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : langage 	 Is Stopword : False
# Word : courant 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : inclut 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : dispositifs 	 Is Stopword : False
# Word : imitant 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : remplaçant 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : homme 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : certaines 	 Is Stopword : True
# Word : mises 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : œuvre 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : ses 	 Is Stopword : True
# Word : fonctions 	 Is Stopword : False
# Word : cognitives 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Les 	 Is Stopword : True
# Word : applications 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : comprennent 	 Is Stopword : False
# Word : notamment 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : moteurs 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : recherche 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : systèmes 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : recommandation 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : aide 	 Is Stopword : False
# Word : au 	 Is Stopword : True
# Word : diagnostic 	 Is Stopword : False
# Word : médical 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : la 	 Is Stopword : True
# Word : compréhension 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : langage 	 Is Stopword : False
# Word : naturel 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : voitures 	 Is Stopword : False
# Word : autonomes 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : chatbots 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : outils 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : génération 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : images 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : outils 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : prise 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : décision 	 Is Stopword : False
# Word : automatisée 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : programmes 	 Is Stopword : False
# Word : compétitifs 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : jeux 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : stratégie 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : certains 	 Is Stopword : True
# Word : personnages 	 Is Stopword : False
# Word : non-joueurs 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : jeu 	 Is Stopword : False
# Word : vidéo 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Depuis 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : apparition 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : concept 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : finalités 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : enjeux 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : développement 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : suscitent 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : nombreuses 	 Is Stopword : True
# Word : interprétations 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : fantasmes 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : inquiétudes 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : que 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : on 	 Is Stopword : True
# Word : retrouve 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : récits 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : films 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : science 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : fiction 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : essais 	 Is Stopword : False
# Word : philosophiques 	 Is Stopword : False
# Word : ainsi 	 Is Stopword : True
# Word : que 	 Is Stopword : True
# Word : parmi 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : économistes 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#
#
#  	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : Définition 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word :
#
#  	 Is Stopword : False
# Word : Le 	 Is Stopword : True
# Word : terme 	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : souvent 	 Is Stopword : True
# Word : abrégé 	 Is Stopword : False
# Word : par 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : sigle 	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : IA 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : « 	 Is Stopword : False
# Word : AI 	 Is Stopword : True
# Word : » 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : anglais 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : pour 	 Is Stopword : True
# Word : artificial 	 Is Stopword : False
# Word : intelligence 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : a 	 Is Stopword : True
# Word : été 	 Is Stopword : False
# Word : créé 	 Is Stopword : False
# Word : par 	 Is Stopword : True
# Word : John 	 Is Stopword : False
# Word : McCarthy 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : a 	 Is Stopword : True
# Word : défini 	 Is Stopword : False
# Word : comme 	 Is Stopword : True
# Word : « 	 Is Stopword : False
# Word : la 	 Is Stopword : True
# Word : science 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : ingénierie 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : fabrication 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : machines 	 Is Stopword : False
# Word : intelligentes 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : particulier 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : programmes 	 Is Stopword : False
# Word : informatiques 	 Is Stopword : False
# Word : intelligents 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Elle 	 Is Stopword : True
# Word : est 	 Is Stopword : True
# Word : liée 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : tâche 	 Is Stopword : False
# Word : similaire 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : consiste 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : utiliser 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : ordinateurs 	 Is Stopword : False
# Word : pour 	 Is Stopword : True
# Word : comprendre 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : humaine 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : mais 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : ne 	 Is Stopword : True
# Word : doit 	 Is Stopword : True
# Word : pas 	 Is Stopword : True
# Word : se 	 Is Stopword : True
# Word : limiter 	 Is Stopword : False
# Word : aux 	 Is Stopword : True
# Word : méthodes 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : sont 	 Is Stopword : True
# Word : biologiquement 	 Is Stopword : False
# Word : observables 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Pour 	 Is Stopword : True
# Word : Marvin 	 Is Stopword : False
# Word : Lee 	 Is Stopword : False
# Word : Minsky 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : un 	 Is Stopword : True
# Word : de 	 Is Stopword : True
# Word : ses 	 Is Stopword : True
# Word : créateurs 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : est 	 Is Stopword : True
# Word : « 	 Is Stopword : False
# Word : la 	 Is Stopword : True
# Word : construction 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : programmes 	 Is Stopword : False
# Word : informatiques 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : s' 	 Is Stopword : True
# Word : adonnent 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : tâches 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : sont 	 Is Stopword : True
# Word : , 	 Is Stopword : False
# Word : pour 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : instant 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : accomplies 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : façon 	 Is Stopword : True
# Word : plus 	 Is Stopword : True
# Word : satisfaisante 	 Is Stopword : False
# Word : par 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : êtres 	 Is Stopword : False
# Word : humains 	 Is Stopword : False
# Word : car 	 Is Stopword : True
# Word : elles 	 Is Stopword : True
# Word : demandent 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : processus 	 Is Stopword : False
# Word : mentaux 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : haut 	 Is Stopword : False
# Word : niveau 	 Is Stopword : False
# Word : tels 	 Is Stopword : True
# Word : que 	 Is Stopword : True
# Word : : 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : perceptuel 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : organisation 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : mémoire 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : raisonnement 	 Is Stopword : False
# Word : critique 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Cette 	 Is Stopword : True
# Word : définition 	 Is Stopword : False
# Word : combine 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : aspect 	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : artificiel 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : ordinateurs 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : processus 	 Is Stopword : False
# Word : informatiques 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : aux 	 Is Stopword : True
# Word : aspects 	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : intelligents 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : imitation 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : comportements 	 Is Stopword : False
# Word : humains 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : notamment 	 Is Stopword : True
# Word : de 	 Is Stopword : True
# Word : raisonnement 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : d' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Celui 	 Is Stopword : True
# Word : - 	 Is Stopword : False
# Word : ci 	 Is Stopword : True
# Word : est 	 Is Stopword : True
# Word : à 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : œuvre 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : jeux 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : pratique 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : mathématiques 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : compréhension 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : langage 	 Is Stopword : False
# Word : naturel 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : perception 	 Is Stopword : False
# Word : visuelle 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : interprétation 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : images 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : scènes 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : auditive 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : compréhension 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : langage 	 Is Stopword : False
# Word : parlé 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : par 	 Is Stopword : True
# Word : d' 	 Is Stopword : True
# Word : autres 	 Is Stopword : True
# Word : capteurs 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : commande 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : un 	 Is Stopword : True
# Word : robot 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : un 	 Is Stopword : True
# Word : milieu 	 Is Stopword : False
# Word : inconnu 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : hostile 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Avant 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : années 	 Is Stopword : False
# Word : 2000 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : autres 	 Is Stopword : True
# Word : définitions 	 Is Stopword : False
# Word : sont 	 Is Stopword : True
# Word : proches 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : celle 	 Is Stopword : True
# Word : de 	 Is Stopword : True
# Word : Minsky 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : mais 	 Is Stopword : True
# Word : varient 	 Is Stopword : False
# Word : sur 	 Is Stopword : True
# Word : deux 	 Is Stopword : True
# Word : points 	 Is Stopword : False
# Word : fondamentaux 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word :
#
#  	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : définitions 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : lient 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : un 	 Is Stopword : True
# Word : aspect 	 Is Stopword : False
# Word : humain 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : celles 	 Is Stopword : True
# Word : qui 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : lient 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : un 	 Is Stopword : True
# Word : modèle 	 Is Stopword : False
# Word : idéal 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : non 	 Is Stopword : False
# Word : forcément 	 Is Stopword : False
# Word : humaine 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : nommée 	 Is Stopword : False
# Word : rationalité 	 Is Stopword : False
# Word : ; 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : définitions 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : insistent 	 Is Stopword : False
# Word : sur 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : fait 	 Is Stopword : True
# Word : que 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : a 	 Is Stopword : True
# Word : pour 	 Is Stopword : True
# Word : but 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : avoir 	 Is Stopword : True
# Word : toutes 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : apparences 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : humaine 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : rationnelle 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : celles 	 Is Stopword : True
# Word : qui 	 Is Stopword : True
# Word : insistent 	 Is Stopword : False
# Word : sur 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : fait 	 Is Stopword : True
# Word : que 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : fonctionnement 	 Is Stopword : False
# Word : interne 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : système 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : doit 	 Is Stopword : True
# Word : ressembler 	 Is Stopword : False
# Word : également 	 Is Stopword : True
# Word : à 	 Is Stopword : True
# Word : celui 	 Is Stopword : True
# Word : de 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : être 	 Is Stopword : True
# Word : humain 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : être 	 Is Stopword : True
# Word : au 	 Is Stopword : True
# Word : moins 	 Is Stopword : True
# Word : aussi 	 Is Stopword : True
# Word : rationnel 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#
#  	 Is Stopword : False
# Word : Le 	 Is Stopword : True
# Word : grand 	 Is Stopword : False
# Word : public 	 Is Stopword : False
# Word : confond 	 Is Stopword : False
# Word : souvent 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : avec 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : automatique 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : machine 	 Is Stopword : False
# Word : learning 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : profond 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : deep 	 Is Stopword : False
# Word : learning 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Ces 	 Is Stopword : True
# Word : trois 	 Is Stopword : True
# Word : notions 	 Is Stopword : False
# Word : diffèrent 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : sont 	 Is Stopword : True
# Word : en 	 Is Stopword : True
# Word : réalité 	 Is Stopword : False
# Word : imbriquées 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : englobe 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : automatique 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : lui-même 	 Is Stopword : True
# Word : englobe 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : profond 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Les 	 Is Stopword : True
# Word : définitions 	 Is Stopword : False
# Word : font 	 Is Stopword : True
# Word : souvent 	 Is Stopword : True
# Word : intervenir 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word :
#
#  	 Is Stopword : False
# Word : une 	 Is Stopword : True
# Word : capacité 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : percevoir 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : environnement 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : à 	 Is Stopword : True
# Word : prendre 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : compte 	 Is Stopword : False
# Word : la 	 Is Stopword : True
# Word : complexité 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : monde 	 Is Stopword : False
# Word : réel 	 Is Stopword : False
# Word : ; 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : un 	 Is Stopword : True
# Word : traitement 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : information 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : collecter 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : interpréter 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : intrants 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : captés 	 Is Stopword : False
# Word : sous 	 Is Stopword : True
# Word : forme 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : données 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : ; 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : prises 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : décision 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : y 	 Is Stopword : True
# Word : compris 	 Is Stopword : True
# Word : dans 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : raisonnement 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : choix 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : actions 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : exécution 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : tâches 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : dont 	 Is Stopword : True
# Word : d' 	 Is Stopword : True
# Word : adaptation 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : réaction 	 Is Stopword : False
# Word : aux 	 Is Stopword : True
# Word : changements 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : contexte 	 Is Stopword : False
# Word : … 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : avec 	 Is Stopword : True
# Word : un 	 Is Stopword : True
# Word : certain 	 Is Stopword : True
# Word : niveau 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : autonomie 	 Is Stopword : False
# Word : ; 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : la 	 Is Stopword : True
# Word : réalisation 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : objectifs 	 Is Stopword : False
# Word : spécifiques 	 Is Stopword : True
# Word : ( 	 Is Stopword : False
# Word : raison 	 Is Stopword : False
# Word : ultime 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : systèmes 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Le 	 Is Stopword : True
# Word : groupe 	 Is Stopword : False
# Word : AI 	 Is Stopword : True
# Word : Watch 	 Is Stopword : False
# Word : note 	 Is Stopword : False
# Word : que 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : peuvent 	 Is Stopword : True
# Word : aussi 	 Is Stopword : True
# Word : être 	 Is Stopword : True
# Word : classées 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : fonction 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : familles 	 Is Stopword : False
# Word : d’ 	 Is Stopword : True
# Word : algorithmes 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : / 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : modèles 	 Is Stopword : False
# Word : théoriques 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : sous-tendent 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : capacités 	 Is Stopword : False
# Word : cognitives 	 Is Stopword : False
# Word : reproduites 	 Is Stopword : False
# Word : par 	 Is Stopword : True
# Word : l’ 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : fonctions 	 Is Stopword : False
# Word : exécutées 	 Is Stopword : False
# Word : par 	 Is Stopword : True
# Word : l’ 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Les 	 Is Stopword : True
# Word : applications 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l’ 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : peuvent 	 Is Stopword : True
# Word : , 	 Is Stopword : False
# Word : elles 	 Is Stopword : True
# Word : , 	 Is Stopword : False
# Word : être 	 Is Stopword : True
# Word : classées 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : fonction 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : secteur 	 Is Stopword : False
# Word : socioéconomique 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : / 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : fonctions 	 Is Stopword : False
# Word : qu' 	 Is Stopword : True
# Word : elles 	 Is Stopword : True
# Word : y 	 Is Stopword : True
# Word : remplissent 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Une 	 Is Stopword : True
# Word : manière 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : définir 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : est 	 Is Stopword : True
# Word : de 	 Is Stopword : True
# Word : considérer 	 Is Stopword : False
# Word : ses 	 Is Stopword : True
# Word : applications 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : types 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : tâches 	 Is Stopword : False
# Word : qu' 	 Is Stopword : True
# Word : elle 	 Is Stopword : True
# Word : résout 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Un 	 Is Stopword : True
# Word : rapport 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : Commission 	 Is Stopword : False
# Word : européenne 	 Is Stopword : False
# Word : publié 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : 2020 	 Is Stopword : False
# Word : présente 	 Is Stopword : False
# Word : une 	 Is Stopword : True
# Word : taxonomie 	 Is Stopword : False
# Word : classant 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : définitions 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : selon 	 Is Stopword : True
# Word : diverses 	 Is Stopword : True
# Word : tâches 	 Is Stopword : False
# Word : réalisées 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : telles 	 Is Stopword : True
# Word : que 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : raisonnement 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : la 	 Is Stopword : True
# Word : perception 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : etc 	 Is Stopword : True
# Word : .. 	 Is Stopword : False
# Word : La 	 Is Stopword : True
# Word : même 	 Is Stopword : True
# Word : année 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : le 	 Is Stopword : True
# Word : professeur 	 Is Stopword : False
# Word : Jack 	 Is Stopword : False
# Word : Copeland 	 Is Stopword : False
# Word : propose 	 Is Stopword : False
# Word : une 	 Is Stopword : True
# Word : définition 	 Is Stopword : False
# Word : similaire 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : qui 	 Is Stopword : True
# Word : permet 	 Is Stopword : True
# Word : de 	 Is Stopword : True
# Word : distinguer 	 Is Stopword : False
# Word : plus 	 Is Stopword : True
# Word : clairement 	 Is Stopword : False
# Word : les 	 Is Stopword : True
# Word : facettes 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : selon 	 Is Stopword : True
# Word : cinq 	 Is Stopword : True
# Word : catégories 	 Is Stopword : False
# Word : principales 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word :
#
#  	 Is Stopword : False
# Word : L' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : généralisé 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : apprend 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : partir 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : données 	 Is Stopword : False
# Word : diverses 	 Is Stopword : True
# Word : pour 	 Is Stopword : True
# Word : identifier 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : modèles 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : appliquer 	 Is Stopword : False
# Word : ces 	 Is Stopword : True
# Word : connaissances 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : de 	 Is Stopword : True
# Word : nouvelles 	 Is Stopword : False
# Word : situations 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : comme 	 Is Stopword : True
# Word : détecter 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : fraudes 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : ligne 	 Is Stopword : False
# Word : ; 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Le 	 Is Stopword : True
# Word : raisonnement 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : cette 	 Is Stopword : True
# Word : capacité 	 Is Stopword : False
# Word : permet 	 Is Stopword : True
# Word : à 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : faire 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : prédictions 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : tirer 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : conclusions 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : partir 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : données 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : aidant 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : décisions 	 Is Stopword : False
# Word : comme 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : prédiction 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : comportements 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : achat 	 Is Stopword : False
# Word : ; 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : La 	 Is Stopword : True
# Word : résolution 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : problèmes 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : trouve 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : solutions 	 Is Stopword : False
# Word : optimales 	 Is Stopword : False
# Word : pour 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : problèmes 	 Is Stopword : False
# Word : spécifiques 	 Is Stopword : True
# Word : , 	 Is Stopword : False
# Word : utilisée 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : contextes 	 Is Stopword : False
# Word : comme 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : optimisation 	 Is Stopword : False
# Word : industrielle 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : stratégies 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : jeu 	 Is Stopword : False
# Word : ; 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : La 	 Is Stopword : True
# Word : perception 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : elle 	 Is Stopword : True
# Word : permet 	 Is Stopword : True
# Word : à 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : reconnaître 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : interagir 	 Is Stopword : False
# Word : avec 	 Is Stopword : True
# Word : son 	 Is Stopword : True
# Word : environnement 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : utilisée 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : robotique 	 Is Stopword : False
# Word : avancée 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : véhicules 	 Is Stopword : False
# Word : autonomes 	 Is Stopword : False
# Word : pour 	 Is Stopword : True
# Word : naviguer 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : accomplir 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : tâches 	 Is Stopword : False
# Word : ; 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : La 	 Is Stopword : True
# Word : compréhension 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : langage 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : analyse 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : génère 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : langage 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : travers 	 Is Stopword : False
# Word : le 	 Is Stopword : True
# Word : NLP 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : utilisé 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : applications 	 Is Stopword : False
# Word : comme 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : assistants 	 Is Stopword : False
# Word : vocaux 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : chatbots 	 Is Stopword : False
# Word : pour 	 Is Stopword : True
# Word : améliorer 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : interaction 	 Is Stopword : False
# Word : utilisateur 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#
#
#  	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : Techniques 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word :
#
#
#  	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : Comportements 	 Is Stopword : False
# Word : prédéfinis 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : imitation 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word :
#
#  	 Is Stopword : False
# Word : Pour 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : intelligences 	 Is Stopword : False
# Word : artificielles 	 Is Stopword : False
# Word : servant 	 Is Stopword : False
# Word : principalement 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : donner 	 Is Stopword : False
# Word : une 	 Is Stopword : True
# Word : impression 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : un 	 Is Stopword : True
# Word : cadre 	 Is Stopword : False
# Word : contrôlé 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : notamment 	 Is Stopword : True
# Word : pour 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : personnages 	 Is Stopword : False
# Word : non-joueurs 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : jeux 	 Is Stopword : False
# Word : vidéo 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : il 	 Is Stopword : True
# Word : est 	 Is Stopword : True
# Word : courant 	 Is Stopword : False
# Word : que 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : automatique 	 Is Stopword : False
# Word : ne 	 Is Stopword : True
# Word : soit 	 Is Stopword : True
# Word : pas 	 Is Stopword : True
# Word : utilisé 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Un 	 Is Stopword : True
# Word : ensemble 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : fonctions 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : comportements 	 Is Stopword : False
# Word : plus 	 Is Stopword : True
# Word : précises 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : moins 	 Is Stopword : True
# Word : flexibles 	 Is Stopword : False
# Word : sont 	 Is Stopword : True
# Word : alors 	 Is Stopword : True
# Word : implémentés 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Il 	 Is Stopword : True
# Word : s' 	 Is Stopword : True
# Word : agit 	 Is Stopword : False
# Word : souvent 	 Is Stopword : True
# Word : de 	 Is Stopword : True
# Word : liste 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : textes 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : paroles 	 Is Stopword : False
# Word : prédéfinis 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : aux 	 Is Stopword : True
# Word : déclenchements 	 Is Stopword : False
# Word : parfois 	 Is Stopword : True
# Word : conditionnels 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : par 	 Is Stopword : True
# Word : exemple 	 Is Stopword : False
# Word : un 	 Is Stopword : True
# Word : choix 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : mouvements 	 Is Stopword : False
# Word : suivant 	 Is Stopword : True
# Word : une 	 Is Stopword : True
# Word : série 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : règles 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : des 	 Is Stopword : True
# Word : déplacements 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : pathfinding 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#
#
#  	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : Apprentissage 	 Is Stopword : False
# Word : automatique 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : L' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : automatique 	 Is Stopword : False
# Word : consiste 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : permettre 	 Is Stopword : False
# Word : au 	 Is Stopword : True
# Word : modèle 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : apprendre 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : effectuer 	 Is Stopword : False
# Word : une 	 Is Stopword : True
# Word : tâche 	 Is Stopword : False
# Word : au 	 Is Stopword : True
# Word : lieu 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : spécifier 	 Is Stopword : False
# Word : exactement 	 Is Stopword : True
# Word : comment 	 Is Stopword : True
# Word : il 	 Is Stopword : True
# Word : doit 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : accomplir 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Le 	 Is Stopword : True
# Word : modèle 	 Is Stopword : False
# Word : contient 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : paramètres 	 Is Stopword : False
# Word : dont 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : valeurs 	 Is Stopword : False
# Word : sont 	 Is Stopword : True
# Word : ajustées 	 Is Stopword : False
# Word : tout 	 Is Stopword : True
# Word : au 	 Is Stopword : True
# Word : long 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : La 	 Is Stopword : True
# Word : méthode 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : rétropropagation 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : gradient 	 Is Stopword : False
# Word : est 	 Is Stopword : True
# Word : capable 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : détecter 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : pour 	 Is Stopword : True
# Word : chaque 	 Is Stopword : True
# Word : paramètre 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : dans 	 Is Stopword : True
# Word : quelle 	 Is Stopword : True
# Word : mesure 	 Is Stopword : False
# Word : il 	 Is Stopword : True
# Word : a 	 Is Stopword : True
# Word : contribué 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : une 	 Is Stopword : True
# Word : bonne 	 Is Stopword : False
# Word : réponse 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : à 	 Is Stopword : True
# Word : une 	 Is Stopword : True
# Word : erreur 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : modèle 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : peut 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : ajuster 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : conséquence 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : L' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : automatique 	 Is Stopword : False
# Word : nécessite 	 Is Stopword : False
# Word : un 	 Is Stopword : True
# Word : moyen 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : évaluer 	 Is Stopword : False
# Word : la 	 Is Stopword : True
# Word : qualité 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : réponses 	 Is Stopword : False
# Word : fournies 	 Is Stopword : False
# Word : par 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : modèle 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Les 	 Is Stopword : True
# Word : principales 	 Is Stopword : False
# Word : méthodes 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : apprentissage 	 Is Stopword : False
# Word : sont 	 Is Stopword : True
# Word : : 	 Is Stopword : False
# Word :
#
#  	 Is Stopword : False
# Word : Apprentissage 	 Is Stopword : False
# Word : supervisé 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Un 	 Is Stopword : True
# Word : jeu 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : données 	 Is Stopword : False
# Word : annoté 	 Is Stopword : False
# Word : est 	 Is Stopword : True
# Word : utilisé 	 Is Stopword : False
# Word : pour 	 Is Stopword : True
# Word : entraîner 	 Is Stopword : False
# Word : l' 	 Is Stopword : True
# Word : algorithme 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : Il 	 Is Stopword : True
# Word : contient 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : données 	 Is Stopword : False
# Word : d' 	 Is Stopword : True
# Word : entrée 	 Is Stopword : False
# Word : fournies 	 Is Stopword : False
# Word : au 	 Is Stopword : True
# Word : modèle 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : réponses 	 Is Stopword : False
# Word : correspondantes 	 Is Stopword : False
# Word : attendues 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : que 	 Is Stopword : True
# Word : le 	 Is Stopword : True
# Word : modèle 	 Is Stopword : False
# Word : est 	 Is Stopword : True
# Word : entraîné 	 Is Stopword : False
# ...
# Word : 176 	 Is Stopword : False
# Word : p. 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : ISBN 	 Is Stopword : False
# Word : 978 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 2 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 7598 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 1772 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 6 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Marion 	 Is Stopword : False
# Word : Montaigne 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : dessin 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : Jean-Noël 	 Is Stopword : False
# Word : Lafargue 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : scénario 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : L' 	 Is Stopword : True
# Word : Intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : fantasmes 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : réalités 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : Bruxelles 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : Le 	 Is Stopword : True
# Word : Lombard 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : coll 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : La 	 Is Stopword : True
# Word : petite 	 Is Stopword : False
# Word : bédéthèque 	 Is Stopword : False
# Word : des 	 Is Stopword : True
# Word : savoirs 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : 2016 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : 72 	 Is Stopword : False
# Word : p. 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : ISBN 	 Is Stopword : False
# Word : 978 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 2 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 8036 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 3638 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 9 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Arnold 	 Is Stopword : False
# Word : Zéphir 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : scénariste 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : FibreTigre 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : scénariste 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : Héloïse 	 Is Stopword : False
# Word : Chochois 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : Intelligences 	 Is Stopword : False
# Word : Artificielles 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : Miroirs 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : nos 	 Is Stopword : True
# Word : vies 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : Delcourt 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : coll 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : Octopus 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : 6 	 Is Stopword : False
# Word : mars 	 Is Stopword : False
# Word : 2019 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : ISBN 	 Is Stopword : False
# Word : 978 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 2413013143 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word :
#   	 Is Stopword : False
# Word : [ 	 Is Stopword : False
# Word : vidéo 	 Is Stopword : False
# Word : ] 	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : L' 	 Is Stopword : True
# Word : IA 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : efficacité 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : sur 	 Is Stopword : True
# Word : Savoir 	 Is Stopword : False
# Word : média 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : 2021 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : 30 	 Is Stopword : False
# Word : min 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : consulté 	 Is Stopword : False
# Word : le 	 Is Stopword : True
# Word : 31 	 Is Stopword : False
# Word : mai 	 Is Stopword : False
# Word : 2022 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word :
#
#
#  	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : Politique 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : relations 	 Is Stopword : False
# Word : internationales 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Daniel 	 Is Stopword : False
# Word : Ventre 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : Intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : cybersécurité 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : cyberdéfense 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : Londres 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : ISTE 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : 2020 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : 246 	 Is Stopword : False
# Word : p. 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : ISBN 	 Is Stopword : False
# Word : 978 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 1 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 78405 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 679 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 7 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : 978 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 1 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 78406 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 679 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : 6 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : SUDOC 	 Is Stopword : False
# Word : 248481614 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : présentation 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : ligne 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#
#
#  	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : Liens 	 Is Stopword : False
# Word : externes 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : IA 	 Is Stopword : False
# Word : militaire 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : drones 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : guerre 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : La 	 Is Stopword : True
# Word : Science 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : CQFD 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : France 	 Is Stopword : False
# Word : Culture 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : 25 	 Is Stopword : False
# Word : juin 	 Is Stopword : False
# Word : 2024 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : Intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : publications 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : ligne 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : Interstices 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : INRIA 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : ) 	 Is Stopword : False
# Word : European 	 Is Stopword : False
# Word : Association 	 Is Stopword : False
# Word : for 	 Is Stopword : False
# Word : Artificial 	 Is Stopword : False
# Word : Intelligence 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : EurAI 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : Association 	 Is Stopword : False
# Word : européenne 	 Is Stopword : False
# Word : pour 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Association 	 Is Stopword : False
# Word : française 	 Is Stopword : False
# Word : pour 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : AfIA 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : GDR 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : Radia 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : groupement 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : recherche 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : CNRS 	 Is Stopword : False
# Word : sur 	 Is Stopword : True
# Word : les 	 Is Stopword : True
# Word : aspects 	 Is Stopword : False
# Word : formels 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : algorithmiques 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Dossier 	 Is Stopword : False
# Word : sur 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : Intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : savoirs.ens.fr 	 Is Stopword : False
# Word : ( 	 Is Stopword : False
# Word : conférences 	 Is Stopword : False
# Word : ) 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : École 	 Is Stopword : False
# Word : normale 	 Is Stopword : False
# Word : supérieure 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Sébastien 	 Is Stopword : False
# Word : Konieczny 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : L' 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : menace 	 Is Stopword : False
# Word : ou 	 Is Stopword : True
# Word : avancée 	 Is Stopword : False
# Word : ? 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : Huffington 	 Is Stopword : False
# Word : Post 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : 9 	 Is Stopword : False
# Word : mars 	 Is Stopword : False
# Word : 2016 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : Intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : en 	 Is Stopword : True
# Word : mon 	 Is Stopword : True
# Word : âme 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : conscience 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : La 	 Is Stopword : True
# Word : Science 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : CQFD 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : France 	 Is Stopword : False
# Word : Culture 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : 1er 	 Is Stopword : False
# Word : juin 	 Is Stopword : False
# Word : 2023 	 Is Stopword : False
# Word : . 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : William 	 Is Stopword : False
# Word : Audureau 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : « 	 Is Stopword : False
# Word : Tout 	 Is Stopword : True
# Word : comprendre 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : l’ 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : cette 	 Is Stopword : True
# Word : technologie 	 Is Stopword : False
# Word : source 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : nombreux 	 Is Stopword : True
# Word : malentendus 	 Is Stopword : False
# Word : » 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : sur 	 Is Stopword : True
# Word : Les 	 Is Stopword : True
# Word : Décodeurs 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : Le 	 Is Stopword : True
# Word : Monde 	 Is Stopword : False
# Word : , 	 Is Stopword : False
# Word : 20 	 Is Stopword : False
# Word : avril 	 Is Stopword : False
# Word : 2024 	 Is Stopword : False
# Word :
#
#
#  	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : Bases 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : données 	 Is Stopword : False
# Word : et 	 Is Stopword : True
# Word : dictionnaires 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word : = 	 Is Stopword : False
# Word :
#
#  	 Is Stopword : False
# Word : Ressources 	 Is Stopword : False
# Word : relatives 	 Is Stopword : False
# Word : à 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : recherche 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : Internet 	 Is Stopword : False
# Word : Encyclopedia 	 Is Stopword : False
# Word : of 	 Is Stopword : False
# Word : Philosophy 	 Is Stopword : False
# Word : JSTOR 	 Is Stopword : False
# Word : Stanford 	 Is Stopword : False
# Word : Encyclopedia 	 Is Stopword : False
# Word : of 	 Is Stopword : False
# Word : Philosophy 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Ressource 	 Is Stopword : False
# Word : relative 	 Is Stopword : True
# Word : à 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : santé 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : Medical 	 Is Stopword : False
# Word : Subject 	 Is Stopword : False
# Word : Headings 	 Is Stopword : False
# Word :
#  	 Is Stopword : False
# Word : Ressource 	 Is Stopword : False
# Word : relative 	 Is Stopword : True
# Word : à 	 Is Stopword : True
# Word : l' 	 Is Stopword : True
# Word : audiovisuel 	 Is Stopword : False
# Word : : 	 Is Stopword : False
# Word : France 	 Is Stopword : False
# Word : 24 	 Is Stopword : False
# Word :
#
#   	 Is Stopword : False
# Word : Portail 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l’ 	 Is Stopword : True
# Word : intelligence 	 Is Stopword : False
# Word : artificielle 	 Is Stopword : False
# Word :    	 Is Stopword : False
# Word : Portail 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l’ 	 Is Stopword : True
# Word : informatique 	 Is Stopword : False
# Word :    	 Is Stopword : False
# Word : Portail 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : robotique 	 Is Stopword : False
# Word :    	 Is Stopword : False
# Word : Portail 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : science 	 Is Stopword : False
# Word : - 	 Is Stopword : False
# Word : fiction 	 Is Stopword : False
# Word :    	 Is Stopword : False
# Word : Portail 	 Is Stopword : False
# Word : du 	 Is Stopword : True
# Word : jeu 	 Is Stopword : False
# Word : vidéo 	 Is Stopword : False
# Word :    	 Is Stopword : False
# Word : Portail 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : l’ 	 Is Stopword : True
# Word : économie 	 Is Stopword : False
# Word :    	 Is Stopword : False
# Word : Portail 	 Is Stopword : False
# Word : de 	 Is Stopword : True
# Word : la 	 Is Stopword : True
# Word : philosophie 	 Is Stopword : False
