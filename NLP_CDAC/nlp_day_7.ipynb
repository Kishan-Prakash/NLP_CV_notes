# %% [markdown]
# # Sentiment-Analysis using Hugging face

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")

sentences = [

    "I love this product! It's amazing.",

    "The weather is terrible today.",

    "I'm not sure if I like this movie.",

    "Overall, it was an average performance.",

    "Not too bad.",

    "I did somewhat ok in the test.",

    "I did ok in the test.",

    "Doing this will be TERRIBLE!!!",

    "Doing this will be terrible.",

    "Spacy is a great library for NLP." ]

for sentence in sentences:

    result = classifier(sentence)[0]

    label = result['label']

    score = result['score']

    print(f"Sentence: {sentence}\nLabel: {label}\nScore: {score}\n")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# WARNING:tensorflow:From c:\Users\dai.STUDENTSDC\.conda\envs\NLP\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu
# Sentence: I love this product! It's amazing.
# Label: POSITIVE
# Score: 0.9998866319656372
#
# Sentence: The weather is terrible today.
# Label: NEGATIVE
# Score: 0.9986808896064758
#
# Sentence: I'm not sure if I like this movie.
# Label: NEGATIVE
# Score: 0.9846425652503967
#
# Sentence: Overall, it was an average performance.
# Label: POSITIVE
# Score: 0.9938940405845642
#
# Sentence: Not too bad.
# Label: POSITIVE
# Score: 0.9989375472068787
#
# Sentence: I did somewhat ok in the test.
# Label: POSITIVE
# Score: 0.9994540810585022
#
# Sentence: I did ok in the test.
# Label: POSITIVE
# Score: 0.9997157454490662
#
# Sentence: Doing this will be TERRIBLE!!!
# Label: NEGATIVE
# Score: 0.99970942735672
#
# Sentence: Doing this will be terrible.
# Label: NEGATIVE
# Score: 0.9996702671051025
#
# Sentence: Spacy is a great library for NLP.
# Label: POSITIVE
# Score: 0.9996583461761475

# %%
# !pip install langchain-community
# Out:
# Collecting langchain-community
#   Using cached langchain_community-0.2.19-py3-none-any.whl (2.3 MB)
# Requirement already satisfied: requests<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (2.24.0)
# Collecting langchain<0.3.0,>=0.2.17
#   Using cached langchain-0.2.17-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (3.10.11)
# Collecting SQLAlchemy<3,>=1.4
#   Using cached sqlalchemy-2.0.41-cp38-cp38-win_amd64.whl (2.1 MB)
# Collecting dataclasses-json<0.7,>=0.5.7
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (5.3.1)
# Collecting langchain-core<0.3.0,>=0.2.43
#   Using cached langchain_core-0.2.43-py3-none-any.whl (397 kB)
# Requirement already satisfied: numpy<2,>=1; python_version < "3.12" in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (1.19.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (0.1.147)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.0.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\programdata\anaconda3\lib\site-packages (from langchain<0.3.0,>=0.2.17->langchain-community) (2.10.6)
# Collecting async-timeout<5.0.0,>=4.0.0; python_version < "3.11"
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0
#   Using cached langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.15.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (20.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\dai.studentsdc\appdata\roaming\python\python38\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (4.13.0)
# Collecting greenlet>=1; python_version < "3.14" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32"))))))
#   Using cached greenlet-3.1.1-cp38-cp38-win_amd64.whl (298 kB)
# Collecting typing-inspect<1,>=0.4.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Using cached marshmallow-3.22.0-py3-none-any.whl (49 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<0.3.0,>=0.2.43->langchain-community) (1.33)
# Collecting packaging<25,>=23.2
#   Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14; platform_python_implementation != "PyPy" in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community) (3.10.15)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community) (0.28.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-community) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.17->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.17->langchain-community) (2.27.2)
# Requirement already satisfied: propcache>=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.0)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.43->langchain-community) (3.0.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.0.9)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (4.5.2)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2; python_version < "3.11" in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.3.1)
# Installing collected packages: async-timeout, greenlet, SQLAlchemy, packaging, langchain-core, langchain-text-splitters, langchain, mypy-extensions, typing-inspect, marshmallow, dataclasses-json, langchain-community
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 5.0.1
#     Uninstalling async-timeout-5.0.1:
#       Successfully uninstalled async-timeout-5.0.1
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 0.4.17
#     Uninstalling greenlet-0.4.17:
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\include\\greenlet\\greenlet.h'
# Consider using the `--user` option or check the permissions.

# %%
# !pip install langchain-core
# Out:
# Collecting langchain-core
#   Using cached langchain_core-0.2.43-py3-none-any.whl (397 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Collecting packaging<25,>=23.2
#   Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (8.5.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (5.3.1)
# Requirement already satisfied: pydantic<3,>=1; python_full_version < "3.12.4" in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (2.10.6)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\dai.studentsdc\appdata\roaming\python\python38\site-packages (from langchain-core) (4.13.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (0.1.147)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1; python_full_version < "3.12.4"->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1; python_full_version < "3.12.4"->langchain-core) (2.27.2)
# Requirement already satisfied: requests<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core) (2.24.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core) (1.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14; platform_python_implementation != "PyPy" in c:\programdata\anaconda3\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core) (3.10.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.112->langchain-core) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.112->langchain-core) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.112->langchain-core) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.112->langchain-core) (1.25.11)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core) (4.5.2)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core) (1.0.9)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2; python_version < "3.11" in c:\programdata\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core) (1.3.0)
# Requirement already satisfied: h11>=0.16 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core) (0.16.0)
# Installing collected packages: packaging, langchain-core
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.4
#     Uninstalling packaging-20.4:
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\programdata\\anaconda3\\lib\\site-packages\\packaging-20.4.dist-info\\INSTALLER'
# Consider using the `--user` option or check the permissions.

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.llms import Ollama
from langchain.chains import LLMChain

# %%
sentences = [

    "I love this product! It's amazing.",

    "The weather is terrible today.",

    "I'm not sure if I like this movie.",

    "Overall, it was an average performance.",

    "Not too bad.",

    "I did somewhat ok in the test.",

    "I did ok in the test.",

    "Doing this will be TERRIBLE!!!",

    "Doing this will be terrible.",

    "Spacy is a great library for NLP." ]

# %%
prompt = PromptTemplate(
    input_variables=["sentence"],
    template=('Classify the  following sentences as Positive and Negative, or Neutral:\n\n'
              '"{sentence}"\n\n'
              'Respond with only one word : Positive, Negative or Neutral.'
),)

# %%
llm = Ollama(model="llama3.2")

chain = LLMChain(llm=llm, prompt=prompt, output_parser=StrOutputParser())

for sentence in sentences:

    result = chain.run({"sentence":sentence}).strip()

    print(f"Sentence : {sentence}")
    print()
    print(f"Sentiment : {result}")
# Out:
# Sentence : I love this product! It's amazing.
#
# Sentiment : Positive
# Sentence : The weather is terrible today.
#
# Sentiment : Negative
# Sentence : I'm not sure if I like this movie.
#
# Sentiment : Neutral
# Sentence : Overall, it was an average performance.
#
# Sentiment : Neutral.
# Sentence : Not too bad.
#
# Sentiment : Positive
# Sentence : I did somewhat ok in the test.
#
# Sentiment : Neutral.
# Sentence : I did ok in the test.
#
# Sentiment : Neutral
# Sentence : Doing this will be TERRIBLE!!!
#
# Sentiment : Negative
# Sentence : Doing this will be terrible.
#
# Sentiment : Negative.
# Sentence : Spacy is a great library for NLP.
#
# Sentiment : Positive
