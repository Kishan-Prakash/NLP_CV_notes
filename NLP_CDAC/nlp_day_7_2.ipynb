# %%
# Markov Model: Predict
import numpy as np

# %%
P = np.array([
    [0.6,0.3,0.1],
    [0.4,0.5,0.1],
    [0.2,0.4,0.4]
])

initial_state = np.array([1,0,0])

steps = 3

state_distribution = initial_state

for _ in range(steps):

    state_distribution = np.dot(state_distribution,P)

print("State distribution after 3 steps : ")

print(f"Sunny : {state_distribution[0]}")
print(f"Rainy: {state_distribution[1]}")
print(f"Cloudy : {state_distribution[2]}")
# Out:
# State distribution after 3 steps :
# Sunny : 0.474
# Rainy: 0.38699999999999996
# Cloudy : 0.139

# %%
import pandas as pd
from collections import defaultdict, Counter

df = pd.read_csv('movie_reviews.csv')
df
# Out:
#           movie_title rating                                       genre  \
# 0     A Dog's Journey     PG                        Drama, Kids & Family
# 1    A Dog's Way Home     PG                                       Drama
# 2      A Tuba to Cuba     NR      Documentary, Musical & Performing Arts
# 3         A Vigilante      R                                       Drama
# 4               After  PG-13                              Drama, Romance
# ..                ...    ...                                         ...
# 161    Velvet Buzzsaw      R           Comedy, Drama, Mystery & Suspense
# 162     What Men Want      R                                      Comedy
# 163         Wild Rose      R                               Comedy, Drama
# 164      Wine Country      R                                      Comedy
# 165         Yesterday  PG-13  Comedy, Science Fiction & Fantasy, Romance
#
#     in_theaters_date                                         movie_info  \
# 0            5/17/19  Bailey (voiced again by Josh Gad) is living th...
# 1         01/11/2019  Separated from her owner, a dog sets off on an...
# 2            2/15/19  The leader of New Orleans' famed Preservation ...
# 3            3/29/19  A once abused woman, Sadie (Olivia Wilde), dev...
# 4         04/12/2019  Based on Anna Todd's best-selling novel which ...
# ..               ...                                                ...
# 161       02/01/2019  Velvet Buzzsaw is a satirical thriller set in ...
# 162       02/08/2019  Inspired by the Nancy Meyers hit romantic come...
# 163          6/21/19  WILD ROSE tells the complicated story of Rose-...
# 164       05/08/2019  In honor of Rebecca (Rachel Dratch)'s 50th bir...
# 165          6/28/19  Jack Malik (Himesh Patel, BBC's Eastenders) is...
#
#                          directors director_gender  tomatometer_rating  \
# 0                     Gail Mancuso          female                  50
# 1             Charles Martin Smith            male                  60
# 2    Danny Clinch, T.G. Herrington            male                 100
# 3             Sarah Daggar-Nickson          female                  92
# 4                       Jenny Gage          female                  17
# ..                             ...             ...                 ...
# 161                     Dan Gilroy            male                  63
# 162                  Adam Shankman            male                  44
# 163                     Tom Harper            male                  93
# 164                    Amy Poehler          female                  66
# 165                    Danny Boyle            male                  63
#
#      audience_rating                                  critics_consensus
# 0                 92  A Dog's Journey is as sentimental as one might...
# 1                 71  A Dog's Way Home may not quite be a family-fri...
# 2                 82                                                NaN
# 3                 50  Led by Olivia Wilde's fearless performance and...
# 4                 72  Tepid and tired, After's fun flourishes are le...
# ..               ...                                                ...
# 161               36  If you only watch one art-world satire with ho...
# 162               33  Admittedly uneven but easy to like, What Men W...
# 163               88  There's no shortage of star-is-born stories, b...
# 164               30  Wine Country's comedy might not be quite as ro...
# 165               89  Yesterday may fall short of fab, but the end r...
#
# [166 rows x 10 columns]

# %%
texts = df["critics_consensus"].dropna()

# transitions = {
#     'fun':{'movie':3, 'experience':2},
#     'great':{'plot':1, 'acting':2}
# }

transitions = defaultdict(Counter)

for text in texts:

    words = text.lower().split()

    for i in range(len(words)-1):

        transitions[words[i]][words[i+1]]+=1

for current_word, next_words in transitions.items():

    print(f"{current_word} ----> {dict(next_words)}")
# Out:
# a ----> {"dog's": 2, 'tear': 1, 'family-friendly': 1, 'vigilante': 1, 'thoughtful': 1, 'pivotal': 3, 'good': 3, 'satisfying': 2, 'smart': 1, 'diverting': 1, 'captive': 1, 'welcome': 1, 'disappointing': 3, 'liam': 1, 'sophisticated': 1, 'completely': 1, 'fun': 1, 'second': 1, 'classic': 1, 'crowded': 2, 'thoroughly': 2, 'career-best': 1, 'step': 1, 'handful': 1, 'truly': 1, 'passing': 1, 'grounded': 1, 'single': 1, 'potent': 1, 'complex': 1, 'talented': 1, 'poignant': 1, 'few': 2, 'bonkers': 1, 'reasonably': 2, 'pair': 2, 'deeply': 1, 'funnier': 1, 'sci-fi': 1, 'sequel': 1, 'tenth': 1, 'well-made': 2, 'visually': 1, 'feel-good': 1, 'star': 3, 'heist': 1, 'galvanizing': 1, 'thought-provoking': 1, 'disappointingly': 2, 'familiar': 2, 'big': 1, 'story': 4, 'grimly': 2, 'commendable': 1, 'sharp': 1, 'real-life': 1, 'stellar': 1, 'satisfyingly': 1, 'labored': 1, 'true': 1, 'franchise': 1, 'horror': 1, 'future': 2, 'compelling': 1, 'visual': 1, 'little': 1, 'solid': 1, 'towering': 1, 'documentary': 1, 'revival.': 1, 'sadistic': 1, 'smartly': 1, 'certain': 1, 'watch.': 3, 'clichéd': 1, 'fascinating': 1, 'ponderously': 1, 'long,': 1, 'rock': 1, 'surprisingly': 1, 'rich': 1, 'gripping': 1, 'high-concept': 1, 'twist,': 1, 'thrilling': 1, 'superhero': 1, 'bit': 1, 'worthy': 2, 'committed': 1, 'breezily': 1, 'strong': 4, 'five-star': 1, 'fault,': 1, 'lifetime': 1, 'problematic': 1, 'zom-com': 1, 'chillingly': 1, 'poorly': 1, 'tense,': 1, 'flawed': 1, 'different': 1, 'remake': 1, 'timeless': 1, 'period': 1, 'filmmaker': 2, 'by-the-numbers': 1, 'muddled': 1, 'misguided': 1, 'uniquely': 1, 'well-told': 1, 'generous': 1, 'storyline': 1, 'brilliant': 1, 'practically': 1, 'challenging': 1, 'state': 1, 'rental.': 1, 'lackluster': 1, 'madea': 1, 'high': 1, 'dramatic': 1, 'hot-button': 1, 'gender-swapped': 1, 'nicely': 1, 'sweetly': 1}
# dog's ----> {'journey': 1, 'way': 1}
# journey ----> {'is': 1}
# is ----> {'as': 2, 'no': 1, 'an': 1, 'true': 1, 'the': 1, 'purest': 1, 'fiercely': 1, 'a': 9, 'my': 1, 'held': 1, 'essential': 1, 'nothing': 1, 'still': 3, 'somewhat': 1, 'challenging,': 1, 'to': 2, 'nowhere': 1, 'something': 1, 'worth': 1, 'set': 1, 'being': 1, 'sometimes': 1, 'also': 1, 'easy': 1, 'immediately': 1, 'us.': 1}
# as ----> {'sentimental': 1, 'one': 1, 'hard': 1, 'its': 6, 'frightening': 1, 'some': 1, 'bold,': 1, 'grim': 1, 'well': 2, 'the': 5, 'high': 1, 'deftly': 1, 'it': 6, 'fiendishly': 1, 'visually': 1, 'exploitative,': 1, 'many': 1, 'an': 4, 'groundbreaking': 1, 'often': 1, 'far': 1, 'clever': 1, 'entertaining': 1, 'a': 2, 'much': 1, 'robust': 1, 'fans': 1}
# sentimental ----> {'as': 1}
# one ----> {'might': 1, 'doing': 1, 'aspiring': 1, 'reinvigorates': 1, 'art-world': 1}
# might ----> {'expect,': 1, 'mean': 1, 'make': 1, 'appeal': 1, 'still': 1, 'have': 1, 'not': 1}
# expect, ----> {'but': 2}
# but ----> {'even': 1, 'this': 5, 'fans': 3, 'its': 1, 'it': 3, 'suffers': 1, 'for': 3, 'a': 2, "what's": 1, 'gets': 1, 'bogged': 1, 'ultimately': 1, 'the': 5, 'hotel': 1, "isn't": 1, 'viewers': 1, 'overall': 1, 'uneven': 1, 'her': 1, 'writer-director': 1, 'that': 1, "they're": 1, "it's": 3, 'sharp': 1, 'tests': 1, 'as': 1, 'lacks': 1, 'action': 1, 'unicorn': 1, 'easy': 1, 'wild': 1}
# even ----> {'cynical': 1, 'if': 2, 'for': 1, 'a': 1, 'bad': 1}
# cynical ----> {'viewers': 1}
# viewers ----> {'may': 2, 'in': 2, 'of': 1, 'attuned': 1, 'on': 1}
# may ----> {'find': 1, 'not': 5, 'still': 2, 'seem': 1, 'wear': 1, 'have': 1, 'test': 1, 'just': 1, 'be': 1, 'fall': 1}
# find ----> {'their': 1, 'themselves': 1, 'its': 1, 'this': 1, 'the': 1}
# their ----> {'ability': 1, 'efforts': 1}
# ability ----> {'to': 1}
# to ----> {'resist': 2, 'the': 9, 'keep': 2, 'find': 1, 'send': 1, 'a': 6, 'get': 1, 'observe': 1, 'deliver': 2, "marvel's": 1, 'offer': 2, 'work.': 1, 'make': 2, 'newcomers,': 1, 'unlock': 1, 'stay': 1, 'overcome': 1, 'say': 1, 'train': 1, 'roll.': 1, 'light': 1, 'bear': 1, 'no': 1, 'continue.': 1, 'be': 5, 'balance': 1, 'cheer': 1, 'celebrate.': 1, 'capture': 1, 'go': 1, 'mesh': 1, 'offset': 1, 'coast': 1, 'varying': 1, 'consume.': 1, 'powerful': 1, 'dramatize': 1, 'writer-director': 1, 'fans': 1, 'set': 1, 'watch.': 1, 'dramatizing': 1, 'spare.': 1, 'long-gestating': 1, 'satisfy': 1, 'sam': 1, 'life': 1, 'any': 1, 'fear,': 1, 'appreciate': 1, 'unraveling': 1, 'truly': 1, 'its': 1, 'rate': 1, 'tyler': 1, 'recognize': 1, 'admire': 1, 'like': 1, 'beat': 1, 'like,': 1}
# resist ----> {'shedding': 1, 'as': 1}
# shedding ----> {'a': 1}
# tear ----> {'stretched': 1}
# stretched ----> {'to': 1}
# the ----> {'puppermost': 1, 'dazzling': 1, 'animated': 1, 'infectious': 1, 'dynamic': 1, '21st-century': 1, 'conjuring': 1, 'way': 3, 'one': 1, 'surviving.': 1, 'seemingly': 1, 'coming-of-age': 1, 'pitch-black': 1, 'superhero': 1, "mcu's": 1, "franchise's": 3, 'story.': 1, 'internet': 1, 'action': 1, 'x-men': 1, 'right': 1, 'laurel': 1, 'musical': 1, 'canyon': 1, 'breaking': 2, 'potential': 1, 'sum': 3, 'efforts': 1, 'sport': 1, 'heartstrings': 1, 'traditional': 1, 'admirable': 1, 'framework': 1, 'conclusion': 1, "writer-director's": 1, 'title': 2, 'task.': 1, 'monsters': 1, 'original': 2, 'imaginative': 1, 'rare': 1, 'hidden': 1, 'brilliantly': 1, 'franchise': 1, 'end': 5, 'scenes': 1, 'house': 1, 'patience,': 1, 'odd': 1, 'gears': 1, 'mood': 2, 'basis': 1, 'rom-com': 1, 'cast': 1, 'demographic': 1, 'formidable': 1, 'highs': 1, 'original,': 2, "genre's": 1, 'stage': 1, 'next': 1, 'mcu.': 1, 'material': 1, 'aftermath': 1, 'most': 1, 'art': 1, 'role': 1, 'beach': 1, 'unfocused': 1, 'best': 2, 'boy': 1, 'wind': 2, 'changeover': 1, 'curse': 1, 'dead': 1, 'fanatic': 1, 'golem': 1, 'great': 1, 'haunting': 1, 'events': 1, 'highwaymen': 1, 'bonnie': 1, 'hole': 1, 'ground': 1, 'devil': 1, 'loud': 1, 'fright': 1, 'hummingbird': 1, "hustle's": 1, 'intruder': 1, 'kid': 2, 'multitude': 1, 'family': 1, 'king': 1, 'last': 1, 'laundromat': 1, 'real-life': 1, 'lego': 1, 'second': 1, 'energy': 1, 'man': 2, 'bigfoot': 1, 'wild': 1, 'mustang': 1, 'prodigy': 1, 'bad': 1, 'professor': 1, 'public': 1, 'secret': 1, 'material,': 1, 'souvenir': 1, 'standoff': 1, 'sun': 1, "audience's": 1, 'upside': 1, "vanishing's": 1, 'white': 1, 'nimble': 1, 'life': 1, 'landing.': 1, 'period': 1, 'imagination': 1, 'unlikely': 1, 'audience': 1, 'wrong': 1, 'many': 1, 'silver': 1, 'camera.': 1, 'feelings': 1, 'issue.': 1, 'sophomore': 1, 'odds': 1, 'lead.': 1, 'nose': 1}
# puppermost ----> {'limit.': 1}
# way ----> {'home': 1, 'of': 1, 'fan': 1, 'data': 1}
# home ----> {'may': 1, 'suggests': 1, 'stylishly': 1}
# not ----> {'quite': 2, 'necessarily': 1, 'essential,': 1, 'wholly': 1, 'take': 1, 'all': 1, 'anywhere': 1, 'bite': 1, 'live': 1, 'to': 1, 'be': 1}
# quite ----> {'be': 1, 'as': 4}
# be ----> {'a': 2, 'my': 1, 'rewarded': 1, 'reckoned': 1, 'worth': 2, 'so': 1, 'at': 1, 'king': 1, 'enough.': 1, 'painful': 1, 'entertained': 1, 'drawn': 1, 'best': 1, 'velvet': 1, 'thoroughly': 1, 'quite': 1}
# family-friendly ----> {'animal': 1}
# animal ----> {'drama': 1}
# drama ----> {"fan's": 1, 'instead': 1, 'that': 2, 'anchored': 1, 'well': 1, 'enthusiasts.': 1, 'worth': 1}
# fan's ----> {'best': 1}
# best ----> {'friend,': 1, 'installments,': 1, 'of': 2, 'enjoyed': 1}
# friend, ----> {'but': 1}
# this ----> {'canine': 1, 'variety': 1, 'sci-fi': 1, 'an': 1, 'long-running': 1, 'live-action': 1, 'a': 3, 'soulless': 1, 'long': 1, 'thriller': 1, 'remake': 1, 'offbeat': 1, 'multi-generational': 1, 'timely': 1, 'gender-flipped': 1, "thriller's": 1, 'funny,': 1, 'year': 1, 'ensemble': 1}
# canine ----> {'adventure': 1}
# adventure ----> {'is': 1}
# no ----> {'less': 1, 'substitute': 1, 'knowledge': 1, 'small': 1, 'shortage': 1}
# less ----> {'heartwarming': 1, 'subtle': 1, 'than': 2, 'likely': 1}
# heartwarming ----> {'for': 1}
# for ----> {'its': 4, 'fans': 2, 'the': 3, 'slow-burning': 1, 'longtime': 1, 'rock': 1, 'representation': 1, 'suspense': 1, 'writer-director': 3, 'a': 6, 'both.': 1, 'another': 1, 'viewers': 1, 'audiences': 1, 'laika,': 1, 'thought.': 1, 'itself': 1, 'future': 2, 'an': 1, 'matthew': 1, 'more': 1, 'political': 1, 'some': 1, 'horror': 1, 'all': 1, 'colorful': 1, 'lead': 1}
# its ----> {'familiarity.': 1, 'protagonist.': 1, 'generic': 1, 'classic': 1, 'special': 1, 'own': 2, 'predecessors,': 1, 'lead': 1, 'less': 1, 'setup,': 1, 'infamous': 1, 'treatment': 1, 'subject.': 1, 'title,': 2, 'action-packed': 1, 'clichéd': 1, 'premise,': 1, 'parts': 1, 'narrative': 1, 'well-matched': 1, 'mind': 1, 'difficult': 1, 'a-list': 1, 'predecessor,': 2, 'depiction': 1, 'saga': 1, 'deliberate': 1, 'talented,': 1, 'leads,': 1, 'marks.': 1, 'timely': 1, 'unhinged': 1, 'subject;': 1, "stars'": 1, 'real-life': 1, 'subject': 2, 'source': 1, 'extreme': 1, 'wonderfully': 1, 'talented': 1, "tale's": 1, 'characters': 1, 'surface,': 1, 'contrasting': 1, 'predictably': 1, 'younger': 1, "story's": 1, 'marquee': 1, 'underlying': 1, 'feminine': 1, 'impressive': 1, 'incredible': 1, 'visual': 1, 'intentions': 1, 'execution,': 1, 'animated': 1, 'mystery.': 1, 'subject,': 1, 'fresh': 1, 'title': 1, 'attention-getting': 1, 'affirmative': 1, 'stride': 1}
# led ----> {'by': 3}
# by ----> {'olivia': 1, 'timely': 1, 'its': 3, 'the': 3, '--': 1, 'adding': 1, 'strong': 1, 'taking': 2, 'tim': 1, 'a': 3, 'haley': 1, 'clichés,': 1, 'standout': 1, 'well-matched': 1, 'heart,': 1, 'harmony': 1, 'powerful': 1, 'uglydolls': 1, '-': 1, 'audiences': 1}
# olivia ----> {"wilde's": 1}
# wilde's ----> {'fearless': 1}
# fearless ----> {'performance': 1}
# performance ----> {'and': 1, 'from': 3, 'but': 1, 'in': 1, 'overpowers': 1, 'add': 1}
# and ----> {'elevated': 1, 'tired,': 1, 'skill,': 1, 'beautifully': 2, 'randall': 1, 'cleverly': 1, 'troubling': 1, 'employers': 1, 'better.': 1, 'inspiring': 1, 'emotionally': 2, 'fresh,': 1, 'an': 1, 'visual': 1, 'generally': 1, 'a': 14, 'benefits': 1, 'ultimately': 2, 'grinding': 1, 'has': 1, 'overstretched': 1, 'thrilling': 1, 'vile': 1, 'over-the-top': 1, 'committed': 1, 'refreshingly': 1, "she's": 1, 'reaffirms': 1, 'struggles': 1, 'deceptively': 1, 'above': 1, 'even': 1, 'transcends': 1, 'unintentional': 1, 'lows': 1, 'inventively': 1, 'visually': 1, 'heart,': 1, 'superhero': 1, 'dave': 1, 'elle': 1, 'serves': 1, 'impressive': 1, 'themes': 1, 'what': 1, 'offensively': 1, 'clyde': 1, 'gory': 1, 'well-acted,': 1, 'undermines': 1, 'well-intentioned,': 1, 'repurposes': 1, 'gripping': 1, 'unfocused': 1, 'humor': 1, 'heart': 1, 'then': 1, 'matthias': 1, 'arranged': 1, 'often.': 1, 'reasonably': 1, 'unpredictable,': 1, 'frustratingly': 1, 'kevin': 1, 'effective': 1, 'strong': 1, 'perhaps': 1, 'puts': 1, 'exerts': 1, 'ambitious': 1, 'elevate': 1, 'gritty': 1, 'it': 2, 'the': 1, 'marks': 1}
# elevated ----> {'by': 4, 'considerably': 1}
# timely ----> {'themes,': 1, 'themes': 2, 'drama': 1}
# themes, ----> {'a': 1}
# vigilante ----> {'is': 1}
# an ----> {'uncompromising': 1, 'elegiac': 1, 'urgent,': 1, 'uplifting': 1, 'origin': 1, "'80s": 1, 'uncommonly': 1, 'action-packed': 1, 'era': 1, 'outstanding': 3, 'incredible': 1, 'action': 1, 'inspirational,': 1, 'exhuming': 1, 'entertaining': 1, "artist's": 1, 'effortlessly': 1, 'overtly': 1, 'enjoyable': 1, 'effective': 2, 'examination': 1, 'alarming': 1, 'affecting': 1, 'animated': 1, 'evil': 1, 'earnest': 1, 'evocative': 1, 'admirably': 1, 'unsettling': 1, 'uneven': 1, 'intriguing': 1}
# uncompromising ----> {'thriller': 1}
# thriller ----> {'that': 1, "doesn't": 1, 'may': 1, '--': 1, 'from': 1}
# that ----> {'hits': 1, 'a': 1, 'makes': 3, 'make': 1, 'should': 1, 'approaches': 1, 'cutting-edge': 1, 'made': 2, 'really': 1, 'fans': 1, 'marks': 1, 'addresses': 1, 'delivers': 1, 'embraces': 1, 'disrespects': 1, "isn't": 2, 'finds': 1, 'never': 1, 'inspired': 1, 'lacks': 1, 'may': 1, 'strains': 1, 'captures': 1}
# hits ----> {'as': 1, 'its': 2}
# hard ----> {'as': 1, 'to': 1, 'it': 1, 'not': 1}
# tepid ----> {'and': 1}
# tired, ----> {"after's": 1}
# after's ----> {'fun': 1}
# fun ----> {'flourishes': 1, 'for': 1, 'throw-back': 1, 'as': 1}
# flourishes ----> {'are': 1}
# are ----> {'let': 1, 'balanced': 1, 'still': 1, 'familiar,': 1, 'sometimes': 1, 'substantially': 1}
# let ----> {'down': 1}
# down ----> {'by': 2, 'the': 1}
# generic ----> {'story.': 1}
# aladdin ----> {'retells': 1}
# retells ----> {'its': 1}
# classic ----> {'source': 1, 'comics': 1, 'all-ages': 1}
# source ----> {"material's": 1, 'material': 2}
# material's ----> {'story': 1}
# story ----> {'with': 2, 'struggles': 1, 'that': 5, 'leave': 1, '--': 1, 'is': 1, 'as': 1, 'keep': 1, 'interesting.': 1, 'dramatized': 1, 'and': 1, 'we': 1, 'rooted': 1, "that's": 1, 'powerfully': 1, 'populated': 1, 'topped': 1, 'further': 1, '4': 1, 'help': 1}
# with ----> {'sufficient': 1, 'its': 1, 'an': 4, 'action,': 1, 'ambitious': 1, 'predictably': 1, 'humor': 1, 'just': 1, 'deeply': 1, 'more': 1, 'a': 16, 'my': 1, 'fittingly': 1, 'some': 1, 'potential': 1, 'little': 1, 'lots': 1, 'modern': 1, 'tones': 1, 'enough': 1, 'timely': 1, 'heart': 1, 'thinly': 1, 'the': 1, 'jordan': 1, 'horror': 1, 'taraji': 1}
# sufficient ----> {'spectacle': 1}
# spectacle ----> {'and': 1}
# skill, ----> {'even': 1}
# if ----> {'it': 2, 'not': 3, 'at': 1, 'only': 1, 'you': 1}
# it ----> {'never': 1, 'all': 1, "isn't": 2, 'takes': 1, 'offers': 1, 'work.': 1, 'represents': 1, 'celebrates,': 1, 'should.': 1, 'remains': 1, 'is': 3, 'follows': 1, 'mocks,': 1, 'romantic': 1, 'lacks': 2, 'also': 1, 'does': 1, 'could': 1, 'appears': 1, 'thinks.': 1, 'makes': 1, 'his': 1, 'might': 2, 'seeks': 1, 'of': 1, 'can': 1, 'bears': 1, 'just': 1, 'stumbles,': 1, 'suggests': 1, 'should': 1}
# never ----> {'approaches': 1, 'forgets': 1}
# approaches ----> {'the': 1, 'its': 2}
# dazzling ----> {'splendor': 1, 'and': 1}
# splendor ----> {'of': 1}
# of ----> {'the': 19, 'futuristic': 1, 'ali': 1, 'this': 2, 'stylized': 1, 'its': 10, 'dialogue': 1, 'depth': 1, 'things': 1, 'high-speed': 1, 'jump': 1, 'a': 9, 'an': 3, 'zac': 1, 'energy': 1, 'age': 2, 'm.': 1, 'visual': 1, 'talented': 1, 'their': 1, 'his': 1, 'real-life': 1, 'tragic': 1, 'thieves': 1, 'which,': 1, 'all': 1, 'my': 1, 'chaos': 1, 'violence.': 2, "ma's": 1, 'or': 1, 'character': 1, 'humor,': 1, 'heart,': 1, 'sex': 1, 'potential': 1, 'judi': 1, 'humor': 1, 'teen': 1, 'humanity': 1, 'trust': 1, 'self-defense': 1, 'enemies': 1, 'intentions,': 1, 'insight.': 1, 'la': 1, 'success,': 1, 'sharon': 1, 'contemporary': 1, 'decades': 1, 'shout-at-the-screen': 1, 'suspense': 1, 'other': 1, 'director': 1, 'pets': 1, 'her': 1, 'easy-to-love': 1, 'it.': 1, 'extending': 1, 'flux': 1, 'grim': 1, 'viewers': 1, 'star-is-born': 1, 'fab,': 1}
# animated ----> {'original.': 1, 'triumph': 1, 'all-ages': 1, 'stars': 1, 'saga.': 1}
# alita: ----> {'battle': 1}
# battle ----> {"angel's": 1}
# angel's ----> {'story': 1}
# struggles ----> {'to': 3}
# keep ----> {'up': 1, 'this': 1, 'its': 1, 'audiences': 1}
# up ----> {'with': 1, 'to': 4, 'in': 1}
# special ----> {'effects,': 1}
# effects, ----> {'but': 1}
# fans ----> {'of': 7, 'even': 1, 'a': 1, 'expect': 1, 'that': 1, 'in': 2, 'an': 1, 'should': 1}
# futuristic ----> {'sci-fi': 1}
# sci-fi ----> {'action': 1, 'thriller': 1, 'bent,': 1, 'outing': 1}
# action ----> {'may': 1, 'have': 1, 'with': 1, 'audiences': 1, 'sequences.': 1, '--': 1, 'that': 1, 'hero;': 1, 'fans': 1}
# still ----> {'find': 3, 'some': 1, 'enough': 1, 'tense': 1, 'no': 1, 'well-executed': 1, 'largely': 1, 'be': 2, 'satisfy.': 1, 'a': 1}
# themselves ----> {'more': 1}
# more ----> {'than': 2, 'workmanlike': 1, 'on': 1, 'consistent': 1, 'seasoned': 1, 'often': 1}
# than ----> {'sufficiently': 1, 'wondrous.': 1, 'ordinary.': 1, 'the': 2, 'punching': 1, 'most': 1, 'uncomfortably': 1, 'tap': 1, 'its': 1, 'it': 1}
# sufficiently ----> {'entertained.': 1}
# impressively ----> {'cast': 1, 'crafted,': 1}
# cast ----> {'and': 2, 'to': 1, '-': 1, 'for': 1, 'is': 1, 'make': 1, 'by': 1, 'keep': 1}
# beautifully ----> {'filmed,': 1, 'animated': 1, 'filmed': 1, 'animated,': 1}
# filmed, ----> {'all': 1}
# all ----> {'is': 1, 'done': 1, 'political': 1, 'unsettling,': 1, '--': 1, 'the': 1}
# true ----> {'takes': 1, 'pioneer.': 1}
# takes ----> {'an': 1, 'familiar': 1, 'a': 1, 'to': 1, 'its': 1}
# elegiac ----> {'look': 1}
# look ----> {'at': 3}
# at ----> {"shakespeare's": 1, 'the': 3, 'adapting': 1, 'his': 1, 'first': 1, 'times': 1, 'sparrow': 1}
# shakespeare's ----> {'final': 1}
# final ----> {'days.': 1}
# carried ----> {'by': 1}
# infectious ----> {'charms': 1}
# charms ----> {'of': 1}
# ali ----> {'wong': 1}
# wong ----> {'and': 1}
# randall ----> {'park,': 1}
# park, ----> {'always': 1}
# always ----> {'be': 1, 'enough': 1}
# my ----> {'maybe': 1, 'name': 1, 'family': 1, "life's": 1}
# maybe ----> {'takes': 1}
# familiar ----> {'rom-com': 1, 'themes': 1, 'formula,': 1, 'redemption': 1, 'elements': 1}
# rom-com ----> {'beats': 1, 'with': 2}
# beats ----> {'and': 1}
# cleverly ----> {'layers': 1}
# layers ----> {'in': 1}
# in ----> {'smart': 1, 'the': 11, 'his': 1, 'equal': 1, 'american': 1, 'a': 6, 'its': 5, 'dramatizing': 1, 'superhero': 1, 'search': 2, 'thought-provoking': 1, 'sailing,': 1, 'perplexingly': 1, 'theaters': 1, 'rich': 1, 'sheer': 1, 'originality.': 1, 'san': 1, 'no': 1, 'command': 1, 'by': 1}
# smart ----> {'social': 1, 'new': 1, 'and': 1}
# social ----> {'commentary': 1, 'advocacy': 1}
# commentary ----> {'to': 1}
# own ----> {'sweet': 1, 'transcendent': 1}
# sweet ----> {'groove.': 1}
# american ----> {'factory': 1, 'history.': 1, 'masculinity': 1}
# factory ----> {'takes': 1}
# thoughtful ----> {'--': 1}
# -- ----> {'and': 17, 'look': 1, 'especially': 1, 'but': 2, 'results.': 1, 'along': 1, 'with': 1, 'led': 1, 'unfortunately,': 2, 'most': 1, 'if': 3, 'of': 1, 'as': 1, 'or': 2, 'journey.': 1, 'a': 2, 'for': 1, 'it': 1, 'albeit': 1, 'premise.': 1}
# troubling ----> {'--': 1}
# dynamic ----> {'between': 1}
# between ----> {'workers': 1, 'kumail': 1}
# workers ----> {'and': 1}
# employers ----> {'in': 1}
# 21st-century ----> {'globalized': 1}
# globalized ----> {'economy.': 1}
# anna ----> {'finds': 1}
# finds ----> {'writer-director': 2, 'director': 1, 'fresh': 1}
# writer-director ----> {'luc': 1, 'zhangke': 1, 'asghar': 1, 'nia': 1, 'ari': 1, 'max': 1, 'riley': 1, 'kim': 1, 'david': 1}
# luc ----> {'besson': 1}
# besson ----> {'squarely': 1}
# squarely ----> {'in': 1}
# his ----> {'wheelhouse,': 1, 'twisty': 1, 'inferno.': 1, 'oddly': 1}
# wheelhouse, ----> {'but': 1}
# variety ----> {'of': 1}
# stylized ----> {'action': 1}
# have ----> {'seen': 2, 'left': 1, 'started': 1, 'made': 1}
# seen ----> {'it': 1, 'how': 1}
# done ----> {'before': 1}
# before ----> {'--': 1, 'the': 1, 'a': 1}
# isn't ----> {'as': 2, 'enough': 1, 'it': 1, 'even': 1, 'what': 1, 'always': 1, 'quite': 1}
# frightening ----> {'as': 1}
# some ----> {'of': 1, 'life': 1, 'viewers,': 1, 'as': 1, 'satirical': 1, 'fans': 1}
# predecessors, ----> {'annabelle': 1}
# annabelle ----> {'comes': 1}
# comes ----> {'home': 1}
# suggests ----> {"there's": 1, 'dante': 1, 'gina': 1, 'brie': 1}
# there's ----> {'still': 1, 'no': 1}
# life ----> {'left': 1, 'is': 1, 'makes': 1, 'like': 1, 'by': 1, 'of': 2}
# left ----> {'in': 1, 'is': 1, 'a': 1}
# conjuring ----> {'franchise.': 1}
# edifying ----> {'and': 1}
# inspiring ----> {'in': 1}
# equal ----> {'measure,': 1, 'parts': 1}
# measure, ----> {'apollo': 1}
# apollo ----> {'11': 1}
# 11 ----> {'uses': 1}
# uses ----> {'artfully': 1, 'one': 1}
# artfully ----> {'repurposed': 1, 'exploits': 1}
# repurposed ----> {'archival': 1}
# archival ----> {'footage': 1}
# footage ----> {'to': 1}
# send ----> {'audiences': 1}
# audiences ----> {'soaring': 1, 'expect': 1, 'cheering.': 1, 'with': 2, 'invested': 1}
# soaring ----> {'back': 1}
# back ----> {'to': 1, 'for': 1}
# pivotal ----> {'time': 1, 'election,': 1, 'period': 1}
# time ----> {'in': 1, 'before': 1}
# arctic ----> {'proves': 1}
# proves ----> {'that': 1, 'writer-director': 1, 'contagious.': 1, 'saying': 1, 'a': 1, 'they': 1}
# good ----> {'survival': 1, 'story.': 1, 'use': 1, 'old-fashioned': 1}
# survival ----> {'thriller': 1, 'drama': 1}
# doesn't ----> {'need': 1, 'fully': 1, 'rev': 1, 'tug': 1, 'take': 1, 'teach': 1}
# need ----> {'much': 1}
# much ----> {'in': 1, 'of': 1, 'like': 1, 'fun': 1}
# dialogue ----> {'to': 1}
# get ----> {'by': 1}
# especially ----> {'when': 1}
# when ----> {'mads': 1}
# mads ----> {'mikkelsen': 1}
# mikkelsen ----> {'is': 1}
# doing ----> {'the': 1}
# ash ----> {'is': 1}
# purest ----> {'white': 1}
# white ----> {'finds': 1, 'crow': 1}
# zhangke ----> {'jia': 1}
# jia ----> {'revisiting': 1}
# revisiting ----> {'familiar': 1}
# themes ----> {'while': 1, 'with': 1, 'in': 1, 'to': 2, 'are': 1}
# while ----> {'continuing': 1, 'the': 2, 'it': 2}
# continuing ----> {'to': 1}
# observe ----> {'modern': 1}
# modern ----> {'chinese': 1, 'american': 1}
# chinese ----> {'society': 1}
# society ----> {'with': 1}
# urgent, ----> {'empathetic': 1}
# empathetic ----> {'eye.': 1}
# exciting, ----> {'entertaining,': 1}
# entertaining, ----> {'and': 1}
# emotionally ----> {'impactful,': 1, 'affecting': 1}
# impactful, ----> {'avengers:': 1}
# avengers: ----> {'endgame': 1}
# endgame ----> {'does': 1}
# does ----> {'whatever': 1, 'the': 1, 'a': 1}
# whatever ----> {'it': 1}
# deliver ----> {'a': 2, 'on': 1}
# satisfying ----> {'finale': 1, 'belated': 1}
# finale ----> {'to': 1}
# marvel's ----> {'epic': 1}
# epic ----> {'infinity': 1, 'that': 1}
# infinity ----> {'saga.': 1}
# fast-paced, ----> {'funny,': 1}
# funny, ----> {'and': 2, 'energetic': 1}
# fresh, ----> {'booksmart': 1}
# booksmart ----> {'does': 1}
# seemingly ----> {'impossible': 1}
# impossible ----> {'by': 1}
# adding ----> {'a': 1}
# new ----> {'spin': 1, 'angle,': 1, 'addition': 1, 'places,': 1, 'narrative': 1}
# spin ----> {'to': 1, 'on': 2}
# coming-of-age ----> {'comedy.': 1}
# like ----> {'its': 1, 'colorful': 1, 'the': 1, 'an': 1, 'rocketman.': 1, '--': 1}
# lead ----> {'character,': 1, 'performances': 1, 'performance': 1, 'jessie': 1}
# character, ----> {'breakthrough': 1}
# breakthrough ----> {'is': 1}
# fiercely ----> {'focused': 1}
# focused ----> {'on': 1}
# on ----> {'faith': 1, 'the': 4, 'its': 1, 'julianne': 1, 'some': 1, 'a': 4, 'reasons': 1, 'collegiate': 1, 'jump': 1, 'real-life': 1, 'either': 1}
# faith ----> {'--': 1}
# subtle ----> {'elements': 1}
# elements ----> {'are': 1, 'in': 1}
# balanced ----> {'by': 1, 'finish.': 1}
# strong ----> {'performances': 3, 'case': 1, 'senes': 1, 'cast': 2, 'source': 1}
# performances ----> {'and': 2, 'with': 1, 'make': 1, 'from': 1, 'of': 1}
# uplifting ----> {'story.': 1, 'arc': 1}
# although ----> {'brightburn': 1}
# brightburn ----> {"doesn't": 1}
# fully ----> {'deliver': 1, 'realizing': 1}
# pitch-black ----> {'promise': 1}
# promise ----> {'of': 2}
# setup, ----> {"it's": 1}
# it's ----> {'still': 1, 'everything': 1, 'trying': 1, 'good.': 1, 'going': 1, 'also': 1, 'spooky': 1, 'hard': 1, 'got': 1}
# enough ----> {'to': 7, 'self-awareness': 1, 'momentum': 1, 'for': 2, 'brains': 1, 'of': 1}
# offer ----> {'a': 2}
# diverting ----> {'subversion': 1, 'alien': 1, 'primer': 1}
# subversion ----> {'of': 1}
# superhero ----> {'genre.': 1, 'cinema': 1, 'story': 1, 'movie': 1, 'action,': 1}
# packed ----> {'with': 1}
# action, ----> {'humor,': 1, 'spider-man:': 1}
# humor, ----> {'and': 1, 'plenty': 1}
# visual ----> {'thrills,': 1, 'flair,': 1, 'or': 1, 'treat': 1, 'achievements,the': 1}
# thrills, ----> {'captain': 1}
# captain ----> {'marvel': 1}
# marvel ----> {'introduces': 1}
# introduces ----> {'the': 1}
# mcu's ----> {'latest': 1}
# latest ----> {'hero': 1}
# hero ----> {'with': 1}
# origin ----> {'story': 1}
# makes ----> {'effective': 1, 'dolemite': 1, 'good': 1, 'a': 2, 'up': 1}
# effective ----> {'use': 1, 'remake.': 1, 'if': 1, 'hook.': 1, 'horror': 1, 'comedy': 1, 'scares.': 1}
# use ----> {'of': 3}
# franchise's ----> {'signature': 1, 'best': 1, 'fans.': 1}
# signature ----> {'formula.': 1, 'creative': 1}
# necessarily ----> {'leave': 1}
# leave ----> {'viewers': 1, 'this': 1, 'audiences': 1}
# captive ----> {'state,': 1}
# state, ----> {'but': 1}
# offers ----> {'reasonably': 1, 'horror': 2, 'an': 1}
# reasonably ----> {'diverting': 2, 'gripping,': 1, 'engaging': 1}
# alien ----> {'invasion': 1}
# invasion ----> {'action': 1}
# ambitious ----> {'political': 1, 'story': 2, 'horror': 1}
# political ----> {'undertones.': 1, 'persuasions.': 1, 'gain': 1}
# charlie ----> {'says': 1}
# says ----> {'approaches': 1}
# infamous ----> {'subject': 1}
# subject ----> {'from': 1, 'proves': 1, 'justice.': 1}
# from ----> {'a': 6, 'aaron': 1, 'director': 1, 'tessa': 1, 'fully': 1, 'hermione': 1, 'the': 2, 'jamie': 1, 'home': 1, 'debuting': 1, 'bruce': 1}
# welcome ----> {'new': 1}
# angle, ----> {'but': 1}
# suffers ----> {'from': 1}
# disappointing ----> {'lack': 2, 'results.': 1, 'step': 1}
# lack ----> {'of': 2}
# depth ----> {'in': 1, 'of': 1}
# treatment ----> {'of': 1}
# child's ----> {'play': 1}
# play ----> {'updates': 1}
# updates ----> {'an': 1}
# '80s ----> {'horror': 1}
# horror ----> {'icon': 1, 'fans': 3, 'will': 1, 'auteur': 1, 'anthologies,': 1, 'fans,': 1, 'story': 1, 'outing': 1, 'to': 1, 'film,': 1, 'overtones': 1}
# icon ----> {'for': 1}
# internet ----> {'of': 1}
# things ----> {'era,': 1}
# era, ----> {'with': 1}
# predictably ----> {'gruesome': 1, 'uplifting': 1}
# gruesome ----> {'--': 1}
# generally ----> {'entertaining': 1}
# entertaining ----> {'--': 2, 'look': 1, 'if': 1, 'tribute': 1, 'outing': 1, 'as': 1, 'blend': 1, 'diversion': 1, 'despite': 1, 'enough': 1}
# cold ----> {'pursuit': 1}
# pursuit ----> {'delivers': 1}
# delivers ----> {'the': 1, 'spectacular': 1, 'unpredictable': 1}
# expect ----> {'from': 2}
# liam ----> {'neeson': 1}
# neeson ----> {'thriller': 1}
# along ----> {'with': 1}
# humor ----> {'and': 2, 'to': 1}
# sophisticated ----> {'streak': 1}
# streak ----> {'that': 1}
# make ----> {'this': 4, 'it': 1, 'her': 1, 'sword': 1, 'an': 1}
# uncommonly ----> {'effective': 1}
# action-packed ----> {'creature': 1, 'apogee.': 1}
# creature ----> {'feature': 1}
# feature ----> {"that's": 1}
# that's ----> {'fast,': 1, 'further': 1, 'far': 1, 'unfortunately': 1}
# fast, ----> {'terrifying,': 1}
# terrifying, ----> {'and': 1}
# benefits ----> {'greatly': 1, 'from': 1}
# greatly ----> {'from': 1}
# completely ----> {'game': 1, 'on': 1}
# game ----> {'kaya': 1}
# kaya ----> {'scodelario,': 1}
# scodelario, ----> {'crawl': 1}
# crawl ----> {'is': 1}
# throw-back ----> {'with': 1}
# just ----> {'enough': 1, 'as': 1, 'the': 1, 'be': 1, 'about': 2}
# self-awareness ----> {'to': 1}
# dark ----> {'phoenix': 1}
# phoenix ----> {'ends': 1}
# ends ----> {'an': 1}
# era ----> {'of': 2}
# x-men ----> {'franchise': 1}
# franchise ----> {'by': 1, 'near': 1, 'demand.': 1, 'running': 1, 'with': 1}
# taking ----> {'a': 2, 'full': 1}
# second ----> {'stab': 1, 'part': 1, 'inventive,': 1}
# stab ----> {'at': 1}
# adapting ----> {'a': 1}
# comics ----> {'arc': 1}
# arc ----> {'--': 1, 'through': 1}
# deeply ----> {'disappointing': 1, 'mediocre': 1}
# dramatizing ----> {'rudy': 1, 'the': 1}
# rudy ----> {'ray': 1}
# ray ----> {"moore's": 1}
# moore's ----> {'stranger-than-fiction': 1, 'performance': 1}
# stranger-than-fiction ----> {'story,': 1}
# story, ----> {'eddie': 1}
# eddie ----> {'murphy': 1}
# murphy ----> {'makes': 1}
# dolemite ----> {'is': 1}
# name ----> {'just': 1}
# bold, ----> {'brash,': 1}
# brash, ----> {'and': 1}
# ultimately ----> {'hard': 1, 'disappoints': 1, 'rewarding': 1}
# grim ----> {'and': 2, 'outlook': 1}
# grinding ----> {'as': 1}
# title, ----> {'dragged': 1, 'due': 1}
# dragged ----> {'across': 1}
# across ----> {'concrete': 1}
# concrete ----> {'opts': 1}
# opts ----> {'for': 1}
# slow-burning ----> {'drama': 1}
# instead ----> {'of': 1}
# high-speed ----> {'thrills': 1}
# thrills ----> {'--': 1}
# has ----> {'just': 1, 'obvious': 1, 'a': 3, 'the': 2}
# right ----> {'cast': 1}
# dragon ----> {'ball': 1}
# ball ----> {'super:': 1}
# super: ----> {'broly': 1}
# broly ----> {'may': 1}
# seem ----> {'like': 1}
# colorful ----> {'chaos': 1, 'whimsy,': 1}
# chaos ----> {'to': 1, 'presents': 1}
# newcomers, ----> {'but': 1}
# longtime ----> {'fans,': 1}
# fans, ----> {'it': 1, 'but': 1}
# represents ----> {'this': 1, 'a': 1}
# long-running ----> {'franchise': 1, 'franchise,': 1}
# near ----> {'its': 1, 'as': 2, 'peak': 1}
# dumbo ----> {'is': 1}
# held ----> {'partly': 1}
# partly ----> {'aloft': 1}
# aloft ----> {'by': 1}
# tim ----> {"burton's": 1}
# burton's ----> {'visual': 1}
# flair, ----> {'but': 1}
# crowded ----> {'canvas': 1, 'field': 1}
# canvas ----> {'and': 1}
# overstretched ----> {'story': 1}
# live-action ----> {'remake': 1}
# remake ----> {'more': 1, 'feels': 1, 'of': 1, 'adds': 1, 'can': 1}
# workmanlike ----> {'than': 1}
# thoroughly ----> {'entertaining': 2, 'enjoyable': 1}
# laurel ----> {'canyon': 1}
# canyon ----> {'scene': 1, 'is': 1}
# scene ----> {'as': 1, 'whose': 1}
# well ----> {'as': 2, 'worth': 1}
# musical ----> {'history': 1}
# history ----> {'surrounding': 1}
# surrounding ----> {'it,': 1}
# it, ----> {'echo': 1}
# echo ----> {'in': 1}
# essential ----> {'viewing': 1}
# viewing ----> {'for': 1, 'even': 1}
# rock ----> {'doc': 1, 'biopic': 1}
# doc ----> {'fans.': 1}
# essential, ----> {'el': 1}
# el ----> {'camino': 1, 'chicano': 1}
# camino ----> {'adds': 1}
# adds ----> {'a': 1, 'little': 1}
# belated ----> {'coda': 1}
# coda ----> {'to': 1}
# breaking ----> {'bad': 1, 'point.': 1}
# bad ----> {'story': 1, 'guys,': 1, 'enough': 1, "it's": 1, 'seed': 1}
# career-best ----> {'performance': 1}
# aaron ----> {'paul.': 1}
# chicano ----> {'represents': 1}
# step ----> {'forward': 1, 'back': 1}
# forward ----> {'for': 1}
# representation ----> {'in': 1}
# cinema ----> {'--': 1, 'should': 1}
# unfortunately, ----> {'its': 1, 'it': 2, "it's": 1}
# clichéd ----> {'story': 1, 'comedy': 1}
# nothing ----> {'more': 1}
# intermittently ----> {'effective': 1}
# wholly ----> {'successful,': 1}
# successful, ----> {'eli': 1}
# eli ----> {'offers': 1}
# handful ----> {'of': 1}
# jump ----> {'scares': 2}
# scares ----> {'in': 1, 'rather': 1}
# search ----> {'of': 2}
# truly ----> {'terrifying': 1, 'new': 1, 'do': 1}
# terrifying ----> {'story.': 1}
# escape ----> {'room': 1}
# room ----> {'fails': 1}
# fails ----> {'to': 3, 'early': 1}
# unlock ----> {'much': 1}
# potential ----> {'in': 1, '--': 1, 'untapped': 1}
# premise, ----> {'but': 1}
# what's ----> {'left': 1}
# tense ----> {'and': 1}
# thrilling ----> {'enough': 1, 'and': 1}
# passing ----> {'diversion': 1}
# diversion ----> {'for': 1, "that's": 1}
# suspense ----> {'fans.': 1, '--': 1, 'fans': 1}
# everybody ----> {'knows': 1}
# knows ----> {'is': 1}
# somewhat ----> {'less': 1, 'under-explored': 1}
# sum ----> {'of': 3}
# parts ----> {'despite': 1, 'plot': 1}
# despite ----> {'the': 1, 'its': 1}
# efforts ----> {'of': 2, "isn't": 1}
# outstanding ----> {'cast': 2, 'calling': 1}
# - ----> {'and': 2, 'which': 1, 'parabellum': 1, 'in': 1, 'or': 1, 'writer-director': 1}
# asghar ----> {'farhadi.': 1}
# extremely ----> {'wicked,': 1}
# wicked, ----> {'shockingly': 1}
# shockingly ----> {'evil': 1}
# evil ----> {'and': 1, 'child': 1}
# vile ----> {'often': 1}
# often ----> {'transcends': 1, 'as': 1, 'than': 1}
# transcends ----> {'its': 1, 'genre': 1}
# narrative ----> {'limitations': 1, 'embellishments,': 1, 'tricks': 1, '--': 1}
# limitations ----> {'through': 1}
# through ----> {'sheer': 1, 'the': 1, 'strong': 1}
# sheer ----> {'force': 1, 'effectiveness': 1}
# force ----> {'of': 1}
# zac ----> {"efron's": 1}
# efron's ----> {'compulsively': 1}
# compulsively ----> {'watchable': 1}
# watchable ----> {'performance.': 1}
# hobbs ----> {'&': 1}
# & ----> {'shaw': 1}
# shaw ----> {"doesn't": 1}
# rev ----> {'as': 1}
# high ----> {'as': 1, 'life': 1, 'tolerance': 1}
# installments, ----> {'but': 1}
# gets ----> {'decent': 1}
# decent ----> {'mileage': 1}
# mileage ----> {'out': 1}
# out ----> {'of': 2, 'only': 1}
# well-matched ----> {'stars': 1, 'cast.': 1, 'leads': 1}
# stars ----> {'and': 1, 'on': 1, 'might': 1, 'any': 1}
# over-the-top ----> {'action': 2, 'performance.': 1}
# grounded ----> {'superhero': 1}
# mind ----> {'than': 1}
# punching ----> {'bad': 1}
# guys, ----> {'fast': 1}
# fast ----> {'color': 1}
# color ----> {'leaps': 1}
# leaps ----> {'over': 1}
# over ----> {'uneven': 1, 'into': 1}
# uneven ----> {'execution': 1, 'but': 2, 'pacing': 1, 'narrative': 1}
# execution ----> {'with': 1}
# single ----> {'gugu': 1}
# gugu ----> {'mbatha-raw': 1}
# mbatha-raw ----> {'performance.': 1}
# sport ----> {'it': 1}
# celebrates, ----> {'fighting': 1}
# fighting ----> {'with': 1}
# family ----> {'muscles': 1, 'movie': 1, 'funeral': 1}
# muscles ----> {'past': 1}
# past ----> {'clichés': 1, 'the': 1}
# clichés ----> {'with': 1}
# potent ----> {'blend': 1}
# blend ----> {'of': 3}
# energy ----> {'and': 2}
# committed ----> {'acting': 1, 'performance': 1}
# acting ----> {'that': 1}
# should ----> {'leave': 1, 'prove': 1, 'entertain': 1, 'catch': 1, 'still': 2, 'satisfy': 1, 'probably': 1}
# considerably ----> {'by': 1}
# haley ----> {'lu': 1}
# lu ----> {"richardson's": 1}
# richardson's ----> {'performance': 1}
# bogged ----> {'down': 1}
# clichés, ----> {'five': 1}
# five ----> {'feet': 1}
# feet ----> {'apart': 1}
# apart ----> {"doesn't": 1, 'by': 1, 'from': 1}
# tug ----> {'at': 1}
# heartstrings ----> {'quite': 1}
# deftly ----> {'as': 1}
# giant ----> {'little': 1}
# little ----> {'ones': 1, 'benefits': 1, 'woods': 1, 'to': 1, 'food': 1, 'beyond': 1}
# ones ----> {'puts': 1}
# puts ----> {'a': 1, 'the': 1}
# complex ----> {'and': 1, 'story': 1}
# refreshingly ----> {'nuanced': 1}
# nuanced ----> {'spin': 1}
# traditional ----> {'coming': 1}
# coming ----> {'of': 2}
# age ----> {'drama,': 1, 'drama.': 1}
# drama, ----> {'further': 1}
# further ----> {'elevated': 1, 'fueled': 1, 'proves': 1, 'distinguished': 1}
# admirable ----> {'efforts': 1}
# talented ----> {'cast.': 1, 'veterans,': 1, 'stars': 1}
# girl ----> {'uses': 1}
# aspiring ----> {"dancer's": 1}
# dancer's ----> {'story': 1}
# framework ----> {'for': 1}
# poignant ----> {'drama': 1}
# difficult ----> {'themes': 1}
# fittingly ----> {'alluring': 1}
# alluring ----> {'grace.': 1}
# glass ----> {'displays': 1}
# displays ----> {'a': 1}
# few ----> {'glimmers': 1, 'different': 1}
# glimmers ----> {'of': 1}
# m. ----> {'night': 1}
# night ----> {'shyamalan': 1}
# shyamalan ----> {'at': 1}
# twisty ----> {'world-building': 1}
# world-building ----> {'best,': 1}
# best, ----> {'but': 1}
# disappoints ----> {'as': 1}
# conclusion ----> {'to': 2}
# writer-director's ----> {'long-gestating': 1}
# long-gestating ----> {'trilogy.': 1, 'expectations,': 1}
# free ----> {'of': 1}
# or ----> {'narrative': 1, 'interest': 1, 'depth': 1, 'entertaining': 1, 'anything': 1, 'be': 1, 'most': 1}
# embellishments, ----> {'gloria': 1}
# gloria ----> {'bell': 1}
# bell ----> {'rests': 1, 'make': 1}
# rests ----> {'almost': 1}
# almost ----> {'completely': 1, 'as': 1}
# julianne ----> {"moore's": 1}
# title ----> {'role': 1, 'role.': 1, 'with': 1}
# role ----> {'--': 1, 'of': 1}
# she's ----> {'gloriously': 1}
# gloriously ----> {'up': 1}
# godzilla: ----> {'king': 1}
# king ----> {'of': 2, 'recalls': 1, 'is': 2}
# monsters ----> {'delivers': 1}
# spectacular ----> {'kaiju': 1}
# kaiju ----> {'action': 1}
# reaffirms ----> {'that': 1}
# cutting-edge ----> {'effects': 1}
# effects ----> {'are': 1}
# substitute ----> {'for': 1}
# bonkers ----> {'b': 1}
# b ----> {'movie': 1}
# movie ----> {'occasionally': 1, 'brimming': 1, 'that': 1, 'canon.': 1, '2:': 1}
# occasionally ----> {'elevated': 1}
# a-list ----> {'talent,': 1}
# talent, ----> {'greta': 1}
# greta ----> {'dives': 1}
# dives ----> {'headlong': 1}
# headlong ----> {'into': 1}
# into ----> {'camp': 1, 'atmospheric': 1, 'fatal': 1, 'its': 1, 'toxic': 1, 'an': 1}
# camp ----> {'and': 1}
# stay ----> {'afloat.': 1}
# gwen's ----> {'relentlessly': 1}
# relentlessly ----> {'grim': 1}
# outlook ----> {'may': 1}
# wear ----> {'on': 1}
# viewers, ----> {'but': 1}
# remains ----> {'a': 2, 'an': 1}
# gripping, ----> {'solidly': 1}
# solidly ----> {'assembled': 1}
# assembled ----> {'descent': 1}
# descent ----> {'into': 1}
# atmospheric ----> {'period': 1}
# period ----> {'horror.': 1, 'drama': 2, 'in': 1, 'trappings': 1}
# hampstead ----> {'plays': 1}
# plays ----> {'matchmaker': 1}
# matchmaker ----> {'with': 1}
# pair ----> {'of': 2}
# veterans, ----> {'but': 1}
# overcome ----> {'a': 1, 'an': 1}
# mediocre ----> {'story.': 1}
# funnier ----> {'follow-up': 1}
# follow-up ----> {'with': 1}
# bent, ----> {'happy': 1}
# happy ----> {'death': 1}
# death ----> {'day': 1}
# day ----> {'2u': 1}
# 2u ----> {"isn't": 1}
# fiendishly ----> {'fresh': 1}
# fresh ----> {'as': 1, 'perspectives': 1, 'perspective': 1}
# predecessor, ----> {'but': 1, 'the': 1}
# original ----> {'may': 1, 'so': 1}
# sequel ----> {'worth': 1, 'should': 1}
# worth ----> {'celebrating.': 1, 'a': 3, 'seeking': 1, 'hailing.': 1}
# bereft ----> {'of': 1}
# imaginative ----> {'flair': 1}
# flair ----> {'that': 1}
# made ----> {'earlier': 1, 'the': 1, 'by': 1, 'better': 1}
# earlier ----> {'hellboys': 1}
# hellboys ----> {'so': 1}
# so ----> {'enjoyable,': 1, 'bad': 1, 'beloved--though': 1}
# enjoyable, ----> {'this': 1}
# soulless ----> {'reboot': 1}
# reboot ----> {'suggests': 1}
# dante ----> {'may': 1}
# tenth ----> {'circle': 1}
# circle ----> {'out': 1}
# visually ----> {'arresting': 1, 'dazzling': 1, 'sumptuous': 1}
# arresting ----> {'as': 1}
# challenging, ----> {'confounding,': 1}
# confounding, ----> {'and': 1}
# rewarding ----> {'-': 1}
# which ----> {'is': 1}
# say ----> {"it's": 1}
# everything ----> {'film': 1}
# film ----> {'fans': 1}
# director ----> {'claire': 1, 'zhang': 1, 'chiwetel': 1, 'joe': 1, 'terry': 1}
# claire ----> {'denis.': 1}
# depiction ----> {'of': 1}
# real-life ----> {'horror': 1, 'music': 1, 'subject,': 1, 'story': 1, 'tragedy.': 1, 'events': 1}
# will ----> {'strike': 1, 'be': 1, 'only': 1, 'expect,': 1}
# strike ----> {'some': 1}
# exploitative, ----> {'but': 1}
# hotel ----> {'mumbai': 1}
# mumbai ----> {'remains': 1}
# well-made ----> {'dramatization': 1, 'horror': 1}
# dramatization ----> {'of': 2}
# tragic ----> {'events.': 1}
# rare ----> {'trilogy': 1}
# trilogy ----> {'capper': 1}
# capper ----> {'that': 1}
# really ----> {'works,': 1}
# works, ----> {'how': 1}
# how ----> {'to': 2, 'hard': 1}
# train ----> {'your': 1}
# your ----> {'dragon:': 1}
# dragon: ----> {'the': 1}
# hidden ----> {'world': 1}
# world ----> {'brings': 1}
# brings ----> {'its': 1, 'a': 1}
# saga ----> {'to': 1}
# affecting ----> {'conclusion.': 1, 'story': 1}
# follows ----> {'as': 1}
# many ----> {'genre': 1, 'of': 1, 'familiar': 1}
# genre ----> {'conventions': 1, 'clichés.': 1, 'to': 1}
# conventions ----> {'as': 1}
# mocks, ----> {'but': 1}
# romantic ----> {'is': 1}
# feel-good ----> {'rom-com': 1}
# satirical ----> {'bite': 1}
# bite ----> {'--': 1, 'deep': 1}
# star ----> {'well-suited': 1, 'perfectly': 1, 'has': 1}
# well-suited ----> {'for': 1}
# john ----> {'wick:': 1, 'travolta': 1}
# wick: ----> {'chapter': 1}
# chapter ----> {'3': 1}
# 3 ----> {'-': 1}
# parabellum ----> {'reloads': 1}
# reloads ----> {'for': 1}
# another ----> {'hard-hitting': 1, 'beautifully': 1}
# hard-hitting ----> {'round': 1}
# round ----> {'of': 1}
# brilliantly ----> {'choreographed,': 1, 'to': 1}
# choreographed, ----> {'over-the-top': 1, 'shadow': 1}
# thieves ----> {'unites': 1}
# unites ----> {'an': 1}
# incredible ----> {'cast': 2, 'intrigue': 1}
# heist ----> {'movie': 1, 'thrillers.': 1}
# brimming ----> {'with': 1}
# most ----> {'of': 1, 'horror': 1, '--': 1, 'passionate': 1, 'others': 1}
# which, ----> {'sadly,': 1}
# sadly, ----> {'evaporates': 1}
# evaporates ----> {'long': 1}
# long ----> {'before': 1, 'shot': 1, 'time': 1}
# end ----> {'credits': 1, 'result': 3, 'results': 1}
# credits ----> {'have': 1}
# started ----> {'to': 1}
# galvanizing ----> {'glimpse': 1}
# glimpse ----> {'behind': 1, 'of': 1}
# behind ----> {'the': 2}
# scenes ----> {'of': 1}
# election, ----> {'knock': 1}
# knock ----> {'down': 1}
# house ----> {'should': 1, 'of': 1}
# prove ----> {'engrossing': 1}
# engrossing ----> {'for': 1}
# deliberate ----> {'pace': 1}
# pace ----> {'may': 1}
# test ----> {'the': 1}
# patience, ----> {'but': 1}
# attuned ----> {'to': 1}
# light ----> {'of': 1}
# life's ----> {'sober': 1}
# sober ----> {'wavelength': 1}
# wavelength ----> {'will': 1}
# rewarded ----> {'with': 1}
# thought-provoking ----> {'chiller.': 1, 'fashion.': 1}
# disappointingly ----> {'uneven': 1, 'blunt': 1}
# overall ----> {'agreeable': 1}
# agreeable ----> {'spin': 1}
# formula, ----> {'little': 1}
# big ----> {'heart': 1}
# heart ----> {'--': 1, 'and': 1, 'that': 1}
# talented, ----> {'well-matched': 1}
# standout ----> {'work': 1}
# work ----> {'from': 2, 'in': 1, '--': 1}
# tessa ----> {'thompson,': 1}
# thompson, ----> {'little': 1}
# woods ----> {'tells': 1}
# tells ----> {'a': 2}
# grimly ----> {'absorbing': 1, 'compelling': 1}
# absorbing ----> {'tale': 1}
# tale ----> {'that': 1, 'brought': 1}
# marks ----> {'a': 2, 'its': 1}
# commendable ----> {'debut': 1}
# debut ----> {'for': 1}
# nia ----> {'dacosta.': 1}
# sharp ----> {'and': 1, 'wit': 1}
# deceptively ----> {'layered': 1}
# layered ----> {'comedy': 1, 'survival': 1}
# comedy ----> {"that's": 1, 'that': 1, 'team': 1, 'might': 1}
# fueled ----> {'by': 1}
# odd ----> {'couple': 1}
# couple ----> {'chemistry': 1}
# chemistry ----> {'of': 1, 'through': 1, 'without': 1}
# leads, ----> {'this': 1, 'but': 1}
# shot ----> {'largely': 1}
# largely ----> {'hits': 1, 'fails': 1}
# lords ----> {'of': 1}
# presents ----> {'a': 1}
# compelling ----> {'dramatization': 1, 'story.': 1}
# music ----> {'scene': 1}
# whose ----> {'aggressively': 1, 'evident': 1, 'agenda': 1}
# aggressively ----> {'nihilistic': 1}
# nihilistic ----> {'aesthetic': 1}
# aesthetic ----> {'spilled': 1}
# spilled ----> {'over': 1}
# fatal ----> {'acts': 1}
# acts ----> {'of': 1}
# luce ----> {'brings': 1}
# stellar ----> {'ensemble': 1}
# ensemble ----> {'to': 1, 'will': 1}
# bear ----> {'on': 1}
# satisfyingly ----> {'complex': 1}
# addresses ----> {'its': 1}
# octavia ----> {"spencer's": 1}
# spencer's ----> {'performance': 1}
# overpowers ----> {'many': 1}
# ma's ----> {'flaws,': 1}
# flaws, ----> {'but': 1}
# pacing ----> {'and': 1}
# labored ----> {'story': 1}
# realizing ----> {'its': 1}
# unhinged ----> {'potential.': 1}
# enthralling ----> {'viewing': 1}
# knowledge ----> {'of': 1}
# interest ----> {'in': 1}
# sailing, ----> {'maiden': 1}
# maiden ----> {'pays': 1}
# pays ----> {'powerful': 1, 'entertaining': 1}
# powerful ----> {'tribute': 1, 'effect.': 1, 'performances': 1}
# tribute ----> {'to': 2}
# mary ----> {'magdalene': 1}
# magdalene ----> {'has': 1}
# obvious ----> {'reverence': 1}
# reverence ----> {'for': 1}
# subject; ----> {'unfortunately,': 1}
# lacks ----> {'enough': 1, 'in': 1, 'the': 3}
# momentum ----> {'or': 1}
# character ----> {'to': 1}
# her ----> {'story': 1, 'extraordinary': 1, 'craft': 1}
# amiable ----> {'yet': 1}
# yet ----> {'forgettable,': 1, 'more': 1, 'undeniably': 1, 'intriguing,': 1, 'formulaic': 1}
# forgettable, ----> {'mib': 1}
# mib ----> {'international': 1}
# international ----> {'grinds': 1}
# grinds ----> {'its': 1}
# stars' ----> {'substantial': 1}
# substantial ----> {'chemistry': 1}
# gears ----> {'of': 1}
# running ----> {'low': 1}
# low ----> {'on': 1}
# reasons ----> {'to': 1}
# ambitious, ----> {'impressively': 1}
# crafted, ----> {'and': 1}
# above ----> {'all': 1, 'a': 1}
# unsettling, ----> {'midsommar': 1}
# midsommar ----> {'further': 1}
# ari ----> {'aster': 1}
# aster ----> {'is': 1}
# auteur ----> {'to': 1}
# reckoned ----> {'with.': 1}
# miss ----> {'bala': 1}
# bala ----> {'suggests': 1}
# gina ----> {'rodriguez': 1}
# rodriguez ----> {'has': 1}
# future ----> {'as': 1, 'collaborations': 1, 'elections.': 1, 'behind': 1}
# hero; ----> {'unfortunately,': 1}
# also ----> {'demonstrates': 1, 'not': 1, 'a': 1}
# demonstrates ----> {'how': 1}
# balance ----> {'set': 1}
# set ----> {'pieces': 1, 'apart': 1, 'itself': 1}
# pieces ----> {'against': 1}
# against ----> {'a': 1}
# triumph ----> {'for': 1}
# laika, ----> {'missing': 1}
# missing ----> {'link': 1}
# link ----> {'is': 1}
# treat ----> {'with': 1}
# lots ----> {'of': 1}
# plenty ----> {'of': 1}
# heart, ----> {'and': 1, 'shazam!': 1, 'but': 1}
# food ----> {'for': 1}
# admirably ----> {'eclectic': 1, 'ambitious': 1}
# eclectic ----> {'yet': 1}
# consistent ----> {'than': 1}
# anthologies, ----> {'nightmare': 1}
# nightmare ----> {'cinema': 1}
# entertain ----> {'viewers': 1}
# mood ----> {'for': 2}
# old-fashioned ----> {'creepshow.': 1}
# basis ----> {'of': 1}
# sex ----> {'is': 1}
# nowhere ----> {'near': 1}
# groundbreaking ----> {'as': 1}
# subject, ----> {'but': 2}
# extraordinary ----> {'life': 1}
# solid ----> {'case': 1}
# case ----> {'for': 2}
# itself ----> {'as': 1, 'apart': 1}
# inspirational, ----> {'well-acted': 1}
# well-acted ----> {'biopic.': 1}
# pavarotti ----> {'pays': 1}
# towering ----> {'cultural': 1}
# cultural ----> {'figure': 1}
# figure ----> {'with': 1}
# documentary ----> {'whose': 1}
# evident ----> {'affection': 1}
# affection ----> {'for': 1, 'with': 1}
# pet ----> {'sematary': 1}
# sematary ----> {'takes': 1}
# material ----> {'in': 1, 'and': 2}
# different ----> {'directions,': 1, 'setting,': 1}
# directions, ----> {'but': 1}
# feels ----> {'like': 1}
# exhuming ----> {'almost': 1}
# stylish ----> {'with': 1}
# sadistic ----> {'streak,': 1}
# streak, ----> {'piercing': 1}
# piercing ----> {'pairs': 1}
# pairs ----> {'gripping': 1}
# gripping ----> {'lead': 2, 'performances': 1}
# smartly ----> {'macabre': 1}
# macabre ----> {'story': 1}
# unpredictable ----> {'thrills.': 1, 'blend': 1}
# pledge ----> {'leaves': 1}
# leaves ----> {'a': 1}
# certain ----> {'amount': 1}
# amount ----> {'of': 1}
# untapped ----> {'in': 1}
# extreme ----> {'take': 1}
# take ----> {'on': 2, 'its': 1, 'pride': 1, 'the': 1}
# collegiate ----> {'hazing,': 1}
# hazing, ----> {'but': 1}
# result ----> {'is': 2, 'above': 1}
# well-executed ----> {'enough': 1}
# plus ----> {'one': 1}
# reinvigorates ----> {'the': 1}
# outing ----> {'elevated': 1, 'that': 2}
# leads ----> {'and': 1}
# embraces ----> {'and': 1}
# pokémon ----> {'detective': 1}
# detective ----> {'pikachu': 1}
# pikachu ----> {'may': 1}
# wonderfully ----> {'bizarre': 1}
# bizarre ----> {'premise': 1}
# premise ----> {'as': 1}
# far ----> {'as': 1, 'from': 2}
# could ----> {'have,': 1, 'stand': 1}
# have, ----> {'but': 1}
# offbeat ----> {'adaptation': 1}
# adaptation ----> {'should': 1}
# catch ----> {'most': 1}
# something ----> {'to': 1}
# cheer ----> {'about,': 1}
# about, ----> {'poms': 1}
# poms ----> {'squanders': 1}
# squanders ----> {'its': 1}
# disrespects ----> {'the': 1}
# demographic ----> {"it's": 1}
# trying ----> {'to': 1}
# fascinating ----> {'real-life': 1}
# dramatized ----> {'in': 1}
# perplexingly ----> {'dull': 1}
# dull ----> {'fashion,': 1}
# fashion, ----> {'red': 1}
# red ----> {'joan': 1}
# joan ----> {'wastes': 1}
# wastes ----> {'its': 1}
# tale's ----> {'incredible': 1}
# intrigue ----> {'--': 1}
# formidable ----> {'talents': 1}
# talents ----> {'of': 1}
# judi ----> {'dench.': 1}
# plot ----> {'holes': 1, 'robs': 1}
# holes ----> {'and': 1}
# unintentional ----> {'laughs,': 1}
# laughs, ----> {'replicas': 1}
# replicas ----> {'is': 1}
# ponderously ----> {'lame': 1}
# lame ----> {'sci-fi': 1}
# going ----> {'to': 1}
# long, ----> {'long': 1}
# biopic ----> {'manages': 1}
# manages ----> {'to': 1, 'the': 1}
# capture ----> {'the': 1}
# highs ----> {'and': 1}
# lows ----> {'of': 1}
# artist's ----> {'life': 1}
# rust ----> {'creek': 1}
# creek ----> {'subverts': 1, 'should': 1}
# subverts ----> {'expectations': 1}
# expectations ----> {'with': 1}
# surprisingly ----> {'layered': 1}
# anchored ----> {'in': 1}
# rich ----> {'setting': 1, 'folklore,': 1}
# setting ----> {'and': 1}
# hermione ----> {'corfield.': 1}
# high-concept ----> {'mystery': 1}
# mystery ----> {'with': 1}
# twist, ----> {'serenity': 1}
# serenity ----> {"isn't": 1}
# what ----> {'it': 3, 'men': 1}
# appears ----> {'to': 1}
# first ----> {'--': 1}
# anywhere ----> {'near': 1}
# clever ----> {'or': 1}
# filmed ----> {'and': 1}
# inventively ----> {'choreographed,': 1}
# shadow ----> {'is': 1}
# sumptuous ----> {'wuxia': 1}
# wuxia ----> {'epic': 1}
# zhang ----> {'yimou': 1}
# yimou ----> {'near': 1}
# peak ----> {'form.': 1}
# decades ----> {'removed': 1, 'past.': 1}
# removed ----> {'from': 1}
# original, ----> {'this': 2}
# multi-generational ----> {'shaft': 1}
# shaft ----> {'struggles': 1}
# characters ----> {'interesting': 1, 'and': 2, '-': 1}
# interesting ----> {'--': 1}
# anything ----> {'other': 1}
# other ----> {'than': 1, 'westerns': 1}
# uncomfortably ----> {'outdated.': 1}
# effortlessly ----> {'entertaining': 1}
# shazam! ----> {'is': 1}
# forgets ----> {'the': 1}
# genre's ----> {'real': 1}
# real ----> {'power:': 1}
# power: ----> {'joyous': 1}
# joyous ----> {'wish': 1}
# wish ----> {'fulfillment.': 1}
# skin ----> {'could': 1}
# stand ----> {'to': 1}
# go ----> {'a': 1}
# bit ----> {'deeper': 1}
# deeper ----> {'below': 1}
# below ----> {'its': 1}
# surface, ----> {'but': 1}
# worthy ----> {'story': 1, 'biopic,': 1}
# jamie ----> {'bell': 1}
# breezily ----> {'unpredictable': 1}
# teen ----> {'romance': 1, 'spirit': 1}
# romance ----> {'and': 1}
# spider-man: ----> {'far': 1}
# stylishly ----> {'sets': 1}
# sets ----> {'the': 1}
# stage ----> {'for': 1}
# next ----> {'era': 1}
# though ----> {'it': 1, 'its': 1}
# collaborations ----> {'between': 1}
# kumail ----> {'nanjiani': 1}
# nanjiani ----> {'and': 1}
# dave ----> {'bautista,': 1}
# bautista, ----> {'stuber': 1}
# stuber ----> {'fails': 1}
# mesh ----> {'its': 1}
# contrasting ----> {'genres,': 1}
# genres, ----> {'settling': 1}
# settling ----> {'for': 1}
# overtly ----> {'violent,': 1}
# violent, ----> {'mildly': 1}
# mildly ----> {'entertaining': 1}
# five-star ----> {'ride.': 1}
# expertly ----> {'drawn': 1}
# drawn ----> {'characters': 1, 'in': 1}
# senes ----> {'of': 1}
# humanity ----> {'make': 1}
# sword ----> {'of': 1}
# trust ----> {'an': 1}
# enjoyable ----> {'--': 1, 'new': 1}
# times ----> {'meandering': 1}
# meandering ----> {'--': 1}
# spirit ----> {'tells': 1}
# we ----> {'know': 1, 'have': 1}
# know ----> {'by': 1}
# max ----> {"minghella's": 1}
# minghella's ----> {'connection': 1}
# connection ----> {'to': 1}
# elle ----> {"fanning's": 1}
# fanning's ----> {'remarkable': 1}
# remarkable ----> {'performance': 1}
# add ----> {'an': 1}
# tasteful ----> {'to': 1}
# fault, ----> {'the': 1}
# aftermath ----> {'is': 1}
# seeking ----> {'out': 1}
# only ----> {'for': 1, 'because': 1, 'reinforce': 1, 'watch': 1}
# passionate ----> {'period': 1}
# art ----> {'of': 1}
# self-defense ----> {'grapples': 1}
# grapples ----> {'compellingly': 1}
# compellingly ----> {'with': 1}
# masculinity ----> {'--': 1}
# serves ----> {'as': 1}
# calling ----> {'card': 1}
# card ----> {'for': 1}
# riley ----> {'stearns.': 1}
# lifetime ----> {'for': 1}
# matthew ----> {'mcconaughey,': 1}
# mcconaughey, ----> {'the': 1}
# beach ----> {'bum': 1}
# bum ----> {'is': 1}
# harmony ----> {"korine's": 1}
# korine's ----> {'distinctive': 1}
# distinctive ----> {'style,': 1}
# style, ----> {'but': 1}
# offset ----> {'the': 1}
# unfocused ----> {'story.': 1, 'approach': 1}
# enemies ----> {'has': 1}
# intentions, ----> {'but': 1}
# they're ----> {'derailed': 1, 'less': 1}
# derailed ----> {'by': 1}
# problematic ----> {'perspective': 1}
# perspective ----> {'and': 2}
# boy ----> {'who': 1}
# who ----> {'harnessed': 1, 'would': 1, 'killed': 2}
# harnessed ----> {'the': 1}
# wind ----> {'earns': 1, 'offers': 1}
# earns ----> {'its': 1}
# impressive ----> {'work': 1, 'parts,': 1}
# debuting ----> {'director': 1}
# chiwetel ----> {'ejiofor.': 1}
# changeover ----> {'may': 1}
# deep ----> {'enough': 1}
# seasoned ----> {'horror': 1}
# spooky ----> {'enough': 1}
# younger ----> {'target': 1}
# target ----> {'demographic.': 1}
# content ----> {'to': 1}
# coast ----> {'on': 1}
# rather ----> {'than': 1}
# tap ----> {'into': 1}
# story's ----> {'creepy': 1}
# creepy ----> {'potential,': 1}
# potential, ----> {'the': 1}
# curse ----> {'of': 1}
# la ----> {'llorona': 1}
# llorona ----> {'arrives': 1}
# arrives ----> {'in': 1}
# theaters ----> {'already': 1}
# already ----> {'broken.': 1}
# dead ----> {"don't": 1}
# don't ----> {'die': 1}
# die ----> {'dabbles': 1}
# dabbles ----> {'with': 1}
# tones ----> {'and': 1}
# varying ----> {'degrees': 1}
# degrees ----> {'of': 1}
# success, ----> {'but': 1}
# wit ----> {'and': 1}
# zom-com ----> {'with': 1}
# brains ----> {'to': 1}
# travolta ----> {'gives': 1}
# gives ----> {'it': 1}
# oddly ----> {'coiffed': 1}
# coiffed ----> {'all,': 1}
# all, ----> {'but': 1}
# fanatic ----> {'rings': 1}
# rings ----> {'hollow': 1}
# hollow ----> {'as': 1}
# examination ----> {'of': 1}
# fan ----> {'appreciation': 1}
# appreciation ----> {'can': 1}
# can ----> {'curdle': 1, 'take': 1, 'be': 1, 'work': 1, 'still': 1}
# curdle ----> {'into': 1}
# toxic ----> {'obsession.': 1}
# chillingly ----> {'effective': 1}
# rooted ----> {'in': 1}
# folklore, ----> {'the': 1}
# golem ----> {'blends': 1}
# blends ----> {'centuries-old': 1}
# centuries-old ----> {'stories': 1}
# stories ----> {'with': 1}
# great ----> {'hack': 1}
# hack ----> {'offers': 1}
# alarming ----> {'glimpse': 1}
# data ----> {'is': 1}
# being ----> {'weaponized': 1}
# weaponized ----> {'for': 1}
# gain ----> {'--': 1}
# mean ----> {'for': 1}
# haunting ----> {'of': 1}
# sharon ----> {'tate': 1}
# tate ----> {'dishonors': 1}
# dishonors ----> {'the': 1}
# events ----> {'it': 1, 'that': 1}
# seeks ----> {'to': 1}
# dramatize ----> {'with': 1}
# poorly ----> {'acted': 1}
# acted ----> {'and': 1}
# offensively ----> {'exploitative': 1}
# exploitative ----> {'take': 1}
# highwaymen ----> {'depicts': 1}
# depicts ----> {'law': 1}
# law ----> {"enforcement's": 1}
# enforcement's ----> {'side': 1}
# side ----> {'of': 2}
# bonnie ----> {'and': 1}
# clyde ----> {'manhunt': 1}
# manhunt ----> {'--': 1}
# unfortunately ----> {'not': 1}
# marquee ----> {'leads.': 1}
# hole ----> {'in': 1}
# ground ----> {'artfully': 1}
# exploits ----> {'parental': 1}
# parental ----> {'fears': 1}
# fears ----> {'with': 1}
# effectiveness ----> {'what': 1}
# underlying ----> {'themes': 1}
# familiar, ----> {'house': 1}
# devil ----> {'effectively': 1}
# effectively ----> {'sheds': 1}
# sheds ----> {'the': 1}
# loud ----> {'and': 1}
# gory ----> {'cliches': 1}
# cliches ----> {'of': 1}
# contemporary ----> {'horror': 1}
# tense, ----> {'slowly': 1}
# slowly ----> {'building': 1}
# building ----> {'throwback': 1}
# throwback ----> {'to': 1}
# fright ----> {'flicks': 1}
# flicks ----> {'of': 1}
# well-acted, ----> {'the': 1}
# hummingbird ----> {'project': 1}
# project ----> {'marks': 1}
# flawed ----> {'yet': 1}
# undeniably ----> {'intriguing': 1}
# intriguing ----> {'addition': 1, '--': 1}
# addition ----> {'to': 2}
# kim ----> {"nguyen's": 1}
# nguyen's ----> {'filmography.': 1}
# hustle's ----> {'stars': 1}
# team ----> {'in': 1}
# setting, ----> {'but': 1, 'and': 1}
# gender-flipped ----> {'remake': 1}
# beyond ----> {'its': 1}
# feminine ----> {'twist.': 1}
# intruder ----> {'might': 1}
# appeal ----> {'to': 1}
# shout-at-the-screen ----> {'cinema,': 1}
# cinema, ----> {'but': 1}
# thriller's ----> {'ludicrous': 1}
# ludicrous ----> {'plot': 1}
# robs ----> {'it': 1}
# undermines ----> {'dennis': 1}
# dennis ----> {"quaid's": 1}
# quaid's ----> {'suitably': 1}
# suitably ----> {'over-the-top': 1}
# well-framed, ----> {'well-cast,': 1}
# well-cast, ----> {'and': 1}
# well-intentioned, ----> {'the': 1}
# kid ----> {'still': 1, 'who': 1}
# multitude ----> {'of': 1}
# westerns ----> {'covering': 1}
# covering ----> {'similar': 1}
# similar ----> {'territory.': 1}
# would ----> {'be': 1}
# recalls ----> {'classic': 1}
# all-ages ----> {'adventures': 1, 'franchise': 1}
# adventures ----> {'--': 1}
# repurposes ----> {'a': 1}
# timeless ----> {'legend': 1}
# legend ----> {'--': 1}
# sometimes ----> {'less': 1, 'easier': 1}
# parts, ----> {'strong': 1}
# powerfully ----> {'told,': 1}
# told, ----> {'the': 1}
# last ----> {'black': 1}
# black ----> {'man': 1}
# man ----> {'in': 1, 'who': 2}
# san ----> {'francisco': 1}
# francisco ----> {'immediately': 1}
# immediately ----> {'establishes': 1, 'clear,': 1}
# establishes ----> {'director': 1}
# joe ----> {'talbot': 1}
# talbot ----> {'as': 1}
# filmmaker ----> {'to': 1, 'in': 1}
# laundromat ----> {'misuses': 1}
# misuses ----> {'its': 1}
# blunt ----> {'and': 1}
# approach ----> {'to': 3}
# inspired ----> {'it.': 1}
# lego ----> {'movie': 1}
# 2: ----> {'the': 1}
# part ----> {'fits': 1, 'to': 1}
# fits ----> {'neatly': 1}
# neatly ----> {'into': 1}
# pride ----> {'in': 1}
# achievements,the ----> {'lion': 1}
# lion ----> {'king': 1}
# by-the-numbers ----> {'retelling': 1}
# retelling ----> {'that': 1}
# beloved--though ----> {'for': 1}
# killed ----> {'don': 1, 'hitler': 1}
# don ----> {'quixote': 1}
# quixote ----> {'may': 1}
# live ----> {'up': 1}
# expectations, ----> {'but': 1}
# bears ----> {'enough': 1}
# terry ----> {"gilliam's": 1}
# gilliam's ----> {'signature': 1}
# creative ----> {'stamp': 1}
# stamp ----> {'to': 1}
# satisfy ----> {'fans.': 1, 'suspense': 1}
# hitler ----> {'and': 1}
# then ----> {'the': 1}
# bigfoot ----> {'just': 1}
# about ----> {'lives': 1, 'sticks': 1}
# lives ----> {'up': 2}
# wild ----> {'promise': 1, 'rose': 1}
# due ----> {'in': 1}
# small ----> {'part': 1}
# sam ----> {"elliott's": 1}
# elliott's ----> {'world-weary': 1}
# world-weary ----> {'work': 1}
# mustang ----> {'finds': 1}
# perspectives ----> {'in': 1}
# redemption ----> {'tale': 1}
# brought ----> {'brilliantly': 1}
# bruce ----> {'dern': 1}
# dern ----> {'and': 1}
# matthias ----> {'schoenaerts.': 1}
# prodigy ----> {"doesn't": 1}
# seed ----> {'genre': 1}
# any ----> {'truly': 1, 'new': 1}
# places, ----> {'but': 1}
# child ----> {'to': 1}
# fear, ----> {'it': 1}
# muddled ----> {'story': 1}
# populated ----> {'with': 1}
# thinly ----> {'written': 1}
# written ----> {'characters': 1}
# arranged ----> {'around': 1}
# around ----> {'a': 1}
# misguided ----> {'johnny': 1}
# johnny ----> {'depp': 1}
# depp ----> {'performance,': 1}
# performance, ----> {'the': 1}
# professor ----> {'fails': 1}
# early ----> {'and': 1}
# intentions ----> {'are': 1}
# easier ----> {'to': 1}
# appreciate ----> {'than': 1}
# execution, ----> {'but': 1}
# public ----> {'remains': 1}
# earnest ----> {'and': 1}
# engaging ----> {'social': 1}
# advocacy ----> {'drama.': 1}
# secret ----> {'life': 1}
# pets ----> {'2': 1}
# 2 ----> {"doesn't": 1}
# teach ----> {'its': 1}
# tricks ----> {'--': 1}
# energetic ----> {'sequel': 1}
# command ----> {'of': 1}
# craft ----> {'and': 1}
# perfectly ----> {'matched': 1}
# matched ----> {'with': 1}
# material, ----> {'the': 1}
# souvenir ----> {'is': 1}
# uniquely ----> {'impactful': 1}
# impactful ----> {'coming': 1}
# taut ----> {'and': 1}
# unpredictable, ----> {'the': 1}
# standoff ----> {'at': 1}
# sparrow ----> {'creek': 1}
# well-told ----> {'story': 1}
# topped ----> {'with': 1}
# generous ----> {'helping': 1}
# helping ----> {'of': 1}
# sun ----> {'is': 1}
# easy-to-love ----> {'leads,': 1}
# tests ----> {'the': 1}
# audience's ----> {'affection': 1}
# storyline ----> {'that': 1}
# strains ----> {'credulity': 1}
# credulity ----> {'past': 1}
# preachy, ----> {'manipulative,': 1}
# manipulative, ----> {'and': 1}
# frustratingly ----> {'clichéd,': 1}
# clichéd, ----> {'the': 1}
# upside ----> {'showcases': 1}
# showcases ----> {'bryan': 1}
# bryan ----> {'cranston': 1}
# cranston ----> {'and': 1}
# kevin ----> {"hart's": 1}
# hart's ----> {'chemistry': 1}
# without ----> {'ever': 1}
# ever ----> {'taking': 1}
# full ----> {'advantage': 1}
# advantage ----> {'of': 1}
# suspenseful ----> {'atmosphere,': 1}
# atmosphere, ----> {'an': 1}
# evocative ----> {'setting,': 1}
# invested ----> {'throughout': 1}
# throughout ----> {'the': 1}
# vanishing's ----> {'patient': 1}
# patient ----> {'approach': 1}
# unraveling ----> {'its': 1}
# crow ----> {'lacks': 1}
# nimble ----> {'grace': 1}
# grace ----> {'of': 1}
# primer ----> {'on': 1}
# brilliant ----> {'artist,': 1}
# artist, ----> {'it': 1}
# sticks ----> {'the': 1}
# imperfect ----> {'yet': 1}
# intriguing, ----> {'the': 1}
# distinguished ----> {'by': 1}
# tolkien ----> {'has': 1}
# trappings ----> {'and': 1}
# biopic, ----> {'but': 1}
# imagination ----> {'required': 1}
# required ----> {'to': 1}
# do ----> {'its': 1}
# heartwarming, ----> {'funny,': 1}
# animated, ----> {'toy': 1}
# toy ----> {'story': 1}
# 4 ----> {'manages': 1}
# unlikely ----> {'feat': 1}
# feat ----> {'of': 1}
# extending ----> {'--': 1}
# perhaps ----> {'concluding': 1}
# concluding ----> {'--': 1}
# practically ----> {'perfect': 1}
# perfect ----> {'animated': 1}
# transit ----> {'lives': 1}
# challenging ----> {'drama': 1}
# captures ----> {'characters': 1}
# audience ----> {'-': 1}
# state ----> {'of': 1}
# flux ----> {'and': 1}
# exerts ----> {'an': 1}
# unsettling ----> {'pull.': 1}
# help ----> {'triple': 1}
# triple ----> {'frontier': 1, 'threat': 1}
# frontier ----> {'overcome': 1}
# elevate ----> {'the': 1}
# field ----> {'of': 1}
# gritty ----> {'heist': 1}
# threat ----> {'might': 1}
# better ----> {'use': 1}
# attention-getting ----> {'cast,': 1}
# cast, ----> {'but': 1}
# results ----> {'entertaining': 1}
# rate ----> {'a': 1}
# lackluster ----> {'conclusion': 1}
# tyler ----> {"perry's": 1}
# perry's ----> {'long-running': 1}
# franchise, ----> {'a': 1}
# madea ----> {'family': 1}
# funeral ----> {'proves': 1}
# saying ----> {'goodbye': 1}
# goodbye ----> {'can': 1}
# painful ----> {'for': 1}
# wrong ----> {'reasons.': 1}
# very ----> {'young': 1}
# young ----> {'viewers': 1}
# entertained ----> {'by': 1}
# uglydolls ----> {'--': 1}
# because ----> {"they're": 1}
# likely ----> {'to': 1}
# recognize ----> {'the': 1}
# affirmative ----> {'yet': 1}
# formulaic ----> {'story.': 1}
# under ----> {'the': 1}
# silver ----> {'lake': 1}
# lake ----> {'hits': 1}
# stride ----> {'slightly': 1}
# slightly ----> {'more': 1}
# stumbles, ----> {'but': 1}
# admire ----> {'-': 1}
# david ----> {'robert': 1}
# robert ----> {"mitchell's": 1}
# mitchell's ----> {'ambition.': 1}
# it'll ----> {'be': 1}
# enjoyed ----> {'by': 1}
# tolerance ----> {'for': 1}
# whimsy, ----> {'but': 1}
# unicorn ----> {'store': 1}
# store ----> {'is': 1}
# easy ----> {'to': 2}
# brie ----> {'larson': 1}
# larson ----> {'has': 1}
# dramatic ----> {'approach': 1}
# hot-button ----> {'topic': 1}
# topic ----> {'whose': 1}
# agenda ----> {'is': 1}
# clear, ----> {'unplanned': 1}
# unplanned ----> {'will': 1}
# reinforce ----> {'the': 1}
# feelings ----> {'of': 1}
# either ----> {'side': 1}
# jordan ----> {"peele's": 1}
# peele's ----> {'second': 1}
# inventive, ----> {'ambitious': 1}
# film, ----> {'we': 1}
# beat ----> {'the': 1}
# sophomore ----> {'jinx,': 1}
# jinx, ----> {'and': 1}
# you ----> {'only': 1}
# watch ----> {'one': 1}
# art-world ----> {'satire': 1}
# satire ----> {'with': 1}
# overtones ----> {'this': 1}
# year ----> {'--': 1}
# others ----> {'--': 1}
# probably ----> {'be': 1}
# velvet ----> {'buzzsaw.': 1}
# admittedly ----> {'uneven': 1}
# like, ----> {'what': 1}
# men ----> {'want': 1}
# want ----> {'proves': 1}
# gender-swapped ----> {'remake': 1}
# odds ----> {'are': 1}
# substantially ----> {'improved': 1}
# improved ----> {'with': 1}
# taraji ----> {'p.': 1}
# p. ----> {'henson': 1}
# henson ----> {'in': 1}
# shortage ----> {'of': 1}
# star-is-born ----> {'stories,': 1}
# stories, ----> {'but': 1}
# rose ----> {'proves': 1}
# they ----> {'can': 1}
# transcendent ----> {'moment': 1}
# moment ----> {'for': 1}
# jessie ----> {'buckley.': 1}
# wine ----> {"country's": 1}
# country's ----> {'comedy': 1}
# robust ----> {'as': 1}
# got ----> {'sweetness': 1}
# sweetness ----> {'on': 1}
# nose ----> {'and': 1}
# nicely ----> {'balanced': 1}
# yesterday ----> {'may': 1}
# fall ----> {'short': 1}
# short ----> {'of': 1}
# fab, ----> {'but': 1}
# sweetly ----> {'charming': 1}
# charming ----> {'fantasy': 1}
# fantasy ----> {'with': 1}
# albeit ----> {'somewhat': 1}
# under-explored ----> {'--': 1}

# %%
transition_matrix = {}

for current_word, next_words in transitions.items():

    total = sum(next_words.values())

    transition_matrix[current_word] = {

        next_word:count/total for next_word, count in next_words.items()
    }

next_words.items()
# Out:
# dict_items([('--', 1)])

# %%
current = 'thriller'

if current in transition_matrix:

    next_words = transition_matrix[current]

    sorted_next = sorted(next_words.items(), key=lambda x:x[1], reverse=True)

    print(f"Most likely next word(s) after '{current}' : ")

    for word, prob in sorted_next:

        print(f"{word} ----> {prob}")

else:

    print(f"The word '{current}' was not found in the transition matrix. ")
# Out:
# Most likely next word(s) after 'thriller' :
# that ----> 0.2
# doesn't ----> 0.2
# may ----> 0.2
# -- ----> 0.2
# from ----> 0.2

# %%
def calculate_entropy(transition_matrix):

    entropy = {}

    for current_word, next_probs in transition_matrix.items():

        entropy[current_word] = -sum(p*np.log2(p) for p in next_probs.values() if p > 0)

    return entropy

entropy = calculate_entropy(transition_matrix)

print("Entropy for each word : ")

for word, H in entropy.items():

    print(f"{word} ----> {H}")
# Out:
# Entropy for each word :
# a ----> 6.838869969720591
# dog's ----> 1.0
# journey ----> -0.0
# is ----> 4.266764026202947
# as ----> 4.335970858598519
# sentimental ----> -0.0
# one ----> 2.321928094887362
# might ----> 2.807354922057604
# expect, ----> -0.0
# but ----> 4.663320189106002
# even ----> 2.2516291673878226
# cynical ----> -0.0
# viewers ----> 2.2359263506290326
# may ----> 2.999581230646064
# find ----> 2.321928094887362
# their ----> 1.0
# ability ----> -0.0
# to ----> 5.5569576083772985
# resist ----> 1.0
# shedding ----> -0.0
# tear ----> -0.0
# stretched ----> -0.0
# the ----> 6.970627692490496
# puppermost ----> -0.0
# way ----> 2.0
# home ----> 1.584962500721156
# not ----> 3.418295834054489
# quite ----> 0.7219280948873623
# be ----> 3.94770277922009
# family-friendly ----> -0.0
# animal ----> -0.0
# drama ----> 2.75
# fan's ----> -0.0
# best ----> 1.9219280948873623
# friend, ----> -0.0
# this ----> 4.165894208390023
# canine ----> -0.0
# adventure ----> -0.0
# no ----> 2.321928094887362
# less ----> 1.9219280948873623
# heartwarming ----> -0.0
# for ----> 4.454636150748477
# its ----> 5.94668620538314
# led ----> -0.0
# by ----> 4.152492594515677
# olivia ----> -0.0
# wilde's ----> -0.0
# fearless ----> -0.0
# performance ----> 2.4056390622295662
# and ----> 5.857225337483041
# elevated ----> 0.7219280948873623
# timely ----> 1.5
# themes, ----> -0.0
# vigilante ----> -0.0
# an ----> 4.8887896794220005
# uncompromising ----> -0.0
# thriller ----> 2.321928094887362
# that ----> 4.43063240949075
# hits ----> 0.9182958340544896
# hard ----> 2.0
# tepid ----> -0.0
# tired, ----> -0.0
# after's ----> -0.0
# fun ----> 2.0
# flourishes ----> -0.0
# are ----> 2.584962500721156
# let ----> -0.0
# down ----> 0.9182958340544896
# generic ----> -0.0
# aladdin ----> -0.0
# retells ----> -0.0
# classic ----> 1.584962500721156
# source ----> 0.9182958340544896
# material's ----> -0.0
# story ----> 4.0994705707972505
# with ----> 3.891853096329677
# sufficient ----> -0.0
# spectacle ----> -0.0
# skill, ----> -0.0
# if ----> 2.1556390622295662
# it ----> 4.8711781263822145
# never ----> 1.0
# approaches ----> 0.9182958340544896
# dazzling ----> 1.0
# splendor ----> -0.0
# of ----> 5.227227062184885
# animated ----> 2.321928094887362
# alita: ----> -0.0
# battle ----> -0.0
# angel's ----> -0.0
# struggles ----> -0.0
# keep ----> 2.0
# up ----> 1.2516291673878228
# special ----> -0.0
# effects, ----> -0.0
# fans ----> 2.463458298648303
# futuristic ----> -0.0
# sci-fi ----> 2.0
# action ----> 3.169925001442312
# still ----> 3.180832987205441
# themselves ----> -0.0
# more ----> 2.5216406363433186
# than ----> 3.277613436819116
# sufficiently ----> -0.0
# impressively ----> 1.0
# cast ----> 2.94770277922009
# beautifully ----> 2.0
# filmed, ----> -0.0
# all ----> 2.584962500721156
# true ----> 1.0
# takes ----> 2.321928094887362
# elegiac ----> -0.0
# look ----> -0.0
# at ----> 2.6416041678685933
# shakespeare's ----> -0.0
# final ----> -0.0
# carried ----> -0.0
# infectious ----> -0.0
# charms ----> -0.0
# ali ----> -0.0
# wong ----> -0.0
# randall ----> -0.0
# park, ----> -0.0
# always ----> 1.0
# my ----> 2.0
# maybe ----> -0.0
# familiar ----> 2.321928094887362
# rom-com ----> 0.9182958340544896
# beats ----> -0.0
# cleverly ----> -0.0
# layers ----> -0.0
# in ----> 3.7191821684284743
# smart ----> 1.584962500721156
# social ----> 1.0
# commentary ----> -0.0
# own ----> 1.0
# sweet ----> -0.0
# american ----> 1.584962500721156
# factory ----> -0.0
# thoughtful ----> -0.0
# -- ----> 3.4341803798402077
# troubling ----> -0.0
# dynamic ----> -0.0
# between ----> 1.0
# workers ----> -0.0
# employers ----> -0.0
# 21st-century ----> -0.0
# globalized ----> -0.0
# anna ----> -0.0
# finds ----> 1.5
# writer-director ----> 3.169925001442312
# luc ----> -0.0
# besson ----> -0.0
# squarely ----> -0.0
# his ----> 2.0
# wheelhouse, ----> -0.0
# variety ----> -0.0
# stylized ----> -0.0
# have ----> 1.9219280948873623
# seen ----> 1.0
# done ----> -0.0
# before ----> 1.584962500721156
# isn't ----> 2.75
# frightening ----> -0.0
# some ----> 2.584962500721156
# predecessors, ----> -0.0
# annabelle ----> -0.0
# comes ----> -0.0
# suggests ----> 2.0
# there's ----> 1.0
# life ----> 2.521640636343318
# left ----> 1.584962500721156
# conjuring ----> -0.0
# edifying ----> -0.0
# inspiring ----> -0.0
# equal ----> 1.0
# measure, ----> -0.0
# apollo ----> -0.0
# 11 ----> -0.0
# uses ----> 1.0
# artfully ----> 1.0
# repurposed ----> -0.0
# archival ----> -0.0
# footage ----> -0.0
# send ----> -0.0
# audiences ----> 2.251629167387823
# soaring ----> -0.0
# back ----> 1.0
# pivotal ----> 1.584962500721156
# time ----> 1.0
# arctic ----> -0.0
# proves ----> 2.584962500721156
# good ----> 2.0
# survival ----> 1.0
# doesn't ----> 2.584962500721156
# need ----> -0.0
# much ----> 2.0
# dialogue ----> -0.0
# get ----> -0.0
# especially ----> -0.0
# when ----> -0.0
# mads ----> -0.0
# mikkelsen ----> -0.0
# doing ----> -0.0
# ash ----> -0.0
# purest ----> -0.0
# white ----> 1.0
# zhangke ----> -0.0
# jia ----> -0.0
# revisiting ----> -0.0
# themes ----> 2.251629167387823
# while ----> 1.5219280948873621
# continuing ----> -0.0
# observe ----> -0.0
# modern ----> 1.0
# chinese ----> -0.0
# society ----> -0.0
# urgent, ----> -0.0
# empathetic ----> -0.0
# exciting, ----> -0.0
# entertaining, ----> -0.0
# emotionally ----> 1.0
# impactful, ----> -0.0
# avengers: ----> -0.0
# endgame ----> -0.0
# does ----> 1.584962500721156
# whatever ----> -0.0
# deliver ----> 0.9182958340544896
# satisfying ----> 1.0
# finale ----> -0.0
# marvel's ----> -0.0
# epic ----> 1.0
# infinity ----> -0.0
# fast-paced, ----> -0.0
# funny, ----> 0.9182958340544896
# fresh, ----> -0.0
# booksmart ----> -0.0
# seemingly ----> -0.0
# impossible ----> -0.0
# adding ----> -0.0
# new ----> 2.321928094887362
# spin ----> 0.9182958340544896
# coming-of-age ----> -0.0
# like ----> 2.584962500721156
# lead ----> 2.0
# character, ----> -0.0
# breakthrough ----> -0.0
# fiercely ----> -0.0
# focused ----> -0.0
# on ----> 3.1462863706621045
# faith ----> -0.0
# subtle ----> -0.0
# elements ----> 1.0
# balanced ----> 1.0
# strong ----> 2.1556390622295662
# performances ----> 2.2516291673878226
# uplifting ----> 1.0
# although ----> -0.0
# brightburn ----> -0.0
# fully ----> 1.0
# pitch-black ----> -0.0
# promise ----> -0.0
# setup, ----> -0.0
# it's ----> 3.169925001442312
# enough ----> 2.0349409139562287
# offer ----> -0.0
# diverting ----> 1.584962500721156
# subversion ----> -0.0
# superhero ----> 2.321928094887362
# packed ----> -0.0
# action, ----> 1.0
# humor, ----> 1.0
# visual ----> 2.321928094887362
# thrills, ----> -0.0
# captain ----> -0.0
# marvel ----> -0.0
# introduces ----> -0.0
# mcu's ----> -0.0
# latest ----> -0.0
# hero ----> -0.0
# origin ----> -0.0
# makes ----> 2.251629167387823
# effective ----> 2.807354922057604
# use ----> -0.0
# franchise's ----> 1.584962500721156
# signature ----> 1.0
# necessarily ----> -0.0
# leave ----> 1.584962500721156
# captive ----> -0.0
# state, ----> -0.0
# offers ----> 1.5
# reasonably ----> 1.5
# alien ----> -0.0
# invasion ----> -0.0
# ambitious ----> 1.5
# political ----> 1.584962500721156
# charlie ----> -0.0
# says ----> -0.0
# infamous ----> -0.0
# subject ----> 1.584962500721156
# from ----> 3.057476076289932
# welcome ----> -0.0
# angle, ----> -0.0
# suffers ----> -0.0
# disappointing ----> 1.5
# lack ----> -0.0
# depth ----> 1.0
# treatment ----> -0.0
# child's ----> -0.0
# play ----> -0.0
# updates ----> -0.0
# '80s ----> -0.0
# horror ----> 3.334679141051595
# icon ----> -0.0
# internet ----> -0.0
# things ----> -0.0
# era, ----> -0.0
# predictably ----> 1.0
# gruesome ----> -0.0
# generally ----> -0.0
# entertaining ----> 3.2776134368191165
# cold ----> -0.0
# pursuit ----> -0.0
# delivers ----> 1.584962500721156
# expect ----> -0.0
# liam ----> -0.0
# neeson ----> -0.0
# along ----> -0.0
# humor ----> 0.9182958340544896
# sophisticated ----> -0.0
# streak ----> -0.0
# make ----> 2.0
# uncommonly ----> -0.0
# action-packed ----> 1.0
# creature ----> -0.0
# feature ----> -0.0
# that's ----> 2.0
# fast, ----> -0.0
# terrifying, ----> -0.0
# benefits ----> 1.0
# greatly ----> -0.0
# completely ----> 1.0
# game ----> -0.0
# kaya ----> -0.0
# scodelario, ----> -0.0
# crawl ----> -0.0
# throw-back ----> -0.0
# just ----> 2.2516291673878226
# self-awareness ----> -0.0
# dark ----> -0.0
# phoenix ----> -0.0
# ends ----> -0.0
# era ----> -0.0
# x-men ----> -0.0
# franchise ----> 2.321928094887362
# taking ----> 0.9182958340544896
# second ----> 1.584962500721156
# stab ----> -0.0
# adapting ----> -0.0
# comics ----> -0.0
# arc ----> 1.0
# deeply ----> 1.0
# dramatizing ----> 1.0
# rudy ----> -0.0
# ray ----> -0.0
# moore's ----> 1.0
# stranger-than-fiction ----> -0.0
# story, ----> -0.0
# eddie ----> -0.0
# murphy ----> -0.0
# dolemite ----> -0.0
# name ----> -0.0
# bold, ----> -0.0
# brash, ----> -0.0
# ultimately ----> 1.584962500721156
# grim ----> 0.9182958340544896
# grinding ----> -0.0
# title, ----> 1.0
# dragged ----> -0.0
# across ----> -0.0
# concrete ----> -0.0
# opts ----> -0.0
# slow-burning ----> -0.0
# instead ----> -0.0
# high-speed ----> -0.0
# thrills ----> -0.0
# has ----> 1.8423709931771084
# right ----> -0.0
# dragon ----> -0.0
# ball ----> -0.0
# super: ----> -0.0
# broly ----> -0.0
# seem ----> -0.0
# colorful ----> 1.0
# chaos ----> 1.0
# newcomers, ----> -0.0
# longtime ----> -0.0
# fans, ----> 1.0
# represents ----> 1.0
# long-running ----> 1.0
# near ----> 1.5
# dumbo ----> -0.0
# held ----> -0.0
# partly ----> -0.0
# aloft ----> -0.0
# tim ----> -0.0
# burton's ----> -0.0
# flair, ----> -0.0
# crowded ----> 1.0
# canvas ----> -0.0
# overstretched ----> -0.0
# live-action ----> -0.0
# remake ----> 2.321928094887362
# workmanlike ----> -0.0
# thoroughly ----> 0.9182958340544896
# laurel ----> -0.0
# canyon ----> 1.0
# scene ----> 1.0
# well ----> 0.9182958340544896
# musical ----> -0.0
# history ----> -0.0
# surrounding ----> -0.0
# it, ----> -0.0
# echo ----> -0.0
# essential ----> -0.0
# viewing ----> 1.0
# rock ----> 1.0
# doc ----> -0.0
# essential, ----> -0.0
# el ----> 1.0
# camino ----> -0.0
# adds ----> 1.0
# belated ----> -0.0
# coda ----> -0.0
# breaking ----> 1.0
# bad ----> 2.321928094887362
# career-best ----> -0.0
# aaron ----> -0.0
# chicano ----> -0.0
# step ----> 1.0
# forward ----> -0.0
# representation ----> -0.0
# cinema ----> 1.0
# unfortunately, ----> 1.5
# clichéd ----> 1.0
# nothing ----> -0.0
# intermittently ----> -0.0
# wholly ----> -0.0
# successful, ----> -0.0
# eli ----> -0.0
# handful ----> -0.0
# jump ----> -0.0
# scares ----> 1.0
# search ----> -0.0
# truly ----> 1.584962500721156
# terrifying ----> -0.0
# escape ----> -0.0
# room ----> -0.0
# fails ----> 0.8112781244591328
# unlock ----> -0.0
# potential ----> 1.584962500721156
# premise, ----> -0.0
# what's ----> -0.0
# tense ----> -0.0
# thrilling ----> 1.0
# passing ----> -0.0
# diversion ----> 1.0
# suspense ----> 1.584962500721156
# everybody ----> -0.0
# knows ----> -0.0
# somewhat ----> 1.0
# sum ----> -0.0
# parts ----> 1.0
# despite ----> 1.0
# efforts ----> 0.9182958340544896
# outstanding ----> 0.9182958340544896
# - ----> 2.5216406363433186
# asghar ----> -0.0
# extremely ----> -0.0
# wicked, ----> -0.0
# shockingly ----> -0.0
# evil ----> 1.0
# vile ----> -0.0
# often ----> 1.584962500721156
# transcends ----> 1.0
# narrative ----> 2.0
# limitations ----> -0.0
# through ----> 1.584962500721156
# sheer ----> 1.0
# force ----> -0.0
# zac ----> -0.0
# efron's ----> -0.0
# compulsively ----> -0.0
# watchable ----> -0.0
# hobbs ----> -0.0
# & ----> -0.0
# shaw ----> -0.0
# rev ----> -0.0
# high ----> 1.584962500721156
# installments, ----> -0.0
# gets ----> -0.0
# decent ----> -0.0
# mileage ----> -0.0
# out ----> 0.9182958340544896
# well-matched ----> 1.584962500721156
# stars ----> 2.0
# over-the-top ----> 0.9182958340544896
# grounded ----> -0.0
# mind ----> -0.0
# punching ----> -0.0
# guys, ----> -0.0
# fast ----> -0.0
# color ----> -0.0
# leaps ----> -0.0
# over ----> 1.0
# uneven ----> 1.9219280948873623
# execution ----> -0.0
# single ----> -0.0
# gugu ----> -0.0
# mbatha-raw ----> -0.0
# sport ----> -0.0
# celebrates, ----> -0.0
# fighting ----> -0.0
# family ----> 1.584962500721156
# muscles ----> -0.0
# past ----> 1.0
# clichés ----> -0.0
# potent ----> -0.0
# blend ----> -0.0
# energy ----> -0.0
# committed ----> 1.0
# acting ----> -0.0
# should ----> 2.75
# considerably ----> -0.0
# haley ----> -0.0
# lu ----> -0.0
# richardson's ----> -0.0
# bogged ----> -0.0
# clichés, ----> -0.0
# five ----> -0.0
# feet ----> -0.0
# apart ----> 1.584962500721156
# tug ----> -0.0
# heartstrings ----> -0.0
# deftly ----> -0.0
# giant ----> -0.0
# little ----> 2.584962500721156
# ones ----> -0.0
# puts ----> 1.0
# complex ----> 1.0
# refreshingly ----> -0.0
# nuanced ----> -0.0
# traditional ----> -0.0
# coming ----> -0.0
# age ----> 1.0
# drama, ----> -0.0
# further ----> 2.0
# admirable ----> -0.0
# talented ----> 1.584962500721156
# girl ----> -0.0
# aspiring ----> -0.0
# dancer's ----> -0.0
# framework ----> -0.0
# poignant ----> -0.0
# difficult ----> -0.0
# fittingly ----> -0.0
# alluring ----> -0.0
# glass ----> -0.0
# displays ----> -0.0
# few ----> 1.0
# glimmers ----> -0.0
# m. ----> -0.0
# night ----> -0.0
# shyamalan ----> -0.0
# twisty ----> -0.0
# world-building ----> -0.0
# best, ----> -0.0
# disappoints ----> -0.0
# conclusion ----> -0.0
# writer-director's ----> -0.0
# long-gestating ----> 1.0
# free ----> -0.0
# or ----> 2.807354922057604
# embellishments, ----> -0.0
# gloria ----> -0.0
# bell ----> 1.0
# rests ----> -0.0
# almost ----> 1.0
# julianne ----> -0.0
# title ----> 1.584962500721156
# role ----> 1.0
# she's ----> -0.0
# gloriously ----> -0.0
# godzilla: ----> -0.0
# king ----> 1.5219280948873621
# monsters ----> -0.0
# spectacular ----> -0.0
# kaiju ----> -0.0
# reaffirms ----> -0.0
# cutting-edge ----> -0.0
# effects ----> -0.0
# substitute ----> -0.0
# bonkers ----> -0.0
# b ----> -0.0
# movie ----> 2.321928094887362
# occasionally ----> -0.0
# a-list ----> -0.0
# talent, ----> -0.0
# greta ----> -0.0
# dives ----> -0.0
# headlong ----> -0.0
# into ----> 2.584962500721156
# camp ----> -0.0
# stay ----> -0.0
# gwen's ----> -0.0
# relentlessly ----> -0.0
# outlook ----> -0.0
# wear ----> -0.0
# viewers, ----> -0.0
# remains ----> 0.9182958340544896
# gripping, ----> -0.0
# solidly ----> -0.0
# assembled ----> -0.0
# descent ----> -0.0
# atmospheric ----> -0.0
# period ----> 1.9219280948873623
# hampstead ----> -0.0
# plays ----> -0.0
# matchmaker ----> -0.0
# pair ----> -0.0
# veterans, ----> -0.0
# overcome ----> 1.0
# mediocre ----> -0.0
# funnier ----> -0.0
# follow-up ----> -0.0
# bent, ----> -0.0
# happy ----> -0.0
# death ----> -0.0
# day ----> -0.0
# 2u ----> -0.0
# fiendishly ----> -0.0
# fresh ----> 1.584962500721156
# predecessor, ----> 1.0
# original ----> 1.0
# sequel ----> 1.0
# worth ----> 1.7924812503605778
# bereft ----> -0.0
# imaginative ----> -0.0
# flair ----> -0.0
# made ----> 2.0
# earlier ----> -0.0
# hellboys ----> -0.0
# so ----> 1.584962500721156
# enjoyable, ----> -0.0
# soulless ----> -0.0
# reboot ----> -0.0
# dante ----> -0.0
# tenth ----> -0.0
# circle ----> -0.0
# visually ----> 1.584962500721156
# arresting ----> -0.0
# challenging, ----> -0.0
# confounding, ----> -0.0
# rewarding ----> -0.0
# which ----> -0.0
# say ----> -0.0
# everything ----> -0.0
# film ----> -0.0
# director ----> 2.321928094887362
# claire ----> -0.0
# depiction ----> -0.0
# real-life ----> 2.584962500721156
# will ----> 2.0
# strike ----> -0.0
# exploitative, ----> -0.0
# hotel ----> -0.0
# mumbai ----> -0.0
# well-made ----> 1.0
# dramatization ----> -0.0
# tragic ----> -0.0
# rare ----> -0.0
# trilogy ----> -0.0
# capper ----> -0.0
# really ----> -0.0
# works, ----> -0.0
# how ----> 0.9182958340544896
# train ----> -0.0
# your ----> -0.0
# dragon: ----> -0.0
# hidden ----> -0.0
# world ----> -0.0
# brings ----> 1.0
# saga ----> -0.0
# affecting ----> 1.0
# follows ----> -0.0
# many ----> 1.584962500721156
# genre ----> 1.584962500721156
# conventions ----> -0.0
# mocks, ----> -0.0
# romantic ----> -0.0
# feel-good ----> -0.0
# satirical ----> -0.0
# bite ----> 1.0
# star ----> 1.584962500721156
# well-suited ----> -0.0
# john ----> 1.0
# wick: ----> -0.0
# chapter ----> -0.0
# 3 ----> -0.0
# parabellum ----> -0.0
# reloads ----> -0.0
# another ----> 1.0
# hard-hitting ----> -0.0
# round ----> -0.0
# brilliantly ----> 1.0
# choreographed, ----> 1.0
# thieves ----> -0.0
# unites ----> -0.0
# incredible ----> 0.9182958340544896
# heist ----> 1.0
# brimming ----> -0.0
# most ----> 2.321928094887362
# which, ----> -0.0
# sadly, ----> -0.0
# evaporates ----> -0.0
# long ----> 1.584962500721156
# end ----> 1.3709505944546687
# credits ----> -0.0
# started ----> -0.0
# galvanizing ----> -0.0
# glimpse ----> 1.0
# behind ----> -0.0
# scenes ----> -0.0
# election, ----> -0.0
# knock ----> -0.0
# house ----> 1.0
# prove ----> -0.0
# engrossing ----> -0.0
# deliberate ----> -0.0
# pace ----> -0.0
# test ----> -0.0
# patience, ----> -0.0
# attuned ----> -0.0
# light ----> -0.0
# life's ----> -0.0
# sober ----> -0.0
# wavelength ----> -0.0
# rewarded ----> -0.0
# thought-provoking ----> 1.0
# disappointingly ----> 1.0
# overall ----> -0.0
# agreeable ----> -0.0
# formula, ----> -0.0
# big ----> -0.0
# heart ----> 1.584962500721156
# talented, ----> -0.0
# standout ----> -0.0
# work ----> 1.5
# tessa ----> -0.0
# thompson, ----> -0.0
# woods ----> -0.0
# tells ----> -0.0
# grimly ----> 1.0
# absorbing ----> -0.0
# tale ----> 1.0
# marks ----> 0.9182958340544896
# commendable ----> -0.0
# debut ----> -0.0
# nia ----> -0.0
# sharp ----> 1.0
# deceptively ----> -0.0
# layered ----> 1.0
# comedy ----> 2.0
# fueled ----> -0.0
# odd ----> -0.0
# couple ----> -0.0
# chemistry ----> 1.584962500721156
# leads, ----> 1.0
# shot ----> -0.0
# largely ----> 1.0
# lords ----> -0.0
# presents ----> -0.0
# compelling ----> 1.0
# music ----> -0.0
# whose ----> 1.584962500721156
# aggressively ----> -0.0
# nihilistic ----> -0.0
# aesthetic ----> -0.0
# spilled ----> -0.0
# fatal ----> -0.0
# acts ----> -0.0
# luce ----> -0.0
# stellar ----> -0.0
# ensemble ----> 1.0
# bear ----> -0.0
# satisfyingly ----> -0.0
# addresses ----> -0.0
# octavia ----> -0.0
# spencer's ----> -0.0
# overpowers ----> -0.0
# ma's ----> -0.0
# flaws, ----> -0.0
# pacing ----> -0.0
# labored ----> -0.0
# realizing ----> -0.0
# unhinged ----> -0.0
# enthralling ----> -0.0
# knowledge ----> -0.0
# interest ----> -0.0
# sailing, ----> -0.0
# maiden ----> -0.0
# pays ----> 1.0
# powerful ----> 1.584962500721156
# tribute ----> -0.0
# mary ----> -0.0
# magdalene ----> -0.0
# obvious ----> -0.0
# reverence ----> -0.0
# subject; ----> -0.0
# lacks ----> 1.3709505944546687
# momentum ----> -0.0
# character ----> -0.0
# her ----> 1.584962500721156
# amiable ----> -0.0
# yet ----> 2.321928094887362
# forgettable, ----> -0.0
# mib ----> -0.0
# international ----> -0.0
# grinds ----> -0.0
# stars' ----> -0.0
# substantial ----> -0.0
# gears ----> -0.0
# running ----> -0.0
# low ----> -0.0
# reasons ----> -0.0
# ambitious, ----> -0.0
# crafted, ----> -0.0
# above ----> 1.0
# unsettling, ----> -0.0
# midsommar ----> -0.0
# ari ----> -0.0
# aster ----> -0.0
# auteur ----> -0.0
# reckoned ----> -0.0
# miss ----> -0.0
# bala ----> -0.0
# gina ----> -0.0
# rodriguez ----> -0.0
# future ----> 2.0
# hero; ----> -0.0
# also ----> 1.584962500721156
# demonstrates ----> -0.0
# balance ----> -0.0
# set ----> 1.584962500721156
# pieces ----> -0.0
# against ----> -0.0
# triumph ----> -0.0
# laika, ----> -0.0
# missing ----> -0.0
# link ----> -0.0
# treat ----> -0.0
# lots ----> -0.0
# plenty ----> -0.0
# heart, ----> 1.584962500721156
# food ----> -0.0
# admirably ----> 1.0
# eclectic ----> -0.0
# consistent ----> -0.0
# anthologies, ----> -0.0
# nightmare ----> -0.0
# entertain ----> -0.0
# mood ----> -0.0
# old-fashioned ----> -0.0
# basis ----> -0.0
# sex ----> -0.0
# nowhere ----> -0.0
# groundbreaking ----> -0.0
# subject, ----> -0.0
# extraordinary ----> -0.0
# solid ----> -0.0
# case ----> -0.0
# itself ----> 1.0
# inspirational, ----> -0.0
# well-acted ----> -0.0
# pavarotti ----> -0.0
# towering ----> -0.0
# cultural ----> -0.0
# figure ----> -0.0
# documentary ----> -0.0
# evident ----> -0.0
# affection ----> 1.0
# pet ----> -0.0
# sematary ----> -0.0
# material ----> 0.9182958340544896
# different ----> 1.0
# directions, ----> -0.0
# feels ----> -0.0
# exhuming ----> -0.0
# stylish ----> -0.0
# sadistic ----> -0.0
# streak, ----> -0.0
# piercing ----> -0.0
# pairs ----> -0.0
# gripping ----> 0.9182958340544896
# smartly ----> -0.0
# macabre ----> -0.0
# unpredictable ----> 1.0
# pledge ----> -0.0
# leaves ----> -0.0
# certain ----> -0.0
# amount ----> -0.0
# untapped ----> -0.0
# extreme ----> -0.0
# take ----> 1.9219280948873623
# collegiate ----> -0.0
# hazing, ----> -0.0
# result ----> 0.9182958340544896
# well-executed ----> -0.0
# plus ----> -0.0
# reinvigorates ----> -0.0
# outing ----> 0.9182958340544896
# leads ----> -0.0
# embraces ----> -0.0
# pokémon ----> -0.0
# detective ----> -0.0
# pikachu ----> -0.0
# wonderfully ----> -0.0
# bizarre ----> -0.0
# premise ----> -0.0
# far ----> 0.9182958340544896
# could ----> 1.0
# have, ----> -0.0
# offbeat ----> -0.0
# adaptation ----> -0.0
# catch ----> -0.0
# something ----> -0.0
# cheer ----> -0.0
# about, ----> -0.0
# poms ----> -0.0
# squanders ----> -0.0
# disrespects ----> -0.0
# demographic ----> -0.0
# trying ----> -0.0
# fascinating ----> -0.0
# dramatized ----> -0.0
# perplexingly ----> -0.0
# dull ----> -0.0
# fashion, ----> -0.0
# red ----> -0.0
# joan ----> -0.0
# wastes ----> -0.0
# tale's ----> -0.0
# intrigue ----> -0.0
# formidable ----> -0.0
# talents ----> -0.0
# judi ----> -0.0
# plot ----> 1.0
# holes ----> -0.0
# unintentional ----> -0.0
# laughs, ----> -0.0
# replicas ----> -0.0
# ponderously ----> -0.0
# lame ----> -0.0
# going ----> -0.0
# long, ----> -0.0
# biopic ----> -0.0
# manages ----> 1.0
# capture ----> -0.0
# highs ----> -0.0
# lows ----> -0.0
# artist's ----> -0.0
# rust ----> -0.0
# creek ----> 1.0
# subverts ----> -0.0
# expectations ----> -0.0
# surprisingly ----> -0.0
# anchored ----> -0.0
# rich ----> 1.0
# setting ----> -0.0
# hermione ----> -0.0
# high-concept ----> -0.0
# mystery ----> -0.0
# twist, ----> -0.0
# serenity ----> -0.0
# what ----> 0.8112781244591328
# appears ----> -0.0
# first ----> -0.0
# anywhere ----> -0.0
# clever ----> -0.0
# filmed ----> -0.0
# inventively ----> -0.0
# shadow ----> -0.0
# sumptuous ----> -0.0
# wuxia ----> -0.0
# zhang ----> -0.0
# yimou ----> -0.0
# peak ----> -0.0
# decades ----> 1.0
# removed ----> -0.0
# original, ----> -0.0
# multi-generational ----> -0.0
# shaft ----> -0.0
# characters ----> 1.5
# interesting ----> -0.0
# anything ----> -0.0
# other ----> 1.0
# uncomfortably ----> -0.0
# effortlessly ----> -0.0
# shazam! ----> -0.0
# forgets ----> -0.0
# genre's ----> -0.0
# real ----> -0.0
# power: ----> -0.0
# joyous ----> -0.0
# wish ----> -0.0
# skin ----> -0.0
# stand ----> -0.0
# go ----> -0.0
# bit ----> -0.0
# deeper ----> -0.0
# below ----> -0.0
# surface, ----> -0.0
# worthy ----> 1.0
# jamie ----> -0.0
# breezily ----> -0.0
# teen ----> 1.0
# romance ----> -0.0
# spider-man: ----> -0.0
# stylishly ----> -0.0
# sets ----> -0.0
# stage ----> -0.0
# next ----> -0.0
# though ----> 1.0
# collaborations ----> -0.0
# kumail ----> -0.0
# nanjiani ----> -0.0
# dave ----> -0.0
# bautista, ----> -0.0
# stuber ----> -0.0
# mesh ----> -0.0
# contrasting ----> -0.0
# genres, ----> -0.0
# settling ----> -0.0
# overtly ----> -0.0
# violent, ----> -0.0
# mildly ----> -0.0
# five-star ----> -0.0
# expertly ----> -0.0
# drawn ----> 1.0
# senes ----> -0.0
# humanity ----> -0.0
# sword ----> -0.0
# trust ----> -0.0
# enjoyable ----> 1.0
# times ----> -0.0
# meandering ----> -0.0
# spirit ----> -0.0
# we ----> 1.0
# know ----> -0.0
# max ----> -0.0
# minghella's ----> -0.0
# connection ----> -0.0
# elle ----> -0.0
# fanning's ----> -0.0
# remarkable ----> -0.0
# add ----> -0.0
# tasteful ----> -0.0
# fault, ----> -0.0
# aftermath ----> -0.0
# seeking ----> -0.0
# only ----> 2.0
# passionate ----> -0.0
# art ----> -0.0
# self-defense ----> -0.0
# grapples ----> -0.0
# compellingly ----> -0.0
# masculinity ----> -0.0
# serves ----> -0.0
# calling ----> -0.0
# card ----> -0.0
# riley ----> -0.0
# lifetime ----> -0.0
# matthew ----> -0.0
# mcconaughey, ----> -0.0
# beach ----> -0.0
# bum ----> -0.0
# harmony ----> -0.0
# korine's ----> -0.0
# distinctive ----> -0.0
# style, ----> -0.0
# offset ----> -0.0
# unfocused ----> 1.0
# enemies ----> -0.0
# intentions, ----> -0.0
# they're ----> 1.0
# derailed ----> -0.0
# problematic ----> -0.0
# perspective ----> -0.0
# boy ----> -0.0
# who ----> 1.5
# harnessed ----> -0.0
# wind ----> 1.0
# earns ----> -0.0
# impressive ----> 1.0
# debuting ----> -0.0
# chiwetel ----> -0.0
# changeover ----> -0.0
# deep ----> -0.0
# seasoned ----> -0.0
# spooky ----> -0.0
# younger ----> -0.0
# target ----> -0.0
# content ----> -0.0
# coast ----> -0.0
# rather ----> -0.0
# tap ----> -0.0
# story's ----> -0.0
# creepy ----> -0.0
# potential, ----> -0.0
# curse ----> -0.0
# la ----> -0.0
# llorona ----> -0.0
# arrives ----> -0.0
# theaters ----> -0.0
# already ----> -0.0
# dead ----> -0.0
# don't ----> -0.0
# die ----> -0.0
# dabbles ----> -0.0
# tones ----> -0.0
# varying ----> -0.0
# degrees ----> -0.0
# success, ----> -0.0
# wit ----> -0.0
# zom-com ----> -0.0
# brains ----> -0.0
# travolta ----> -0.0
# gives ----> -0.0
# oddly ----> -0.0
# coiffed ----> -0.0
# all, ----> -0.0
# fanatic ----> -0.0
# rings ----> -0.0
# hollow ----> -0.0
# examination ----> -0.0
# fan ----> -0.0
# appreciation ----> -0.0
# can ----> 2.321928094887362
# curdle ----> -0.0
# toxic ----> -0.0
# chillingly ----> -0.0
# rooted ----> -0.0
# folklore, ----> -0.0
# golem ----> -0.0
# blends ----> -0.0
# centuries-old ----> -0.0
# stories ----> -0.0
# great ----> -0.0
# hack ----> -0.0
# alarming ----> -0.0
# data ----> -0.0
# being ----> -0.0
# weaponized ----> -0.0
# gain ----> -0.0
# mean ----> -0.0
# haunting ----> -0.0
# sharon ----> -0.0
# tate ----> -0.0
# dishonors ----> -0.0
# events ----> 1.0
# seeks ----> -0.0
# dramatize ----> -0.0
# poorly ----> -0.0
# acted ----> -0.0
# offensively ----> -0.0
# exploitative ----> -0.0
# highwaymen ----> -0.0
# depicts ----> -0.0
# law ----> -0.0
# enforcement's ----> -0.0
# side ----> -0.0
# bonnie ----> -0.0
# clyde ----> -0.0
# manhunt ----> -0.0
# unfortunately ----> -0.0
# marquee ----> -0.0
# hole ----> -0.0
# ground ----> -0.0
# exploits ----> -0.0
# parental ----> -0.0
# fears ----> -0.0
# effectiveness ----> -0.0
# underlying ----> -0.0
# familiar, ----> -0.0
# devil ----> -0.0
# effectively ----> -0.0
# sheds ----> -0.0
# loud ----> -0.0
# gory ----> -0.0
# cliches ----> -0.0
# contemporary ----> -0.0
# tense, ----> -0.0
# slowly ----> -0.0
# building ----> -0.0
# throwback ----> -0.0
# fright ----> -0.0
# flicks ----> -0.0
# well-acted, ----> -0.0
# hummingbird ----> -0.0
# project ----> -0.0
# flawed ----> -0.0
# undeniably ----> -0.0
# intriguing ----> 1.0
# addition ----> -0.0
# kim ----> -0.0
# nguyen's ----> -0.0
# hustle's ----> -0.0
# team ----> -0.0
# setting, ----> 1.0
# gender-flipped ----> -0.0
# beyond ----> -0.0
# feminine ----> -0.0
# intruder ----> -0.0
# appeal ----> -0.0
# shout-at-the-screen ----> -0.0
# cinema, ----> -0.0
# thriller's ----> -0.0
# ludicrous ----> -0.0
# robs ----> -0.0
# undermines ----> -0.0
# dennis ----> -0.0
# quaid's ----> -0.0
# suitably ----> -0.0
# well-framed, ----> -0.0
# well-cast, ----> -0.0
# well-intentioned, ----> -0.0
# kid ----> 1.0
# multitude ----> -0.0
# westerns ----> -0.0
# covering ----> -0.0
# similar ----> -0.0
# would ----> -0.0
# recalls ----> -0.0
# all-ages ----> 1.0
# adventures ----> -0.0
# repurposes ----> -0.0
# timeless ----> -0.0
# legend ----> -0.0
# sometimes ----> 1.0
# parts, ----> -0.0
# powerfully ----> -0.0
# told, ----> -0.0
# last ----> -0.0
# black ----> -0.0
# man ----> 0.9182958340544896
# san ----> -0.0
# francisco ----> -0.0
# immediately ----> 1.0
# establishes ----> -0.0
# joe ----> -0.0
# talbot ----> -0.0
# filmmaker ----> 1.0
# laundromat ----> -0.0
# misuses ----> -0.0
# blunt ----> -0.0
# approach ----> -0.0
# inspired ----> -0.0
# lego ----> -0.0
# 2: ----> -0.0
# part ----> 1.0
# fits ----> -0.0
# neatly ----> -0.0
# pride ----> -0.0
# achievements,the ----> -0.0
# lion ----> -0.0
# by-the-numbers ----> -0.0
# retelling ----> -0.0
# beloved--though ----> -0.0
# killed ----> 1.0
# don ----> -0.0
# quixote ----> -0.0
# live ----> -0.0
# expectations, ----> -0.0
# bears ----> -0.0
# terry ----> -0.0
# gilliam's ----> -0.0
# creative ----> -0.0
# stamp ----> -0.0
# satisfy ----> 1.0
# hitler ----> -0.0
# then ----> -0.0
# bigfoot ----> -0.0
# about ----> 1.0
# lives ----> -0.0
# wild ----> 1.0
# due ----> -0.0
# small ----> -0.0
# sam ----> -0.0
# elliott's ----> -0.0
# world-weary ----> -0.0
# mustang ----> -0.0
# perspectives ----> -0.0
# redemption ----> -0.0
# brought ----> -0.0
# bruce ----> -0.0
# dern ----> -0.0
# matthias ----> -0.0
# prodigy ----> -0.0
# seed ----> -0.0
# any ----> 1.0
# places, ----> -0.0
# child ----> -0.0
# fear, ----> -0.0
# muddled ----> -0.0
# populated ----> -0.0
# thinly ----> -0.0
# written ----> -0.0
# arranged ----> -0.0
# around ----> -0.0
# misguided ----> -0.0
# johnny ----> -0.0
# depp ----> -0.0
# performance, ----> -0.0
# professor ----> -0.0
# early ----> -0.0
# intentions ----> -0.0
# easier ----> -0.0
# appreciate ----> -0.0
# execution, ----> -0.0
# public ----> -0.0
# earnest ----> -0.0
# engaging ----> -0.0
# advocacy ----> -0.0
# secret ----> -0.0
# pets ----> -0.0
# 2 ----> -0.0
# teach ----> -0.0
# tricks ----> -0.0
# energetic ----> -0.0
# command ----> -0.0
# craft ----> -0.0
# perfectly ----> -0.0
# matched ----> -0.0
# material, ----> -0.0
# souvenir ----> -0.0
# uniquely ----> -0.0
# impactful ----> -0.0
# taut ----> -0.0
# unpredictable, ----> -0.0
# standoff ----> -0.0
# sparrow ----> -0.0
# well-told ----> -0.0
# topped ----> -0.0
# generous ----> -0.0
# helping ----> -0.0
# sun ----> -0.0
# easy-to-love ----> -0.0
# tests ----> -0.0
# audience's ----> -0.0
# storyline ----> -0.0
# strains ----> -0.0
# credulity ----> -0.0
# preachy, ----> -0.0
# manipulative, ----> -0.0
# frustratingly ----> -0.0
# clichéd, ----> -0.0
# upside ----> -0.0
# showcases ----> -0.0
# bryan ----> -0.0
# cranston ----> -0.0
# kevin ----> -0.0
# hart's ----> -0.0
# without ----> -0.0
# ever ----> -0.0
# full ----> -0.0
# advantage ----> -0.0
# suspenseful ----> -0.0
# atmosphere, ----> -0.0
# evocative ----> -0.0
# invested ----> -0.0
# throughout ----> -0.0
# vanishing's ----> -0.0
# patient ----> -0.0
# unraveling ----> -0.0
# crow ----> -0.0
# nimble ----> -0.0
# grace ----> -0.0
# primer ----> -0.0
# brilliant ----> -0.0
# artist, ----> -0.0
# sticks ----> -0.0
# imperfect ----> -0.0
# intriguing, ----> -0.0
# distinguished ----> -0.0
# tolkien ----> -0.0
# trappings ----> -0.0
# biopic, ----> -0.0
# imagination ----> -0.0
# required ----> -0.0
# do ----> -0.0
# heartwarming, ----> -0.0
# animated, ----> -0.0
# toy ----> -0.0
# 4 ----> -0.0
# unlikely ----> -0.0
# feat ----> -0.0
# extending ----> -0.0
# perhaps ----> -0.0
# concluding ----> -0.0
# practically ----> -0.0
# perfect ----> -0.0
# transit ----> -0.0
# challenging ----> -0.0
# captures ----> -0.0
# audience ----> -0.0
# state ----> -0.0
# flux ----> -0.0
# exerts ----> -0.0
# unsettling ----> -0.0
# help ----> -0.0
# triple ----> 1.0
# frontier ----> -0.0
# elevate ----> -0.0
# field ----> -0.0
# gritty ----> -0.0
# threat ----> -0.0
# better ----> -0.0
# attention-getting ----> -0.0
# cast, ----> -0.0
# results ----> -0.0
# rate ----> -0.0
# lackluster ----> -0.0
# tyler ----> -0.0
# perry's ----> -0.0
# franchise, ----> -0.0
# madea ----> -0.0
# funeral ----> -0.0
# saying ----> -0.0
# goodbye ----> -0.0
# painful ----> -0.0
# wrong ----> -0.0
# very ----> -0.0
# young ----> -0.0
# entertained ----> -0.0
# uglydolls ----> -0.0
# because ----> -0.0
# likely ----> -0.0
# recognize ----> -0.0
# affirmative ----> -0.0
# formulaic ----> -0.0
# under ----> -0.0
# silver ----> -0.0
# lake ----> -0.0
# stride ----> -0.0
# slightly ----> -0.0
# stumbles, ----> -0.0
# admire ----> -0.0
# david ----> -0.0
# robert ----> -0.0
# mitchell's ----> -0.0
# it'll ----> -0.0
# enjoyed ----> -0.0
# tolerance ----> -0.0
# whimsy, ----> -0.0
# unicorn ----> -0.0
# store ----> -0.0
# easy ----> -0.0
# brie ----> -0.0
# larson ----> -0.0
# dramatic ----> -0.0
# hot-button ----> -0.0
# topic ----> -0.0
# agenda ----> -0.0
# clear, ----> -0.0
# unplanned ----> -0.0
# reinforce ----> -0.0
# feelings ----> -0.0
# either ----> -0.0
# jordan ----> -0.0
# peele's ----> -0.0
# inventive, ----> -0.0
# film, ----> -0.0
# beat ----> -0.0
# sophomore ----> -0.0
# jinx, ----> -0.0
# you ----> -0.0
# watch ----> -0.0
# art-world ----> -0.0
# satire ----> -0.0
# overtones ----> -0.0
# year ----> -0.0
# others ----> -0.0
# probably ----> -0.0
# velvet ----> -0.0
# admittedly ----> -0.0
# like, ----> -0.0
# men ----> -0.0
# want ----> -0.0
# gender-swapped ----> -0.0
# odds ----> -0.0
# substantially ----> -0.0
# improved ----> -0.0
# taraji ----> -0.0
# p. ----> -0.0
# henson ----> -0.0
# shortage ----> -0.0
# star-is-born ----> -0.0
# stories, ----> -0.0
# rose ----> -0.0
# they ----> -0.0
# transcendent ----> -0.0
# moment ----> -0.0
# jessie ----> -0.0
# wine ----> -0.0
# country's ----> -0.0
# robust ----> -0.0
# got ----> -0.0
# sweetness ----> -0.0
# nose ----> -0.0
# nicely ----> -0.0
# yesterday ----> -0.0
# fall ----> -0.0
# short ----> -0.0
# fab, ----> -0.0
# sweetly ----> -0.0
# charming ----> -0.0
# fantasy ----> -0.0
# albeit ----> -0.0
# under-explored ----> -0.0

# %%
# find the 10 maximum and minimum entropies
#(i.e. word after which word is the worst to predict and which ones are the easiest to predict)


df = pd.DataFrame(list(entropy.items()), columns=['word', 'entropy'])

df_max = df.sort_values(by='entropy', ascending=False).head(10)

df_max
# Out:
#    word   entropy
# 22  the  6.970628
# 0     a  6.838870
# 42  its  5.946686
# 49  and  5.857225
# 17   to  5.556958
# 85   of  5.227227
# 54   an  4.888790
# 80   it  4.871178
# 9   but  4.663320
# 41  for  4.454636

# %%
df_min = df.sort_values(by='entropy', ascending=True).head(10)

df_min
# Out:
#               word  entropy
# 1518          nose     -0.0
# 1247        legend     -0.0
# 34         friend,     -0.0
# 1249        parts,     -0.0
# 36          canine     -0.0
# 37       adventure     -0.0
# 1250    powerfully     -0.0
# 1251         told,     -0.0
# 40    heartwarming     -0.0
# 1252          last     -0.0

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------- ------------------------ 5.0/12.8 MB 23.2 MB/s eta 0:00:01
#      --------------------------------------  12.6/12.8 MB 34.2 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 28.6 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Find the entropies for stop words

import spacy

nlp = spacy.load('en_core_web_sm')

series=[]
for word in df['word']:
    series.append(nlp(word)[0].is_stop)

df = df[series]

df
# Out:
#                 word   entropy
# 0                  a  6.838870
# 3                 is  4.266764
# 4                 as  4.335971
# 6                one  2.321928
# 7              might  2.807355
# ...              ...       ...
# 1477          either -0.000000
# 1485             you -0.000000
# 1491          others -0.000000
# 1509            they -0.000000
# 1528  under-explored -0.000000
#
# [177 rows x 2 columns]

# %%
for i in df['word']:
    print(i)
# Out:
# a
# is
# as
# one
# might
# but
# even
# may
# their
# to
# the
# not
# quite
# be
# this
# no
# less
# for
# its
# by
# and
# an
# that
# after's
# are
# down
# with
# if
# it
# never
# of
# keep
# up
# still
# themselves
# more
# than
# all
# at
# always
# my
# in
# own
# between
# his
# have
# done
# before
# isn't
# some
# there's
# back
# doesn't
# much
# get
# when
# doing
# while
# does
# whatever
# on
# although
# it's
# enough
# from
# along
# make
# that's
# just
# name
# across
# has
# seem
# well
# it,
# nothing
# what's
# often
# through
# out
# well-matched
# over-the-top
# over
# should
# five
# further
# few
# or
# almost
# she's
# a-list
# into
# made
# so
# which
# say
# everything
# will
# well-made
# really
# how
# your
# many
# well-suited
# another
# most
# which,
# behind
# whose
# her
# yet
# above
# also
# against
# nowhere
# itself
# well-acted
# amount
# take
# well-executed
# could
# have,
# something
# about,
# what
# first
# anywhere
# anything
# other
# go
# below
# next
# though
# five-star
# we
# only
# they're
# who
# rather
# already
# don't
# all,
# can
# being
# side
# well-acted,
# beyond
# well-framed,
# well-cast,
# well-intentioned,
# would
# all-ages
# sometimes
# last
# part
# by-the-numbers
# then
# about
# due
# any
# around
# well-told
# without
# ever
# full
# throughout
# do
# perhaps
# very
# because
# under
# it'll
# either
# you
# others
# they
# under-explored

# %%
# Find entropies of stopwords

stop_words = set(['a', 'an', 'the', 'and', 'or', 'but',
                  'if', 'or','to','in','on','at','by',
                  'this','for','from','as','for','with',])

stop_word_entropy = {word:entropy.get(word, 0) for word in stop_words}

for word, H in stop_word_entropy.items():
    print(f"Entropy of '{word}' : {H}")
# Out:
# Entropy of 'but' : 4.663320189106002
# Entropy of 'if' : 2.1556390622295662
# Entropy of 'an' : 4.8887896794220005
# Entropy of 'and' : 5.857225337483041
# Entropy of 'a' : 6.838869969720591
# Entropy of 'the' : 6.970627692490496
# Entropy of 'or' : 2.807354922057604
# Entropy of 'to' : 5.5569576083772985
# Entropy of 'in' : 3.7191821684284743
# Entropy of 'on' : 3.1462863706621045
# Entropy of 'at' : 2.6416041678685933
# Entropy of 'for' : 4.454636150748477
# Entropy of 'from' : 3.057476076289932
# Entropy of 'as' : 4.335970858598519
# Entropy of 'with' : 3.891853096329677
# Entropy of 'by' : 4.152492594515677
# Entropy of 'this' : 4.165894208390023
